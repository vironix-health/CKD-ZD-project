# %%
import sys
import os

# Use os.getcwd() to get the current working directory in a Jupyter notebook
parent_dir = os.path.dirname(os.getcwd())  # Get the parent directory of the current working directory
sys.path.append(parent_dir)

# %%
import pandas as pd
from skopt.space import Real, Integer
from driver import Driver

# %% [markdown]
# # Load Cleaned Master MIMIC-IV Dataset

# %%
# Cleaned Master MIMIC Data Set
df_master = pd.read_pickle('../MIMIC_IV/df_ckd_master_clean.pkl')
df_base = pd.read_pickle('../MIMIC_IV/df_ckd_base.pkl')

# %% [markdown]
# # Evaluate Random Forest Pipeline

# %%
RandomForest_cfg = {
    'name': 'RandomForest',
    'tag': 'rdmf', # Identifier tag for feature selection model
    'response': 'stage_delta',  # Response variable for binary classification and Cox Proportional Hazards
    'duration': 'duration', # Duration in days until response or censorship
    'n_novel': 40, # Number of ranked novel features included in augmented KFRE dataset
    'test_size': 0.1, # Ratio of data reserved for testing
    'val_size': 0.2, # Ratio of data reserved for testing in validation sets
    'n_valsets': 5, # Number of training validation sets
    'n_bayesian': 10, # Number of Bayesian hyperparameter optimization iterations 
    'n_folds': 5, # Number of folds for CoxPH cross validation
    'penalizer': 0.0007, # CoxPH model penalizer
    'auc_space': [
        Integer(50, 200, name="n_estimators"),
        Integer(2, 50, name="max_depth"),
        Integer(2, 20, name="min_samples_split"),
        Integer(1, 20, name="min_samples_leaf")
    ], # Search space for Bayesian hyperparameter optimization
    'random_state': 42 # Seed for reproducibility
}

driver = Driver(RandomForest_cfg, df_master, df_base)
driver.ClassicalLearningPipe()
# Out:
# Testing params: {'n_estimators': 169, 'max_depth': 11, 'min_samples_split': 16, 'min_samples_leaf': 12}
# AUC for params: 0.8698220927653662
# Testing params: {'n_estimators': 117, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 7}
# AUC for params: 0.8596493310071832
# Testing params: {'n_estimators': 71, 'max_depth': 33, 'min_samples_split': 3, 'min_samples_leaf': 15}
# AUC for params: 0.8662510947701729
# Testing params: {'n_estimators': 191, 'max_depth': 2, 'min_samples_split': 20, 'min_samples_leaf': 13}
# AUC for params: 0.8202081686549011
# Testing params: {'n_estimators': 142, 'max_depth': 2, 'min_samples_split': 2, 'min_samples_leaf': 11}
# AUC for params: 0.8156140150264901
# Testing params: {'n_estimators': 110, 'max_depth': 4, 'min_samples_split': 20, 'min_samples_leaf': 5}
# AUC for params: 0.8377174765515365
# Testing params: {'n_estimators': 64, 'max_depth': 32, 'min_samples_split': 9, 'min_samples_leaf': 20}
# AUC for params: 0.8642561669656402
# Testing params: {'n_estimators': 120, 'max_depth': 43, 'min_samples_split': 14, 'min_samples_leaf': 10}
# AUC for params: 0.8688776674952268
# Testing params: {'n_estimators': 52, 'max_depth': 47, 'min_samples_split': 12, 'min_samples_leaf': 8}
# AUC for params: 0.8659377705484157
# Testing params: {'n_estimators': 52, 'max_depth': 13, 'min_samples_split': 6, 'min_samples_leaf': 14}
# AUC for params: 0.8653381086015527
# Best parameters found:  {'n_estimators': 169, 'max_depth': 11, 'min_samples_split': 16, 'min_samples_leaf': 12}
# Best average AUC across validation sets:  0.8698220927653662
# Test AUC: 0.5663345410628019
# Iteration 1: norm_delta = 6.75e+00, step_size = 0.9500, log_lik = -8744.90665, newton_decrement = 9.87e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.37e+00, step_size = 0.2375, log_lik = -8333.91450, newton_decrement = 5.30e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.02e+00, step_size = 0.0772, log_lik = -8255.25795, newton_decrement = 4.54e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.88e+00, step_size = 0.0326, log_lik = -8226.15579, newton_decrement = 4.26e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.65e+00, step_size = 0.0551, log_lik = -8180.53022, newton_decrement = 3.82e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.28e+00, step_size = 0.0931, log_lik = -8112.69666, newton_decrement = 3.17e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 3.68e+00, step_size = 0.1574, log_lik = -8020.76781, newton_decrement = 2.28e+02, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.80e+00, step_size = 0.2660, log_lik = -7915.33986, newton_decrement = 1.26e+02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.61e+00, step_size = 0.4496, log_lik = -7827.46899, newton_decrement = 3.94e+01, seconds_since_start = 0.8
# Iteration 10: norm_delta = 4.19e-01, step_size = 0.7598, log_lik = -7790.25666, newton_decrement = 2.47e+00, seconds_since_start = 0.9
# Iteration 11: norm_delta = 2.89e-03, step_size = 1.0000, log_lik = -7787.77508, newton_decrement = 4.00e-04, seconds_since_start = 1.0
# Iteration 12: norm_delta = 4.06e-06, step_size = 1.0000, log_lik = -7787.77468, newton_decrement = 7.19e-10, seconds_since_start = 1.1
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.87e+00, step_size = 0.9500, log_lik = -8829.99117, newton_decrement = 9.82e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.49e+00, step_size = 0.2375, log_lik = -8420.48592, newton_decrement = 5.36e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.13e+00, step_size = 0.0772, log_lik = -8340.98865, newton_decrement = 4.57e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.99e+00, step_size = 0.0326, log_lik = -8311.64625, newton_decrement = 4.29e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.76e+00, step_size = 0.0551, log_lik = -8265.69933, newton_decrement = 3.84e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.37e+00, step_size = 0.0931, log_lik = -8197.54122, newton_decrement = 3.17e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 3.77e+00, step_size = 0.1574, log_lik = -8105.56206, newton_decrement = 2.27e+02, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.86e+00, step_size = 0.2660, log_lik = -8000.87556, newton_decrement = 1.24e+02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.65e+00, step_size = 0.4496, log_lik = -7914.63922, newton_decrement = 3.81e+01, seconds_since_start = 0.9
# Iteration 10: norm_delta = 4.29e-01, step_size = 0.7598, log_lik = -7878.61227, newton_decrement = 2.36e+00, seconds_since_start = 1.0
# Iteration 11: norm_delta = 3.21e-03, step_size = 1.0000, log_lik = -7876.23907, newton_decrement = 4.09e-04, seconds_since_start = 1.1
# Iteration 12: norm_delta = 4.88e-06, step_size = 1.0000, log_lik = -7876.23866, newton_decrement = 8.38e-10, seconds_since_start = 1.2
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.78e+00, step_size = 0.9500, log_lik = -8805.41001, newton_decrement = 9.64e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.40e+00, step_size = 0.2375, log_lik = -8403.23668, newton_decrement = 5.30e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.05e+00, step_size = 0.0772, log_lik = -8324.58045, newton_decrement = 4.53e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.91e+00, step_size = 0.0326, log_lik = -8295.54560, newton_decrement = 4.24e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.68e+00, step_size = 0.0551, log_lik = -8250.07919, newton_decrement = 3.80e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.30e+00, step_size = 0.0931, log_lik = -8182.63106, newton_decrement = 3.14e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 3.71e+00, step_size = 0.1574, log_lik = -8091.60018, newton_decrement = 2.25e+02, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.82e+00, step_size = 0.2660, log_lik = -7987.94846, newton_decrement = 1.23e+02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.63e+00, step_size = 0.4496, log_lik = -7902.42077, newton_decrement = 3.80e+01, seconds_since_start = 0.9
# Iteration 10: norm_delta = 4.22e-01, step_size = 0.7598, log_lik = -7866.52334, newton_decrement = 2.37e+00, seconds_since_start = 1.0
# Iteration 11: norm_delta = 2.66e-03, step_size = 1.0000, log_lik = -7864.14377, newton_decrement = 3.43e-04, seconds_since_start = 1.1
# Iteration 12: norm_delta = 2.74e-06, step_size = 1.0000, log_lik = -7864.14342, newton_decrement = 4.13e-10, seconds_since_start = 1.2
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.96e+00, step_size = 0.9500, log_lik = -9037.41005, newton_decrement = 9.67e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.54e+00, step_size = 0.2375, log_lik = -8634.21212, newton_decrement = 5.35e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.18e+00, step_size = 0.0772, log_lik = -8554.85168, newton_decrement = 4.58e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 5.04e+00, step_size = 0.0326, log_lik = -8525.47956, newton_decrement = 4.30e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.98e+00, step_size = 0.0138, log_lik = -8513.72350, newton_decrement = 4.18e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.88e+00, step_size = 0.0233, log_lik = -8494.46954, newton_decrement = 4.00e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 4.72e+00, step_size = 0.0394, log_lik = -8463.61866, newton_decrement = 3.70e+02, seconds_since_start = 0.7
# Iteration 8: norm_delta = 4.45e+00, step_size = 0.0665, log_lik = -8416.00514, newton_decrement = 3.25e+02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 4.01e+00, step_size = 0.1124, log_lik = -8347.13708, newton_decrement = 2.58e+02, seconds_since_start = 0.9
# Iteration 10: norm_delta = 3.33e+00, step_size = 0.1899, log_lik = -8258.29913, newton_decrement = 1.72e+02, seconds_since_start = 1.0
# Iteration 11: norm_delta = 2.35e+00, step_size = 0.3210, log_lik = -8165.35600, newton_decrement = 8.14e+01, seconds_since_start = 1.1
# Iteration 12: norm_delta = 1.13e+00, step_size = 0.5425, log_lik = -8100.82118, newton_decrement = 1.78e+01, seconds_since_start = 1.2
# Iteration 13: norm_delta = 1.11e-01, step_size = 0.9168, log_lik = -8083.01927, newton_decrement = 1.81e-01, seconds_since_start = 1.3
# Iteration 14: norm_delta = 2.94e-03, step_size = 1.0000, log_lik = -8082.83591, newton_decrement = 1.08e-03, seconds_since_start = 1.3
# Iteration 15: norm_delta = 4.30e-04, step_size = 1.0000, log_lik = -8082.83475, newton_decrement = 1.71e-05, seconds_since_start = 1.4
# Iteration 16: norm_delta = 7.37e-06, step_size = 1.0000, log_lik = -8082.83473, newton_decrement = 4.84e-09, seconds_since_start = 1.5
# Convergence success after 16 iterations.
# Iteration 1: norm_delta = 6.76e+00, step_size = 0.9500, log_lik = -8886.68689, newton_decrement = 9.94e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.42e+00, step_size = 0.2375, log_lik = -8472.23473, newton_decrement = 5.39e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.07e+00, step_size = 0.0772, log_lik = -8392.19253, newton_decrement = 4.61e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.93e+00, step_size = 0.0326, log_lik = -8362.60240, newton_decrement = 4.33e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.70e+00, step_size = 0.0551, log_lik = -8316.23171, newton_decrement = 3.88e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.33e+00, step_size = 0.0931, log_lik = -8247.34601, newton_decrement = 3.21e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 3.73e+00, step_size = 0.1574, log_lik = -8154.13268, newton_decrement = 2.31e+02, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.84e+00, step_size = 0.2660, log_lik = -8047.51142, newton_decrement = 1.27e+02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.64e+00, step_size = 0.4496, log_lik = -7958.95080, newton_decrement = 3.96e+01, seconds_since_start = 0.9
# Iteration 10: norm_delta = 4.28e-01, step_size = 0.7598, log_lik = -7921.50805, newton_decrement = 2.51e+00, seconds_since_start = 1.0
# Iteration 11: norm_delta = 3.08e-03, step_size = 1.0000, log_lik = -7918.98968, newton_decrement = 4.84e-04, seconds_since_start = 1.1
# Iteration 12: norm_delta = 1.34e-06, step_size = 1.0000, log_lik = -7918.98920, newton_decrement = 2.48e-10, seconds_since_start = 1.1
# Convergence success after 12 iterations.
# Average C-Index from cross-validation: 0.8854
# Best C-Index from cross-validation: 0.8926
# Standard Deviation of C-Index from cross-validation: 0.0085
#                                                             coef  exp(coef)  \
# covariate
# subject_id                                         -1.579508e-08   1.000000
# gender                                              2.089293e-01   1.232358
# anchor_age                                          3.486226e-01   1.417114
# disch_age                                          -3.539867e-01   0.701884
# CKD_stage_first                                    -1.046139e+00   0.351291
# ...                                                          ...        ...
# Total_Protein,_Urine_first                          7.941496e-04   1.000794
# Asparate_Aminotransferase_(AST)_min                -4.514996e-04   0.999549
# Diabetes with renal manifestations, type II or ... -4.032632e-02   0.960476
# Urea_Nitrogen,_Urine_first                         -4.941566e-04   0.999506
# Albumin,_Urine_max                                 -9.889853e-04   0.999012
#
#                                                         se(coef)  \
# covariate
# subject_id                                          1.034720e-08
# gender                                              6.851388e-02
# anchor_age                                          1.481221e-02
# disch_age                                           1.474120e-02
# CKD_stage_first                                     4.708962e-02
# ...                                                          ...
# Total_Protein,_Urine_first                          6.266784e-04
# Asparate_Aminotransferase_(AST)_min                 7.148112e-04
# Diabetes with renal manifestations, type II or ...  7.362690e-02
# Urea_Nitrogen,_Urine_first                          2.855661e-04
# Albumin,_Urine_max                                  1.028244e-03
#
#                                                     coef lower 95%  \
# covariate
# subject_id                                           -3.607522e-08
# gender                                                7.464457e-02
# anchor_age                                            3.195912e-01
# disch_age                                            -3.828789e-01
# CKD_stage_first                                      -1.138433e+00
# ...                                                            ...
# Total_Protein,_Urine_first                           -4.341175e-04
# Asparate_Aminotransferase_(AST)_min                  -1.852504e-03
# Diabetes with renal manifestations, type II or ...   -1.846324e-01
# Urea_Nitrogen,_Urine_first                           -1.053856e-03
# Albumin,_Urine_max                                   -3.004307e-03
#
#                                                     coef upper 95%  \
# covariate
# subject_id                                            4.485059e-09
# gender                                                3.432141e-01
# anchor_age                                            3.776540e-01
# disch_age                                            -3.250944e-01
# CKD_stage_first                                      -9.538451e-01
# ...                                                            ...
# Total_Protein,_Urine_first                            2.022417e-03
# Asparate_Aminotransferase_(AST)_min                   9.495045e-04
# Diabetes with renal manifestations, type II or ...    1.039798e-01
# Urea_Nitrogen,_Urine_first                            6.554272e-05
# Albumin,_Urine_max                                    1.026336e-03
#
#                                                     exp(coef) lower 95%  \
# covariate
# subject_id                                                     1.000000
# gender                                                         1.077501
# anchor_age                                                     1.376565
# disch_age                                                      0.681895
# CKD_stage_first                                                0.320321
# ...                                                                 ...
# Total_Protein,_Urine_first                                     0.999566
# Asparate_Aminotransferase_(AST)_min                            0.998149
# Diabetes with renal manifestations, type II or ...             0.831410
# Urea_Nitrogen,_Urine_first                                     0.998947
# Albumin,_Urine_max                                             0.997000
#
#                                                     exp(coef) upper 95%  \
# covariate
# subject_id                                                     1.000000
# gender                                                         1.409470
# anchor_age                                                     1.458858
# disch_age                                                      0.722459
# CKD_stage_first                                                0.385257
# ...                                                                 ...
# Total_Protein,_Urine_first                                     1.002024
# Asparate_Aminotransferase_(AST)_min                            1.000950
# Diabetes with renal manifestations, type II or ...             1.109578
# Urea_Nitrogen,_Urine_first                                     1.000066
# Albumin,_Urine_max                                             1.001027
#
#                                                     cmp to          z  \
# covariate
# subject_id                                             0.0  -1.526508
# gender                                                 0.0   3.049445
# anchor_age                                             0.0  23.536159
# disch_age                                              0.0 -24.013425
# CKD_stage_first                                        0.0 -22.215915
# ...                                                    ...        ...
# Total_Protein,_Urine_first                             0.0   1.267236
# Asparate_Aminotransferase_(AST)_min                    0.0  -0.631635
# Diabetes with renal manifestations, type II or ...     0.0  -0.547712
# Urea_Nitrogen,_Urine_first                             0.0  -1.730445
# Albumin,_Urine_max                                     0.0  -0.961820
#
#                                                                 p    -log2(p)
# covariate
# subject_id                                           1.268835e-01    2.978424
# gender                                               2.292647e-03    8.768770
# anchor_age                                          1.739969e-122  404.476166
# disch_age                                           2.013502e-127  420.875161
# CKD_stage_first                                     2.410210e-109  360.821003
# ...                                                           ...         ...
# Total_Protein,_Urine_first                           2.050708e-01    2.285806
# Asparate_Aminotransferase_(AST)_min                  5.276255e-01    0.922414
# Diabetes with renal manifestations, type II or ...   5.838898e-01    0.776232
# Urea_Nitrogen,_Urine_first                           8.355072e-02    3.581204
# Albumin,_Urine_max                                   3.361402e-01    1.572865
#
# [81 rows x 11 columns]
#                                    test_statistic         p  -log2(p)
# Acute kidney failure, unspecified        1.240907  0.265296  1.914323
# Albumin,_Urine_last                      0.175734  0.675066  0.566900
# Albumin,_Urine_max                       0.121463  0.727453  0.459073
# Albumin/Creatinine,_Urine_first          0.004603  0.945907  0.080230
# Albumin/Creatinine,_Urine_last           0.052569  0.818652  0.288678
# ...                                           ...       ...       ...
# eGFR_mean                                0.000297  0.986252  0.019972
# eGFR_median                              0.018490  0.891839  0.165145
# eGFR_min                                 0.060529  0.805661  0.311755
# gender                                   0.487286  0.485140  1.043526
# subject_id                               0.040033  0.841417  0.249107
#
# [81 rows x 3 columns]
