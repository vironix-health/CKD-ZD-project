# %%
import sys
import os

# Use os.getcwd() to get the current working directory in a Jupyter notebook
parent_dir = os.path.dirname(os.getcwd())  # Get the parent directory of the current working directory
sys.path.append(parent_dir)

# %%
import pandas as pd
from skopt.space import Real, Integer
from driver import Driver

# %% [markdown]
# # Load Cleaned Master MIMIC-IV Dataset

# %%
# Cleaned Master MIMIC Data Set
df_master = pd.read_pickle('../MIMIC_IV/df_ckd_master_clean.pkl')
df_base = pd.read_pickle('../MIMIC_IV/df_ckd_base.pkl')

# %% [markdown]
# # Evaluate Random Forest Pipeline

# %%
RandomForest_cfg = {
    'name': 'RandomForest', # Feature selection model long name
    'tag': 'rdmf', # Feature selection model identifier tag
    'response': 'stage_delta',  # Response variable for binary classification and Cox Proportional Hazards
    'duration': 'duration', # Duration in days until response or censorship
    'n_novel': 40, # Number of ranked novel features included in augmented KFRE dataset
    'test_size': 0.1, # Ratio of data reserved for testing
    'val_size': 0.2, # Ratio of data reserved for testing in validation sets
    'n_valsets': 5, # Number of training validation sets
    'n_bayesian': 10, # Number of Bayesian hyperparameter optimization iterations 
    'n_folds': 5, # Number of folds for CoxPH cross validation
    'penalizer': 0.0007, # CoxPH model penalizer
    'auc_space': [
        Integer(50, 200, name="n_estimators"),
        Integer(2, 50, name="max_depth"),
        Integer(2, 20, name="min_samples_split"),
        Integer(1, 20, name="min_samples_leaf")
    ], # Search space for Bayesian hyperparameter optimization
    'seeds': [42, 73, 128, 256, 512] # Seeds for reproducibility
}

driver = Driver(RandomForest_cfg, df_master, df_base)
driver.ClassicalLearningPipe()
# Out:
# Testing params: {'n_estimators': 169, 'max_depth': 11, 'min_samples_split': 16, 'min_samples_leaf': 12}
# AUC for params: 0.8696753964177131
# Testing params: {'n_estimators': 117, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 7}
# AUC for params: 0.8594937330610207
# Testing params: {'n_estimators': 71, 'max_depth': 33, 'min_samples_split': 3, 'min_samples_leaf': 15}
# AUC for params: 0.8679614846579351
# Testing params: {'n_estimators': 191, 'max_depth': 2, 'min_samples_split': 20, 'min_samples_leaf': 13}
# AUC for params: 0.8190796885814994
# Testing params: {'n_estimators': 142, 'max_depth': 2, 'min_samples_split': 2, 'min_samples_leaf': 11}
# AUC for params: 0.8169437530102673
# Testing params: {'n_estimators': 110, 'max_depth': 4, 'min_samples_split': 20, 'min_samples_leaf': 5}
# AUC for params: 0.8404476847427084
# Testing params: {'n_estimators': 64, 'max_depth': 32, 'min_samples_split': 9, 'min_samples_leaf': 20}
# AUC for params: 0.8682125158511347
# Testing params: {'n_estimators': 120, 'max_depth': 43, 'min_samples_split': 14, 'min_samples_leaf': 10}
# AUC for params: 0.8724168595697652
# Testing params: {'n_estimators': 52, 'max_depth': 47, 'min_samples_split': 12, 'min_samples_leaf': 8}
# AUC for params: 0.8694573789865199
# Testing params: {'n_estimators': 52, 'max_depth': 13, 'min_samples_split': 6, 'min_samples_leaf': 14}
# AUC for params: 0.8669995219333124
# Testing params: {'n_estimators': 96, 'max_depth': 31, 'min_samples_split': 5, 'min_samples_leaf': 11}
# AUC for params: 0.8607460883464665
# Testing params: {'n_estimators': 96, 'max_depth': 6, 'min_samples_split': 18, 'min_samples_leaf': 10}
# AUC for params: 0.8466023864095522
# Testing params: {'n_estimators': 175, 'max_depth': 48, 'min_samples_split': 13, 'min_samples_leaf': 10}
# AUC for params: 0.8647329516449032
# Testing params: {'n_estimators': 181, 'max_depth': 17, 'min_samples_split': 16, 'min_samples_leaf': 3}
# AUC for params: 0.8651328674902053
# Testing params: {'n_estimators': 117, 'max_depth': 13, 'min_samples_split': 5, 'min_samples_leaf': 16}
# AUC for params: 0.8609732625018995
# Testing params: {'n_estimators': 68, 'max_depth': 14, 'min_samples_split': 9, 'min_samples_leaf': 12}
# AUC for params: 0.8604472717683815
# Testing params: {'n_estimators': 155, 'max_depth': 34, 'min_samples_split': 19, 'min_samples_leaf': 8}
# AUC for params: 0.8648090675865394
# Testing params: {'n_estimators': 62, 'max_depth': 27, 'min_samples_split': 9, 'min_samples_leaf': 14}
# AUC for params: 0.8611921335059932
# Testing params: {'n_estimators': 90, 'max_depth': 5, 'min_samples_split': 14, 'min_samples_leaf': 13}
# AUC for params: 0.8404673210860191
# Testing params: {'n_estimators': 179, 'max_depth': 14, 'min_samples_split': 20, 'min_samples_leaf': 13}
# AUC for params: 0.8602427699763313
# Testing params: {'n_estimators': 184, 'max_depth': 43, 'min_samples_split': 9, 'min_samples_leaf': 11}
# AUC for params: 0.8762001698440998
# Testing params: {'n_estimators': 105, 'max_depth': 19, 'min_samples_split': 16, 'min_samples_leaf': 12}
# AUC for params: 0.8769985892867771
# Testing params: {'n_estimators': 67, 'max_depth': 39, 'min_samples_split': 19, 'min_samples_leaf': 4}
# AUC for params: 0.8733273153155423
# Testing params: {'n_estimators': 149, 'max_depth': 16, 'min_samples_split': 12, 'min_samples_leaf': 19}
# AUC for params: 0.8755210137471888
# Testing params: {'n_estimators': 184, 'max_depth': 32, 'min_samples_split': 3, 'min_samples_leaf': 17}
# AUC for params: 0.8784881615559973
# Testing params: {'n_estimators': 80, 'max_depth': 21, 'min_samples_split': 16, 'min_samples_leaf': 12}
# AUC for params: 0.870923531541864
# Testing params: {'n_estimators': 107, 'max_depth': 24, 'min_samples_split': 2, 'min_samples_leaf': 2}
# AUC for params: 0.8761234126884674
# Testing params: {'n_estimators': 94, 'max_depth': 30, 'min_samples_split': 17, 'min_samples_leaf': 2}
# AUC for params: 0.8722675414998091
# Testing params: {'n_estimators': 100, 'max_depth': 27, 'min_samples_split': 2, 'min_samples_leaf': 4}
# AUC for params: 0.877628510577013
# Testing params: {'n_estimators': 75, 'max_depth': 37, 'min_samples_split': 17, 'min_samples_leaf': 19}
# AUC for params: 0.8721142041357224
# Testing params: {'n_estimators': 175, 'max_depth': 27, 'min_samples_split': 11, 'min_samples_leaf': 14}
# AUC for params: 0.8711233825556427
# Testing params: {'n_estimators': 196, 'max_depth': 19, 'min_samples_split': 18, 'min_samples_leaf': 12}
# AUC for params: 0.8721598785096509
# Testing params: {'n_estimators': 60, 'max_depth': 39, 'min_samples_split': 14, 'min_samples_leaf': 11}
# AUC for params: 0.8689944745438826
# Testing params: {'n_estimators': 103, 'max_depth': 9, 'min_samples_split': 12, 'min_samples_leaf': 16}
# AUC for params: 0.8675761964639556
# Testing params: {'n_estimators': 128, 'max_depth': 12, 'min_samples_split': 12, 'min_samples_leaf': 9}
# AUC for params: 0.872660253758359
# Testing params: {'n_estimators': 59, 'max_depth': 24, 'min_samples_split': 9, 'min_samples_leaf': 2}
# AUC for params: 0.8675180044140263
# Testing params: {'n_estimators': 164, 'max_depth': 3, 'min_samples_split': 11, 'min_samples_leaf': 3}
# AUC for params: 0.8304973742107302
# Testing params: {'n_estimators': 83, 'max_depth': 28, 'min_samples_split': 8, 'min_samples_leaf': 17}
# AUC for params: 0.8705659535953446
# Testing params: {'n_estimators': 56, 'max_depth': 40, 'min_samples_split': 5, 'min_samples_leaf': 9}
# AUC for params: 0.8732852733754255
# Testing params: {'n_estimators': 84, 'max_depth': 22, 'min_samples_split': 7, 'min_samples_leaf': 6}
# AUC for params: 0.870057477904638
# Testing params: {'n_estimators': 113, 'max_depth': 12, 'min_samples_split': 9, 'min_samples_leaf': 5}
# AUC for params: 0.8740999511462109
# Testing params: {'n_estimators': 134, 'max_depth': 35, 'min_samples_split': 8, 'min_samples_leaf': 14}
# AUC for params: 0.872734298834992
# Testing params: {'n_estimators': 183, 'max_depth': 15, 'min_samples_split': 17, 'min_samples_leaf': 4}
# AUC for params: 0.8785709977730065
# Testing params: {'n_estimators': 132, 'max_depth': 13, 'min_samples_split': 20, 'min_samples_leaf': 13}
# AUC for params: 0.8722791315097804
# Testing params: {'n_estimators': 70, 'max_depth': 14, 'min_samples_split': 10, 'min_samples_leaf': 14}
# AUC for params: 0.8676741081843377
# Testing params: {'n_estimators': 98, 'max_depth': 41, 'min_samples_split': 19, 'min_samples_leaf': 16}
# AUC for params: 0.8721445785078705
# Testing params: {'n_estimators': 138, 'max_depth': 33, 'min_samples_split': 6, 'min_samples_leaf': 7}
# AUC for params: 0.8801623535659683
# Testing params: {'n_estimators': 145, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 4}
# AUC for params: 0.8644385342161067
# Testing params: {'n_estimators': 200, 'max_depth': 24, 'min_samples_split': 13, 'min_samples_leaf': 10}
# AUC for params: 0.8771705509455792
# Testing params: {'n_estimators': 161, 'max_depth': 44, 'min_samples_split': 14, 'min_samples_leaf': 17}
# AUC for params: 0.8737058922593368
# Best parameters found:  {'n_estimators': 138, 'max_depth': 33, 'min_samples_split': 6, 'min_samples_leaf': 7}
# Best mean AUC across validation sets:  0.8801623535659683
# Mean AUC: 0.579633693192725
# Standard Deviation: 0.009159874589584293
# Max AUC: 0.5905084498834499
# Iteration 1: norm_delta = 6.78e+00, step_size = 0.9500, log_lik = -8744.90665, newton_decrement = 9.91e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.37e+00, step_size = 0.2375, log_lik = -8332.04526, newton_decrement = 5.31e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.02e+00, step_size = 0.0772, log_lik = -8253.16526, newton_decrement = 4.55e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.88e+00, step_size = 0.0326, log_lik = -8223.97700, newton_decrement = 4.27e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.65e+00, step_size = 0.0551, log_lik = -8178.21342, newton_decrement = 3.83e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.27e+00, step_size = 0.0931, log_lik = -8110.16688, newton_decrement = 3.18e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 3.68e+00, step_size = 0.1574, log_lik = -8017.92986, newton_decrement = 2.29e+02, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.79e+00, step_size = 0.2660, log_lik = -7912.09967, newton_decrement = 1.26e+02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.61e+00, step_size = 0.4496, log_lik = -7823.78275, newton_decrement = 3.97e+01, seconds_since_start = 0.8
# Iteration 10: norm_delta = 4.19e-01, step_size = 0.7598, log_lik = -7786.25506, newton_decrement = 2.52e+00, seconds_since_start = 0.9
# Iteration 11: norm_delta = 3.84e-03, step_size = 1.0000, log_lik = -7783.72767, newton_decrement = 5.50e-04, seconds_since_start = 1.0
# Iteration 12: norm_delta = 8.60e-06, step_size = 1.0000, log_lik = -7783.72712, newton_decrement = 2.30e-09, seconds_since_start = 1.1
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.90e+00, step_size = 0.9500, log_lik = -8829.99117, newton_decrement = 9.82e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.50e+00, step_size = 0.2375, log_lik = -8420.49550, newton_decrement = 5.34e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.14e+00, step_size = 0.0772, log_lik = -8341.21950, newton_decrement = 4.56e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 5.00e+00, step_size = 0.0326, log_lik = -8311.96294, newton_decrement = 4.27e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.94e+00, step_size = 0.0138, log_lik = -8300.26695, newton_decrement = 4.16e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.84e+00, step_size = 0.0233, log_lik = -8281.12083, newton_decrement = 3.97e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 4.68e+00, step_size = 0.0394, log_lik = -8250.46878, newton_decrement = 3.67e+02, seconds_since_start = 0.7
# Iteration 8: norm_delta = 4.41e+00, step_size = 0.0665, log_lik = -8203.23163, newton_decrement = 3.21e+02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 3.98e+00, step_size = 0.1124, log_lik = -8135.08362, newton_decrement = 2.54e+02, seconds_since_start = 0.9
# Iteration 10: norm_delta = 3.30e+00, step_size = 0.1899, log_lik = -8047.57222, newton_decrement = 1.68e+02, seconds_since_start = 1.0
# Iteration 11: norm_delta = 2.32e+00, step_size = 0.3210, log_lik = -7956.72491, newton_decrement = 7.87e+01, seconds_since_start = 1.0
# Iteration 12: norm_delta = 1.12e+00, step_size = 0.5425, log_lik = -7894.40118, newton_decrement = 1.69e+01, seconds_since_start = 1.1
# Iteration 13: norm_delta = 1.10e-01, step_size = 0.9168, log_lik = -7877.52741, newton_decrement = 1.54e-01, seconds_since_start = 1.2
# Iteration 14: norm_delta = 5.19e-04, step_size = 1.0000, log_lik = -7877.37330, newton_decrement = 8.45e-06, seconds_since_start = 1.3
# Iteration 15: norm_delta = 2.51e-07, step_size = 1.0000, log_lik = -7877.37329, newton_decrement = 2.77e-12, seconds_since_start = 1.4
# Convergence success after 15 iterations.
# Iteration 1: norm_delta = 6.79e+00, step_size = 0.9500, log_lik = -8805.41001, newton_decrement = 9.65e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.41e+00, step_size = 0.2375, log_lik = -8402.64968, newton_decrement = 5.30e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.05e+00, step_size = 0.0772, log_lik = -8324.01927, newton_decrement = 4.52e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.91e+00, step_size = 0.0326, log_lik = -8294.99448, newton_decrement = 4.24e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.68e+00, step_size = 0.0551, log_lik = -8249.54408, newton_decrement = 3.80e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.31e+00, step_size = 0.0931, log_lik = -8182.12084, newton_decrement = 3.14e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 3.71e+00, step_size = 0.1574, log_lik = -8091.12483, newton_decrement = 2.25e+02, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.82e+00, step_size = 0.2660, log_lik = -7987.49604, newton_decrement = 1.23e+02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 1.63e+00, step_size = 0.4496, log_lik = -7901.93099, newton_decrement = 3.81e+01, seconds_since_start = 0.8
# Iteration 10: norm_delta = 4.27e-01, step_size = 0.7598, log_lik = -7865.95922, newton_decrement = 2.40e+00, seconds_since_start = 1.0
# Iteration 11: norm_delta = 4.74e-03, step_size = 1.0000, log_lik = -7863.54450, newton_decrement = 5.75e-04, seconds_since_start = 1.0
# Iteration 12: norm_delta = 1.06e-05, step_size = 1.0000, log_lik = -7863.54393, newton_decrement = 2.25e-09, seconds_since_start = 1.1
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.97e+00, step_size = 0.9500, log_lik = -9037.41005, newton_decrement = 9.71e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.55e+00, step_size = 0.2375, log_lik = -8632.68925, newton_decrement = 5.36e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.19e+00, step_size = 0.0772, log_lik = -8553.13470, newton_decrement = 4.59e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 5.05e+00, step_size = 0.0326, log_lik = -8523.68196, newton_decrement = 4.31e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.99e+00, step_size = 0.0138, log_lik = -8511.89260, newton_decrement = 4.19e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.89e+00, step_size = 0.0233, log_lik = -8492.58350, newton_decrement = 4.01e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 4.73e+00, step_size = 0.0394, log_lik = -8461.64291, newton_decrement = 3.71e+02, seconds_since_start = 0.7
# Iteration 8: norm_delta = 4.45e+00, step_size = 0.0665, log_lik = -8413.88845, newton_decrement = 3.26e+02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 4.02e+00, step_size = 0.1124, log_lik = -8344.81459, newton_decrement = 2.59e+02, seconds_since_start = 0.9
# Iteration 10: norm_delta = 3.34e+00, step_size = 0.1899, log_lik = -8255.72016, newton_decrement = 1.73e+02, seconds_since_start = 1.0
# Iteration 11: norm_delta = 2.35e+00, step_size = 0.3210, log_lik = -8162.55090, newton_decrement = 8.16e+01, seconds_since_start = 1.1
# Iteration 12: norm_delta = 1.13e+00, step_size = 0.5425, log_lik = -8097.93415, newton_decrement = 1.78e+01, seconds_since_start = 1.2
# Iteration 13: norm_delta = 1.12e-01, step_size = 0.9168, log_lik = -8080.16567, newton_decrement = 1.78e-01, seconds_since_start = 1.3
# Iteration 14: norm_delta = 2.74e-03, step_size = 1.0000, log_lik = -8079.98559, newton_decrement = 9.45e-04, seconds_since_start = 1.5
# Iteration 15: norm_delta = 3.61e-04, step_size = 1.0000, log_lik = -8079.98458, newton_decrement = 1.25e-05, seconds_since_start = 1.6
# Iteration 16: norm_delta = 5.17e-06, step_size = 1.0000, log_lik = -8079.98457, newton_decrement = 2.49e-09, seconds_since_start = 1.7
# Convergence success after 16 iterations.
# Iteration 1: norm_delta = 6.77e+00, step_size = 0.9500, log_lik = -8886.68689, newton_decrement = 9.96e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.42e+00, step_size = 0.2375, log_lik = -8471.53934, newton_decrement = 5.39e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.07e+00, step_size = 0.0772, log_lik = -8391.56812, newton_decrement = 4.61e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.93e+00, step_size = 0.0326, log_lik = -8361.99934, newton_decrement = 4.32e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.70e+00, step_size = 0.0551, log_lik = -8315.65935, newton_decrement = 3.88e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.33e+00, step_size = 0.0931, log_lik = -8246.81435, newton_decrement = 3.21e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 3.74e+00, step_size = 0.1574, log_lik = -8153.65198, newton_decrement = 2.31e+02, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.84e+00, step_size = 0.2660, log_lik = -8047.09678, newton_decrement = 1.27e+02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.64e+00, step_size = 0.4496, log_lik = -7958.60911, newton_decrement = 3.96e+01, seconds_since_start = 0.9
# Iteration 10: norm_delta = 4.29e-01, step_size = 0.7598, log_lik = -7921.20397, newton_decrement = 2.50e+00, seconds_since_start = 1.0
# Iteration 11: norm_delta = 3.11e-03, step_size = 1.0000, log_lik = -7918.69201, newton_decrement = 4.96e-04, seconds_since_start = 1.1
# Iteration 12: norm_delta = 1.47e-06, step_size = 1.0000, log_lik = -7918.69151, newton_decrement = 2.59e-10, seconds_since_start = 1.2
# Convergence success after 12 iterations.
# Average C-Index from cross-validation: 0.8865
# Best C-Index from cross-validation: 0.8936
# Standard Deviation of C-Index from cross-validation: 0.0082
#                                       coef  exp(coef)      se(coef)  \
# covariate
# subject_id                   -1.584365e-08   1.000000  1.033605e-08
# gender                        2.018583e-01   1.223675  6.804598e-02
# anchor_age                    3.478253e-01   1.415985  1.481865e-02
# disch_age                    -3.533236e-01   0.702350  1.474692e-02
# CKD_stage_first              -1.052522e+00   0.349056  4.713154e-02
# ...                                    ...        ...           ...
# Albumin,_Urine_max           -1.053221e-03   0.998947  1.035956e-03
# Neutrophils_min              -2.251086e-03   0.997751  2.429279e-03
# Protein/Creatinine_Ratio_min -7.090425e-02   0.931551  4.363701e-02
# Urea_Nitrogen,_Urine_last    -5.501328e-04   0.999450  2.727963e-04
# Albumin,_Urine_last           5.010724e-04   1.000501  1.242324e-03
#
#                               coef lower 95%  coef upper 95%  \
# covariate
# subject_id                     -3.610193e-08    4.414629e-09
# gender                          6.849067e-02    3.352260e-01
# anchor_age                      3.187813e-01    3.768693e-01
# disch_age                      -3.822271e-01   -3.244202e-01
# CKD_stage_first                -1.144898e+00   -9.601457e-01
# ...                                      ...             ...
# Albumin,_Urine_max             -3.083659e-03    9.772160e-04
# Neutrophils_min                -7.012384e-03    2.510213e-03
# Protein/Creatinine_Ratio_min   -1.564312e-01    1.462272e-02
# Urea_Nitrogen,_Urine_last      -1.084804e-03   -1.546183e-05
# Albumin,_Urine_last            -1.933839e-03    2.935983e-03
#
#                               exp(coef) lower 95%  exp(coef) upper 95%  \
# covariate
# subject_id                               1.000000             1.000000
# gender                                   1.070891             1.398256
# anchor_age                               1.375450             1.457714
# disch_age                                0.682340             0.722946
# CKD_stage_first                          0.318256             0.382837
# ...                                           ...                  ...
# Albumin,_Urine_max                       0.996921             1.000978
# Neutrophils_min                          0.993012             1.002513
# Protein/Creatinine_Ratio_min             0.855190             1.014730
# Urea_Nitrogen,_Urine_last                0.998916             0.999985
# Albumin,_Urine_last                      0.998068             1.002940
#
#                               cmp to          z              p    -log2(p)
# covariate
# subject_id                       0.0  -1.532854   1.253118e-01    2.996405
# gender                           0.0   2.966499   3.012112e-03    8.375009
# anchor_age                       0.0  23.472133  7.857432e-122  402.301170
# disch_age                        0.0 -23.959151  7.418428e-127  418.993755
# CKD_stage_first                  0.0 -22.331581  1.823599e-110  364.545302
# ...                              ...        ...            ...         ...
# Albumin,_Urine_max               0.0  -1.016666   3.093125e-01    1.692863
# Neutrophils_min                  0.0  -0.926648   3.541094e-01    1.497733
# Protein/Creatinine_Ratio_min     0.0  -1.624865   1.041913e-01    3.262693
# Urea_Nitrogen,_Urine_last        0.0  -2.016643   4.373278e-02    4.515141
# Albumin,_Urine_last              0.0   0.403335   6.867021e-01    0.542244
#
# [81 rows x 11 columns]
#                                    test_statistic         p  -log2(p)
# Acute kidney failure, unspecified        1.819697  0.177349  2.495334
# Albumin,_Urine_last                      0.197414  0.656817  0.606437
# Albumin,_Urine_max                       0.084107  0.771808  0.373687
# Albumin/Creatinine,_Urine_first          0.016719  0.897118  0.156630
# Albumin/Creatinine,_Urine_last           0.014813  0.903131  0.146993
# ...                                           ...       ...       ...
# eGFR_mean                                0.000004  0.998480  0.002194
# eGFR_median                              0.018024  0.893201  0.162944
# eGFR_min                                 0.062824  0.802086  0.318171
# gender                                   0.481914  0.487557  1.036359
# subject_id                               0.173526  0.676997  0.562779
#
# [81 rows x 3 columns]
# Brier Score at 1 year(s): 0.0321
# Brier Score at 2 year(s): 0.0590
# Brier Score at 3 year(s): 0.0732
# Brier Score at 4 year(s): 0.0899
# Brier Score at 5 year(s): 0.1077
# AUC at 1 year(s): 0.9472
# AUC at 2 year(s): 0.9426
# AUC at 3 year(s): 0.9399
# AUC at 4 year(s): 0.9212
# AUC at 5 year(s): 0.9149
