# %%
import sys
import os

# Use os.getcwd() to get the current working directory in a Jupyter notebook
parent_dir = os.path.dirname(os.getcwd())  # Get the parent directory of the current working directory
sys.path.append(parent_dir)

# %%
import pandas as pd
from skopt.space import Real, Integer
from driver import Driver

# %% [markdown]
# # Load Cleaned Master MIMIC-IV Dataset

# %%
# Cleaned Master MIMIC Data Set
df_master = pd.read_pickle('../MIMIC_IV/df_ckd_master_clean.pkl')
df_base = pd.read_pickle('../MIMIC_IV/df_ckd_base.pkl')

# %% [markdown]
# # Evaluate FCNN Pipeline

# %%
FCNN_cfg = {
    'name': 'FCNN',
    'tag': 'fcnn', # Identifier tag for feature selection model
    'response': 'stage_delta',  # Response variable for binary classification and Cox Proportional Hazards
    'duration': 'duration', # Duration in days until response or censorship
    'n_novel': 40, # Number of ranked novel features included in augmented KFRE dataset
    'test_size': 0.2, # Ratio of data reserved for testing
    'epochs': 35,
    'patience': 5,
    'learning_rate': 0.001,
    'weight_decay': 1e-4,
    'batch_size': 256, # Batch size for SHAP computation
    'n_folds': 5, # Number of folds for CoxPH cross validation
    'penalizer': 0.0007, # CoxPH model penalizer
    'random_state': 42 # Seed for reproducibility
}

driver = Driver(FCNN_cfg, df_master, df_base)
driver.DeepLearningPipe()
# Out:
# Epoch 1/35, Training Loss: 0.2802146215161139, Validation Loss: 0.27526436576789076
# Epoch 2/35, Training Loss: 0.19269245486198502, Validation Loss: 0.3108631670475006
# Epoch 3/35, Training Loss: 0.12888247638263486, Validation Loss: 0.3988764367320321
# Epoch 4/35, Training Loss: 0.08366191194297491, Validation Loss: 0.5017805333164606
# Epoch 5/35, Training Loss: 0.056281304292497225, Validation Loss: 0.6860888065262274
# Epoch 6/35, Training Loss: 0.042325258615164785, Validation Loss: 0.6656918762759729
# Early stopping triggered
# Test AUC: 0.6590002379898303
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:20<00:00,  1.85s/it]
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\shap\plots\_beeswarm.py:962: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   pl.tight_layout()
# Iteration 1: norm_delta = 6.47e+00, step_size = 0.9500, log_lik = -8744.90665, newton_decrement = 9.88e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.22e+00, step_size = 0.2375, log_lik = -8332.25027, newton_decrement = 5.54e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.89e+00, step_size = 0.0772, log_lik = -8250.04183, newton_decrement = 4.76e+02, seconds_since_start = 0.4
# Iteration 4: norm_delta = 4.35e+00, step_size = 0.1304, log_lik = -8134.00022, newton_decrement = 3.66e+02, seconds_since_start = 0.5
# Iteration 5: norm_delta = 3.52e+00, step_size = 0.2205, log_lik = -7990.25585, newton_decrement = 2.30e+02, seconds_since_start = 0.6
# Iteration 6: norm_delta = 2.34e+00, step_size = 0.3726, log_lik = -7850.45107, newton_decrement = 9.57e+01, seconds_since_start = 0.7
# Iteration 7: norm_delta = 9.37e-01, step_size = 0.6296, log_lik = -7767.48577, newton_decrement = 1.45e+01, seconds_since_start = 0.8
# Iteration 8: norm_delta = 1.46e-02, step_size = 1.0000, log_lik = -7752.86254, newton_decrement = 1.09e-02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.84e-05, step_size = 1.0000, log_lik = -7752.85167, newton_decrement = 5.12e-08, seconds_since_start = 0.9
# Convergence success after 9 iterations.
# Iteration 1: norm_delta = 6.57e+00, step_size = 0.9500, log_lik = -8829.99117, newton_decrement = 9.78e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.32e+00, step_size = 0.2375, log_lik = -8421.42789, newton_decrement = 5.49e+02, seconds_since_start = 0.3
# Iteration 3: norm_delta = 4.99e+00, step_size = 0.0772, log_lik = -8339.95796, newton_decrement = 4.71e+02, seconds_since_start = 0.5
# Iteration 4: norm_delta = 4.45e+00, step_size = 0.1304, log_lik = -8225.04313, newton_decrement = 3.62e+02, seconds_since_start = 0.6
# Iteration 5: norm_delta = 3.61e+00, step_size = 0.2205, log_lik = -8082.95744, newton_decrement = 2.27e+02, seconds_since_start = 0.7
# Iteration 6: norm_delta = 2.40e+00, step_size = 0.3726, log_lik = -7945.26572, newton_decrement = 9.39e+01, seconds_since_start = 0.8
# Iteration 7: norm_delta = 9.61e-01, step_size = 0.6296, log_lik = -7863.84252, newton_decrement = 1.42e+01, seconds_since_start = 0.9
# Iteration 8: norm_delta = 1.43e-02, step_size = 1.0000, log_lik = -7849.47426, newton_decrement = 1.07e-02, seconds_since_start = 1.0
# Iteration 9: norm_delta = 1.24e-04, step_size = 1.0000, log_lik = -7849.46351, newton_decrement = 3.06e-07, seconds_since_start = 1.1
# Iteration 10: norm_delta = 2.35e-07, step_size = 1.0000, log_lik = -7849.46350, newton_decrement = 9.13e-13, seconds_since_start = 1.2
# Convergence success after 10 iterations.
# Iteration 1: norm_delta = 6.50e+00, step_size = 0.9500, log_lik = -8805.41001, newton_decrement = 9.81e+02, seconds_since_start = 0.2
# Iteration 2: norm_delta = 5.24e+00, step_size = 0.2375, log_lik = -8395.80041, newton_decrement = 5.43e+02, seconds_since_start = 0.3
# Iteration 3: norm_delta = 4.91e+00, step_size = 0.0772, log_lik = -8315.24093, newton_decrement = 4.64e+02, seconds_since_start = 0.4
# Iteration 4: norm_delta = 4.38e+00, step_size = 0.1304, log_lik = -8201.96297, newton_decrement = 3.55e+02, seconds_since_start = 0.6
# Iteration 5: norm_delta = 3.55e+00, step_size = 0.2205, log_lik = -8062.53424, newton_decrement = 2.21e+02, seconds_since_start = 0.6
# Iteration 6: norm_delta = 2.36e+00, step_size = 0.3726, log_lik = -7928.13664, newton_decrement = 9.13e+01, seconds_since_start = 0.7
# Iteration 7: norm_delta = 9.46e-01, step_size = 0.6296, log_lik = -7848.94517, newton_decrement = 1.38e+01, seconds_since_start = 0.8
# Iteration 8: norm_delta = 1.30e-02, step_size = 1.0000, log_lik = -7834.97197, newton_decrement = 9.01e-03, seconds_since_start = 0.9
# Iteration 9: norm_delta = 2.84e-05, step_size = 1.0000, log_lik = -7834.96295, newton_decrement = 3.29e-08, seconds_since_start = 1.0
# Convergence success after 9 iterations.
# Iteration 1: norm_delta = 6.66e+00, step_size = 0.9500, log_lik = -9037.41005, newton_decrement = 9.78e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.39e+00, step_size = 0.2375, log_lik = -8628.77937, newton_decrement = 5.53e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.05e+00, step_size = 0.0772, log_lik = -8546.66753, newton_decrement = 4.75e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.91e+00, step_size = 0.0326, log_lik = -8516.17891, newton_decrement = 4.46e+02, seconds_since_start = 0.5
# Iteration 5: norm_delta = 4.69e+00, step_size = 0.0551, log_lik = -8468.31976, newton_decrement = 4.01e+02, seconds_since_start = 0.6
# Iteration 6: norm_delta = 4.32e+00, step_size = 0.0931, log_lik = -8397.01528, newton_decrement = 3.34e+02, seconds_since_start = 0.8
# Iteration 7: norm_delta = 3.74e+00, step_size = 0.1574, log_lik = -8300.03422, newton_decrement = 2.42e+02, seconds_since_start = 0.8
# Iteration 8: norm_delta = 2.85e+00, step_size = 0.2660, log_lik = -8188.09903, newton_decrement = 1.35e+02, seconds_since_start = 0.9
# Iteration 9: norm_delta = 1.65e+00, step_size = 0.4496, log_lik = -8093.69331, newton_decrement = 4.31e+01, seconds_since_start = 1.0
# Iteration 10: norm_delta = 4.32e-01, step_size = 0.7598, log_lik = -8052.87698, newton_decrement = 2.81e+00, seconds_since_start = 1.1
# Iteration 11: norm_delta = 2.85e-03, step_size = 1.0000, log_lik = -8050.05374, newton_decrement = 4.87e-04, seconds_since_start = 1.2
# Iteration 12: norm_delta = 7.73e-07, step_size = 1.0000, log_lik = -8050.05325, newton_decrement = 1.30e-10, seconds_since_start = 1.3
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.53e+00, step_size = 0.9500, log_lik = -8886.68689, newton_decrement = 9.96e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.27e+00, step_size = 0.2375, log_lik = -8470.91753, newton_decrement = 5.53e+02, seconds_since_start = 0.3
# Iteration 3: norm_delta = 4.94e+00, step_size = 0.0772, log_lik = -8388.81539, newton_decrement = 4.75e+02, seconds_since_start = 0.4
# Iteration 4: norm_delta = 4.40e+00, step_size = 0.1304, log_lik = -8273.03049, newton_decrement = 3.65e+02, seconds_since_start = 0.6
# Iteration 5: norm_delta = 3.57e+00, step_size = 0.2205, log_lik = -8129.65599, newton_decrement = 2.30e+02, seconds_since_start = 0.7
# Iteration 6: norm_delta = 2.37e+00, step_size = 0.3726, log_lik = -7989.72599, newton_decrement = 9.71e+01, seconds_since_start = 0.7
# Iteration 7: norm_delta = 9.52e-01, step_size = 0.6296, log_lik = -7905.32465, newton_decrement = 1.53e+01, seconds_since_start = 0.8
# Iteration 8: norm_delta = 1.41e-02, step_size = 1.0000, log_lik = -7889.79627, newton_decrement = 1.66e-02, seconds_since_start = 0.9
# Iteration 9: norm_delta = 2.94e-05, step_size = 1.0000, log_lik = -7889.77966, newton_decrement = 1.63e-07, seconds_since_start = 1.0
# Iteration 10: norm_delta = 6.43e-09, step_size = 1.0000, log_lik = -7889.77966, newton_decrement = 1.99e-15, seconds_since_start = 1.1
# Convergence success after 10 iterations.
# Average C-Index from cross-validation: 0.8868
# Best C-Index from cross-validation: 0.8928
# Standard Deviation of C-Index from cross-validation: 0.0069
#                                                coef  exp(coef)      se(coef)  \
# covariate
# subject_id                            -2.370189e-08   1.000000  1.042731e-08
# gender                                 5.938714e-02   1.061186  6.875574e-02
# anchor_age                             3.475453e-01   1.415588  1.482197e-02
# disch_age                             -3.508469e-01   0.704092  1.477769e-02
# CKD_stage_first                       -1.077997e+00   0.340276  4.936502e-02
# ...                                             ...        ...           ...
# MCHC_min                               3.528910e-02   1.035919  2.733707e-02
# MCH_max                                1.165375e-02   1.011722  1.310600e-02
# Asthma, unspecified type, unspecified -2.287828e-01   0.795501  9.744761e-02
# MCHC_max                              -1.082963e-01   0.897362  3.191781e-02
# White_Blood_Cells_min                 -1.290965e-02   0.987173  1.625448e-02
#
#                                        coef lower 95%  coef upper 95%  \
# covariate
# subject_id                              -4.413905e-08   -3.264728e-09
# gender                                  -7.537163e-02    1.941459e-01
# anchor_age                               3.184947e-01    3.765958e-01
# disch_age                               -3.798106e-01   -3.218831e-01
# CKD_stage_first                         -1.174751e+00   -9.812432e-01
# ...                                               ...             ...
# MCHC_min                                -1.829057e-02    8.886877e-02
# MCH_max                                 -1.403353e-02    3.734103e-02
# Asthma, unspecified type, unspecified   -4.197766e-01   -3.778898e-02
# MCHC_max                                -1.708540e-01   -4.573853e-02
# White_Blood_Cells_min                   -4.476784e-02    1.894854e-02
#
#                                        exp(coef) lower 95%  \
# covariate
# subject_id                                        1.000000
# gender                                            0.927399
# anchor_age                                        1.375056
# disch_age                                         0.683991
# CKD_stage_first                                   0.308896
# ...                                                    ...
# MCHC_min                                          0.981876
# MCH_max                                           0.986064
# Asthma, unspecified type, unspecified             0.657194
# MCHC_max                                          0.842945
# White_Blood_Cells_min                             0.956219
#
#                                        exp(coef) upper 95%  cmp to          z  \
# covariate
# subject_id                                        1.000000     0.0  -2.273058
# gender                                            1.214273     0.0   0.863741
# anchor_age                                        1.457315     0.0  23.447982
# disch_age                                         0.724783     0.0 -23.741655
# CKD_stage_first                                   0.374845     0.0 -21.837263
# ...                                                    ...     ...        ...
# MCHC_min                                          1.092937     0.0   1.290888
# MCH_max                                           1.038047     0.0   0.889192
# Asthma, unspecified type, unspecified             0.962916     0.0  -2.347752
# MCHC_max                                          0.955292     0.0  -3.392974
# White_Blood_Cells_min                             1.019129     0.0  -0.794221
#
#                                                    p    -log2(p)
# covariate
# subject_id                              2.302270e-02    5.440799
# gender                                  3.877303e-01    1.366875
# anchor_age                             1.386079e-121  401.482290
# disch_age                              1.340016e-124  411.496834
# CKD_stage_first                        1.027278e-105  348.763623
# ...                                              ...         ...
# MCHC_min                                1.967424e-01    2.345620
# MCH_max                                 3.738998e-01    1.419276
# Asthma, unspecified type, unspecified   1.888711e-02    5.726454
# MCHC_max                                6.913821e-04   10.498229
# White_Blood_Cells_min                   4.270667e-01    1.227467
#
# [81 rows x 11 columns]
#                                           test_statistic         p  -log2(p)
# Acidosis                                        7.417884  0.006458  7.274725
# Acute kidney failure, unspecified               2.313263  0.128275  2.962694
# Acute on chronic diastolic heart failure        0.255552  0.613193  0.705587
# Albumin/Creatinine,_Urine_first                 0.711426  0.398971  1.325645
# Albumin/Creatinine,_Urine_last                  0.070468  0.790657  0.338877
# ...                                                  ...       ...       ...
# eGFR_median                                     0.109230  0.741023  0.432410
# eGFR_min                                        0.061252  0.804528  0.313786
# gender                                          5.723292  0.016741  5.900444
# race_WHITE                                      0.008957  0.924602  0.113096
# subject_id                                      0.125641  0.722995  0.467942
#
# [81 rows x 3 columns]
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sksurv\metrics.py:482: RuntimeWarning: invalid value encountered in divide
#   true_pos = cumsum_tp / cumsum_tp[-1]
