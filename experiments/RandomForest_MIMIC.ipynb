# %%
import sys
import os

# Use os.getcwd() to get the current working directory in a Jupyter notebook
parent_dir = os.path.dirname(os.getcwd())  # Get the parent directory of the current working directory
sys.path.append(parent_dir)

# %%
import pandas as pd
from skopt.space import Real, Integer
from driver import Driver

# %% [markdown]
# # Load Cleaned Master MIMIC-IV Dataset

# %%
# Cleaned Master MIMIC Data Set
df_master = pd.read_pickle('../MIMIC_IV/df_ckd_master_clean.pkl')
df_base = pd.read_pickle('../MIMIC_IV/df_ckd_base.pkl')

# %% [markdown]
# # Evaluate Random Forest Pipeline

# %%
RandomForest_cfg = {
    'tag': 'rdmf', # Identifier tag for feature selection model
    'response': 'stage_delta',  # Response variable for binary classification and Cox Proportional Hazards
    'duration': 'duration', # Duration in days until response or censorship
    'n_novel': 40, # Number of ranked novel features included in augmented KFRE dataset
    'test_size': 0.1, # Ratio of data reserved for testing
    'val_size': 0.2, # Ratio of data reserved for testing in validation sets
    'n_valsets': 5, # Number of training validation sets
    'n_bayesian': 10, # Number of Bayesian hyperparameter optimization iterations 
    'n_folds': 5, # Number of folds for CoxPH cross validation
    'penalizer': 0.0007, # CoxPH model penalizer
    'auc_space': [
        Integer(50, 200, name="n_estimators"),
        Integer(2, 50, name="max_depth"),
        Integer(2, 20, name="min_samples_split"),
        Integer(1, 20, name="min_samples_leaf")
    ], # Search space for Bayesian hyperparameter optimization
    'random_state': 42 # Seed for reproducibility
}

driver = Driver(RandomForest_cfg, df_master, df_base)
driver.ClassicalLearningPipe()
# Out:
# Testing params: {'n_estimators': 169, 'max_depth': 11, 'min_samples_split': 16, 'min_samples_leaf': 12}
# AUC for params: 0.8592687467129352
# Testing params: {'n_estimators': 117, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 7}
# AUC for params: 0.8573756472870248
# Testing params: {'n_estimators': 71, 'max_depth': 33, 'min_samples_split': 3, 'min_samples_leaf': 15}
# AUC for params: 0.8561993459700685
# Testing params: {'n_estimators': 191, 'max_depth': 2, 'min_samples_split': 20, 'min_samples_leaf': 13}
# AUC for params: 0.8172385924073529
# Testing params: {'n_estimators': 142, 'max_depth': 2, 'min_samples_split': 2, 'min_samples_leaf': 11}
# AUC for params: 0.8159067648303925
# Testing params: {'n_estimators': 110, 'max_depth': 4, 'min_samples_split': 20, 'min_samples_leaf': 5}
# AUC for params: 0.8370364965340963
# Testing params: {'n_estimators': 64, 'max_depth': 32, 'min_samples_split': 9, 'min_samples_leaf': 20}
# AUC for params: 0.8627162215123224
# Testing params: {'n_estimators': 120, 'max_depth': 43, 'min_samples_split': 14, 'min_samples_leaf': 10}
# AUC for params: 0.8649908299466912
# Testing params: {'n_estimators': 52, 'max_depth': 47, 'min_samples_split': 12, 'min_samples_leaf': 8}
# AUC for params: 0.8579529447191664
# Testing params: {'n_estimators': 52, 'max_depth': 13, 'min_samples_split': 6, 'min_samples_leaf': 14}
# AUC for params: 0.8581614802164234
# Best parameters found:  {'n_estimators': 120, 'max_depth': 43, 'min_samples_split': 14, 'min_samples_leaf': 10}
# Best average AUC across validation sets:  0.8649908299466912
# Test AUC: 0.563209541062802
# Iteration 1: norm_delta = 6.78e+00, step_size = 0.9500, log_lik = -8744.90665, newton_decrement = 1.05e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.34e+00, step_size = 0.2375, log_lik = -8308.97891, newton_decrement = 5.40e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.98e+00, step_size = 0.0772, log_lik = -8228.81840, newton_decrement = 4.57e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.41e+00, step_size = 0.1304, log_lik = -8117.27444, newton_decrement = 3.44e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.54e+00, step_size = 0.2205, log_lik = -7982.34121, newton_decrement = 2.09e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.33e+00, step_size = 0.3726, log_lik = -7855.62476, newton_decrement = 8.37e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.35e-01, step_size = 0.6296, log_lik = -7783.18082, newton_decrement = 1.25e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.36e-02, step_size = 1.0000, log_lik = -7770.58545, newton_decrement = 1.48e-02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.98e-04, step_size = 1.0000, log_lik = -7770.57061, newton_decrement = 5.61e-07, seconds_since_start = 0.9
# Iteration 10: norm_delta = 2.03e-08, step_size = 1.0000, log_lik = -7770.57061, newton_decrement = 5.95e-15, seconds_since_start = 1.0
# Convergence success after 10 iterations.
# Iteration 1: norm_delta = 6.91e+00, step_size = 0.9500, log_lik = -8829.99117, newton_decrement = 1.03e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.49e+00, step_size = 0.2375, log_lik = -8401.89543, newton_decrement = 5.40e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.12e+00, step_size = 0.0772, log_lik = -8321.76402, newton_decrement = 4.57e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.98e+00, step_size = 0.0326, log_lik = -8292.46045, newton_decrement = 4.27e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.74e+00, step_size = 0.0551, log_lik = -8246.73209, newton_decrement = 3.80e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.35e+00, step_size = 0.0931, log_lik = -8179.27715, newton_decrement = 3.11e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 3.74e+00, step_size = 0.1574, log_lik = -8089.03157, newton_decrement = 2.20e+02, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.84e+00, step_size = 0.2660, log_lik = -7987.50972, newton_decrement = 1.19e+02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.64e+00, step_size = 0.4496, log_lik = -7904.72913, newton_decrement = 3.67e+01, seconds_since_start = 0.9
# Iteration 10: norm_delta = 4.31e-01, step_size = 0.7598, log_lik = -7869.97407, newton_decrement = 2.38e+00, seconds_since_start = 1.0
# Iteration 11: norm_delta = 3.72e-03, step_size = 1.0000, log_lik = -7867.58184, newton_decrement = 6.03e-04, seconds_since_start = 1.1
# Iteration 12: norm_delta = 4.48e-06, step_size = 1.0000, log_lik = -7867.58124, newton_decrement = 9.98e-10, seconds_since_start = 1.2
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.81e+00, step_size = 0.9500, log_lik = -8805.41001, newton_decrement = 1.00e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.41e+00, step_size = 0.2375, log_lik = -8387.20603, newton_decrement = 5.30e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.05e+00, step_size = 0.0772, log_lik = -8308.58315, newton_decrement = 4.49e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.91e+00, step_size = 0.0326, log_lik = -8279.79414, newton_decrement = 4.19e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.67e+00, step_size = 0.0551, log_lik = -8234.84527, newton_decrement = 3.74e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.29e+00, step_size = 0.0931, log_lik = -8168.47973, newton_decrement = 3.07e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 3.70e+00, step_size = 0.1574, log_lik = -8079.54531, newton_decrement = 2.18e+02, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.81e+00, step_size = 0.2660, log_lik = -7979.17356, newton_decrement = 1.18e+02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.63e+00, step_size = 0.4496, log_lik = -7896.76361, newton_decrement = 3.69e+01, seconds_since_start = 0.9
# Iteration 10: norm_delta = 4.32e-01, step_size = 0.7598, log_lik = -7861.78115, newton_decrement = 2.44e+00, seconds_since_start = 1.0
# Iteration 11: norm_delta = 4.89e-03, step_size = 1.0000, log_lik = -7859.32078, newton_decrement = 6.76e-04, seconds_since_start = 1.1
# Iteration 12: norm_delta = 5.26e-06, step_size = 1.0000, log_lik = -7859.32010, newton_decrement = 6.74e-10, seconds_since_start = 1.2
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.99e+00, step_size = 0.9500, log_lik = -9037.41005, newton_decrement = 1.01e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.54e+00, step_size = 0.2375, log_lik = -8616.86600, newton_decrement = 5.38e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.18e+00, step_size = 0.0772, log_lik = -8537.00495, newton_decrement = 4.57e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 5.03e+00, step_size = 0.0326, log_lik = -8507.68293, newton_decrement = 4.28e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.97e+00, step_size = 0.0138, log_lik = -8495.98203, newton_decrement = 4.16e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.87e+00, step_size = 0.0233, log_lik = -8476.84150, newton_decrement = 3.97e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 4.71e+00, step_size = 0.0394, log_lik = -8446.23415, newton_decrement = 3.66e+02, seconds_since_start = 0.7
# Iteration 8: norm_delta = 4.43e+00, step_size = 0.0665, log_lik = -8399.15396, newton_decrement = 3.19e+02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 3.99e+00, step_size = 0.1124, log_lik = -8331.42359, newton_decrement = 2.52e+02, seconds_since_start = 0.8
# Iteration 10: norm_delta = 3.31e+00, step_size = 0.1899, log_lik = -8244.76510, newton_decrement = 1.66e+02, seconds_since_start = 1.0
# Iteration 11: norm_delta = 2.33e+00, step_size = 0.3210, log_lik = -8155.04391, newton_decrement = 7.80e+01, seconds_since_start = 1.1
# Iteration 12: norm_delta = 1.13e+00, step_size = 0.5425, log_lik = -8093.19067, newton_decrement = 1.72e+01, seconds_since_start = 1.1
# Iteration 13: norm_delta = 1.14e-01, step_size = 0.9168, log_lik = -8075.93126, newton_decrement = 1.93e-01, seconds_since_start = 1.2
# Iteration 14: norm_delta = 1.44e-03, step_size = 1.0000, log_lik = -8075.73654, newton_decrement = 2.26e-04, seconds_since_start = 1.3
# Iteration 15: norm_delta = 8.77e-05, step_size = 1.0000, log_lik = -8075.73631, newton_decrement = 6.95e-07, seconds_since_start = 1.5
# Iteration 16: norm_delta = 3.00e-07, step_size = 1.0000, log_lik = -8075.73631, newton_decrement = 8.07e-12, seconds_since_start = 1.5
# Convergence success after 16 iterations.
# Iteration 1: norm_delta = 6.80e+00, step_size = 0.9500, log_lik = -8886.68689, newton_decrement = 1.03e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.42e+00, step_size = 0.2375, log_lik = -8459.44200, newton_decrement = 5.41e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.06e+00, step_size = 0.0772, log_lik = -8379.22428, newton_decrement = 4.59e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.92e+00, step_size = 0.0326, log_lik = -8349.79478, newton_decrement = 4.29e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.69e+00, step_size = 0.0551, log_lik = -8303.80908, newton_decrement = 3.83e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.31e+00, step_size = 0.0931, log_lik = -8235.82005, newton_decrement = 3.15e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 3.72e+00, step_size = 0.1574, log_lik = -8144.50694, newton_decrement = 2.24e+02, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.82e+00, step_size = 0.2660, log_lik = -8041.13139, newton_decrement = 1.22e+02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.64e+00, step_size = 0.4496, log_lik = -7956.04849, newton_decrement = 3.82e+01, seconds_since_start = 0.9
# Iteration 10: norm_delta = 4.29e-01, step_size = 0.7598, log_lik = -7919.89339, newton_decrement = 2.53e+00, seconds_since_start = 1.0
# Iteration 11: norm_delta = 3.52e-03, step_size = 1.0000, log_lik = -7917.34861, newton_decrement = 7.44e-04, seconds_since_start = 1.1
# Iteration 12: norm_delta = 2.13e-06, step_size = 1.0000, log_lik = -7917.34787, newton_decrement = 5.47e-10, seconds_since_start = 1.2
# Convergence success after 12 iterations.
# Average C-Index from cross-validation: 0.8866
# Best C-Index from cross-validation: 0.8963
# Standard Deviation of C-Index from cross-validation: 0.0103
#                                      coef  exp(coef)      se(coef)  \
# covariate
# subject_id                  -1.715959e-08   1.000000  1.011482e-08
# gender                       1.118414e-01   1.118335  6.719775e-02
# anchor_age                   3.617506e-01   1.435841  1.466195e-02
# disch_age                   -3.650286e-01   0.694177  1.460889e-02
# CKD_stage_first             -1.018894e+00   0.360994  4.751667e-02
# ...                                   ...        ...           ...
# Uric_Acid_mean              -1.015288e-01   0.903455  1.191531e-01
# Uric_Acid_median             1.685208e-01   1.183553  1.062630e-01
# Hemoglobin_min_y            -2.621345e-02   0.974127  2.317026e-02
# White_Blood_Cells_min       -2.624581e-02   0.974096  1.658994e-02
# Urea_Nitrogen,_Urine_median  6.509189e-04   1.000651  9.337019e-04
#
#                              coef lower 95%  coef upper 95%  \
# covariate
# subject_id                    -3.698427e-08    2.665091e-09
# gender                        -1.986378e-02    2.435466e-01
# anchor_age                     3.330137e-01    3.904875e-01
# disch_age                     -3.936615e-01   -3.363958e-01
# CKD_stage_first               -1.112025e+00   -9.257635e-01
# ...                                     ...             ...
# Uric_Acid_mean                -3.350647e-01    1.320071e-01
# Uric_Acid_median              -3.975082e-02    3.767924e-01
# Hemoglobin_min_y              -7.162632e-02    1.919943e-02
# White_Blood_Cells_min         -5.876150e-02    6.269877e-03
# Urea_Nitrogen,_Urine_median   -1.179103e-03    2.480941e-03
#
#                              exp(coef) lower 95%  exp(coef) upper 95%  cmp to  \
# covariate
# subject_id                              1.000000             1.000000     0.0
# gender                                  0.980332             1.275766     0.0
# anchor_age                              1.395166             1.477701     0.0
# disch_age                               0.674582             0.714340     0.0
# CKD_stage_first                         0.328892             0.396229     0.0
# ...                                          ...                  ...     ...
# Uric_Acid_mean                          0.715292             1.141116     0.0
# Uric_Acid_median                        0.961029             1.457602     0.0
# Hemoglobin_min_y                        0.930879             1.019385     0.0
# White_Blood_Cells_min                   0.942932             1.006290     0.0
# Urea_Nitrogen,_Urine_median             0.998822             1.002484     0.0
#
#                                      z              p    -log2(p)
# covariate
# subject_id                   -1.696480   8.979499e-02    3.477221
# gender                        1.664362   9.604009e-02    3.380219
# anchor_age                   24.672744  2.098323e-134  444.069128
# disch_age                   -24.986755  8.516916e-138  455.335746
# CKD_stage_first             -21.442886  5.320978e-102  336.424974
# ...                                ...            ...         ...
# Uric_Acid_mean               -0.852087   3.941660e-01    1.343125
# Uric_Acid_median              1.585884   1.127655e-01    3.148602
# Hemoglobin_min_y             -1.131340   2.579119e-01    1.955050
# White_Blood_Cells_min        -1.582032   1.136424e-01    3.137427
# Urea_Nitrogen,_Urine_median   0.697138   4.857165e-01    1.041813
#
# [82 rows x 11 columns]
#                                    test_statistic         p  -log2(p)
# Acute kidney failure, unspecified        0.473965  0.491169  1.025710
# Albumin/Creatinine,_Urine_first          0.259004  0.610805  0.711215
# Albumin/Creatinine,_Urine_last           0.016816  0.896821  0.157108
# Albumin/Creatinine,_Urine_max            0.003636  0.951915  0.071095
# Albumin/Creatinine,_Urine_mean           0.213354  0.644151  0.634529
# ...                                           ...       ...       ...
# eGFR_median                              0.029581  0.863444  0.211826
# eGFR_min                                 0.063944  0.800367  0.321266
# first_stage_icd                          4.371457  0.036546  4.774153
# gender                                   2.539939  0.110999  3.171380
# subject_id                               0.668693  0.413508  1.274014
#
# [82 rows x 3 columns]
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sksurv\metrics.py:482: RuntimeWarning: invalid value encountered in divide
#   true_pos = cumsum_tp / cumsum_tp[-1]
