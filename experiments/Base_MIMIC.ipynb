# %%
import sys
import os

# Use os.getcwd() to get the current working directory in a Jupyter notebook
parent_dir = os.path.dirname(os.getcwd())  # Get the parent directory of the current working directory
sys.path.append(parent_dir)

# %%
import pandas as pd
from skopt.space import Real, Integer
from driver import Driver

# %% [markdown]
# # Load Cleaned Master MIMIC-IV Dataset

# %%
# Cleaned Master MIMIC Data Set
# df_master = pd.read_pickle('../MIMIC_IV/df_ckd_master_clean.pkl')
df_base = pd.read_pickle('../MIMIC_IV/df_ckd_base.pkl')

# %% [markdown]
# # Evaluate Base Pipeline with only KFRE Features

# %%
Base_cfg = {
    'name': 'Base', # Feature selection model long name
    'tag': 'base', # Feature selection model identifier tag
    'response': 'stage_delta',  # Response variable for binary classification and Cox Proportional Hazards
    'duration': 'duration', # Duration in days until response or censorship
    'n_folds': 5, # Number of folds for CoxPH cross validation
    'penalizer': 0.0007, # CoxPH model penalizer
    'seeds': [42, 73, 128, 256, 512] # Seeds for reproducibility
}

driver = Driver(Base_cfg, base=df_base)
driver.VanillaPipe()
# Out:
# Iteration 1: norm_delta = 6.82e+00, step_size = 0.9500, log_lik = -8744.90665, newton_decrement = 7.83e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.45e+00, step_size = 0.2375, log_lik = -8416.80544, newton_decrement = 4.74e+02, seconds_since_start = 0.1
# Iteration 3: norm_delta = 5.09e+00, step_size = 0.0772, log_lik = -8346.46332, newton_decrement = 4.10e+02, seconds_since_start = 0.2
# Iteration 4: norm_delta = 4.94e+00, step_size = 0.0326, log_lik = -8320.17879, newton_decrement = 3.86e+02, seconds_since_start = 0.3
# Iteration 5: norm_delta = 4.71e+00, step_size = 0.0551, log_lik = -8278.85136, newton_decrement = 3.47e+02, seconds_since_start = 0.4
# Iteration 6: norm_delta = 4.32e+00, step_size = 0.0931, log_lik = -8217.16569, newton_decrement = 2.89e+02, seconds_since_start = 0.4
# Iteration 7: norm_delta = 3.72e+00, step_size = 0.1574, log_lik = -8133.21546, newton_decrement = 2.09e+02, seconds_since_start = 0.5
# Iteration 8: norm_delta = 2.81e+00, step_size = 0.2660, log_lik = -8036.78644, newton_decrement = 1.14e+02, seconds_since_start = 0.6
# Iteration 9: norm_delta = 1.61e+00, step_size = 0.4496, log_lik = -7957.00033, newton_decrement = 3.50e+01, seconds_since_start = 0.7
# Iteration 10: norm_delta = 4.15e-01, step_size = 0.7598, log_lik = -7924.06631, newton_decrement = 2.04e+00, seconds_since_start = 0.7
# Iteration 11: norm_delta = 2.11e-03, step_size = 1.0000, log_lik = -7922.02346, newton_decrement = 1.31e-04, seconds_since_start = 0.8
# Iteration 12: norm_delta = 1.32e-07, step_size = 1.0000, log_lik = -7922.02333, newton_decrement = 4.09e-12, seconds_since_start = 0.9
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.95e+00, step_size = 0.9500, log_lik = -8829.99117, newton_decrement = 7.88e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.56e+00, step_size = 0.2375, log_lik = -8499.73312, newton_decrement = 4.75e+02, seconds_since_start = 0.1
# Iteration 3: norm_delta = 5.20e+00, step_size = 0.0772, log_lik = -8429.22945, newton_decrement = 4.09e+02, seconds_since_start = 0.2
# Iteration 4: norm_delta = 5.05e+00, step_size = 0.0326, log_lik = -8402.97693, newton_decrement = 3.85e+02, seconds_since_start = 0.3
# Iteration 5: norm_delta = 4.99e+00, step_size = 0.0138, log_lik = -8392.45383, newton_decrement = 3.75e+02, seconds_since_start = 0.4
# Iteration 6: norm_delta = 4.89e+00, step_size = 0.0233, log_lik = -8375.21091, newton_decrement = 3.58e+02, seconds_since_start = 0.4
# Iteration 7: norm_delta = 4.72e+00, step_size = 0.0394, log_lik = -8347.56339, newton_decrement = 3.32e+02, seconds_since_start = 0.5
# Iteration 8: norm_delta = 4.45e+00, step_size = 0.0665, log_lik = -8304.85935, newton_decrement = 2.91e+02, seconds_since_start = 0.6
# Iteration 9: norm_delta = 4.01e+00, step_size = 0.1124, log_lik = -8243.06609, newton_decrement = 2.31e+02, seconds_since_start = 0.7
# Iteration 10: norm_delta = 3.32e+00, step_size = 0.1899, log_lik = -8163.48125, newton_decrement = 1.53e+02, seconds_since_start = 0.7
# Iteration 11: norm_delta = 2.33e+00, step_size = 0.3210, log_lik = -8080.84669, newton_decrement = 7.11e+01, seconds_since_start = 0.8
# Iteration 12: norm_delta = 1.12e+00, step_size = 0.5425, log_lik = -8024.64238, newton_decrement = 1.49e+01, seconds_since_start = 0.9
# Iteration 13: norm_delta = 1.06e-01, step_size = 0.9168, log_lik = -8009.85632, newton_decrement = 1.11e-01, seconds_since_start = 1.0
# Iteration 14: norm_delta = 1.23e-04, step_size = 1.0000, log_lik = -8009.74535, newton_decrement = 2.64e-07, seconds_since_start = 1.1
# Iteration 15: norm_delta = 2.49e-10, step_size = 1.0000, log_lik = -8009.74535, newton_decrement = 1.32e-17, seconds_since_start = 1.1
# Convergence success after 15 iterations.
# Iteration 1: norm_delta = 6.86e+00, step_size = 0.9500, log_lik = -8805.41001, newton_decrement = 7.92e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.48e+00, step_size = 0.2375, log_lik = -8473.55237, newton_decrement = 4.76e+02, seconds_since_start = 0.1
# Iteration 3: norm_delta = 5.12e+00, step_size = 0.0772, log_lik = -8402.82678, newton_decrement = 4.10e+02, seconds_since_start = 0.2
# Iteration 4: norm_delta = 4.97e+00, step_size = 0.0326, log_lik = -8376.53933, newton_decrement = 3.85e+02, seconds_since_start = 0.3
# Iteration 5: norm_delta = 4.74e+00, step_size = 0.0551, log_lik = -8335.29679, newton_decrement = 3.45e+02, seconds_since_start = 0.4
# Iteration 6: norm_delta = 4.35e+00, step_size = 0.0931, log_lik = -8273.96208, newton_decrement = 2.86e+02, seconds_since_start = 0.4
# Iteration 7: norm_delta = 3.74e+00, step_size = 0.1574, log_lik = -8190.98779, newton_decrement = 2.05e+02, seconds_since_start = 0.5
# Iteration 8: norm_delta = 2.83e+00, step_size = 0.2660, log_lik = -8096.54480, newton_decrement = 1.11e+02, seconds_since_start = 0.6
# Iteration 9: norm_delta = 1.62e+00, step_size = 0.4496, log_lik = -8019.29712, newton_decrement = 3.35e+01, seconds_since_start = 0.7
# Iteration 10: norm_delta = 4.19e-01, step_size = 0.7598, log_lik = -7987.71548, newton_decrement = 1.95e+00, seconds_since_start = 0.7
# Iteration 11: norm_delta = 2.07e-03, step_size = 1.0000, log_lik = -7985.76277, newton_decrement = 1.19e-04, seconds_since_start = 0.8
# Iteration 12: norm_delta = 1.12e-07, step_size = 1.0000, log_lik = -7985.76265, newton_decrement = 3.59e-12, seconds_since_start = 0.9
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.99e+00, step_size = 0.9500, log_lik = -9037.41005, newton_decrement = 7.81e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.59e+00, step_size = 0.2375, log_lik = -8710.01297, newton_decrement = 4.78e+02, seconds_since_start = 0.1
# Iteration 3: norm_delta = 5.22e+00, step_size = 0.0772, log_lik = -8639.12038, newton_decrement = 4.13e+02, seconds_since_start = 0.2
# Iteration 4: norm_delta = 5.08e+00, step_size = 0.0326, log_lik = -8612.63701, newton_decrement = 3.88e+02, seconds_since_start = 0.3
# Iteration 5: norm_delta = 5.02e+00, step_size = 0.0138, log_lik = -8602.00776, newton_decrement = 3.79e+02, seconds_since_start = 0.4
# Iteration 6: norm_delta = 4.99e+00, step_size = 0.0058, log_lik = -8597.61282, newton_decrement = 3.75e+02, seconds_since_start = 0.4
# Iteration 7: norm_delta = 4.95e+00, step_size = 0.0098, log_lik = -8590.27983, newton_decrement = 3.68e+02, seconds_since_start = 0.5
# Iteration 8: norm_delta = 4.88e+00, step_size = 0.0166, log_lik = -8578.15310, newton_decrement = 3.56e+02, seconds_since_start = 0.6
# Iteration 9: norm_delta = 4.76e+00, step_size = 0.0281, log_lik = -8558.40059, newton_decrement = 3.38e+02, seconds_since_start = 0.7
# Iteration 10: norm_delta = 4.57e+00, step_size = 0.0475, log_lik = -8527.05195, newton_decrement = 3.09e+02, seconds_since_start = 0.7
# Iteration 11: norm_delta = 4.24e+00, step_size = 0.0803, log_lik = -8479.48567, newton_decrement = 2.64e+02, seconds_since_start = 0.8
# Iteration 12: norm_delta = 3.73e+00, step_size = 0.1356, log_lik = -8412.79354, newton_decrement = 2.00e+02, seconds_since_start = 0.9
# Iteration 13: norm_delta = 2.95e+00, step_size = 0.2292, log_lik = -8331.70677, newton_decrement = 1.21e+02, seconds_since_start = 0.9
# Iteration 14: norm_delta = 1.88e+00, step_size = 0.3874, log_lik = -8256.32052, newton_decrement = 4.61e+01, seconds_since_start = 1.0
# Iteration 15: norm_delta = 6.84e-01, step_size = 0.6546, log_lik = -8215.70818, newton_decrement = 5.65e+00, seconds_since_start = 1.1
# Iteration 16: norm_delta = 5.53e-03, step_size = 1.0000, log_lik = -8210.04936, newton_decrement = 1.03e-03, seconds_since_start = 1.2
# Iteration 17: norm_delta = 1.07e-06, step_size = 1.0000, log_lik = -8210.04833, newton_decrement = 3.46e-10, seconds_since_start = 1.2
# Convergence success after 17 iterations.
# Iteration 1: norm_delta = 6.87e+00, step_size = 0.9500, log_lik = -8886.68689, newton_decrement = 7.97e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.51e+00, step_size = 0.2375, log_lik = -8552.66922, newton_decrement = 4.86e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.15e+00, step_size = 0.0772, log_lik = -8480.56448, newton_decrement = 4.20e+02, seconds_since_start = 0.2
# Iteration 4: norm_delta = 5.01e+00, step_size = 0.0326, log_lik = -8453.62428, newton_decrement = 3.95e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.95e+00, step_size = 0.0138, log_lik = -8442.81085, newton_decrement = 3.85e+02, seconds_since_start = 0.4
# Iteration 6: norm_delta = 4.85e+00, step_size = 0.0233, log_lik = -8425.08227, newton_decrement = 3.69e+02, seconds_since_start = 0.5
# Iteration 7: norm_delta = 4.69e+00, step_size = 0.0394, log_lik = -8396.62931, newton_decrement = 3.42e+02, seconds_since_start = 0.6
# Iteration 8: norm_delta = 4.42e+00, step_size = 0.0665, log_lik = -8352.61211, newton_decrement = 3.01e+02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 3.98e+00, step_size = 0.1124, log_lik = -8288.75412, newton_decrement = 2.40e+02, seconds_since_start = 0.7
# Iteration 10: norm_delta = 3.30e+00, step_size = 0.1899, log_lik = -8206.17371, newton_decrement = 1.60e+02, seconds_since_start = 0.8
# Iteration 11: norm_delta = 2.32e+00, step_size = 0.3210, log_lik = -8119.91470, newton_decrement = 7.48e+01, seconds_since_start = 0.9
# Iteration 12: norm_delta = 1.11e+00, step_size = 0.5425, log_lik = -8060.78317, newton_decrement = 1.58e+01, seconds_since_start = 1.0
# Iteration 13: norm_delta = 1.07e-01, step_size = 0.9168, log_lik = -8045.06330, newton_decrement = 1.24e-01, seconds_since_start = 1.0
# Iteration 14: norm_delta = 1.36e-04, step_size = 1.0000, log_lik = -8044.93914, newton_decrement = 8.41e-07, seconds_since_start = 1.1
# Iteration 15: norm_delta = 1.39e-09, step_size = 1.0000, log_lik = -8044.93913, newton_decrement = 5.56e-16, seconds_since_start = 1.2
# Convergence success after 15 iterations.
# Average C-Index from cross-validation: 0.8820
# Best C-Index from cross-validation: 0.8910
# Standard Deviation of C-Index from cross-validation: 0.0082
#                                           coef  exp(coef)      se(coef)  \
# covariate
# subject_id                       -8.090656e-09   1.000000  1.017885e-08
# gender                            2.907521e-01   1.337433  6.203948e-02
# anchor_age                        3.553315e-01   1.426653  1.462906e-02
# disch_age                        -3.601627e-01   0.697563  1.461645e-02
# CKD_stage_first                  -9.386850e-01   0.391142  4.218277e-02
# eGFR_first                       -2.833517e-02   0.972063  1.392297e-02
# eGFR_last                         3.507608e-02   1.035699  1.413908e-02
# eGFR_min                          8.858645e-05   1.000089  1.364165e-02
# eGFR_max                         -4.995305e-04   0.999501  1.387050e-02
# eGFR_mean                        -1.988669e-02   0.980310  1.382950e-02
# eGFR_median                      -2.637378e-02   0.973971  1.386341e-02
# Albumin/Creatinine,_Urine_first   9.945087e-05   1.000099  1.149266e-04
# Albumin/Creatinine,_Urine_last    1.206949e-04   1.000121  1.169183e-04
# Albumin/Creatinine,_Urine_min    -1.386818e-04   0.999861  1.654758e-04
# Albumin/Creatinine,_Urine_max    -4.827107e-05   0.999952  1.315294e-04
# Albumin/Creatinine,_Urine_mean    1.443892e-04   1.000144  3.450060e-04
# Albumin/Creatinine,_Urine_median -8.916099e-05   0.999911  2.148689e-04
# Bicarbonate_first                 1.152142e-02   1.011588  8.938556e-03
# Bicarbonate_last                  1.921218e-02   1.019398  8.502826e-03
# Bicarbonate_min                  -1.449362e-02   0.985611  1.814527e-02
# Bicarbonate_max                   2.665611e-02   1.027015  1.533262e-02
# Bicarbonate_mean                 -5.391797e-02   0.947510  5.742768e-02
# Bicarbonate_median               -3.840929e-02   0.962319  4.393000e-02
# Albumin_first                     4.134233e-02   1.042209  7.847869e-02
# Albumin_last                     -7.563768e-02   0.927152  7.312636e-02
# Albumin_min                       1.692734e-01   1.184444  1.251496e-01
# Albumin_max                      -8.418229e-02   0.919264  1.309278e-01
# Albumin_mean                     -5.806178e-01   0.559553  3.986890e-01
# Albumin_median                    1.108995e-01   1.117283  2.543535e-01
# Phosphate_first                  -2.296886e-03   0.997706  3.004777e-02
# Phosphate_last                    5.115003e-03   1.005128  2.441554e-02
# Phosphate_min                    -1.985656e-01   0.819906  6.637704e-02
# Phosphate_max                    -7.655346e-03   0.992374  2.675315e-02
# Phosphate_mean                    7.669682e-01   2.153228  1.659177e-01
# Phosphate_median                 -2.068052e-01   0.813178  1.218970e-01
# Calcium,_Total_first              7.627141e-03   1.007656  4.994210e-02
# Calcium,_Total_last              -4.287974e-02   0.958027  5.336195e-02
# Calcium,_Total_min                1.094264e-01   1.115638  7.494147e-02
# Calcium,_Total_max               -2.595010e-02   0.974384  6.057007e-02
# Calcium,_Total_mean               1.194779e-01   1.126908  2.950854e-01
# Calcium,_Total_median            -2.903741e-02   0.971380  2.344420e-01
#
#                                   coef lower 95%  coef upper 95%  \
# covariate
# subject_id                         -2.804084e-08    1.185953e-08
# gender                              1.691569e-01    4.123472e-01
# anchor_age                          3.266590e-01    3.840039e-01
# disch_age                          -3.888104e-01   -3.315150e-01
# CKD_stage_first                    -1.021362e+00   -8.560083e-01
# eGFR_first                         -5.562369e-02   -1.046648e-03
# eGFR_last                           7.363992e-03    6.278818e-02
# eGFR_min                           -2.664856e-02    2.682573e-02
# eGFR_max                           -2.768522e-02    2.668616e-02
# eGFR_mean                          -4.699202e-02    7.218639e-03
# eGFR_median                        -5.354557e-02    7.980061e-04
# Albumin/Creatinine,_Urine_first    -1.258012e-04    3.247029e-04
# Albumin/Creatinine,_Urine_last     -1.084608e-04    3.498506e-04
# Albumin/Creatinine,_Urine_min      -4.630084e-04    1.856448e-04
# Albumin/Creatinine,_Urine_max      -3.060640e-04    2.095219e-04
# Albumin/Creatinine,_Urine_mean     -5.318101e-04    8.205885e-04
# Albumin/Creatinine,_Urine_median   -5.102962e-04    3.319742e-04
# Bicarbonate_first                  -5.997827e-03    2.904067e-02
# Bicarbonate_last                    2.546951e-03    3.587742e-02
# Bicarbonate_min                    -5.005770e-02    2.107046e-02
# Bicarbonate_max                    -3.395277e-03    5.670749e-02
# Bicarbonate_mean                   -1.664742e-01    5.863821e-02
# Bicarbonate_median                 -1.245105e-01    4.769192e-02
# Albumin_first                      -1.124731e-01    1.951577e-01
# Albumin_last                       -2.189627e-01    6.768734e-02
# Albumin_min                        -7.601521e-02    4.145620e-01
# Albumin_max                        -3.407962e-01    1.724316e-01
# Albumin_mean                       -1.362034e+00    2.007982e-01
# Albumin_median                     -3.876241e-01    6.094231e-01
# Phosphate_first                    -6.118944e-02    5.659567e-02
# Phosphate_last                     -4.273857e-02    5.296858e-02
# Phosphate_min                      -3.286622e-01   -6.846896e-02
# Phosphate_max                      -6.009055e-02    4.477986e-02
# Phosphate_mean                      4.417756e-01    1.092161e+00
# Phosphate_median                   -4.457189e-01    3.210856e-02
# Calcium,_Total_first               -9.025757e-02    1.055119e-01
# Calcium,_Total_last                -1.474672e-01    6.170775e-02
# Calcium,_Total_min                 -3.745618e-02    2.563090e-01
# Calcium,_Total_max                 -1.446652e-01    9.276505e-02
# Calcium,_Total_mean                -4.588787e-01    6.978346e-01
# Calcium,_Total_median              -4.885353e-01    4.304604e-01
#
#                                   exp(coef) lower 95%  exp(coef) upper 95%  \
# covariate
# subject_id                                   1.000000             1.000000
# gender                                       1.184306             1.510359
# anchor_age                                   1.386329             1.468151
# disch_age                                    0.677863             0.717835
# CKD_stage_first                              0.360104             0.424855
# eGFR_first                                   0.945895             0.998954
# eGFR_last                                    1.007391             1.064801
# eGFR_min                                     0.973703             1.027189
# eGFR_max                                     0.972695             1.027045
# eGFR_mean                                    0.954095             1.007245
# eGFR_median                                  0.947863             1.000798
# Albumin/Creatinine,_Urine_first              0.999874             1.000325
# Albumin/Creatinine,_Urine_last               0.999892             1.000350
# Albumin/Creatinine,_Urine_min                0.999537             1.000186
# Albumin/Creatinine,_Urine_max                0.999694             1.000210
# Albumin/Creatinine,_Urine_mean               0.999468             1.000821
# Albumin/Creatinine,_Urine_median             0.999490             1.000332
# Bicarbonate_first                            0.994020             1.029466
# Bicarbonate_last                             1.002550             1.036529
# Bicarbonate_min                              0.951175             1.021294
# Bicarbonate_max                              0.996610             1.058346
# Bicarbonate_mean                             0.846645             1.060392
# Bicarbonate_median                           0.882929             1.048847
# Albumin_first                                0.893621             1.215503
# Albumin_last                                 0.803352             1.070031
# Albumin_min                                  0.926802             1.513708
# Albumin_max                                  0.711204             1.188191
# Albumin_mean                                 0.256139             1.222378
# Albumin_median                               0.678667             1.839370
# Phosphate_first                              0.940645             1.058228
# Phosphate_last                               0.958162             1.054397
# Phosphate_min                                0.719886             0.933822
# Phosphate_max                                0.941679             1.045798
# Phosphate_mean                               1.555467             2.980708
# Phosphate_median                             0.640364             1.032630
# Calcium,_Total_first                         0.913696             1.111279
# Calcium,_Total_last                          0.862891             1.063651
# Calcium,_Total_min                           0.963237             1.292152
# Calcium,_Total_max                           0.865312             1.097204
# Calcium,_Total_mean                          0.631992             2.009397
# Calcium,_Total_median                        0.613524             1.537965
#
#                                   cmp to          z              p    -log2(p)
# covariate
# subject_id                           0.0  -0.794849   4.267011e-01    1.228702
# gender                               0.0   4.686565   2.778282e-06   18.457376
# anchor_age                           0.0  24.289431  2.535320e-130  430.508484
# disch_age                            0.0 -24.640908  4.606181e-134  442.934794
# CKD_stage_first                      0.0 -22.252804  1.059560e-109  362.006696
# eGFR_first                           0.0  -2.035138   4.183697e-02    4.579078
# eGFR_last                            0.0   2.480789   1.310918e-02    6.253278
# eGFR_min                             0.0   0.006494   9.948187e-01    0.007494
# eGFR_max                             0.0  -0.036014   9.712713e-01    0.042054
# eGFR_mean                            0.0  -1.437990   1.504368e-01    2.732770
# eGFR_median                          0.0  -1.902402   5.711862e-02    4.129895
# Albumin/Creatinine,_Urine_first      0.0   0.865342   3.868509e-01    1.370151
# Albumin/Creatinine,_Urine_last       0.0   1.032301   3.019312e-01    1.727708
# Albumin/Creatinine,_Urine_min        0.0  -0.838079   4.019863e-01    1.314782
# Albumin/Creatinine,_Urine_max        0.0  -0.366998   7.136203e-01    0.486771
# Albumin/Creatinine,_Urine_mean       0.0   0.418512   6.755726e-01    0.565817
# Albumin/Creatinine,_Urine_median     0.0  -0.414955   6.781746e-01    0.560271
# Bicarbonate_first                    0.0   1.288958   1.974128e-01    2.340713
# Bicarbonate_last                     0.0   2.259506   2.385195e-02    5.389749
# Bicarbonate_min                      0.0  -0.798755   4.244327e-01    1.236392
# Bicarbonate_max                      0.0   1.738523   8.211878e-02    3.606144
# Bicarbonate_mean                     0.0  -0.938885   3.477899e-01    1.523712
# Bicarbonate_median                   0.0  -0.874330   3.819388e-01    1.388587
# Albumin_first                        0.0   0.526797   5.983347e-01    0.740975
# Albumin_last                         0.0  -1.034342   3.009762e-01    1.732279
# Albumin_min                          0.0   1.352569   1.761934e-01    2.504769
# Albumin_max                          0.0  -0.642967   5.202455e-01    0.942736
# Albumin_mean                         0.0  -1.456318   1.453048e-01    2.782846
# Albumin_median                       0.0   0.436005   6.628328e-01    0.593283
# Phosphate_first                      0.0  -0.076441   9.390681e-01    0.090698
# Phosphate_last                       0.0   0.209498   8.340596e-01    0.261778
# Phosphate_min                        0.0  -2.991480   2.776290e-03    8.492626
# Phosphate_max                        0.0  -0.286148   7.747652e-01    0.368169
# Phosphate_mean                       0.0   4.622583   3.789904e-06   18.009407
# Phosphate_median                     0.0  -1.696557   8.978050e-02    3.477454
# Calcium,_Total_first                 0.0   0.152720   8.786194e-01    0.186690
# Calcium,_Total_last                  0.0  -0.803564   4.216488e-01    1.245886
# Calcium,_Total_min                   0.0   1.460158   1.442466e-01    2.793391
# Calcium,_Total_max                   0.0  -0.428431   6.683373e-01    0.581352
# Calcium,_Total_mean                  0.0   0.404893   6.855563e-01    0.544653
# Calcium,_Total_median                0.0  -0.123858   9.014280e-01    0.149716
#                                   test_statistic         p   -log2(p)
# Albumin/Creatinine,_Urine_first         0.125894  0.722728   0.468476
# Albumin/Creatinine,_Urine_last          0.023656  0.877764   0.188095
# Albumin/Creatinine,_Urine_max           0.060651  0.805470   0.312098
# Albumin/Creatinine,_Urine_mean          0.034242  0.853194   0.229055
# Albumin/Creatinine,_Urine_median        0.072010  0.788433   0.342940
# Albumin/Creatinine,_Urine_min           0.006045  0.938025   0.092302
# Albumin_first                           1.280998  0.257714   1.956160
# Albumin_last                            0.861189  0.353406   1.500600
# Albumin_max                             0.448299  0.503144   0.990957
# Albumin_mean                            0.508704  0.475701   1.071874
# Albumin_median                          0.085327  0.770205   0.376686
# Albumin_min                             2.008573  0.156412   2.676573
# Bicarbonate_first                       0.720099  0.396112   1.336021
# Bicarbonate_last                        1.327154  0.249312   2.003975
# Bicarbonate_max                         0.566168  0.451786   1.146289
# Bicarbonate_mean                        0.099058  0.752963   0.409349
# Bicarbonate_median                      0.277394  0.598414   0.740784
# Bicarbonate_min                         0.000927  0.975714   0.035470
# CKD_stage_first                        13.525981  0.000235  12.053313
# Calcium,_Total_first                    2.589325  0.107586   3.216435
# Calcium,_Total_last                     2.490662  0.114524   3.126284
# Calcium,_Total_max                      0.361261  0.547807   0.868261
# Calcium,_Total_mean                     1.033086  0.309435   1.692292
# Calcium,_Total_median                   2.191524  0.138772   2.849212
# Calcium,_Total_min                      0.085287  0.770257   0.376589
# Phosphate_first                         1.608009  0.204772   2.287910
# Phosphate_last                          2.579751  0.108239   3.207711
# Phosphate_max                           0.353421  0.552183   0.856782
# Phosphate_mean                          0.392382  0.531050   0.913080
# Phosphate_median                        0.155934  0.692928   0.529222
# Phosphate_min                           0.752252  0.385764   1.374209
# anchor_age                             11.896051  0.000563  10.795780
# disch_age                              12.536530  0.000399  11.291061
# eGFR_first                              0.405921  0.524047   0.932231
# eGFR_last                               0.032703  0.856492   0.223488
# eGFR_max                                0.101416  0.750138   0.414773
# eGFR_mean                               0.003255  0.954505   0.067175
# eGFR_median                             0.101505  0.750031   0.414979
# eGFR_min                                0.331434  0.564816   0.824148
# gender                                  1.152803  0.282963   1.821314
# subject_id                              0.024576  0.875428   0.191939
# Brier Score at 1 year(s): 0.0321
# Brier Score at 2 year(s): 0.0581
# Brier Score at 3 year(s): 0.0730
# Brier Score at 4 year(s): 0.0901
# Brier Score at 5 year(s): 0.1120
# AUC at 1 year(s): 0.9551
# AUC at 2 year(s): 0.9369
# AUC at 3 year(s): 0.9357
# AUC at 4 year(s): 0.9212
# AUC at 5 year(s): 0.9113
