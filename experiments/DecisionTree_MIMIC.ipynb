# %%
import sys
import os

# Use os.getcwd() to get the current working directory in a Jupyter notebook
parent_dir = os.path.dirname(os.getcwd())  # Get the parent directory of the current working directory
sys.path.append(parent_dir)

# %%
import pandas as pd
from skopt.space import Real, Integer
from driver import Driver

# %% [markdown]
# # Load Cleaned Master MIMIC-IV Dataset

# %%
# Cleaned Master MIMIC Data Set
df_master = pd.read_pickle('../MIMIC_IV/df_ckd_master_clean.pkl')
df_base = pd.read_pickle('../MIMIC_IV/df_ckd_base.pkl')

# %% [markdown]
# # Evaluate Decision Tree Pipeline

# %%
DecisionTree_cfg = {
    'name': 'DecisionTree', # Feature selection model long name
    'tag': 'dct', # Feature selection model identifier tag
    'response': 'stage_delta',  # Response variable for binary classification and Cox Proportional Hazards
    'duration': 'duration', # Duration in days until response or censorship
    'n_novel': 11, # Number of ranked novel features included in augmented KFRE dataset
    'test_size': 0.1, # Ratio of data reserved for testing
    'val_size': 0.2, # Ratio of data reserved for testing in validation sets
    'n_valsets': 5, # Number of training validation sets
    'n_bayesian': 10, # Number of Bayesian hyperparameter optimization iterations 
    'n_folds': 5, # Number of folds for CoxPH cross validation
    'penalizer': 0.0007, # CoxPH model penalizer
    'auc_space': [
        Integer(1, 50, name='max_depth'),
        Integer(2, 20, name="min_samples_split"),
        Integer(1, 20, name="min_samples_leaf"),
    ], # Search space for Bayesian hyperparameter optimization
    'random_state': 42 # Seed for reproducibility
}

driver = Driver(DecisionTree_cfg, df_master, df_base)
driver.ClassicalLearningPipe()
# Out:
# Testing params: {'max_depth': 40, 'min_samples_split': 5, 'min_samples_leaf': 16}
# AUC for params: 0.8585443793575651
# Testing params: {'max_depth': 30, 'min_samples_split': 10, 'min_samples_leaf': 3}
# AUC for params: 0.7831827569625254
# Testing params: {'max_depth': 24, 'min_samples_split': 8, 'min_samples_leaf': 4}
# AUC for params: 0.7903196902781073
# Testing params: {'max_depth': 33, 'min_samples_split': 3, 'min_samples_leaf': 15}
# AUC for params: 0.8498445547723783
# Testing params: {'max_depth': 47, 'min_samples_split': 2, 'min_samples_leaf': 20}
# AUC for params: 0.8610599788743898
# Testing params: {'max_depth': 31, 'min_samples_split': 13, 'min_samples_leaf': 1}
# AUC for params: 0.7785590770755769
# Testing params: {'max_depth': 2, 'min_samples_split': 11, 'min_samples_leaf': 9}
# AUC for params: 0.7820774898386798
# Testing params: {'max_depth': 3, 'min_samples_split': 20, 'min_samples_leaf': 5}
# AUC for params: 0.8438820479201118
# Testing params: {'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 8}
# AUC for params: 0.9039762514356813
# Testing params: {'max_depth': 49, 'min_samples_split': 10, 'min_samples_leaf': 17}
# AUC for params: 0.8597651462582789
# Best parameters found:  {'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 8}
# Best average AUC across validation sets:  0.9039762514356813
# Test AUC: 0.656556964573269
# Iteration 1: norm_delta = 6.83e+00, step_size = 0.9500, log_lik = -8744.90665, newton_decrement = 8.83e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.48e+00, step_size = 0.2375, log_lik = -8375.87667, newton_decrement = 5.12e+02, seconds_since_start = 0.1
# Iteration 3: norm_delta = 5.12e+00, step_size = 0.0772, log_lik = -8299.83256, newton_decrement = 4.41e+02, seconds_since_start = 0.2
# Iteration 4: norm_delta = 4.98e+00, step_size = 0.0326, log_lik = -8271.50646, newton_decrement = 4.15e+02, seconds_since_start = 0.2
# Iteration 5: norm_delta = 4.74e+00, step_size = 0.0551, log_lik = -8227.01071, newton_decrement = 3.73e+02, seconds_since_start = 0.3
# Iteration 6: norm_delta = 4.36e+00, step_size = 0.0931, log_lik = -8160.68002, newton_decrement = 3.11e+02, seconds_since_start = 0.4
# Iteration 7: norm_delta = 3.75e+00, step_size = 0.1574, log_lik = -8070.52650, newton_decrement = 2.24e+02, seconds_since_start = 0.4
# Iteration 8: norm_delta = 2.84e+00, step_size = 0.2660, log_lik = -7966.99689, newton_decrement = 1.23e+02, seconds_since_start = 0.5
# Iteration 9: norm_delta = 1.63e+00, step_size = 0.4496, log_lik = -7881.03123, newton_decrement = 3.81e+01, seconds_since_start = 0.5
# Iteration 10: norm_delta = 4.21e-01, step_size = 0.7598, log_lik = -7845.10645, newton_decrement = 2.30e+00, seconds_since_start = 0.6
# Iteration 11: norm_delta = 2.41e-03, step_size = 1.0000, log_lik = -7842.80159, newton_decrement = 2.00e-04, seconds_since_start = 0.7
# Iteration 12: norm_delta = 3.42e-07, step_size = 1.0000, log_lik = -7842.80139, newton_decrement = 2.31e-11, seconds_since_start = 0.7
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.99e+00, step_size = 0.9500, log_lik = -8829.99117, newton_decrement = 8.81e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.61e+00, step_size = 0.2375, log_lik = -8461.59961, newton_decrement = 5.13e+02, seconds_since_start = 0.1
# Iteration 3: norm_delta = 5.24e+00, step_size = 0.0772, log_lik = -8385.40555, newton_decrement = 4.41e+02, seconds_since_start = 0.2
# Iteration 4: norm_delta = 5.10e+00, step_size = 0.0326, log_lik = -8357.11295, newton_decrement = 4.14e+02, seconds_since_start = 0.2
# Iteration 5: norm_delta = 5.04e+00, step_size = 0.0138, log_lik = -8345.78283, newton_decrement = 4.03e+02, seconds_since_start = 0.3
# Iteration 6: norm_delta = 5.01e+00, step_size = 0.0058, log_lik = -8341.10230, newton_decrement = 3.99e+02, seconds_since_start = 0.4
# Iteration 7: norm_delta = 5.00e+00, step_size = 0.0025, log_lik = -8339.14343, newton_decrement = 3.97e+02, seconds_since_start = 0.4
# Iteration 8: norm_delta = 5.00e+00, step_size = 0.0010, log_lik = -8338.31911, newton_decrement = 3.96e+02, seconds_since_start = 0.5
# Iteration 9: norm_delta = 4.99e+00, step_size = 0.0018, log_lik = -8336.92928, newton_decrement = 3.95e+02, seconds_since_start = 0.6
# Iteration 10: norm_delta = 4.98e+00, step_size = 0.0030, log_lik = -8334.58977, newton_decrement = 3.92e+02, seconds_since_start = 0.6
# Iteration 11: norm_delta = 4.95e+00, step_size = 0.0050, log_lik = -8330.66246, newton_decrement = 3.89e+02, seconds_since_start = 0.7
# Iteration 12: norm_delta = 4.92e+00, step_size = 0.0085, log_lik = -8324.10032, newton_decrement = 3.82e+02, seconds_since_start = 0.7
# Iteration 13: norm_delta = 4.86e+00, step_size = 0.0143, log_lik = -8313.22186, newton_decrement = 3.72e+02, seconds_since_start = 0.8
# Iteration 14: norm_delta = 4.76e+00, step_size = 0.0242, log_lik = -8295.42860, newton_decrement = 3.55e+02, seconds_since_start = 0.9
# Iteration 15: norm_delta = 4.59e+00, step_size = 0.0409, log_lik = -8266.98632, newton_decrement = 3.27e+02, seconds_since_start = 0.9
# Iteration 16: norm_delta = 4.31e+00, step_size = 0.0691, log_lik = -8223.28841, newton_decrement = 2.85e+02, seconds_since_start = 1.0
# Iteration 17: norm_delta = 3.86e+00, step_size = 0.1169, log_lik = -8160.64466, newton_decrement = 2.23e+02, seconds_since_start = 1.0
# Iteration 18: norm_delta = 3.17e+00, step_size = 0.1975, log_lik = -8081.25120, newton_decrement = 1.44e+02, seconds_since_start = 1.1
# Iteration 19: norm_delta = 2.18e+00, step_size = 0.3338, log_lik = -8000.99508, newton_decrement = 6.43e+01, seconds_since_start = 1.2
# Iteration 20: norm_delta = 9.96e-01, step_size = 0.5641, log_lik = -7948.93419, newton_decrement = 1.23e+01, seconds_since_start = 1.2
# Iteration 21: norm_delta = 5.79e-02, step_size = 0.9533, log_lik = -7936.67271, newton_decrement = 3.37e-02, seconds_since_start = 1.3
# Iteration 22: norm_delta = 4.01e-05, step_size = 1.0000, log_lik = -7936.63901, newton_decrement = 4.78e-08, seconds_since_start = 1.3
# Convergence success after 22 iterations.
# Iteration 1: norm_delta = 6.88e+00, step_size = 0.9500, log_lik = -8805.41001, newton_decrement = 8.60e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.52e+00, step_size = 0.2375, log_lik = -8445.43549, newton_decrement = 5.05e+02, seconds_since_start = 0.1
# Iteration 3: norm_delta = 5.16e+00, step_size = 0.0772, log_lik = -8370.41865, newton_decrement = 4.34e+02, seconds_since_start = 0.2
# Iteration 4: norm_delta = 5.02e+00, step_size = 0.0326, log_lik = -8342.54383, newton_decrement = 4.08e+02, seconds_since_start = 0.2
# Iteration 5: norm_delta = 4.96e+00, step_size = 0.0138, log_lik = -8331.37816, newton_decrement = 3.97e+02, seconds_since_start = 0.3
# Iteration 6: norm_delta = 4.86e+00, step_size = 0.0233, log_lik = -8313.08735, newton_decrement = 3.80e+02, seconds_since_start = 0.4
# Iteration 7: norm_delta = 4.70e+00, step_size = 0.0394, log_lik = -8283.77330, newton_decrement = 3.52e+02, seconds_since_start = 0.4
# Iteration 8: norm_delta = 4.42e+00, step_size = 0.0665, log_lik = -8238.53267, newton_decrement = 3.08e+02, seconds_since_start = 0.5
# Iteration 9: norm_delta = 3.99e+00, step_size = 0.1124, log_lik = -8173.17829, newton_decrement = 2.44e+02, seconds_since_start = 0.6
# Iteration 10: norm_delta = 3.30e+00, step_size = 0.1899, log_lik = -8089.30914, newton_decrement = 1.61e+02, seconds_since_start = 0.6
# Iteration 11: norm_delta = 2.32e+00, step_size = 0.3210, log_lik = -8002.62915, newton_decrement = 7.44e+01, seconds_since_start = 0.7
# Iteration 12: norm_delta = 1.11e+00, step_size = 0.5425, log_lik = -7943.83864, newton_decrement = 1.56e+01, seconds_since_start = 0.7
# Iteration 13: norm_delta = 1.06e-01, step_size = 0.9168, log_lik = -7928.36564, newton_decrement = 1.17e-01, seconds_since_start = 0.8
# Iteration 14: norm_delta = 1.26e-04, step_size = 1.0000, log_lik = -7928.24869, newton_decrement = 4.18e-07, seconds_since_start = 0.9
# Iteration 15: norm_delta = 5.83e-10, step_size = 1.0000, log_lik = -7928.24869, newton_decrement = 6.13e-17, seconds_since_start = 0.9
# Convergence success after 15 iterations.
# Iteration 1: norm_delta = 7.01e+00, step_size = 0.9500, log_lik = -9037.41005, newton_decrement = 8.77e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.63e+00, step_size = 0.2375, log_lik = -8670.72351, newton_decrement = 5.18e+02, seconds_since_start = 0.1
# Iteration 3: norm_delta = 5.26e+00, step_size = 0.0772, log_lik = -8593.89035, newton_decrement = 4.46e+02, seconds_since_start = 0.2
# Iteration 4: norm_delta = 5.12e+00, step_size = 0.0326, log_lik = -8565.24725, newton_decrement = 4.20e+02, seconds_since_start = 0.2
# Iteration 5: norm_delta = 5.06e+00, step_size = 0.0138, log_lik = -8553.75734, newton_decrement = 4.09e+02, seconds_since_start = 0.3
# Iteration 6: norm_delta = 5.03e+00, step_size = 0.0058, log_lik = -8549.00739, newton_decrement = 4.05e+02, seconds_since_start = 0.4
# Iteration 7: norm_delta = 5.02e+00, step_size = 0.0025, log_lik = -8547.01886, newton_decrement = 4.03e+02, seconds_since_start = 0.4
# Iteration 8: norm_delta = 5.02e+00, step_size = 0.0010, log_lik = -8546.18195, newton_decrement = 4.02e+02, seconds_since_start = 0.5
# Iteration 9: norm_delta = 5.02e+00, step_size = 0.0004, log_lik = -8545.82893, newton_decrement = 4.02e+02, seconds_since_start = 0.5
# Iteration 10: norm_delta = 5.01e+00, step_size = 0.0002, log_lik = -8545.67989, newton_decrement = 4.02e+02, seconds_since_start = 0.6
# Iteration 11: norm_delta = 5.01e+00, step_size = 0.0001, log_lik = -8545.61693, newton_decrement = 4.02e+02, seconds_since_start = 0.7
# Iteration 12: norm_delta = 5.01e+00, step_size = 0.0000, log_lik = -8545.59034, newton_decrement = 4.02e+02, seconds_since_start = 0.7
# Iteration 13: norm_delta = 5.01e+00, step_size = 0.0000, log_lik = -8545.57910, newton_decrement = 4.02e+02, seconds_since_start = 0.8
# Iteration 14: norm_delta = 5.01e+00, step_size = 0.0000, log_lik = -8545.57436, newton_decrement = 4.02e+02, seconds_since_start = 0.8
# Convergence failed. See any warning messages.
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\lifelines\fitters\coxph_fitter.py:1614: ConvergenceWarning: Newton-Raphson failed to converge sufficiently. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-model
#   warnings.warn(
# Iteration 1: norm_delta = 6.90e+00, step_size = 0.9500, log_lik = -8886.68689, newton_decrement = 9.08e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.52e+00, step_size = 0.2375, log_lik = -8507.15754, newton_decrement = 5.25e+02, seconds_since_start = 0.1
# Iteration 3: norm_delta = 5.16e+00, step_size = 0.0772, log_lik = -8429.24377, newton_decrement = 4.52e+02, seconds_since_start = 0.2
# Iteration 4: norm_delta = 5.02e+00, step_size = 0.0326, log_lik = -8400.26913, newton_decrement = 4.24e+02, seconds_since_start = 0.3
# Iteration 5: norm_delta = 4.96e+00, step_size = 0.0138, log_lik = -8388.65538, newton_decrement = 4.13e+02, seconds_since_start = 0.3
# Iteration 6: norm_delta = 4.86e+00, step_size = 0.0233, log_lik = -8369.62444, newton_decrement = 3.96e+02, seconds_since_start = 0.4
# Iteration 7: norm_delta = 4.70e+00, step_size = 0.0394, log_lik = -8339.10598, newton_decrement = 3.67e+02, seconds_since_start = 0.5
# Iteration 8: norm_delta = 4.43e+00, step_size = 0.0665, log_lik = -8291.95055, newton_decrement = 3.22e+02, seconds_since_start = 0.5
# Iteration 9: norm_delta = 3.99e+00, step_size = 0.1124, log_lik = -8223.65316, newton_decrement = 2.56e+02, seconds_since_start = 0.6
# Iteration 10: norm_delta = 3.31e+00, step_size = 0.1899, log_lik = -8135.52141, newton_decrement = 1.70e+02, seconds_since_start = 0.6
# Iteration 11: norm_delta = 2.32e+00, step_size = 0.3210, log_lik = -8043.86383, newton_decrement = 7.92e+01, seconds_since_start = 0.7
# Iteration 12: norm_delta = 1.12e+00, step_size = 0.5425, log_lik = -7981.18028, newton_decrement = 1.69e+01, seconds_since_start = 0.8
# Iteration 13: norm_delta = 1.07e-01, step_size = 0.9168, log_lik = -7964.34890, newton_decrement = 1.43e-01, seconds_since_start = 0.8
# Iteration 14: norm_delta = 1.58e-04, step_size = 1.0000, log_lik = -7964.20617, newton_decrement = 1.63e-06, seconds_since_start = 0.9
# Iteration 15: norm_delta = 3.01e-09, step_size = 1.0000, log_lik = -7964.20617, newton_decrement = 2.17e-15, seconds_since_start = 0.9
# Convergence success after 15 iterations.
# Average C-Index from cross-validation: 0.8881
# Best C-Index from cross-validation: 0.8954
# Standard Deviation of C-Index from cross-validation: 0.0050
#                                            coef  exp(coef)      se(coef)  \
# covariate
# subject_id                        -1.217034e-08   1.000000  1.024664e-08
# gender                             1.834617e-01   1.201369  6.639916e-02
# anchor_age                         3.603194e-01   1.433787  1.468223e-02
# disch_age                         -3.633514e-01   0.695342  1.463369e-02
# CKD_stage_first                   -1.023933e+00   0.359179  4.496319e-02
# eGFR_first                        -3.219790e-02   0.968315  1.392645e-02
# eGFR_last                          3.196597e-02   1.032482  1.414416e-02
# eGFR_min                          -8.823461e-03   0.991215  1.368000e-02
# eGFR_max                           5.419757e-03   1.005434  1.391622e-02
# eGFR_mean                         -1.240418e-02   0.987672  1.385532e-02
# eGFR_median                       -1.851553e-02   0.981655  1.388011e-02
# Albumin/Creatinine,_Urine_first    1.038806e-04   1.000104  1.219789e-04
# Albumin/Creatinine,_Urine_last     8.689764e-05   1.000087  1.244250e-04
# Albumin/Creatinine,_Urine_min     -7.550539e-05   0.999924  1.797151e-04
# Albumin/Creatinine,_Urine_max     -3.849133e-05   0.999962  1.400157e-04
# Albumin/Creatinine,_Urine_mean     8.515807e-05   1.000085  3.577273e-04
# Albumin/Creatinine,_Urine_median  -1.253815e-04   0.999875  2.222214e-04
# Bicarbonate_first                  6.944148e-03   1.006968  9.133211e-03
# Bicarbonate_last                   1.377156e-02   1.013867  8.526650e-03
# Bicarbonate_min                    1.210486e-02   1.012178  1.861816e-02
# Bicarbonate_max                    1.351236e-02   1.013604  1.586550e-02
# Bicarbonate_mean                  -5.828926e-02   0.943377  5.806545e-02
# Bicarbonate_median                -3.773300e-02   0.962970  4.424385e-02
# Albumin_first                     -8.728476e-03   0.991310  7.941853e-02
# Albumin_last                      -1.235581e-01   0.883770  7.415018e-02
# Albumin_min                        1.702943e-01   1.185654  1.251700e-01
# Albumin_max                       -1.363875e-01   0.872504  1.334524e-01
# Albumin_mean                      -3.142064e-01   0.730368  4.035554e-01
# Albumin_median                     1.994531e-02   1.020146  2.580455e-01
# Phosphate_first                    1.535274e-02   1.015471  3.039077e-02
# Phosphate_last                     1.519244e-02   1.015308  2.940605e-02
# Phosphate_min                     -1.450564e-01   0.864974  6.819276e-02
# Phosphate_max                     -5.040470e-02   0.950845  2.940857e-02
# Phosphate_mean                     3.989657e-01   1.490283  1.810509e-01
# Phosphate_median                  -6.290631e-02   0.939031  1.386735e-01
# Calcium,_Total_first               6.232368e-02   1.064307  5.148731e-02
# Calcium,_Total_last               -2.650550e-02   0.973843  5.378766e-02
# Calcium,_Total_min                 1.448049e-01   1.155814  7.538713e-02
# Calcium,_Total_max                -3.853282e-02   0.962200  6.207086e-02
# Calcium,_Total_mean                5.956679e-02   1.061377  2.975780e-01
# Calcium,_Total_median             -5.253489e-02   0.948821  2.383671e-01
# Urea_Nitrogen_max                  5.850055e-03   1.005867  9.839761e-04
# Creatinine_mean                    7.519100e-02   1.078090  3.514181e-02
# Renal dialysis status              5.608486e-01   1.752159  9.929476e-02
# Protein_max                        2.672880e-04   1.000267  1.921381e-04
# Creatinine_last                    1.035785e-02   1.010412  2.309575e-02
# Platelet_Count_first              -9.251299e-04   0.999075  3.204696e-04
# MCHC_mean                         -6.142292e-02   0.940425  3.052130e-02
# Glucose_max                       -9.069904e-04   0.999093  3.800729e-04
# Cholesterol_Ratio_(Total/HDL)_min  5.404101e-02   1.055528  2.368626e-02
# WBC_Count_last                    -1.846947e-02   0.981700  4.268802e-02
# Protein/Creatinine_Ratio_mean      1.237608e-02   1.012453  7.931967e-03
#
#                                    coef lower 95%  coef upper 95%  \
# covariate
# subject_id                          -3.225338e-08    7.912705e-09
# gender                               5.332176e-02    3.136017e-01
# anchor_age                           3.315428e-01    3.890961e-01
# disch_age                           -3.920329e-01   -3.346699e-01
# CKD_stage_first                     -1.112059e+00   -9.358070e-01
# eGFR_first                          -5.949324e-02   -4.902566e-03
# eGFR_last                            4.243937e-03    5.968801e-02
# eGFR_min                            -3.563577e-02    1.798885e-02
# eGFR_max                            -2.185554e-02    3.269506e-02
# eGFR_mean                           -3.956011e-02    1.475174e-02
# eGFR_median                         -4.572004e-02    8.688979e-03
# Albumin/Creatinine,_Urine_first     -1.351938e-04    3.429549e-04
# Albumin/Creatinine,_Urine_last      -1.569710e-04    3.307662e-04
# Albumin/Creatinine,_Urine_min       -4.277405e-04    2.767298e-04
# Albumin/Creatinine,_Urine_max       -3.129170e-04    2.359343e-04
# Albumin/Creatinine,_Urine_mean      -6.159745e-04    7.862907e-04
# Albumin/Creatinine,_Urine_median    -5.609274e-04    3.101644e-04
# Bicarbonate_first                   -1.095662e-02    2.484491e-02
# Bicarbonate_last                    -2.940365e-03    3.048349e-02
# Bicarbonate_min                     -2.438607e-02    4.859578e-02
# Bicarbonate_max                     -1.758344e-02    4.460816e-02
# Bicarbonate_mean                    -1.720955e-01    5.551693e-02
# Bicarbonate_median                  -1.244494e-01    4.898336e-02
# Albumin_first                       -1.643859e-01    1.469290e-01
# Albumin_last                        -2.688898e-01    2.177361e-02
# Albumin_min                         -7.503434e-02    4.156230e-01
# Albumin_max                         -3.979494e-01    1.251745e-01
# Albumin_mean                        -1.105160e+00    4.767476e-01
# Albumin_median                      -4.858146e-01    5.257053e-01
# Phosphate_first                     -4.421207e-02    7.491756e-02
# Phosphate_last                      -4.244236e-02    7.282723e-02
# Phosphate_min                       -2.787117e-01   -1.140100e-02
# Phosphate_max                       -1.080444e-01    7.235033e-03
# Phosphate_mean                       4.411256e-02    7.538189e-01
# Phosphate_median                    -3.347015e-01    2.088888e-01
# Calcium,_Total_first                -3.858959e-02    1.632370e-01
# Calcium,_Total_last                 -1.319274e-01    7.891638e-02
# Calcium,_Total_min                  -2.951201e-03    2.925609e-01
# Calcium,_Total_max                  -1.601895e-01    8.312383e-02
# Calcium,_Total_mean                 -5.236753e-01    6.428089e-01
# Calcium,_Total_median               -5.197258e-01    4.146560e-01
# Urea_Nitrogen_max                    3.921497e-03    7.778613e-03
# Creatinine_mean                      6.314310e-03    1.440677e-01
# Renal dialysis status                3.662344e-01    7.554627e-01
# Protein_max                         -1.092957e-04    6.438718e-04
# Creatinine_last                     -3.490900e-02    5.562469e-02
# Platelet_Count_first                -1.553239e-03   -2.970210e-04
# MCHC_mean                           -1.212436e-01   -1.602273e-03
# Glucose_max                         -1.651920e-03   -1.620612e-04
# Cholesterol_Ratio_(Total/HDL)_min    7.616794e-03    1.004652e-01
# WBC_Count_last                      -1.021365e-01    6.519751e-02
# Protein/Creatinine_Ratio_mean       -3.170286e-03    2.792245e-02
#
#                                    exp(coef) lower 95%  exp(coef) upper 95%  \
# covariate
# subject_id                                    1.000000             1.000000
# gender                                        1.054769             1.368345
# anchor_age                                    1.393116             1.475646
# disch_age                                     0.675682             0.715574
# CKD_stage_first                               0.328881             0.392269
# eGFR_first                                    0.942242             0.995109
# eGFR_last                                     1.004253             1.061505
# eGFR_min                                      0.964992             1.018152
# eGFR_max                                      0.978382             1.033235
# eGFR_mean                                     0.961212             1.014861
# eGFR_median                                   0.955309             1.008727
# Albumin/Creatinine,_Urine_first               0.999865             1.000343
# Albumin/Creatinine,_Urine_last                0.999843             1.000331
# Albumin/Creatinine,_Urine_min                 0.999572             1.000277
# Albumin/Creatinine,_Urine_max                 0.999687             1.000236
# Albumin/Creatinine,_Urine_mean                0.999384             1.000787
# Albumin/Creatinine,_Urine_median              0.999439             1.000310
# Bicarbonate_first                             0.989103             1.025156
# Bicarbonate_last                              0.997064             1.030953
# Bicarbonate_min                               0.975909             1.049796
# Bicarbonate_max                               0.982570             1.045618
# Bicarbonate_mean                              0.841899             1.057087
# Bicarbonate_median                            0.882983             1.050203
# Albumin_first                                 0.848415             1.158272
# Albumin_last                                  0.764227             1.022012
# Albumin_min                                   0.927712             1.515314
# Albumin_max                                   0.671696             1.133346
# Albumin_mean                                  0.331158             1.610827
# Albumin_median                                0.615196             1.691651
# Phosphate_first                               0.956751             1.077795
# Phosphate_last                                0.958446             1.075545
# Phosphate_min                                 0.756758             0.988664
# Phosphate_max                                 0.897588             1.007261
# Phosphate_mean                                1.045100             2.125100
# Phosphate_median                              0.715552             1.232308
# Calcium,_Total_first                          0.962146             1.177316
# Calcium,_Total_last                           0.876405             1.082114
# Calcium,_Total_min                            0.997053             1.339854
# Calcium,_Total_max                            0.851982             1.086676
# Calcium,_Total_mean                           0.592339             1.901815
# Calcium,_Total_median                         0.594684             1.513850
# Urea_Nitrogen_max                             1.003929             1.007809
# Creatinine_mean                               1.006334             1.154962
# Renal dialysis status                         1.442293             2.128596
# Protein_max                                   0.999891             1.000644
# Creatinine_last                               0.965693             1.057201
# Platelet_Count_first                          0.998448             0.999703
# MCHC_mean                                     0.885818             0.998399
# Glucose_max                                   0.998349             0.999838
# Cholesterol_Ratio_(Total/HDL)_min             1.007646             1.105685
# WBC_Count_last                                0.902906             1.067370
# Protein/Creatinine_Ratio_mean                 0.996835             1.028316
#
#                                    cmp to          z              p  \
# covariate
# subject_id                            0.0  -1.187740   2.349361e-01
# gender                                0.0   2.763013   5.727055e-03
# anchor_age                            0.0  24.541191  5.370896e-133
# disch_age                             0.0 -24.829793  4.275084e-136
# CKD_stage_first                       0.0 -22.772701  8.551046e-115
# eGFR_first                            0.0  -2.311997   2.077787e-02
# eGFR_last                             0.0   2.260013   2.382046e-02
# eGFR_min                              0.0  -0.644990   5.189338e-01
# eGFR_max                              0.0   0.389456   6.969389e-01
# eGFR_mean                             0.0  -0.895265   3.706454e-01
# eGFR_median                           0.0  -1.333962   1.822164e-01
# Albumin/Creatinine,_Urine_first       0.0   0.851627   3.944211e-01
# Albumin/Creatinine,_Urine_last        0.0   0.698394   4.849311e-01
# Albumin/Creatinine,_Urine_min         0.0  -0.420139   6.743837e-01
# Albumin/Creatinine,_Urine_max         0.0  -0.274907   7.833875e-01
# Albumin/Creatinine,_Urine_mean        0.0   0.238053   8.118399e-01
# Albumin/Creatinine,_Urine_median      0.0  -0.564219   5.726053e-01
# Bicarbonate_first                     0.0   0.760318   4.470643e-01
# Bicarbonate_last                      0.0   1.615120   1.062847e-01
# Bicarbonate_min                       0.0   0.650164   5.155863e-01
# Bicarbonate_max                       0.0   0.851682   3.943905e-01
# Bicarbonate_mean                      0.0  -1.003854   3.154488e-01
# Bicarbonate_median                    0.0  -0.852842   3.937471e-01
# Albumin_first                         0.0  -0.109905   9.124849e-01
# Albumin_last                          0.0  -1.666322   9.564930e-02
# Albumin_min                           0.0   1.360504   1.736703e-01
# Albumin_max                           0.0  -1.021993   3.067841e-01
# Albumin_mean                          0.0  -0.778596   4.362180e-01
# Albumin_median                        0.0   0.077294   9.383899e-01
# Phosphate_first                       0.0   0.505178   6.134339e-01
# Phosphate_last                        0.0   0.516643   6.054052e-01
# Phosphate_min                         0.0  -2.127152   3.340747e-02
# Phosphate_max                         0.0  -1.713946   8.653862e-02
# Phosphate_mean                        0.0   2.203611   2.755169e-02
# Phosphate_median                      0.0  -0.453629   6.500961e-01
# Calcium,_Total_first                  0.0   1.210467   2.260998e-01
# Calcium,_Total_last                   0.0  -0.492780   6.221679e-01
# Calcium,_Total_min                    0.0   1.920817   5.475482e-02
# Calcium,_Total_max                    0.0  -0.620788   5.347394e-01
# Calcium,_Total_mean                   0.0   0.200172   8.413460e-01
# Calcium,_Total_median                 0.0  -0.220395   8.255636e-01
# Urea_Nitrogen_max                     0.0   5.945322   2.759138e-09
# Creatinine_mean                       0.0   2.139645   3.238348e-02
# Renal dialysis status                 0.0   5.648320   1.620234e-08
# Protein_max                           0.0   1.391125   1.641877e-01
# Creatinine_last                       0.0   0.448474   6.538110e-01
# Platelet_Count_first                  0.0  -2.886794   3.891884e-03
# MCHC_mean                             0.0  -2.012461   4.417138e-02
# Glucose_max                           0.0  -2.386359   1.701613e-02
# Cholesterol_Ratio_(Total/HDL)_min     0.0   2.281534   2.251686e-02
# WBC_Count_last                        0.0  -0.432662   6.652606e-01
# Protein/Creatinine_Ratio_mean         0.0   1.560279   1.186939e-01
#
#                                      -log2(p)
# covariate
# subject_id                           2.089660
# gender                               7.447991
# anchor_age                         439.391274
# disch_age                          449.686268
# CKD_stage_first                    378.925630
# eGFR_first                           5.588809
# eGFR_last                            5.391655
# eGFR_min                             0.946378
# eGFR_max                             0.520896
# eGFR_mean                            1.431888
# eGFR_median                          2.456275
# Albumin/Creatinine,_Urine_first      1.342191
# Albumin/Creatinine,_Urine_last       1.044148
# Albumin/Creatinine,_Urine_min        0.568359
# Albumin/Creatinine,_Urine_max        0.352202
# Albumin/Creatinine,_Urine_mean       0.300733
# Albumin/Creatinine,_Urine_median     0.804387
# Bicarbonate_first                    1.161446
# Bicarbonate_last                     3.233994
# Bicarbonate_min                      0.955714
# Bicarbonate_max                      1.342303
# Bicarbonate_mean                     1.664522
# Bicarbonate_median                   1.344659
# Albumin_first                        0.132127
# Albumin_last                         3.386102
# Albumin_min                          2.525577
# Albumin_max                          1.704704
# Albumin_mean                         1.196879
# Albumin_median                       0.091741
# Phosphate_first                      0.705020
# Phosphate_last                       0.724027
# Phosphate_min                        4.903685
# Phosphate_max                        3.530512
# Phosphate_mean                       5.181715
# Phosphate_median                     0.621275
# Calcium,_Total_first                 2.144968
# Calcium,_Total_last                  0.684624
# Calcium,_Total_min                   4.190870
# Calcium,_Total_max                   0.903092
# Calcium,_Total_mean                  0.249229
# Calcium,_Total_median                0.276549
# Urea_Nitrogen_max                   28.433135
# Creatinine_mean                      4.948598
# Renal dialysis status               25.879222
# Protein_max                          2.606582
# Creatinine_last                      0.613054
# Platelet_Count_first                 8.005315
# MCHC_mean                            4.500744
# Glucose_max                          5.876953
# Cholesterol_Ratio_(Total/HDL)_min    5.472851
# WBC_Count_last                       0.588009
# Protein/Creatinine_Ratio_mean        3.074682
#                                    test_statistic         p   -log2(p)
# Albumin/Creatinine,_Urine_first          0.080873  0.776118   0.365652
# Albumin/Creatinine,_Urine_last           0.014132  0.905372   0.143417
# Albumin/Creatinine,_Urine_max            0.004075  0.949104   0.075363
# Albumin/Creatinine,_Urine_mean           0.006535  0.935568   0.096086
# Albumin/Creatinine,_Urine_median         0.007858  0.929362   0.105687
# Albumin/Creatinine,_Urine_min            0.030347  0.861704   0.214736
# Albumin_first                            3.616751  0.057200   4.127829
# Albumin_last                             0.050399  0.822370   0.282141
# Albumin_max                              0.034992  0.851612   0.231731
# Albumin_mean                             0.242399  0.622478   0.683904
# Albumin_median                           0.175235  0.675501   0.565971
# Albumin_min                              0.836815  0.360309   1.472692
# Bicarbonate_first                        1.608574  0.204692   2.288471
# Bicarbonate_last                         2.327132  0.127136   2.975556
# Bicarbonate_max                          1.175745  0.278224   1.845681
# Bicarbonate_mean                         0.215616  0.642401   0.638454
# Bicarbonate_median                       0.564017  0.452646   1.143545
# Bicarbonate_min                          0.152594  0.696069   0.522698
# CKD_stage_first                         14.939828  0.000111  13.137220
# Calcium,_Total_first                     3.186887  0.074231   3.751830
# Calcium,_Total_last                      1.301035  0.254024   1.976961
# Calcium,_Total_max                       0.262099  0.608682   0.716240
# Calcium,_Total_mean                      1.097159  0.294890   1.761749
# Calcium,_Total_median                    3.294294  0.069521   3.846407
# Calcium,_Total_min                       0.354791  0.551414   0.858793
# Cholesterol_Ratio_(Total/HDL)_min        1.670044  0.196253   2.349216
# Creatinine_last                          0.032442  0.857061   0.222531
# Creatinine_mean                          0.880418  0.348087   1.522479
# Glucose_max                              2.012621  0.155996   2.680422
# MCHC_mean                                0.136465  0.711821   0.490414
# Phosphate_first                          1.086304  0.297292   1.750050
# Phosphate_last                           1.510099  0.219124   2.190181
# Phosphate_max                            1.330013  0.248803   2.006925
# Phosphate_mean                           0.277907  0.598077   0.741598
# Phosphate_median                         0.069300  0.792359   0.335774
# Phosphate_min                            0.969316  0.324851   1.622151
# Platelet_Count_first                     4.202190  0.040372   4.630508
# Protein/Creatinine_Ratio_mean            1.827824  0.176385   2.503202
# Protein_max                              0.042089  0.837450   0.255924
# Renal dialysis status                    0.205712  0.650149   0.621157
# Urea_Nitrogen_max                        1.079713  0.298762   1.742933
# WBC_Count_last                           0.021021  0.884723   0.176702
# anchor_age                              14.284684  0.000157  12.635678
# disch_age                               14.509065  0.000139  12.807585
# eGFR_first                               0.303865  0.581470   0.782224
# eGFR_last                                0.002356  0.961283   0.056967
# eGFR_max                                 0.030205  0.862025   0.214198
# eGFR_mean                                0.010358  0.918935   0.121966
# eGFR_median                              0.006633  0.935087   0.096827
# eGFR_min                                 0.112368  0.737464   0.439355
# gender                                   0.208981  0.647567   0.626898
# subject_id                               0.015826  0.899889   0.152181
# Brier Score at 1 year(s): 0.0323
# Brier Score at 2 year(s): 0.0582
# Brier Score at 3 year(s): 0.0714
# Brier Score at 4 year(s): 0.0879
# Brier Score at 5 year(s): 0.1088
# AUC at 1 year(s): 0.9535
# AUC at 2 year(s): 0.9397
# AUC at 3 year(s): 0.9417
# AUC at 4 year(s): 0.9261
# AUC at 5 year(s): 0.9169
