# %%
import sys
import os

# Use os.getcwd() to get the current working directory in a Jupyter notebook
parent_dir = os.path.dirname(os.getcwd())  # Get the parent directory of the current working directory
sys.path.append(parent_dir)

# %%
import pandas as pd
from skopt.space import Real, Integer
from driver import Driver

# %% [markdown]
# # Load Cleaned Master MIMIC-IV Dataset

# %%
# Cleaned Master MIMIC Data Set
df_master = pd.read_pickle('../MIMIC_IV/df_ckd_master_clean.pkl')
df_base = pd.read_pickle('../MIMIC_IV/df_ckd_base.pkl')

# %% [markdown]
# # Evaluate FCNN Pipeline

# %%
FCNN_cfg = {
    'name': 'FCNN', # Feature selection model long name
    'tag': 'fcnn', # Feature selection model identifier tag
    'response': 'stage_delta',  # Response variable for binary classification and Cox Proportional Hazards
    'duration': 'duration', # Duration in days until response or censorship
    'n_novel': 40, # Number of ranked novel features included in augmented KFRE dataset
    'test_size': 0.2, # Ratio of data reserved for testing
    'epochs': 35,
    'patience': 5,
    'learning_rate': 0.001,
    'weight_decay': 1e-4,
    'batch_size': 256, # Batch size for SHAP computation
    'n_folds': 5, # Number of folds for CoxPH cross validation
    'penalizer': 0.0007, # CoxPH model penalizer
    'random_state': 42 # Seed for reproducibility
}

driver = Driver(FCNN_cfg, df_master, df_base)
driver.DeepLearningPipe()
# Out:
# Epoch 1/35, Training Loss: 0.2856718202290887, Validation Loss: 0.2720666944303296
# Epoch 2/35, Training Loss: 0.19299869235097009, Validation Loss: 0.31814993409947917
# Epoch 3/35, Training Loss: 0.13225898910737174, Validation Loss: 0.40104795416647737
# Epoch 4/35, Training Loss: 0.07969347108684649, Validation Loss: 0.5184059708633206
# Epoch 5/35, Training Loss: 0.054640690481226724, Validation Loss: 0.6465027115561746
# Epoch 6/35, Training Loss: 0.04372192310455086, Validation Loss: 0.7669139054011215
# Early stopping triggered
# Test AUC: 0.6556293551499208
#  ... (more hidden) ...
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\shap\plots\_beeswarm.py:962: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   pl.tight_layout()
# Iteration 1: norm_delta = 6.54e+00, step_size = 0.9500, log_lik = -8744.90665, newton_decrement = 9.84e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.27e+00, step_size = 0.2375, log_lik = -8333.99400, newton_decrement = 5.50e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.93e+00, step_size = 0.0772, log_lik = -8252.28839, newton_decrement = 4.72e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.38e+00, step_size = 0.1304, log_lik = -8137.02561, newton_decrement = 3.63e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.54e+00, step_size = 0.2205, log_lik = -7994.38339, newton_decrement = 2.28e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.34e+00, step_size = 0.3726, log_lik = -7855.84415, newton_decrement = 9.46e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.35e-01, step_size = 0.6296, log_lik = -7773.85239, newton_decrement = 1.42e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 1.43e-02, step_size = 1.0000, log_lik = -7759.52713, newton_decrement = 1.04e-02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 2.05e-05, step_size = 1.0000, log_lik = -7759.51672, newton_decrement = 6.58e-08, seconds_since_start = 0.8
# Convergence success after 9 iterations.
# Iteration 1: norm_delta = 6.61e+00, step_size = 0.9500, log_lik = -8829.99117, newton_decrement = 9.74e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.35e+00, step_size = 0.2375, log_lik = -8423.49504, newton_decrement = 5.46e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.02e+00, step_size = 0.0772, log_lik = -8342.50351, newton_decrement = 4.68e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.88e+00, step_size = 0.0326, log_lik = -8312.46842, newton_decrement = 4.40e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.66e+00, step_size = 0.0551, log_lik = -8265.34736, newton_decrement = 3.95e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.29e+00, step_size = 0.0931, log_lik = -8195.21375, newton_decrement = 3.28e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 3.71e+00, step_size = 0.1574, log_lik = -8100.00597, newton_decrement = 2.37e+02, seconds_since_start = 0.6
# Iteration 8: norm_delta = 2.83e+00, step_size = 0.2660, log_lik = -7990.49538, newton_decrement = 1.32e+02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 1.64e+00, step_size = 0.4496, log_lik = -7898.60952, newton_decrement = 4.18e+01, seconds_since_start = 0.8
# Iteration 10: norm_delta = 4.30e-01, step_size = 0.7598, log_lik = -7859.05097, newton_decrement = 2.72e+00, seconds_since_start = 0.9
# Iteration 11: norm_delta = 2.90e-03, step_size = 1.0000, log_lik = -7856.31700, newton_decrement = 4.18e-04, seconds_since_start = 1.0
# Iteration 12: norm_delta = 7.68e-06, step_size = 1.0000, log_lik = -7856.31658, newton_decrement = 1.30e-09, seconds_since_start = 1.1
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.54e+00, step_size = 0.9500, log_lik = -8805.41001, newton_decrement = 9.78e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.27e+00, step_size = 0.2375, log_lik = -8397.16417, newton_decrement = 5.40e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.94e+00, step_size = 0.0772, log_lik = -8317.02583, newton_decrement = 4.62e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.40e+00, step_size = 0.1304, log_lik = -8204.42482, newton_decrement = 3.53e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.57e+00, step_size = 0.2205, log_lik = -8066.02601, newton_decrement = 2.19e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.37e+00, step_size = 0.3726, log_lik = -7932.96548, newton_decrement = 9.00e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.50e-01, step_size = 0.6296, log_lik = -7854.91399, newton_decrement = 1.35e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 1.35e-02, step_size = 1.0000, log_lik = -7841.24974, newton_decrement = 8.95e-03, seconds_since_start = 0.8
# Iteration 9: norm_delta = 4.93e-05, step_size = 1.0000, log_lik = -7841.24078, newton_decrement = 6.74e-08, seconds_since_start = 0.9
# Convergence success after 9 iterations.
# Iteration 1: norm_delta = 6.70e+00, step_size = 0.9500, log_lik = -9037.41005, newton_decrement = 9.80e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.40e+00, step_size = 0.2375, log_lik = -8628.07703, newton_decrement = 5.52e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.06e+00, step_size = 0.0772, log_lik = -8546.11267, newton_decrement = 4.74e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.93e+00, step_size = 0.0326, log_lik = -8515.69881, newton_decrement = 4.45e+02, seconds_since_start = 0.3
# Iteration 5: norm_delta = 4.70e+00, step_size = 0.0551, log_lik = -8467.96762, newton_decrement = 4.00e+02, seconds_since_start = 0.4
# Iteration 6: norm_delta = 4.33e+00, step_size = 0.0931, log_lik = -8396.87836, newton_decrement = 3.33e+02, seconds_since_start = 0.5
# Iteration 7: norm_delta = 3.74e+00, step_size = 0.1574, log_lik = -8300.23598, newton_decrement = 2.41e+02, seconds_since_start = 0.6
# Iteration 8: norm_delta = 2.85e+00, step_size = 0.2660, log_lik = -8188.74135, newton_decrement = 1.35e+02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 1.65e+00, step_size = 0.4496, log_lik = -8094.68761, newton_decrement = 4.30e+01, seconds_since_start = 0.8
# Iteration 10: norm_delta = 4.33e-01, step_size = 0.7598, log_lik = -8053.93437, newton_decrement = 2.83e+00, seconds_since_start = 0.8
# Iteration 11: norm_delta = 2.95e-03, step_size = 1.0000, log_lik = -8051.09128, newton_decrement = 5.68e-04, seconds_since_start = 0.9
# Iteration 12: norm_delta = 1.03e-06, step_size = 1.0000, log_lik = -8051.09071, newton_decrement = 2.40e-10, seconds_since_start = 1.0
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.58e+00, step_size = 0.9500, log_lik = -8886.68689, newton_decrement = 9.93e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.30e+00, step_size = 0.2375, log_lik = -8472.04265, newton_decrement = 5.51e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.97e+00, step_size = 0.0772, log_lik = -8390.19242, newton_decrement = 4.73e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.43e+00, step_size = 0.1304, log_lik = -8274.84653, newton_decrement = 3.63e+02, seconds_since_start = 0.3
# Iteration 5: norm_delta = 3.59e+00, step_size = 0.2205, log_lik = -8132.24298, newton_decrement = 2.28e+02, seconds_since_start = 0.4
# Iteration 6: norm_delta = 2.38e+00, step_size = 0.3726, log_lik = -7993.55412, newton_decrement = 9.56e+01, seconds_since_start = 0.5
# Iteration 7: norm_delta = 9.52e-01, step_size = 0.6296, log_lik = -7910.54127, newton_decrement = 1.49e+01, seconds_since_start = 0.6
# Iteration 8: norm_delta = 1.41e-02, step_size = 1.0000, log_lik = -7895.51181, newton_decrement = 1.56e-02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 2.86e-05, step_size = 1.0000, log_lik = -7895.49617, newton_decrement = 1.87e-07, seconds_since_start = 0.7
# Iteration 10: norm_delta = 3.38e-09, step_size = 1.0000, log_lik = -7895.49617, newton_decrement = 6.34e-16, seconds_since_start = 0.8
# Convergence success after 10 iterations.
# Average C-Index from cross-validation: 0.8877
# Best C-Index from cross-validation: 0.8926
# Standard Deviation of C-Index from cross-validation: 0.0054
#                                               coef  exp(coef)      se(coef)  \
# covariate
# subject_id                           -1.904957e-08   1.000000  1.041301e-08
# gender                                7.127598e-03   1.007153  6.775374e-02
# anchor_age                            3.501819e-01   1.419326  1.477955e-02
# disch_age                            -3.511265e-01   0.703895  1.474950e-02
# CKD_stage_first                      -1.083221e+00   0.338503  4.927538e-02
# ...                                            ...        ...           ...
# Sodium_mean                          -7.749229e-02   0.925434  5.663957e-02
# Hyperosmolality and/or hypernatremia -2.207014e-01   0.801956  1.059271e-01
# Lymphocytes_max                      -4.836652e-03   0.995175  5.403687e-03
# Hypoxemia                            -1.048674e-01   0.900444  8.487934e-02
# Rheumatoid arthritis                 -2.607979e-01   0.770437  1.879610e-01
#
#                                       coef lower 95%  coef upper 95%  \
# covariate
# subject_id                             -3.945869e-08    1.359558e-09
# gender                                 -1.256673e-01    1.399225e-01
# anchor_age                              3.212145e-01    3.791493e-01
# disch_age                              -3.800350e-01   -3.222180e-01
# CKD_stage_first                        -1.179799e+00   -9.866430e-01
# ...                                              ...             ...
# Sodium_mean                            -1.885038e-01    3.351922e-02
# Hyperosmolality and/or hypernatremia   -4.283146e-01   -1.308817e-02
# Lymphocytes_max                        -1.542768e-02    5.754379e-03
# Hypoxemia                              -2.712278e-01    6.149305e-02
# Rheumatoid arthritis                   -6.291948e-01    1.075990e-01
#
#                                       exp(coef) lower 95%  \
# covariate
# subject_id                                       1.000000
# gender                                           0.881908
# anchor_age                                       1.378801
# disch_age                                        0.683838
# CKD_stage_first                                  0.307341
# ...                                                   ...
# Sodium_mean                                      0.828197
# Hyperosmolality and/or hypernatremia             0.651606
# Lymphocytes_max                                  0.984691
# Hypoxemia                                        0.762443
# Rheumatoid arthritis                             0.533021
#
#                                       exp(coef) upper 95%  cmp to          z  \
# covariate
# subject_id                                       1.000000     0.0  -1.829401
# gender                                           1.150185     0.0   0.105199
# anchor_age                                       1.461041     0.0  23.693684
# disch_age                                        0.724540     0.0 -23.805989
# CKD_stage_first                                  0.372826     0.0 -21.983006
# ...                                                   ...     ...        ...
# Sodium_mean                                      1.034087     0.0  -1.368165
# Hyperosmolality and/or hypernatremia             0.986997     0.0  -2.083522
# Lymphocytes_max                                  1.005771     0.0  -0.895065
# Hypoxemia                                        1.063423     0.0  -1.235488
# Rheumatoid arthritis                             1.113601     0.0  -1.387510
#
#                                                   p    -log2(p)
# covariate
# subject_id                             6.733962e-02    3.892401
# gender                                 9.162182e-01    0.126237
# anchor_age                            4.188954e-124  409.852494
# disch_age                             2.895311e-125  413.707293
# CKD_stage_first                       4.187936e-107  353.380067
# ...                                             ...         ...
# Sodium_mean                            1.712603e-01    2.545737
# Hyperosmolality and/or hypernatremia   3.720364e-02    4.748413
# Lymphocytes_max                        3.707522e-01    1.431473
# Hypoxemia                              2.166490e-01    2.206569
# Rheumatoid arthritis                   1.652862e-01    2.596962
#
# [81 rows x 11 columns]
#                                    test_statistic         p  -log2(p)
# Acidosis                                 8.263908  0.004044  7.949966
# Acute kidney failure, unspecified        1.714633  0.190385  2.393005
# Albumin/Creatinine,_Urine_first          0.702121  0.402072  1.314474
# Albumin/Creatinine,_Urine_last           0.128523  0.719968  0.473994
# Albumin/Creatinine,_Urine_max            0.068570  0.793430  0.333825
# ...                                           ...       ...       ...
# eGFR_median                              0.047337  0.827764  0.272709
# eGFR_min                                 0.030515  0.861326  0.215369
# gender                                   3.326908  0.068155  3.875039
# race_WHITE                               0.512960  0.473860  1.077467
# subject_id                               0.002968  0.956552  0.064084
#
# [81 rows x 3 columns]
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sksurv\metrics.py:482: RuntimeWarning: invalid value encountered in divide
#   true_pos = cumsum_tp / cumsum_tp[-1]
