# %%
import sys
import os

# Use os.getcwd() to get the current working directory in a Jupyter notebook
parent_dir = os.path.dirname(os.getcwd())  # Get the parent directory of the current working directory
sys.path.append(parent_dir)

# %%
import pandas as pd
from skopt.space import Real, Integer
from driver import Driver

# %% [markdown]
# # Load Cleaned Master MIMIC-IV Dataset

# %%
# Cleaned Master MIMIC Data Set
df_master = pd.read_pickle('../MIMIC_IV/df_ckd_master_clean.pkl')
df_base = pd.read_pickle('../MIMIC_IV/df_ckd_base.pkl')

# %% [markdown]
# # Evaluate Decision Tree Pipeline

# %%
DecisionTree_cfg = {
    'name': 'DecisionTree', # Feature selection model long name
    'tag': 'dct', # Feature selection model identifier tag
    'response': 'stage_delta',  # Response variable for binary classification and Cox Proportional Hazards
    'duration': 'duration', # Duration in days until response or censorship
    'n_novel': 40, # Number of ranked novel features included in augmented KFRE dataset
    'test_size': 0.1, # Ratio of data reserved for testing
    'val_size': 0.2, # Ratio of data reserved for testing in validation sets
    'n_valsets': 5, # Number of training validation sets
    'n_bayesian': 10, # Number of Bayesian hyperparameter optimization iterations 
    'n_folds': 5, # Number of folds for CoxPH cross validation
    'penalizer': 0.0007, # CoxPH model penalizer
    'auc_space': [
        Integer(1, 50, name='max_depth'),
        Integer(2, 20, name="min_samples_split"),
        Integer(1, 20, name="min_samples_leaf"),
    ], # Search space for Bayesian hyperparameter optimization
    'random_state': 42 # Seed for reproducibility
}

driver = Driver(DecisionTree_cfg, df_master, df_base)
driver.ClassicalLearningPipe()
# Out:
# Testing params: {'max_depth': 40, 'min_samples_split': 5, 'min_samples_leaf': 16}
# AUC for params: 0.8585443793575651
# Testing params: {'max_depth': 30, 'min_samples_split': 10, 'min_samples_leaf': 3}
# AUC for params: 0.7831827569625254
# Testing params: {'max_depth': 24, 'min_samples_split': 8, 'min_samples_leaf': 4}
# AUC for params: 0.7903196902781073
# Testing params: {'max_depth': 33, 'min_samples_split': 3, 'min_samples_leaf': 15}
# AUC for params: 0.8498445547723783
# Testing params: {'max_depth': 47, 'min_samples_split': 2, 'min_samples_leaf': 20}
# AUC for params: 0.8610599788743898
# Testing params: {'max_depth': 31, 'min_samples_split': 13, 'min_samples_leaf': 1}
# AUC for params: 0.7785590770755769
# Testing params: {'max_depth': 2, 'min_samples_split': 11, 'min_samples_leaf': 9}
# AUC for params: 0.7820774898386798
# Testing params: {'max_depth': 3, 'min_samples_split': 20, 'min_samples_leaf': 5}
# AUC for params: 0.8438820479201118
# Testing params: {'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 8}
# AUC for params: 0.9039762514356813
# Testing params: {'max_depth': 49, 'min_samples_split': 10, 'min_samples_leaf': 17}
# AUC for params: 0.8597651462582789
# Best parameters found:  {'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 8}
# Best average AUC across validation sets:  0.9039762514356813
# Test AUC: 0.656556964573269
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\shap\plots\_beeswarm.py:962: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   pl.tight_layout()
# Iteration 1: norm_delta = 6.57e+00, step_size = 0.9500, log_lik = -8744.90665, newton_decrement = 9.41e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.29e+00, step_size = 0.2375, log_lik = -8352.02236, newton_decrement = 5.41e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.95e+00, step_size = 0.0772, log_lik = -8271.67749, newton_decrement = 4.66e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.40e+00, step_size = 0.1304, log_lik = -8157.98496, newton_decrement = 3.59e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.55e+00, step_size = 0.2205, log_lik = -8016.95575, newton_decrement = 2.25e+02, seconds_since_start = 0.4
# Iteration 6: norm_delta = 2.34e+00, step_size = 0.3726, log_lik = -7880.18262, newton_decrement = 9.28e+01, seconds_since_start = 0.5
# Iteration 7: norm_delta = 9.33e-01, step_size = 0.6296, log_lik = -7799.79500, newton_decrement = 1.38e+01, seconds_since_start = 0.6
# Iteration 8: norm_delta = 1.29e-02, step_size = 1.0000, log_lik = -7785.87042, newton_decrement = 8.07e-03, seconds_since_start = 0.7
# Iteration 9: norm_delta = 1.09e-05, step_size = 1.0000, log_lik = -7785.86234, newton_decrement = 2.62e-08, seconds_since_start = 0.8
# Convergence success after 9 iterations.
# Iteration 1: norm_delta = 6.68e+00, step_size = 0.9500, log_lik = -8829.99117, newton_decrement = 9.45e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.38e+00, step_size = 0.2375, log_lik = -8434.77861, newton_decrement = 5.46e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.03e+00, step_size = 0.0772, log_lik = -8353.76223, newton_decrement = 4.68e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.90e+00, step_size = 0.0326, log_lik = -8323.70662, newton_decrement = 4.40e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.67e+00, step_size = 0.0551, log_lik = -8276.56783, newton_decrement = 3.95e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.30e+00, step_size = 0.0931, log_lik = -8206.47584, newton_decrement = 3.27e+02, seconds_since_start = 0.5
# Iteration 7: norm_delta = 3.71e+00, step_size = 0.1574, log_lik = -8111.59961, newton_decrement = 2.35e+02, seconds_since_start = 0.6
# Iteration 8: norm_delta = 2.82e+00, step_size = 0.2660, log_lik = -8003.34344, newton_decrement = 1.28e+02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 1.64e+00, step_size = 0.4496, log_lik = -7913.82618, newton_decrement = 4.00e+01, seconds_since_start = 0.8
# Iteration 10: norm_delta = 4.28e-01, step_size = 0.7598, log_lik = -7875.97322, newton_decrement = 2.54e+00, seconds_since_start = 0.9
# Iteration 11: norm_delta = 2.63e-03, step_size = 1.0000, log_lik = -7873.42023, newton_decrement = 2.63e-04, seconds_since_start = 1.0
# Iteration 12: norm_delta = 3.31e-07, step_size = 1.0000, log_lik = -7873.41997, newton_decrement = 2.21e-11, seconds_since_start = 1.1
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.60e+00, step_size = 0.9500, log_lik = -8805.41001, newton_decrement = 9.24e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.32e+00, step_size = 0.2375, log_lik = -8419.01189, newton_decrement = 5.35e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.98e+00, step_size = 0.0772, log_lik = -8339.60244, newton_decrement = 4.59e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.43e+00, step_size = 0.1304, log_lik = -8227.61865, newton_decrement = 3.52e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.59e+00, step_size = 0.2205, log_lik = -8089.64002, newton_decrement = 2.17e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.37e+00, step_size = 0.3726, log_lik = -7957.75853, newton_decrement = 8.75e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.49e-01, step_size = 0.6296, log_lik = -7882.04764, newton_decrement = 1.27e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 1.25e-02, step_size = 1.0000, log_lik = -7869.29439, newton_decrement = 5.46e-03, seconds_since_start = 0.7
# Iteration 9: norm_delta = 5.22e-06, step_size = 1.0000, log_lik = -7869.28893, newton_decrement = 3.88e-09, seconds_since_start = 0.8
# Convergence success after 9 iterations.
# Iteration 1: norm_delta = 6.69e+00, step_size = 0.9500, log_lik = -9037.41005, newton_decrement = 9.46e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.40e+00, step_size = 0.2375, log_lik = -8642.03133, newton_decrement = 5.50e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.06e+00, step_size = 0.0772, log_lik = -8560.42593, newton_decrement = 4.73e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.92e+00, step_size = 0.0326, log_lik = -8530.07041, newton_decrement = 4.45e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.70e+00, step_size = 0.0551, log_lik = -8482.40389, newton_decrement = 4.00e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.33e+00, step_size = 0.0931, log_lik = -8411.37042, newton_decrement = 3.33e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 3.74e+00, step_size = 0.1574, log_lik = -8314.80702, newton_decrement = 2.41e+02, seconds_since_start = 0.6
# Iteration 8: norm_delta = 2.85e+00, step_size = 0.2660, log_lik = -8203.66645, newton_decrement = 1.33e+02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 1.65e+00, step_size = 0.4496, log_lik = -8110.73429, newton_decrement = 4.16e+01, seconds_since_start = 0.8
# Iteration 10: norm_delta = 4.30e-01, step_size = 0.7598, log_lik = -8071.37823, newton_decrement = 2.62e+00, seconds_since_start = 0.9
# Iteration 11: norm_delta = 2.58e-03, step_size = 1.0000, log_lik = -8068.75176, newton_decrement = 2.62e-04, seconds_since_start = 1.0
# Iteration 12: norm_delta = 2.42e-07, step_size = 1.0000, log_lik = -8068.75150, newton_decrement = 1.04e-11, seconds_since_start = 1.1
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.64e+00, step_size = 0.9500, log_lik = -8886.68689, newton_decrement = 9.72e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.33e+00, step_size = 0.2375, log_lik = -8480.63303, newton_decrement = 5.53e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.99e+00, step_size = 0.0772, log_lik = -8398.47844, newton_decrement = 4.76e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.45e+00, step_size = 0.1304, log_lik = -8282.42313, newton_decrement = 3.66e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.60e+00, step_size = 0.2205, log_lik = -8138.68815, newton_decrement = 2.30e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.38e+00, step_size = 0.3726, log_lik = -7999.22213, newton_decrement = 9.48e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.52e-01, step_size = 0.6296, log_lik = -7917.02552, newton_decrement = 1.45e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 1.33e-02, step_size = 1.0000, log_lik = -7902.38970, newton_decrement = 1.21e-02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.59e-05, step_size = 1.0000, log_lik = -7902.37756, newton_decrement = 4.21e-08, seconds_since_start = 0.8
# Convergence success after 9 iterations.
# Average C-Index from cross-validation: 0.8878
# Best C-Index from cross-validation: 0.8990
# Standard Deviation of C-Index from cross-validation: 0.0072
#                                                             coef  exp(coef)  \
# covariate
# subject_id                                         -1.643197e-08   1.000000
# gender                                              1.342270e-01   1.143652
# anchor_age                                          3.490352e-01   1.417699
# disch_age                                          -3.509800e-01   0.703998
# CKD_stage_first                                    -1.042343e+00   0.352627
# ...                                                          ...        ...
# Chronic airway obstruction, not elsewhere class... -3.825020e-02   0.962472
# Other secondary thrombocytopenia                   -2.967514e-01   0.743229
# Percutaneous transluminal coronary angioplasty ...  7.452089e-02   1.077368
# Acute posthemorrhagic anemia                       -1.738057e-01   0.840460
# Old myocardial infarction                           1.153127e-01   1.122224
#
#                                                         se(coef)  \
# covariate
# subject_id                                          1.032137e-08
# gender                                              6.998031e-02
# anchor_age                                          1.483605e-02
# disch_age                                           1.479180e-02
# CKD_stage_first                                     4.590605e-02
# ...                                                          ...
# Chronic airway obstruction, not elsewhere class...  8.196797e-02
# Other secondary thrombocytopenia                    1.680987e-01
# Percutaneous transluminal coronary angioplasty ...  8.876443e-02
# Acute posthemorrhagic anemia                        7.425043e-02
# Old myocardial infarction                           8.240687e-02
#
#                                                     coef lower 95%  \
# covariate
# subject_id                                           -3.666148e-08
# gender                                               -2.931904e-03
# anchor_age                                            3.199570e-01
# disch_age                                            -3.799714e-01
# CKD_stage_first                                      -1.132317e+00
# ...                                                            ...
# Chronic airway obstruction, not elsewhere class...   -1.989045e-01
# Other secondary thrombocytopenia                     -6.262189e-01
# Percutaneous transluminal coronary angioplasty ...   -9.945419e-02
# Acute posthemorrhagic anemia                         -3.193339e-01
# Old myocardial infarction                            -4.620184e-02
#
#                                                     coef upper 95%  \
# covariate
# subject_id                                            3.797536e-09
# gender                                                2.713859e-01
# anchor_age                                            3.781133e-01
# disch_age                                            -3.219886e-01
# CKD_stage_first                                      -9.523690e-01
# ...                                                            ...
# Chronic airway obstruction, not elsewhere class...    1.224041e-01
# Other secondary thrombocytopenia                      3.271606e-02
# Percutaneous transluminal coronary angioplasty ...    2.484960e-01
# Acute posthemorrhagic anemia                         -2.827755e-02
# Old myocardial infarction                             2.768271e-01
#
#                                                     exp(coef) lower 95%  \
# covariate
# subject_id                                                     1.000000
# gender                                                         0.997072
# anchor_age                                                     1.377069
# disch_age                                                      0.683881
# CKD_stage_first                                                0.322286
# ...                                                                 ...
# Chronic airway obstruction, not elsewhere class...             0.819628
# Other secondary thrombocytopenia                               0.534609
# Percutaneous transluminal coronary angioplasty ...             0.905331
# Acute posthemorrhagic anemia                                   0.726633
# Old myocardial infarction                                      0.954849
#
#                                                     exp(coef) upper 95%  \
# covariate
# subject_id                                                     1.000000
# gender                                                         1.311781
# anchor_age                                                     1.459528
# disch_age                                                      0.724706
# CKD_stage_first                                                0.385826
# ...                                                                 ...
# Chronic airway obstruction, not elsewhere class...             1.130211
# Other secondary thrombocytopenia                               1.033257
# Percutaneous transluminal coronary angioplasty ...             1.282096
# Acute posthemorrhagic anemia                                   0.972119
# Old myocardial infarction                                      1.318938
#
#                                                     cmp to          z  \
# covariate
# subject_id                                             0.0  -1.592034
# gender                                                 0.0   1.918068
# anchor_age                                             0.0  23.526153
# disch_age                                              0.0 -23.728010
# CKD_stage_first                                        0.0 -22.706011
# ...                                                    ...        ...
# Chronic airway obstruction, not elsewhere class...     0.0  -0.466648
# Other secondary thrombocytopenia                       0.0  -1.765340
# Percutaneous transluminal coronary angioplasty ...     0.0   0.839536
# Acute posthemorrhagic anemia                           0.0  -2.340804
# Old myocardial infarction                              0.0   1.399309
#
#                                                                 p    -log2(p)
# covariate
# subject_id                                           1.113770e-01    3.166477
# gender                                               5.510241e-02    4.181741
# anchor_age                                          2.202814e-122  404.135880
# disch_age                                           1.853552e-124  411.028791
# CKD_stage_first                                     3.907475e-114  376.733566
# ...                                                           ...         ...
# Chronic airway obstruction, not elsewhere class...   6.407516e-01    0.642163
# Other secondary thrombocytopenia                     7.750665e-02    3.689536
# Percutaneous transluminal coronary angioplasty ...   4.011689e-01    1.317718
# Acute posthemorrhagic anemia                         1.924225e-02    5.699578
# Old myocardial infarction                            1.617204e-01    2.628426
#
# [81 rows x 11 columns]
#                                  test_statistic         p  -log2(p)
# Acute posthemorrhagic anemia           0.057222  0.810942  0.302329
# Albumin/Creatinine,_Urine_first        0.028279  0.866455  0.206803
# Albumin/Creatinine,_Urine_last         0.058161  0.809427  0.305027
# Albumin/Creatinine,_Urine_max          0.013770  0.906585  0.141486
# Albumin/Creatinine,_Urine_mean         0.000982  0.975002  0.036523
# ...                                         ...       ...       ...
# eGFR_median                            0.002649  0.958950  0.060472
# eGFR_min                               0.055720  0.813393  0.297975
# gender                                 0.059267  0.807659  0.308182
# marital_status_WIDOWED                 0.000005  0.998280  0.002483
# subject_id                             0.054641  0.815176  0.294817
#
# [81 rows x 3 columns]
