# %%
import sys
import os

# Use os.getcwd() to get the current working directory in a Jupyter notebook
parent_dir = os.path.dirname(os.getcwd())  # Get the parent directory of the current working directory
sys.path.append(parent_dir)

# %%
import pandas as pd
from skopt.space import Real, Integer
from driver import Driver

# %% [markdown]
# # Load Cleaned Master MIMIC-IV Dataset

# %%
# Cleaned Master MIMIC Data Set
df_master = pd.read_pickle('../MIMIC_IV/df_ckd_master_clean.pkl')
df_base = pd.read_pickle('../MIMIC_IV/df_ckd_base.pkl')

# %% [markdown]
# # Evaluate Logistic Regression Pipeline

# %%
LogisticRegression_cfg = {
    'tag': 'lr', # Identifier tag for feature selection model
    'response': 'stage_delta',  # Response variable for binary classification and Cox Proportional Hazards
    'duration': 'duration', # Duration in days until response or censorship
    'n_novel': 40, # Number of ranked novel features included in augmented KFRE dataset
    'test_size': 0.1, # Ratio of data reserved for testing
    'val_size': 0.2, # Ratio of data reserved for testing in validation sets
    'n_valsets': 5, # Number of training validation sets
    'n_bayesian': 10, # Number of Bayesian hyperparameter optimization iterations 
    'n_folds': 5, # Number of folds for CoxPH cross validation
    'penalizer': 0.0007, # CoxPH model penalizer
    'auc_space': [
        Real(0.01, 1.0, name="C")
    ], # Search space for Bayesian hyperparameter optimization
    'random_state': 42 # Seed for reproducibility
}

driver = Driver(LogisticRegression_cfg, df_master, df_base)
driver.ClassicalLearningPipe()
# Out:
# Testing params: {'C': 0.7985775569916307}
# AUC for params: 0.7921752329607175
# Testing params: {'C': 0.1916004419675022}
# AUC for params: 0.8031571753776646
# Testing params: {'C': 0.7818940902700418}
# AUC for params: 0.792021218952944
# Testing params: {'C': 0.6008816563670223}
# AUC for params: 0.7942279012777504
# Testing params: {'C': 0.45137442532505534}
# AUC for params: 0.7960840899481706
# Testing params: {'C': 0.10897516665982288}
# AUC for params: 0.8079272736457664
# Testing params: {'C': 0.4646564030462086}
# AUC for params: 0.7960496258095313
# Testing params: {'C': 0.3403715250276317}
# AUC for params: 0.7984274822730675
# Testing params: {'C': 0.1514381497427214}
# AUC for params: 0.8051079511814898
# Testing params: {'C': 0.6543795882193645}
# AUC for params: 0.7930779022980582
# Best parameters found:  {'C': 0.10897516665982288}
# Best average AUC across validation sets:  0.8079272736457664
# Test AUC: 0.7009410225442835
# Iteration 1: norm_delta = 6.64e+00, step_size = 0.9500, log_lik = -8744.90665, newton_decrement = 1.03e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.29e+00, step_size = 0.2375, log_lik = -8314.57198, newton_decrement = 5.55e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.94e+00, step_size = 0.0772, log_lik = -8232.14446, newton_decrement = 4.72e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.38e+00, step_size = 0.1304, log_lik = -8117.09809, newton_decrement = 3.57e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.53e+00, step_size = 0.2205, log_lik = -7977.18943, newton_decrement = 2.19e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.33e+00, step_size = 0.3726, log_lik = -7844.51264, newton_decrement = 8.91e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.36e-01, step_size = 0.6296, log_lik = -7767.23611, newton_decrement = 1.37e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 1.58e-02, step_size = 1.0000, log_lik = -7753.35400, newton_decrement = 1.50e-02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 4.23e-05, step_size = 1.0000, log_lik = -7753.33897, newton_decrement = 2.66e-07, seconds_since_start = 0.8
# Iteration 10: norm_delta = 1.95e-09, step_size = 1.0000, log_lik = -7753.33897, newton_decrement = 5.85e-16, seconds_since_start = 0.9
# Convergence success after 10 iterations.
# Iteration 1: norm_delta = 6.70e+00, step_size = 0.9500, log_lik = -8829.99117, newton_decrement = 1.03e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.36e+00, step_size = 0.2375, log_lik = -8400.74412, newton_decrement = 5.58e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.01e+00, step_size = 0.0772, log_lik = -8317.87677, newton_decrement = 4.75e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.88e+00, step_size = 0.0326, log_lik = -8287.41500, newton_decrement = 4.44e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.65e+00, step_size = 0.0551, log_lik = -8239.78490, newton_decrement = 3.97e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.27e+00, step_size = 0.0931, log_lik = -8169.28288, newton_decrement = 3.27e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 3.69e+00, step_size = 0.1574, log_lik = -8074.39242, newton_decrement = 2.34e+02, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.81e+00, step_size = 0.2660, log_lik = -7966.50862, newton_decrement = 1.28e+02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.64e+00, step_size = 0.4496, log_lik = -7876.88262, newton_decrement = 4.09e+01, seconds_since_start = 0.9
# Iteration 10: norm_delta = 4.34e-01, step_size = 0.7598, log_lik = -7838.01455, newton_decrement = 2.82e+00, seconds_since_start = 0.9
# Iteration 11: norm_delta = 3.95e-03, step_size = 1.0000, log_lik = -7835.17119, newton_decrement = 7.20e-04, seconds_since_start = 1.0
# Iteration 12: norm_delta = 3.09e-06, step_size = 1.0000, log_lik = -7835.17047, newton_decrement = 4.35e-10, seconds_since_start = 1.1
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.64e+00, step_size = 0.9500, log_lik = -8805.41001, newton_decrement = 1.02e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.31e+00, step_size = 0.2375, log_lik = -8381.34364, newton_decrement = 5.46e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.96e+00, step_size = 0.0772, log_lik = -8300.38603, newton_decrement = 4.63e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.41e+00, step_size = 0.1304, log_lik = -8187.48594, newton_decrement = 3.49e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.56e+00, step_size = 0.2205, log_lik = -8050.41248, newton_decrement = 2.14e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.36e+00, step_size = 0.3726, log_lik = -7920.83182, newton_decrement = 8.66e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.52e-01, step_size = 0.6296, log_lik = -7845.75054, newton_decrement = 1.32e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 1.76e-02, step_size = 1.0000, log_lik = -7832.36145, newton_decrement = 1.37e-02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 5.84e-05, step_size = 1.0000, log_lik = -7832.34774, newton_decrement = 1.32e-07, seconds_since_start = 0.9
# Iteration 10: norm_delta = 1.44e-09, step_size = 1.0000, log_lik = -7832.34774, newton_decrement = 6.21e-17, seconds_since_start = 1.0
# Convergence success after 10 iterations.
# Iteration 1: norm_delta = 6.77e+00, step_size = 0.9500, log_lik = -9037.41005, newton_decrement = 1.01e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.42e+00, step_size = 0.2375, log_lik = -8614.32380, newton_decrement = 5.54e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.07e+00, step_size = 0.0772, log_lik = -8532.13375, newton_decrement = 4.72e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.93e+00, step_size = 0.0326, log_lik = -8501.87106, newton_decrement = 4.42e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.70e+00, step_size = 0.0551, log_lik = -8454.51711, newton_decrement = 3.95e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.32e+00, step_size = 0.0931, log_lik = -8384.32916, newton_decrement = 3.26e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 3.73e+00, step_size = 0.1574, log_lik = -8289.62277, newton_decrement = 2.34e+02, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.84e+00, step_size = 0.2660, log_lik = -8181.43453, newton_decrement = 1.30e+02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.65e+00, step_size = 0.4496, log_lik = -8090.77888, newton_decrement = 4.19e+01, seconds_since_start = 0.9
# Iteration 10: norm_delta = 4.39e-01, step_size = 0.7598, log_lik = -8050.89634, newton_decrement = 2.98e+00, seconds_since_start = 1.0
# Iteration 11: norm_delta = 4.35e-03, step_size = 1.0000, log_lik = -8047.89287, newton_decrement = 1.02e-03, seconds_since_start = 1.1
# Iteration 12: norm_delta = 4.42e-06, step_size = 1.0000, log_lik = -8047.89185, newton_decrement = 9.56e-10, seconds_since_start = 1.1
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.68e+00, step_size = 0.9500, log_lik = -8886.68689, newton_decrement = 1.04e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.33e+00, step_size = 0.2375, log_lik = -8454.66295, newton_decrement = 5.61e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.98e+00, step_size = 0.0772, log_lik = -8371.35856, newton_decrement = 4.78e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.42e+00, step_size = 0.1304, log_lik = -8254.87712, newton_decrement = 3.62e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.57e+00, step_size = 0.2205, log_lik = -8112.76034, newton_decrement = 2.23e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.36e+00, step_size = 0.3726, log_lik = -7977.15894, newton_decrement = 9.21e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.54e-01, step_size = 0.6296, log_lik = -7897.15861, newton_decrement = 1.46e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.02e-02, step_size = 1.0000, log_lik = -7882.31770, newton_decrement = 2.30e-02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.03e-04, step_size = 1.0000, log_lik = -7882.29466, newton_decrement = 5.20e-07, seconds_since_start = 0.9
# Iteration 10: norm_delta = 5.21e-09, step_size = 1.0000, log_lik = -7882.29466, newton_decrement = 9.59e-16, seconds_since_start = 1.0
# Convergence success after 10 iterations.
# Average C-Index from cross-validation: 0.8891
# Best C-Index from cross-validation: 0.8977
# Standard Deviation of C-Index from cross-validation: 0.0097
#                                                     coef  exp(coef)  \
# covariate
# subject_id                                 -1.947439e-08   1.000000
# gender                                      9.171541e-02   1.096053
# anchor_age                                  3.511929e-01   1.420761
# disch_age                                  -3.517219e-01   0.703476
# CKD_stage_first                            -9.786184e-01   0.375830
# ...                                                  ...        ...
# Other second degree atrioventricular block -4.073802e-01   0.665391
# Monocytes_max                               1.042602e-03   1.001043
# Urea_Nitrogen_max                          -1.461484e-03   0.998540
# Hemoglobin_last_x                          -5.655099e-03   0.994361
# Monocytes_mean                              3.755992e-02   1.038274
#
#                                                 se(coef)  coef lower 95%  \
# covariate
# subject_id                                  1.033770e-08   -3.973592e-08
# gender                                      6.984365e-02   -4.517562e-02
# anchor_age                                  1.475934e-02    3.222651e-01
# disch_age                                   1.473095e-02   -3.805941e-01
# CKD_stage_first                             4.859923e-02   -1.073871e+00
# ...                                                  ...             ...
# Other second degree atrioventricular block  2.296097e-01   -8.574069e-01
# Monocytes_max                               9.317636e-03   -1.721963e-02
# Urea_Nitrogen_max                           1.818648e-03   -5.025968e-03
# Hemoglobin_last_x                           2.223951e-02   -4.924374e-02
# Monocytes_mean                              7.120292e-02   -1.019952e-01
#
#                                             coef upper 95%  \
# covariate
# subject_id                                    7.871342e-10
# gender                                        2.286064e-01
# anchor_age                                    3.801207e-01
# disch_age                                    -3.228498e-01
# CKD_stage_first                              -8.833656e-01
# ...                                                    ...
# Other second degree atrioventricular block    4.264650e-02
# Monocytes_max                                 1.930483e-02
# Urea_Nitrogen_max                             2.102999e-03
# Hemoglobin_last_x                             3.793354e-02
# Monocytes_mean                                1.771151e-01
#
#                                             exp(coef) lower 95%  \
# covariate
# subject_id                                             1.000000
# gender                                                 0.955830
# anchor_age                                             1.380251
# disch_age                                              0.683455
# CKD_stage_first                                        0.341683
# ...                                                         ...
# Other second degree atrioventricular block             0.424261
# Monocytes_max                                          0.982928
# Urea_Nitrogen_max                                      0.994987
# Hemoglobin_last_x                                      0.951949
# Monocytes_mean                                         0.903034
#
#                                             exp(coef) upper 95%  cmp to  \
# covariate
# subject_id                                             1.000000     0.0
# gender                                                 1.256847     0.0
# anchor_age                                             1.462461     0.0
# disch_age                                              0.724083     0.0
# CKD_stage_first                                        0.413389     0.0
# ...                                                         ...     ...
# Other second degree atrioventricular block             1.043569     0.0
# Monocytes_max                                          1.019492     0.0
# Urea_Nitrogen_max                                      1.002105     0.0
# Hemoglobin_last_x                                      1.038662     0.0
# Monocytes_mean                                         1.193768     0.0
#
#                                                     z              p  \
# covariate
# subject_id                                  -1.883822   5.958907e-02
# gender                                       1.313153   1.891313e-01
# anchor_age                                  23.794620  3.796790e-125
# disch_age                                  -23.876384  5.389365e-126
# CKD_stage_first                            -20.136500   3.534488e-90
# ...                                               ...            ...
# Other second degree atrioventricular block  -1.774229   7.602524e-02
# Monocytes_max                                0.111896   9.109063e-01
# Urea_Nitrogen_max                           -0.803611   4.216219e-01
# Hemoglobin_last_x                           -0.254282   7.992780e-01
# Monocytes_mean                               0.527505   5.978428e-01
#
#                                               -log2(p)
# covariate
# subject_id                                    4.068808
# gender                                        2.402540
# anchor_age                                  413.316232
# disch_age                                   416.132825
# CKD_stage_first                             297.152027
# ...                                                ...
# Other second degree atrioventricular block    3.717378
# Monocytes_max                                 0.134626
# Urea_Nitrogen_max                             1.245978
# Hemoglobin_last_x                             0.323231
# Monocytes_mean                                0.742162
#
# [82 rows x 11 columns]
#                                    test_statistic         p  -log2(p)
# Acute kidney failure, unspecified        1.547117  0.213562  2.227276
# Albumin/Creatinine,_Urine_first          0.095917  0.756786  0.402043
# Albumin/Creatinine,_Urine_last           0.000247  0.987454  0.018214
# Albumin/Creatinine,_Urine_max            0.037199  0.847059  0.239465
# Albumin/Creatinine,_Urine_mean           0.150847  0.697727  0.519264
# ...                                           ...       ...       ...
# eGFR_min                                 0.023636  0.877816  0.188010
# first_stage_icd                          3.875207  0.049004  4.350949
# gender                                   1.986181  0.158741  2.655255
# marital_status_SINGLE                    0.026272  0.871239  0.198860
# subject_id                               0.277684  0.598223  0.741245
#
# [82 rows x 3 columns]
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sksurv\metrics.py:482: RuntimeWarning: invalid value encountered in divide
#   true_pos = cumsum_tp / cumsum_tp[-1]
