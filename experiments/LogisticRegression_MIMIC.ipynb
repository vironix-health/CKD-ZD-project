# %%
import sys
import os

# Use os.getcwd() to get the current working directory in a Jupyter notebook
parent_dir = os.path.dirname(os.getcwd())  # Get the parent directory of the current working directory
sys.path.append(parent_dir)

# %%
import pandas as pd
from skopt.space import Real, Integer
from driver import Driver

# %% [markdown]
# # Load Cleaned Master MIMIC-IV Dataset

# %%
# Cleaned Master MIMIC Data Set
df_master = pd.read_pickle('../MIMIC_IV/df_ckd_master_clean.pkl')
df_base = pd.read_pickle('../MIMIC_IV/df_ckd_base.pkl')

# %% [markdown]
# # Evaluate Logistic Regression Pipeline

# %%
LogisticRegression_cfg = {
    'name': 'LogisticRegression',
    'tag': 'lr', # Identifier tag for feature selection model
    'response': 'stage_delta',  # Response variable for binary classification and Cox Proportional Hazards
    'duration': 'duration', # Duration in days until response or censorship
    'n_novel': 40, # Number of ranked novel features included in augmented KFRE dataset
    'test_size': 0.1, # Ratio of data reserved for testing
    'val_size': 0.2, # Ratio of data reserved for testing in validation sets
    'n_valsets': 5, # Number of training validation sets
    'n_bayesian': 10, # Number of Bayesian hyperparameter optimization iterations 
    'n_folds': 5, # Number of folds for CoxPH cross validation
    'penalizer': 0.0007, # CoxPH model penalizer
    'auc_space': [
        Real(0.01, 1.0, name="C")
    ], # Search space for Bayesian hyperparameter optimization
    'random_state': 42 # Seed for reproducibility
}

driver = Driver(LogisticRegression_cfg, df_master, df_base)
driver.ClassicalLearningPipe()
# Out:
# Testing params: {'C': 0.7985775569916307}
# AUC for params: 0.8254165328728058
# Testing params: {'C': 0.1916004419675022}
# AUC for params: 0.8322887977264711
# Testing params: {'C': 0.7818940902700418}
# AUC for params: 0.8255820401522527
# Testing params: {'C': 0.6008816563670223}
# AUC for params: 0.827066206874143
# Testing params: {'C': 0.45137442532505534}
# AUC for params: 0.8285878066022689
# Testing params: {'C': 0.10897516665982288}
# AUC for params: 0.834162710864662
# Testing params: {'C': 0.4646564030462086}
# AUC for params: 0.8284118467866592
# Testing params: {'C': 0.3403715250276317}
# AUC for params: 0.829782221358393
# Testing params: {'C': 0.1514381497427214}
# AUC for params: 0.8331093992629395
# Testing params: {'C': 0.6543795882193645}
# AUC for params: 0.8268488745862766
# Best parameters found:  {'C': 0.10897516665982288}
# Best average AUC across validation sets:  0.834162710864662
# Test AUC: 0.7091082930756843
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\shap\plots\_beeswarm.py:962: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   pl.tight_layout()
# Iteration 1: norm_delta = 6.49e+00, step_size = 0.9500, log_lik = -8744.90665, newton_decrement = 1.03e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.21e+00, step_size = 0.2375, log_lik = -8317.55937, newton_decrement = 5.50e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.88e+00, step_size = 0.0772, log_lik = -8235.93183, newton_decrement = 4.71e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.35e+00, step_size = 0.1304, log_lik = -8121.12105, newton_decrement = 3.60e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.52e+00, step_size = 0.2205, log_lik = -7979.60584, newton_decrement = 2.25e+02, seconds_since_start = 0.4
# Iteration 6: norm_delta = 2.34e+00, step_size = 0.3726, log_lik = -7842.69032, newton_decrement = 9.35e+01, seconds_since_start = 0.5
# Iteration 7: norm_delta = 9.39e-01, step_size = 0.6296, log_lik = -7761.52439, newton_decrement = 1.43e+01, seconds_since_start = 0.6
# Iteration 8: norm_delta = 1.56e-02, step_size = 1.0000, log_lik = -7747.01190, newton_decrement = 1.57e-02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 6.70e-05, step_size = 1.0000, log_lik = -7746.99618, newton_decrement = 7.04e-07, seconds_since_start = 0.8
# Iteration 10: norm_delta = 5.90e-09, step_size = 1.0000, log_lik = -7746.99618, newton_decrement = 5.48e-15, seconds_since_start = 0.9
# Convergence success after 10 iterations.
# Iteration 1: norm_delta = 6.61e+00, step_size = 0.9500, log_lik = -8829.99117, newton_decrement = 1.01e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.31e+00, step_size = 0.2375, log_lik = -8406.72627, newton_decrement = 5.61e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.97e+00, step_size = 0.0772, log_lik = -8323.52579, newton_decrement = 4.80e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.43e+00, step_size = 0.1304, log_lik = -8206.39740, newton_decrement = 3.68e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.59e+00, step_size = 0.2205, log_lik = -8061.96040, newton_decrement = 2.30e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.38e+00, step_size = 0.3726, log_lik = -7922.32954, newton_decrement = 9.53e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.62e-01, step_size = 0.6296, log_lik = -7839.58927, newton_decrement = 1.47e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.07e-02, step_size = 1.0000, log_lik = -7824.71121, newton_decrement = 1.37e-02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 9.68e-05, step_size = 1.0000, log_lik = -7824.69753, newton_decrement = 2.51e-07, seconds_since_start = 0.8
# Iteration 10: norm_delta = 3.92e-09, step_size = 1.0000, log_lik = -7824.69753, newton_decrement = 3.79e-16, seconds_since_start = 0.9
# Convergence success after 10 iterations.
# Iteration 1: norm_delta = 6.54e+00, step_size = 0.9500, log_lik = -8805.41001, newton_decrement = 1.00e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.26e+00, step_size = 0.2375, log_lik = -8388.07699, newton_decrement = 5.49e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.92e+00, step_size = 0.0772, log_lik = -8306.64728, newton_decrement = 4.69e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.39e+00, step_size = 0.1304, log_lik = -8192.28431, newton_decrement = 3.58e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.55e+00, step_size = 0.2205, log_lik = -8051.85561, newton_decrement = 2.22e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.36e+00, step_size = 0.3726, log_lik = -7917.05214, newton_decrement = 9.12e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.51e-01, step_size = 0.6296, log_lik = -7837.93479, newton_decrement = 1.39e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.02e-02, step_size = 1.0000, log_lik = -7823.85775, newton_decrement = 1.39e-02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 9.43e-05, step_size = 1.0000, log_lik = -7823.84384, newton_decrement = 2.40e-07, seconds_since_start = 0.8
# Iteration 10: norm_delta = 3.51e-09, step_size = 1.0000, log_lik = -7823.84384, newton_decrement = 3.03e-16, seconds_since_start = 0.9
# Convergence success after 10 iterations.
# Iteration 1: norm_delta = 6.68e+00, step_size = 0.9500, log_lik = -9037.41005, newton_decrement = 1.01e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.37e+00, step_size = 0.2375, log_lik = -8616.09550, newton_decrement = 5.57e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.02e+00, step_size = 0.0772, log_lik = -8533.45069, newton_decrement = 4.77e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.89e+00, step_size = 0.0326, log_lik = -8502.85374, newton_decrement = 4.48e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.66e+00, step_size = 0.0551, log_lik = -8454.87282, newton_decrement = 4.02e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.30e+00, step_size = 0.0931, log_lik = -8383.49593, newton_decrement = 3.34e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 3.72e+00, step_size = 0.1574, log_lik = -8286.61376, newton_decrement = 2.42e+02, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.84e+00, step_size = 0.2660, log_lik = -8174.98614, newton_decrement = 1.35e+02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.65e+00, step_size = 0.4496, log_lik = -8080.64117, newton_decrement = 4.36e+01, seconds_since_start = 0.9
# Iteration 10: norm_delta = 4.39e-01, step_size = 0.7598, log_lik = -8039.21426, newton_decrement = 3.00e+00, seconds_since_start = 1.0
# Iteration 11: norm_delta = 5.18e-03, step_size = 1.0000, log_lik = -8036.19786, newton_decrement = 8.51e-04, seconds_since_start = 1.1
# Iteration 12: norm_delta = 7.20e-06, step_size = 1.0000, log_lik = -8036.19701, newton_decrement = 1.40e-09, seconds_since_start = 1.2
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.59e+00, step_size = 0.9500, log_lik = -8886.68689, newton_decrement = 1.03e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.27e+00, step_size = 0.2375, log_lik = -8457.03510, newton_decrement = 5.63e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.93e+00, step_size = 0.0772, log_lik = -8373.42654, newton_decrement = 4.82e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.39e+00, step_size = 0.1304, log_lik = -8255.74643, newton_decrement = 3.70e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.55e+00, step_size = 0.2205, log_lik = -8110.49433, newton_decrement = 2.32e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.36e+00, step_size = 0.3726, log_lik = -7969.46823, newton_decrement = 9.73e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.47e-01, step_size = 0.6296, log_lik = -7884.94776, newton_decrement = 1.54e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.22e-02, step_size = 1.0000, log_lik = -7869.33288, newton_decrement = 2.25e-02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 1.78e-04, step_size = 1.0000, log_lik = -7869.31029, newton_decrement = 9.58e-07, seconds_since_start = 0.8
# Iteration 10: norm_delta = 1.43e-08, step_size = 1.0000, log_lik = -7869.31028, newton_decrement = 5.20e-15, seconds_since_start = 0.9
# Convergence success after 10 iterations.
# Average C-Index from cross-validation: 0.8897
# Best C-Index from cross-validation: 0.8970
# Standard Deviation of C-Index from cross-validation: 0.0079
#                                                             coef  exp(coef)  \
# covariate
# subject_id                                         -1.569410e-08   1.000000
# gender                                              1.687769e-01   1.183856
# anchor_age                                          3.440796e-01   1.410691
# disch_age                                          -3.471907e-01   0.706671
# CKD_stage_first                                    -9.929774e-01   0.370472
# ...                                                          ...        ...
# Creatinine_median                                   9.873724e-02   1.103776
# Diabetes mellitus without mention of complicati... -1.648320e-01   0.848036
# Cholesterol,_LDL,_Calculated_median                 2.679886e-03   1.002683
# Monocytes_mean                                      1.253419e-02   1.012613
# Chloride_median                                     5.817100e-02   1.059896
#
#                                                         se(coef)  \
# covariate
# subject_id                                          1.029750e-08
# gender                                              7.167027e-02
# anchor_age                                          1.487181e-02
# disch_age                                           1.484763e-02
# CKD_stage_first                                     4.764787e-02
# ...                                                          ...
# Creatinine_median                                   3.624385e-02
# Diabetes mellitus without mention of complicati...  6.472132e-02
# Cholesterol,_LDL,_Calculated_median                 1.356704e-03
# Monocytes_mean                                      2.448720e-02
# Chloride_median                                     1.990799e-02
#
#                                                     coef lower 95%  \
# covariate
# subject_id                                           -3.587684e-08
# gender                                                2.830573e-02
# anchor_age                                            3.149314e-01
# disch_age                                            -3.762915e-01
# CKD_stage_first                                      -1.086365e+00
# ...                                                            ...
# Creatinine_median                                     2.770060e-02
# Diabetes mellitus without mention of complicati...   -2.916835e-01
# Cholesterol,_LDL,_Calculated_median                   2.079538e-05
# Monocytes_mean                                       -3.545983e-02
# Chloride_median                                       1.915205e-02
#
#                                                     coef upper 95%  \
# covariate
# subject_id                                            4.488631e-09
# gender                                                3.092480e-01
# anchor_age                                            3.732278e-01
# disch_age                                            -3.180898e-01
# CKD_stage_first                                      -8.995892e-01
# ...                                                            ...
# Creatinine_median                                     1.697739e-01
# Diabetes mellitus without mention of complicati...   -3.798057e-02
# Cholesterol,_LDL,_Calculated_median                   5.338976e-03
# Monocytes_mean                                        6.052822e-02
# Chloride_median                                       9.718995e-02
#
#                                                     exp(coef) lower 95%  \
# covariate
# subject_id                                                     1.000000
# gender                                                         1.028710
# anchor_age                                                     1.370165
# disch_age                                                      0.686402
# CKD_stage_first                                                0.337441
# ...                                                                 ...
# Creatinine_median                                              1.028088
# Diabetes mellitus without mention of complicati...             0.747005
# Cholesterol,_LDL,_Calculated_median                            1.000021
# Monocytes_mean                                                 0.965162
# Chloride_median                                                1.019337
#
#                                                     exp(coef) upper 95%  \
# covariate
# subject_id                                                     1.000000
# gender                                                         1.362400
# anchor_age                                                     1.452415
# disch_age                                                      0.727537
# CKD_stage_first                                                0.406737
# ...                                                                 ...
# Creatinine_median                                              1.185037
# Diabetes mellitus without mention of complicati...             0.962732
# Cholesterol,_LDL,_Calculated_median                            1.005353
# Monocytes_mean                                                 1.062398
# Chloride_median                                                1.102070
#
#                                                     cmp to          z  \
# covariate
# subject_id                                             0.0  -1.524069
# gender                                                 0.0   2.354908
# anchor_age                                             0.0  23.136360
# disch_age                                              0.0 -23.383567
# CKD_stage_first                                        0.0 -20.839912
# ...                                                    ...        ...
# Creatinine_median                                      0.0   2.724248
# Diabetes mellitus without mention of complicati...     0.0  -2.546796
# Cholesterol,_LDL,_Calculated_median                    0.0   1.975292
# Monocytes_mean                                         0.0   0.511867
# Chloride_median                                        0.0   2.921992
#
#                                                                 p    -log2(p)
# covariate
# subject_id                                           1.274915e-01    2.971527
# gender                                               1.852730e-02    5.754203
# anchor_age                                          1.994509e-118  390.991482
# disch_age                                           6.281080e-121  399.302287
# CKD_stage_first                                      1.881854e-96  317.992942
# ...                                                           ...         ...
# Creatinine_median                                    6.444805e-03    7.277648
# Diabetes mellitus without mention of complicati...   1.087168e-02    6.523281
# Cholesterol,_LDL,_Calculated_median                  4.823504e-02    4.373775
# Monocytes_mean                                       6.087439e-01    0.716093
# Chloride_median                                      3.478004e-03    8.167525
#
# [81 rows x 11 columns]
#                                    test_statistic         p  -log2(p)
# Acute kidney failure, unspecified        0.848641  0.356937  1.486258
# Albumin/Creatinine,_Urine_first          0.010373  0.918878  0.122055
# Albumin/Creatinine,_Urine_last           0.089471  0.764850  0.386751
# Albumin/Creatinine,_Urine_max            0.010592  0.918028  0.123389
# Albumin/Creatinine,_Urine_mean           0.032669  0.856567  0.223363
# ...                                           ...       ...       ...
# eGFR_median                              0.009058  0.924177  0.113760
# eGFR_min                                 0.016504  0.897779  0.155568
# gender                                   0.000027  0.995826  0.006034
# marital_status_SINGLE                    1.084398  0.297716  1.747993
# subject_id                               0.063624  0.800857  0.320383
#
# [81 rows x 3 columns]
