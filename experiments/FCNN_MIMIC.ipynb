# %%
import sys
import os

# Use os.getcwd() to get the current working directory in a Jupyter notebook
parent_dir = os.path.dirname(os.getcwd())  # Get the parent directory of the current working directory
sys.path.append(parent_dir)

# %%
import pandas as pd
from skopt.space import Real, Integer
from driver import Driver

# %% [markdown]
# # Load Cleaned Master MIMIC-IV Dataset

# %%
# Cleaned Master MIMIC Data Set
df_master = pd.read_pickle('../MIMIC_IV/df_ckd_master_clean.pkl')
df_base = pd.read_pickle('../MIMIC_IV/df_ckd_base.pkl')

# %% [markdown]
# # Evaluate FCNN Pipeline

# %%
FCNN_cfg = {
    'name': 'FCNN', # Feature selection model long name
    'tag': 'fcnn', # Feature selection model identifier tag
    'response': 'stage_delta',  # Response variable for binary classification and Cox Proportional Hazards
    'duration': 'duration', # Duration in days until response or censorship
    'n_novel': 40, # Number of ranked novel features included in augmented KFRE dataset
    'test_size': 0.2, # Ratio of data reserved for testing
    'epochs': 35,
    'patience': 5,
    'learning_rate': 0.001,
    'weight_decay': 1e-4,
    'batch_size': 256, # Batch size for SHAP computation
    'n_folds': 5, # Number of folds for CoxPH cross validation
    'penalizer': 0.0007, # CoxPH model penalizer
    'random_state': 42 # Seed for reproducibility
}

driver = Driver(FCNN_cfg, df_master, df_base)
driver.DeepLearningPipe()
# Out:
# Epoch 1/35, Training Loss: 0.27854113453279505, Validation Loss: 0.2864282554523511
# Epoch 2/35, Training Loss: 0.19143682188058103, Validation Loss: 0.30280374600128696
# Epoch 3/35, Training Loss: 0.12829127014529976, Validation Loss: 0.39753292280841956
# Epoch 4/35, Training Loss: 0.08251953056738288, Validation Loss: 0.5064598873934962
# Epoch 5/35, Training Loss: 0.05687323042895349, Validation Loss: 0.589881509881128
# Epoch 6/35, Training Loss: 0.04140186261330117, Validation Loss: 0.771412694318728
# Early stopping triggered
# Test AUC: 0.6641496469817515
#  ... (more hidden) ...
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\shap\plots\_beeswarm.py:962: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   pl.tight_layout()
# Iteration 1: norm_delta = 6.46e+00, step_size = 0.9500, log_lik = -8744.90665, newton_decrement = 1.01e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.20e+00, step_size = 0.2375, log_lik = -8324.31298, newton_decrement = 5.61e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.87e+00, step_size = 0.0772, log_lik = -8241.11634, newton_decrement = 4.81e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.34e+00, step_size = 0.1304, log_lik = -8123.83586, newton_decrement = 3.69e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.51e+00, step_size = 0.2205, log_lik = -7978.76636, newton_decrement = 2.32e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.33e+00, step_size = 0.3726, log_lik = -7837.54023, newton_decrement = 9.77e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.42e-01, step_size = 0.6296, log_lik = -7752.62598, newton_decrement = 1.56e+01, seconds_since_start = 0.6
# Iteration 8: norm_delta = 2.50e-02, step_size = 1.0000, log_lik = -7736.74059, newton_decrement = 4.42e-02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 4.30e-04, step_size = 1.0000, log_lik = -7736.69595, newton_decrement = 1.50e-05, seconds_since_start = 0.8
# Iteration 10: norm_delta = 1.83e-07, step_size = 1.0000, log_lik = -7736.69593, newton_decrement = 2.72e-12, seconds_since_start = 0.9
# Convergence success after 10 iterations.
# Iteration 1: norm_delta = 6.57e+00, step_size = 0.9500, log_lik = -8829.99117, newton_decrement = 9.96e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.32e+00, step_size = 0.2375, log_lik = -8414.16733, newton_decrement = 5.61e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.98e+00, step_size = 0.0772, log_lik = -8330.88844, newton_decrement = 4.81e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.45e+00, step_size = 0.1304, log_lik = -8213.52108, newton_decrement = 3.69e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.61e+00, step_size = 0.2205, log_lik = -8068.59013, newton_decrement = 2.31e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.41e+00, step_size = 0.3726, log_lik = -7928.19034, newton_decrement = 9.63e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.85e-01, step_size = 0.6296, log_lik = -7844.52621, newton_decrement = 1.51e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 3.00e-02, step_size = 1.0000, log_lik = -7829.18511, newton_decrement = 2.35e-02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 2.71e-04, step_size = 1.0000, log_lik = -7829.16153, newton_decrement = 1.53e-06, seconds_since_start = 0.8
# Iteration 10: norm_delta = 2.57e-08, step_size = 1.0000, log_lik = -7829.16153, newton_decrement = 1.29e-14, seconds_since_start = 0.9
# Convergence success after 10 iterations.
# Iteration 1: norm_delta = 6.54e+00, step_size = 0.9500, log_lik = -8805.41001, newton_decrement = 9.89e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.27e+00, step_size = 0.2375, log_lik = -8392.51070, newton_decrement = 5.52e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.94e+00, step_size = 0.0772, log_lik = -8310.57457, newton_decrement = 4.72e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.41e+00, step_size = 0.1304, log_lik = -8195.37152, newton_decrement = 3.61e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.58e+00, step_size = 0.2205, log_lik = -8053.60864, newton_decrement = 2.25e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.39e+00, step_size = 0.3726, log_lik = -7916.82992, newton_decrement = 9.36e+01, seconds_since_start = 0.5
# Iteration 7: norm_delta = 9.79e-01, step_size = 0.6296, log_lik = -7835.49785, newton_decrement = 1.47e+01, seconds_since_start = 0.6
# Iteration 8: norm_delta = 3.05e-02, step_size = 1.0000, log_lik = -7820.56110, newton_decrement = 2.27e-02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 2.55e-04, step_size = 1.0000, log_lik = -7820.53831, newton_decrement = 1.30e-06, seconds_since_start = 0.8
# Iteration 10: norm_delta = 2.18e-08, step_size = 1.0000, log_lik = -7820.53831, newton_decrement = 8.92e-15, seconds_since_start = 0.9
# Convergence success after 10 iterations.
# Iteration 1: norm_delta = 6.69e+00, step_size = 0.9500, log_lik = -9037.41005, newton_decrement = 9.82e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.40e+00, step_size = 0.2375, log_lik = -8627.00981, newton_decrement = 5.59e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.07e+00, step_size = 0.0772, log_lik = -8544.07714, newton_decrement = 4.80e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.93e+00, step_size = 0.0326, log_lik = -8513.29270, newton_decrement = 4.51e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.71e+00, step_size = 0.0551, log_lik = -8464.97436, newton_decrement = 4.05e+02, seconds_since_start = 0.4
# Iteration 6: norm_delta = 4.34e+00, step_size = 0.0931, log_lik = -8392.99461, newton_decrement = 3.37e+02, seconds_since_start = 0.5
# Iteration 7: norm_delta = 3.76e+00, step_size = 0.1574, log_lik = -8295.08900, newton_decrement = 2.45e+02, seconds_since_start = 0.6
# Iteration 8: norm_delta = 2.88e+00, step_size = 0.2660, log_lik = -8181.93815, newton_decrement = 1.37e+02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 1.69e+00, step_size = 0.4496, log_lik = -8085.83395, newton_decrement = 4.49e+01, seconds_since_start = 0.8
# Iteration 10: norm_delta = 4.59e-01, step_size = 0.7598, log_lik = -8043.13012, newton_decrement = 3.23e+00, seconds_since_start = 0.9
# Iteration 11: norm_delta = 8.94e-03, step_size = 1.0000, log_lik = -8039.86985, newton_decrement = 2.06e-03, seconds_since_start = 0.9
# Iteration 12: norm_delta = 2.68e-05, step_size = 1.0000, log_lik = -8039.86778, newton_decrement = 1.46e-08, seconds_since_start = 1.0
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.56e+00, step_size = 0.9500, log_lik = -8886.68689, newton_decrement = 1.01e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.29e+00, step_size = 0.2375, log_lik = -8465.66940, newton_decrement = 5.64e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.95e+00, step_size = 0.0772, log_lik = -8381.98737, newton_decrement = 4.83e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.42e+00, step_size = 0.1304, log_lik = -8264.07086, newton_decrement = 3.71e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.58e+00, step_size = 0.2205, log_lik = -8118.30221, newton_decrement = 2.33e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.39e+00, step_size = 0.3726, log_lik = -7976.32539, newton_decrement = 9.88e+01, seconds_since_start = 0.5
# Iteration 7: norm_delta = 9.77e-01, step_size = 0.6296, log_lik = -7890.38267, newton_decrement = 1.60e+01, seconds_since_start = 0.6
# Iteration 8: norm_delta = 3.16e-02, step_size = 1.0000, log_lik = -7874.05305, newton_decrement = 3.28e-02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 3.24e-04, step_size = 1.0000, log_lik = -7874.02007, newton_decrement = 2.41e-06, seconds_since_start = 0.8
# Iteration 10: norm_delta = 3.80e-08, step_size = 1.0000, log_lik = -7874.02007, newton_decrement = 2.91e-14, seconds_since_start = 1.0
# Convergence success after 10 iterations.
# Average C-Index from cross-validation: 0.8892
# Best C-Index from cross-validation: 0.8948
# Standard Deviation of C-Index from cross-validation: 0.0068
#                                                coef  exp(coef)      se(coef)  \
# covariate
# subject_id                            -1.508690e-08   1.000000  1.014427e-08
# gender                                 2.969369e-02   1.030139  6.955520e-02
# anchor_age                             3.567080e-01   1.428619  1.473864e-02
# disch_age                             -3.586553e-01   0.698615  1.470970e-02
# CKD_stage_first                       -1.083803e+00   0.338306  4.975151e-02
# ...                                             ...        ...           ...
# Protein_min                            1.515322e-03   1.001516  4.014718e-04
# Leukocytosis, unspecified             -8.361766e-02   0.919783  8.773005e-02
# Creatinine_first                      -1.175457e-01   0.889100  2.713335e-02
# Asthma, unspecified type, unspecified -1.844738e-01   0.831542  9.536315e-02
# Platelet_Count_min                     5.837703e-04   1.000584  5.699045e-04
#
#                                        coef lower 95%  coef upper 95%  \
# covariate
# subject_id                              -3.496931e-08    4.795513e-09
# gender                                  -1.066320e-01    1.660194e-01
# anchor_age                               3.278208e-01    3.855952e-01
# disch_age                               -3.874857e-01   -3.298248e-01
# CKD_stage_first                         -1.181314e+00   -9.862921e-01
# ...                                               ...             ...
# Protein_min                              7.284522e-04    2.302193e-03
# Leukocytosis, unspecified               -2.555654e-01    8.833008e-02
# Creatinine_first                        -1.707261e-01   -6.436533e-02
# Asthma, unspecified type, unspecified   -3.713821e-01    2.434569e-03
# Platelet_Count_min                      -5.332221e-04    1.700763e-03
#
#                                        exp(coef) lower 95%  \
# covariate
# subject_id                                        1.000000
# gender                                            0.898856
# anchor_age                                        1.387940
# disch_age                                         0.678761
# CKD_stage_first                                   0.306875
# ...                                                    ...
# Protein_min                                       1.000729
# Leukocytosis, unspecified                         0.774478
# Creatinine_first                                  0.843052
# Asthma, unspecified type, unspecified             0.689780
# Platelet_Count_min                                0.999467
#
#                                        exp(coef) upper 95%  cmp to          z  \
# covariate
# subject_id                                        1.000000     0.0  -1.487233
# gender                                            1.180596     0.0   0.426908
# anchor_age                                        1.470489     0.0  24.202239
# disch_age                                         0.719050     0.0 -24.382236
# CKD_stage_first                                   0.372957     0.0 -21.784329
# ...                                                    ...     ...        ...
# Protein_min                                       1.002305     0.0   3.774418
# Leukocytosis, unspecified                         1.092349     0.0  -0.953124
# Creatinine_first                                  0.937662     0.0  -4.332149
# Asthma, unspecified type, unspecified             1.002438     0.0  -1.934435
# Platelet_Count_min                                1.001702     0.0   1.024330
#
#                                                    p    -log2(p)
# covariate
# subject_id                              1.369533e-01    2.868244
# gender                                  6.694462e-01    0.578960
# anchor_age                             2.107181e-129  427.453410
# disch_age                              2.639549e-131  433.772289
# CKD_stage_first                        3.266966e-105  347.094498
# ...                                              ...         ...
# Protein_min                             1.603816e-04   12.606203
# Leukocytosis, unspecified               3.405270e-01    1.554159
# Creatinine_first                        1.476606e-05   16.047355
# Asthma, unspecified type, unspecified   5.305972e-02    4.236239
# Platelet_Count_min                      3.056795e-01    1.709908
#
# [81 rows x 11 columns]
#                                    test_statistic         p  -log2(p)
# Acute kidney failure, unspecified        0.369476  0.543290  0.880206
# Albumin/Creatinine,_Urine_first          0.004705  0.945316  0.081131
# Albumin/Creatinine,_Urine_last           0.746504  0.387585  1.367414
# Albumin/Creatinine,_Urine_max            0.003120  0.955453  0.065744
# Albumin/Creatinine,_Urine_mean           0.195319  0.658526  0.602688
# ...                                           ...       ...       ...
# eGFR_median                              0.004663  0.945560  0.080759
# eGFR_min                                 0.023211  0.878910  0.186212
# gender                                   0.915651  0.338619  1.562263
# race_WHITE                               0.396604  0.528848  0.919075
# subject_id                               0.523898  0.469184  1.091775
#
# [81 rows x 3 columns]
# Brier Score at 1 year(s): 0.0294
# Brier Score at 2 year(s): 0.0512
# Brier Score at 3 year(s): 0.0696
# Brier Score at 4 year(s): 0.0741
# Brier Score at 5 year(s): 0.0766
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sksurv\metrics.py:482: RuntimeWarning: invalid value encountered in divide
#   true_pos = cumsum_tp / cumsum_tp[-1]
# AUC at 1 year(s): 0.9427
# AUC at 2 year(s): 0.9222
# AUC at 3 year(s): 0.9097
# AUC at 4 year(s): 0.9438
# AUC at 5 year(s): 0.9575
