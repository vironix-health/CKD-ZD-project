# %%
import sys
import os

# Use os.getcwd() to get the current working directory in a Jupyter notebook
parent_dir = os.path.dirname(os.getcwd())  # Get the parent directory of the current working directory
sys.path.append(parent_dir)

# %%
import pandas as pd
from skopt.space import Real, Integer
from driver import Driver

# %% [markdown]
# # Load Cleaned Master MIMIC-IV Dataset

# %%
# Cleaned Master MIMIC Data Set
df_master = pd.read_pickle('../MIMIC_IV/df_ckd_master_clean.pkl')
df_base = pd.read_pickle('../MIMIC_IV/df_ckd_base.pkl')

# %% [markdown]
# # Evaluate ResNet Pipeline

# %%
ResNet_cfg = {
    'name': 'ResNet', # Feature selection model long name
    'tag': 'rsnt', # Feature selection model identifier tag
    'response': 'stage_delta',  # Response variable for binary classification and Cox Proportional Hazards
    'duration': 'duration', # Duration in days until response or censorship
    'n_novel': 40, # Number of ranked novel features included in augmented KFRE dataset
    'test_size': 0.2, # Ratio of data reserved for testing
    'num_blocks': 3,
    'hidden_dim': 64,
    'num_classes': 1, # Updated to 1 for binary classification
    'epochs': 30,
    'patience': 5,
    'learning_rate': 0.001,
    'weight_decay': 1e-4,
    'batch_size': 256, # Batch size for SHAP computation
    'n_folds': 5, # Number of folds for CoxPH cross validation
    'penalizer': 0.0007, # CoxPH model penalizer
    'random_state': 42 # Seed for reproducibility
}

driver = Driver(ResNet_cfg, df_master, df_base)
driver.DeepLearningPipe()
# Out:
# Epoch 1/30, Training Loss: 0.282216907732866, Validation Loss: 0.27642647278579796
# Epoch 2/30, Training Loss: 0.17694705339487304, Validation Loss: 0.32815333049405704
# Epoch 3/30, Training Loss: 0.11371860145167871, Validation Loss: 0.4105939451943744
# Epoch 4/30, Training Loss: 0.05898907234024426, Validation Loss: 0.544287617910992
# Epoch 5/30, Training Loss: 0.03939060748763785, Validation Loss: 0.7244108881462704
# Epoch 6/30, Training Loss: 0.026567949710046047, Validation Loss: 0.6988126334141601
# Early stopping triggered
# Test AUC: 0.6584123007474928
#  ... (more hidden) ...
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\shap\plots\_beeswarm.py:962: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   pl.tight_layout()
# Iteration 1: norm_delta = 6.50e+00, step_size = 0.9500, log_lik = -8744.90665, newton_decrement = 9.95e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.24e+00, step_size = 0.2375, log_lik = -8329.70427, newton_decrement = 5.55e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.90e+00, step_size = 0.0772, log_lik = -8247.37629, newton_decrement = 4.76e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.36e+00, step_size = 0.1304, log_lik = -8131.26576, newton_decrement = 3.66e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.53e+00, step_size = 0.2205, log_lik = -7987.63516, newton_decrement = 2.29e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.33e+00, step_size = 0.3726, log_lik = -7848.21774, newton_decrement = 9.52e+01, seconds_since_start = 0.5
# Iteration 7: norm_delta = 9.34e-01, step_size = 0.6296, log_lik = -7765.67692, newton_decrement = 1.44e+01, seconds_since_start = 0.6
# Iteration 8: norm_delta = 1.46e-02, step_size = 1.0000, log_lik = -7751.17192, newton_decrement = 1.06e-02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 1.67e-05, step_size = 1.0000, log_lik = -7751.16134, newton_decrement = 4.25e-08, seconds_since_start = 0.8
# Convergence success after 9 iterations.
# Iteration 1: norm_delta = 6.57e+00, step_size = 0.9500, log_lik = -8829.99117, newton_decrement = 9.94e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.31e+00, step_size = 0.2375, log_lik = -8415.18303, newton_decrement = 5.53e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.98e+00, step_size = 0.0772, log_lik = -8333.09982, newton_decrement = 4.75e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.44e+00, step_size = 0.1304, log_lik = -8217.34806, newton_decrement = 3.64e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.59e+00, step_size = 0.2205, log_lik = -8074.28071, newton_decrement = 2.28e+02, seconds_since_start = 0.4
# Iteration 6: norm_delta = 2.38e+00, step_size = 0.3726, log_lik = -7935.64965, newton_decrement = 9.47e+01, seconds_since_start = 0.5
# Iteration 7: norm_delta = 9.54e-01, step_size = 0.6296, log_lik = -7853.49128, newton_decrement = 1.45e+01, seconds_since_start = 0.6
# Iteration 8: norm_delta = 1.40e-02, step_size = 1.0000, log_lik = -7838.86746, newton_decrement = 1.08e-02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 4.95e-05, step_size = 1.0000, log_lik = -7838.85663, newton_decrement = 9.39e-08, seconds_since_start = 0.8
# Convergence success after 9 iterations.
# Iteration 1: norm_delta = 6.52e+00, step_size = 0.9500, log_lik = -8805.41001, newton_decrement = 9.94e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.24e+00, step_size = 0.2375, log_lik = -8391.25111, newton_decrement = 5.43e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.91e+00, step_size = 0.0772, log_lik = -8310.63835, newton_decrement = 4.65e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.38e+00, step_size = 0.1304, log_lik = -8197.24862, newton_decrement = 3.56e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.55e+00, step_size = 0.2205, log_lik = -8057.55862, newton_decrement = 2.22e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.35e+00, step_size = 0.3726, log_lik = -7922.62412, newton_decrement = 9.20e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.41e-01, step_size = 0.6296, log_lik = -7842.82104, newton_decrement = 1.40e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 1.28e-02, step_size = 1.0000, log_lik = -7828.69971, newton_decrement = 8.78e-03, seconds_since_start = 0.7
# Iteration 9: norm_delta = 4.02e-05, step_size = 1.0000, log_lik = -7828.69092, newton_decrement = 4.76e-08, seconds_since_start = 0.8
# Convergence success after 9 iterations.
# Iteration 1: norm_delta = 6.67e+00, step_size = 0.9500, log_lik = -9037.41005, newton_decrement = 9.94e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.37e+00, step_size = 0.2375, log_lik = -8622.87033, newton_decrement = 5.57e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.03e+00, step_size = 0.0772, log_lik = -8540.19502, newton_decrement = 4.78e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.90e+00, step_size = 0.0326, log_lik = -8509.50251, newton_decrement = 4.49e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.67e+00, step_size = 0.0551, log_lik = -8461.32689, newton_decrement = 4.04e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.31e+00, step_size = 0.0931, log_lik = -8389.55943, newton_decrement = 3.36e+02, seconds_since_start = 0.5
# Iteration 7: norm_delta = 3.72e+00, step_size = 0.1574, log_lik = -8291.96437, newton_decrement = 2.44e+02, seconds_since_start = 0.6
# Iteration 8: norm_delta = 2.83e+00, step_size = 0.2660, log_lik = -8179.33011, newton_decrement = 1.36e+02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 1.64e+00, step_size = 0.4496, log_lik = -8084.28311, newton_decrement = 4.35e+01, seconds_since_start = 0.8
# Iteration 10: norm_delta = 4.29e-01, step_size = 0.7598, log_lik = -8043.07946, newton_decrement = 2.86e+00, seconds_since_start = 0.9
# Iteration 11: norm_delta = 2.86e-03, step_size = 1.0000, log_lik = -8040.20714, newton_decrement = 5.23e-04, seconds_since_start = 1.0
# Iteration 12: norm_delta = 8.86e-07, step_size = 1.0000, log_lik = -8040.20662, newton_decrement = 1.67e-10, seconds_since_start = 1.1
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.54e+00, step_size = 0.9500, log_lik = -8886.68689, newton_decrement = 1.01e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.27e+00, step_size = 0.2375, log_lik = -8466.88299, newton_decrement = 5.55e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.94e+00, step_size = 0.0772, log_lik = -8384.47608, newton_decrement = 4.76e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.40e+00, step_size = 0.1304, log_lik = -8268.29819, newton_decrement = 3.66e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.57e+00, step_size = 0.2205, log_lik = -8124.49871, newton_decrement = 2.31e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.37e+00, step_size = 0.3726, log_lik = -7984.22184, newton_decrement = 9.73e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.50e-01, step_size = 0.6296, log_lik = -7899.62576, newton_decrement = 1.54e+01, seconds_since_start = 0.6
# Iteration 8: norm_delta = 1.57e-02, step_size = 1.0000, log_lik = -7883.99511, newton_decrement = 2.97e-02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 3.27e-04, step_size = 1.0000, log_lik = -7883.96469, newton_decrement = 9.15e-05, seconds_since_start = 0.8
# Iteration 10: norm_delta = 2.17e-06, step_size = 1.0000, log_lik = -7883.96460, newton_decrement = 4.36e-09, seconds_since_start = 0.9
# Convergence success after 10 iterations.
# Average C-Index from cross-validation: 0.8873
# Best C-Index from cross-validation: 0.8946
# Standard Deviation of C-Index from cross-validation: 0.0077
#                                                             coef  exp(coef)  \
# covariate
# subject_id                                         -2.120773e-08   1.000000
# gender                                              6.439945e-02   1.066518
# anchor_age                                          3.473565e-01   1.415321
# disch_age                                          -3.506624e-01   0.704221
# CKD_stage_first                                    -1.083756e+00   0.338322
# ...                                                          ...        ...
# White_Blood_Cells_min                              -7.106155e-03   0.992919
# Hyposmolality and/or hyponatremia                   1.513716e-02   1.015252
# Long-term (current) use of insulin                 -8.259272e-02   0.920726
# Kidney dialysis as the cause of abnormal reacti... -1.246380e-01   0.882816
# Protein_max                                         3.257637e-04   1.000326
#
#                                                         se(coef)  \
# covariate
# subject_id                                          1.039185e-08
# gender                                              6.821478e-02
# anchor_age                                          1.481586e-02
# disch_age                                           1.475981e-02
# CKD_stage_first                                     4.970083e-02
# ...                                                          ...
# White_Blood_Cells_min                               1.614161e-02
# Hyposmolality and/or hyponatremia                   8.618028e-02
# Long-term (current) use of insulin                  7.679312e-02
# Kidney dialysis as the cause of abnormal reacti...  1.302455e-01
# Protein_max                                         1.952421e-04
#
#                                                     coef lower 95%  \
# covariate
# subject_id                                           -4.157538e-08
# gender                                               -6.929905e-02
# anchor_age                                            3.183179e-01
# disch_age                                            -3.795911e-01
# CKD_stage_first                                      -1.181168e+00
# ...                                                            ...
# White_Blood_Cells_min                                -3.874312e-02
# Hyposmolality and/or hyponatremia                    -1.537731e-01
# Long-term (current) use of insulin                   -2.331045e-01
# Kidney dialysis as the cause of abnormal reacti...   -3.799145e-01
# Protein_max                                          -5.690372e-05
#
#                                                     coef upper 95%  \
# covariate
# subject_id                                           -8.400760e-10
# gender                                                1.980980e-01
# anchor_age                                            3.763950e-01
# disch_age                                            -3.217337e-01
# CKD_stage_first                                      -9.863444e-01
# ...                                                            ...
# White_Blood_Cells_min                                 2.453081e-02
# Hyposmolality and/or hyponatremia                     1.840474e-01
# Long-term (current) use of insulin                    6.791903e-02
# Kidney dialysis as the cause of abnormal reacti...    1.306386e-01
# Protein_max                                           7.084311e-04
#
#                                                     exp(coef) lower 95%  \
# covariate
# subject_id                                                     1.000000
# gender                                                         0.933048
# anchor_age                                                     1.374813
# disch_age                                                      0.684141
# CKD_stage_first                                                0.306920
# ...                                                                 ...
# White_Blood_Cells_min                                          0.961998
# Hyposmolality and/or hyponatremia                              0.857467
# Long-term (current) use of insulin                             0.792071
# Kidney dialysis as the cause of abnormal reacti...             0.683920
# Protein_max                                                    0.999943
#
#                                                     exp(coef) upper 95%  \
# covariate
# subject_id                                                     1.000000
# gender                                                         1.219082
# anchor_age                                                     1.457023
# disch_age                                                      0.724891
# CKD_stage_first                                                0.372938
# ...                                                                 ...
# White_Blood_Cells_min                                          1.024834
# Hyposmolality and/or hyponatremia                              1.202073
# Long-term (current) use of insulin                             1.070279
# Kidney dialysis as the cause of abnormal reacti...             1.139556
# Protein_max                                                    1.000709
#
#                                                     cmp to          z  \
# covariate
# subject_id                                             0.0  -2.040804
# gender                                                 0.0   0.944069
# anchor_age                                             0.0  23.444914
# disch_age                                              0.0 -23.757926
# CKD_stage_first                                        0.0 -21.805596
# ...                                                    ...        ...
# White_Blood_Cells_min                                  0.0  -0.440238
# Hyposmolality and/or hyponatremia                      0.0   0.175645
# Long-term (current) use of insulin                     0.0  -1.075522
# Kidney dialysis as the cause of abnormal reacti...     0.0  -0.956946
# Protein_max                                            0.0   1.668512
#
#                                                                 p    -log2(p)
# covariate
# subject_id                                           4.127033e-02    4.598751
# gender                                               3.451344e-01    1.534770
# anchor_age                                          1.489644e-121  401.378332
# disch_age                                           9.098764e-125  412.055341
# CKD_stage_first                                     2.053142e-105  347.764617
# ...                                                           ...         ...
# White_Blood_Cells_min                                6.597644e-01    0.599977
# Hyposmolality and/or hyponatremia                    8.605726e-01    0.216631
# Long-term (current) use of insulin                   2.821409e-01    1.825512
# Kidney dialysis as the cause of abnormal reacti...   3.385944e-01    1.562370
# Protein_max                                          9.521416e-02    3.392680
#
# [81 rows x 11 columns]
#                                           test_statistic         p  -log2(p)
# Acute kidney failure, unspecified               2.833372  0.092324  3.437145
# Acute on chronic diastolic heart failure        0.484167  0.486541  1.039367
# Albumin/Creatinine,_Urine_first                 0.198562  0.655884  0.608486
# Albumin/Creatinine,_Urine_last                  0.000156  0.990044  0.014436
# Albumin/Creatinine,_Urine_max                   0.013414  0.907795  0.139562
# ...                                                  ...       ...       ...
# eGFR_median                                     0.086805  0.768278  0.380299
# eGFR_min                                        0.061301  0.804452  0.313922
# gender                                          4.531283  0.033281  4.909172
# race_WHITE                                      0.003742  0.951222  0.072146
# subject_id                                      0.191338  0.661805  0.595522
#
# [81 rows x 3 columns]
# Brier Score at 1 year(s): 0.0302
# Brier Score at 2 year(s): 0.0485
# Brier Score at 3 year(s): 0.0623
# Brier Score at 4 year(s): 0.0822
# Brier Score at 5 year(s): 0.0981
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sksurv\metrics.py:482: RuntimeWarning: invalid value encountered in divide
#   true_pos = cumsum_tp / cumsum_tp[-1]
# AUC at 1 year(s): 0.9366
# AUC at 2 year(s): 0.9479
# AUC at 3 year(s): 0.9422
# AUC at 4 year(s): 0.9154
# AUC at 5 year(s): 0.9155
