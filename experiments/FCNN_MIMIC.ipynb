# %%
import sys
import os

# Use os.getcwd() to get the current working directory in a Jupyter notebook
parent_dir = os.path.dirname(os.getcwd())  # Get the parent directory of the current working directory
sys.path.append(parent_dir)

# %%
import pandas as pd
from skopt.space import Real, Integer
from driver import Driver

# %% [markdown]
# # Load Cleaned Master MIMIC-IV Dataset

# %%
# Cleaned Master MIMIC Data Set
df_master = pd.read_pickle('../MIMIC_IV/df_ckd_master_clean.pkl')
df_base = pd.read_pickle('../MIMIC_IV/df_ckd_base.pkl')

# %% [markdown]
# # Evaluate XGBoost Pipeline

# %%
FCNN_cfg = {
    'tag': 'fcnn', # Identifier tag for feature selection model
    'response': 'stage_delta',  # Response variable for binary classification and Cox Proportional Hazards
    'duration': 'duration', # Duration in days until response or censorship
    'n_novel': 40, # Number of ranked novel features included in augmented KFRE dataset
    'test_size': 0.1, # Ratio of data reserved for testing
    'val_size': 0.2, # Ratio of data reserved for testing in validation sets
    'n_valsets': 5, # Number of training validation sets
    'n_bayesian': 10, # Number of Bayesian hyperparameter optimization iterations 
    'n_folds': 5, # Number of folds for CoxPH cross validation
    'penalizer': 0.0007, # CoxPH model penalizer
    'auc_space': [
        Integer(5, 20, name='max_depth'),
        Integer(1, 10, name='min_child_weight'),
        Real(0.5, 3.0, name='gamma'),
        Real(0.6, 1.0, name='subsample'),
        Real(0.6, 1.0, name='colsample_bytree'),
        Real(0.01, 0.6, name='colsample_bylevel'),
        Real(0.01, 0.3, name='learning_rate'),
        Integer(50, 150, name='n_estimators')
    ], # Search space for Bayesian hyperparameter optimization
    'random_state': 42 # Seed for reproducibility
}

driver = Driver(FCNN_cfg, df_master, df_base)
driver.DeepLearningPipe()
# Out:
# Testing params: {'max_depth': 17, 'min_child_weight': 3, 'gamma': 2.449227500681924, 'subsample': 0.8387400631785948, 'colsample_bytree': 0.7783331011414365, 'colsample_bylevel': 0.06898520033262172, 'learning_rate': 0.1431821786701015, 'n_estimators': 83}
# AUC for params: 0.9305367517183931
# Testing params: {'max_depth': 7, 'min_child_weight': 7, 'gamma': 0.6410289475677506, 'subsample': 0.88879950890673, 'colsample_bytree': 0.9754210836063002, 'colsample_bylevel': 0.010459471846198455, 'learning_rate': 0.29774135219445313, 'n_estimators': 112}
# AUC for params: 0.8980444684497788
# Testing params: {'max_depth': 14, 'min_child_weight': 1, 'gamma': 0.5576560626035394, 'subsample': 0.8099098641033557, 'colsample_bytree': 0.7599443886861023, 'colsample_bylevel': 0.0375327412960331, 'learning_rate': 0.2923891004640232, 'n_estimators': 73}
# AUC for params: 0.9133003356791107
# Testing params: {'max_depth': 6, 'min_child_weight': 7, 'gamma': 1.456154978167907, 'subsample': 0.9932923543227153, 'colsample_bytree': 0.786705157299192, 'colsample_bylevel': 0.5173648399744293, 'learning_rate': 0.20728918619045614, 'n_estimators': 95}
# AUC for params: 0.950243172497976
# Testing params: {'max_depth': 5, 'min_child_weight': 9, 'gamma': 1.9082205446138485, 'subsample': 0.7541666010159664, 'colsample_bytree': 0.6063865008880857, 'colsample_bylevel': 0.14622735711706794, 'learning_rate': 0.07989738514754341, 'n_estimators': 118}
# AUC for params: 0.9422488991240563
# Testing params: {'max_depth': 14, 'min_child_weight': 8, 'gamma': 0.9334116337694303, 'subsample': 0.7564242430292963, 'colsample_bytree': 0.672894435115225, 'colsample_bylevel': 0.45566323208741505, 'learning_rate': 0.133295203602461, 'n_estimators': 71}
# AUC for params: 0.9510688380429843
# Testing params: {'max_depth': 14, 'min_child_weight': 1, 'gamma': 2.6057119364874968, 'subsample': 0.7799016533479063, 'colsample_bytree': 0.7580600944007259, 'colsample_bylevel': 0.5567287308183387, 'learning_rate': 0.22090887879836207, 'n_estimators': 83}
# AUC for params: 0.9511645339181586
# Testing params: {'max_depth': 14, 'min_child_weight': 6, 'gamma': 2.9029300608733735, 'subsample': 0.9378135394712607, 'colsample_bytree': 0.8989280440549523, 'colsample_bylevel': 0.3284183581095571, 'learning_rate': 0.180157838042516, 'n_estimators': 147}
# AUC for params: 0.9513740008906326
# Testing params: {'max_depth': 14, 'min_child_weight': 3, 'gamma': 1.240683764260206, 'subsample': 0.666106775625201, 'colsample_bytree': 0.6062545626964776, 'colsample_bylevel': 0.25980687361675814, 'learning_rate': 0.12451564027091523, 'n_estimators': 79}
# AUC for params: 0.9496868456015062
# Testing params: {'max_depth': 5, 'min_child_weight': 3, 'gamma': 2.2783548818716253, 'subsample': 0.9160702162124823, 'colsample_bytree': 0.8423839899124046, 'colsample_bylevel': 0.556517518322876, 'learning_rate': 0.19881233739556392, 'n_estimators': 141}
# AUC for params: 0.9525990702121003
# Best parameters found:  {'max_depth': 5, 'min_child_weight': 3, 'gamma': 2.2783548818716253, 'subsample': 0.9160702162124823, 'colsample_bytree': 0.8423839899124046, 'colsample_bylevel': 0.556517518322876, 'learning_rate': 0.19881233739556392, 'n_estimators': 141}
# Best average AUC across validation sets:  0.9525990702121003
# Test AUC: 0.7685587761674718
# Iteration 1: norm_delta = 6.49e+00, step_size = 0.9500, log_lik = -8744.90665, newton_decrement = 1.04e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.17e+00, step_size = 0.2375, log_lik = -8310.21572, newton_decrement = 5.74e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.84e+00, step_size = 0.0772, log_lik = -8225.02745, newton_decrement = 4.90e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.30e+00, step_size = 0.1304, log_lik = -8105.60981, newton_decrement = 3.72e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.47e+00, step_size = 0.2205, log_lik = -7959.43523, newton_decrement = 2.30e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.30e+00, step_size = 0.3726, log_lik = -7819.55831, newton_decrement = 9.48e+01, seconds_since_start = 0.5
# Iteration 7: norm_delta = 9.30e-01, step_size = 0.6296, log_lik = -7737.22902, newton_decrement = 1.47e+01, seconds_since_start = 0.6
# Iteration 8: norm_delta = 1.63e-02, step_size = 1.0000, log_lik = -7722.31662, newton_decrement = 1.42e-02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 2.25e-05, step_size = 1.0000, log_lik = -7722.30245, newton_decrement = 6.28e-08, seconds_since_start = 0.8
# Convergence success after 9 iterations.
# Iteration 1: norm_delta = 6.65e+00, step_size = 0.9500, log_lik = -8829.99117, newton_decrement = 1.04e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.29e+00, step_size = 0.2375, log_lik = -8396.45671, newton_decrement = 5.72e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.95e+00, step_size = 0.0772, log_lik = -8311.49630, newton_decrement = 4.88e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.39e+00, step_size = 0.1304, log_lik = -8192.44506, newton_decrement = 3.71e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.54e+00, step_size = 0.2205, log_lik = -8046.82153, newton_decrement = 2.29e+02, seconds_since_start = 0.4
# Iteration 6: norm_delta = 2.35e+00, step_size = 0.3726, log_lik = -7907.60368, newton_decrement = 9.44e+01, seconds_since_start = 0.5
# Iteration 7: norm_delta = 9.45e-01, step_size = 0.6296, log_lik = -7825.62859, newton_decrement = 1.48e+01, seconds_since_start = 0.6
# Iteration 8: norm_delta = 1.65e-02, step_size = 1.0000, log_lik = -7810.65890, newton_decrement = 1.67e-02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 2.82e-05, step_size = 1.0000, log_lik = -7810.64222, newton_decrement = 8.66e-08, seconds_since_start = 0.8
# Convergence success after 9 iterations.
# Iteration 1: norm_delta = 6.60e+00, step_size = 0.9500, log_lik = -8805.41001, newton_decrement = 1.01e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.25e+00, step_size = 0.2375, log_lik = -8382.56840, newton_decrement = 5.59e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.91e+00, step_size = 0.0772, log_lik = -8299.66747, newton_decrement = 4.76e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.36e+00, step_size = 0.1304, log_lik = -8183.59933, newton_decrement = 3.61e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.52e+00, step_size = 0.2205, log_lik = -8041.86914, newton_decrement = 2.22e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.32e+00, step_size = 0.3726, log_lik = -7906.91275, newton_decrement = 9.08e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.31e-01, step_size = 0.6296, log_lik = -7828.19912, newton_decrement = 1.39e+01, seconds_since_start = 0.6
# Iteration 8: norm_delta = 1.43e-02, step_size = 1.0000, log_lik = -7814.14354, newton_decrement = 1.34e-02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 2.35e-05, step_size = 1.0000, log_lik = -7814.13008, newton_decrement = 6.84e-08, seconds_since_start = 0.8
# Convergence success after 9 iterations.
# Iteration 1: norm_delta = 6.68e+00, step_size = 0.9500, log_lik = -9037.41005, newton_decrement = 1.03e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.33e+00, step_size = 0.2375, log_lik = -8608.34997, newton_decrement = 5.74e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.98e+00, step_size = 0.0772, log_lik = -8523.15167, newton_decrement = 4.90e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.43e+00, step_size = 0.1304, log_lik = -8403.56068, newton_decrement = 3.74e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.58e+00, step_size = 0.2205, log_lik = -8256.86075, newton_decrement = 2.32e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.38e+00, step_size = 0.3726, log_lik = -8116.02242, newton_decrement = 9.60e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.62e-01, step_size = 0.6296, log_lik = -8032.62996, newton_decrement = 1.52e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 1.81e-02, step_size = 1.0000, log_lik = -8017.23842, newton_decrement = 2.22e-02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 5.09e-05, step_size = 1.0000, log_lik = -8017.21621, newton_decrement = 2.78e-07, seconds_since_start = 0.8
# Iteration 10: norm_delta = 1.48e-09, step_size = 1.0000, log_lik = -8017.21621, newton_decrement = 1.36e-16, seconds_since_start = 0.9
# Convergence success after 10 iterations.
# Iteration 1: norm_delta = 6.59e+00, step_size = 0.9500, log_lik = -8886.68689, newton_decrement = 1.05e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.24e+00, step_size = 0.2375, log_lik = -8447.76223, newton_decrement = 5.72e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.90e+00, step_size = 0.0772, log_lik = -8362.91837, newton_decrement = 4.88e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.36e+00, step_size = 0.1304, log_lik = -8243.84390, newton_decrement = 3.73e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.53e+00, step_size = 0.2205, log_lik = -8097.57446, newton_decrement = 2.32e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.34e+00, step_size = 0.3726, log_lik = -7956.25329, newton_decrement = 9.78e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.44e-01, step_size = 0.6296, log_lik = -7871.13107, newton_decrement = 1.60e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 1.81e-02, step_size = 1.0000, log_lik = -7854.88089, newton_decrement = 2.78e-02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 6.28e-05, step_size = 1.0000, log_lik = -7854.85303, newton_decrement = 4.35e-07, seconds_since_start = 0.9
# Iteration 10: norm_delta = 1.38e-09, step_size = 1.0000, log_lik = -7854.85303, newton_decrement = 2.15e-16, seconds_since_start = 0.9
# Convergence success after 10 iterations.
# Average C-Index from cross-validation: 0.8890
# Best C-Index from cross-validation: 0.8971
# Standard Deviation of C-Index from cross-validation: 0.0068
#                                                          coef  exp(coef)  \
# covariate
# subject_id                                      -1.880594e-08   1.000000
# gender                                           1.798434e-01   1.197030
# anchor_age                                       3.442624e-01   1.410949
# disch_age                                       -3.476036e-01   0.706379
# CKD_stage_first                                 -1.086441e+00   0.337415
# ...                                                       ...        ...
# Protein,_Total_last                             -6.645798e-02   0.935702
# MCV_last                                        -4.044114e-03   0.995964
# Protein/Creatinine_Ratio_last                    3.742857e-02   1.038138
# MCV_first                                        2.018202e-02   1.020387
# Secondary hyperparathyroidism (of renal origin)  1.461366e-01   1.157354
#
#                                                      se(coef)  coef lower 95%  \
# covariate
# subject_id                                       1.039605e-08   -3.918182e-08
# gender                                           6.930650e-02    4.400518e-02
# anchor_age                                       1.486916e-02    3.151194e-01
# disch_age                                        1.481443e-02   -3.766393e-01
# CKD_stage_first                                  5.013876e-02   -1.184711e+00
# ...                                                       ...             ...
# Protein,_Total_last                              4.348102e-02   -1.516792e-01
# MCV_last                                         6.483141e-03   -1.675084e-02
# Protein/Creatinine_Ratio_last                    1.597877e-02    6.110767e-03
# MCV_first                                        7.502775e-03    5.476853e-03
# Secondary hyperparathyroidism (of renal origin)  1.130596e-01   -7.545614e-02
#
#                                                  coef upper 95%  \
# covariate
# subject_id                                         1.569933e-09
# gender                                             3.156817e-01
# anchor_age                                         3.734055e-01
# disch_age                                         -3.185679e-01
# CKD_stage_first                                   -9.881707e-01
# ...                                                         ...
# Protein,_Total_last                                1.876324e-02
# MCV_last                                           8.662608e-03
# Protein/Creatinine_Ratio_last                      6.874638e-02
# MCV_first                                          3.488719e-02
# Secondary hyperparathyroidism (of renal origin)    3.677294e-01
#
#                                                  exp(coef) lower 95%  \
# covariate
# subject_id                                                  1.000000
# gender                                                      1.044988
# anchor_age                                                  1.370423
# disch_age                                                   0.686164
# CKD_stage_first                                             0.305835
# ...                                                              ...
# Protein,_Total_last                                         0.859264
# MCV_last                                                    0.983389
# Protein/Creatinine_Ratio_last                               1.006129
# MCV_first                                                   1.005492
# Secondary hyperparathyroidism (of renal origin)             0.927320
#
#                                                  exp(coef) upper 95%  cmp to  \
# covariate
# subject_id                                                  1.000000     0.0
# gender                                                      1.371194     0.0
# anchor_age                                                  1.452673     0.0
# disch_age                                                   0.727190     0.0
# CKD_stage_first                                             0.372257     0.0
# ...                                                              ...     ...
# Protein,_Total_last                                         1.018940     0.0
# MCV_last                                                    1.008700     0.0
# Protein/Creatinine_Ratio_last                               1.071165     0.0
# MCV_first                                                   1.035503     0.0
# Secondary hyperparathyroidism (of renal origin)             1.444451     0.0
#
#                                                          z              p  \
# covariate
# subject_id                                       -1.808951   7.045854e-02
# gender                                            2.594900   9.461851e-03
# anchor_age                                       23.152784  1.362854e-118
# disch_age                                       -23.463857  9.545140e-122
# CKD_stage_first                                 -21.668682  4.051900e-104
# ...                                                    ...            ...
# Protein,_Total_last                              -1.528437   1.264041e-01
# MCV_last                                         -0.623789   5.327660e-01
# Protein/Creatinine_Ratio_last                     2.342394   1.916045e-02
# MCV_first                                         2.689941   7.146466e-03
# Secondary hyperparathyroidism (of renal origin)   1.292563   1.961624e-01
#
#                                                    -log2(p)
# covariate
# subject_id                                         3.827082
# gender                                             6.723662
# anchor_age                                       391.540884
# disch_age                                        402.020461
# CKD_stage_first                                  343.461923
# ...                                                     ...
# Protein,_Total_last                                2.983884
# MCV_last                                           0.908426
# Protein/Creatinine_Ratio_last                      5.705725
# MCV_first                                          7.128554
# Secondary hyperparathyroidism (of renal origin)    2.349880
#
# [82 rows x 11 columns]
#                                   test_statistic         p  -log2(p)
# Albumin/Creatinine,_Urine_first         0.301254  0.583097  0.778192
# Albumin/Creatinine,_Urine_last          0.049091  0.824653  0.278142
# Albumin/Creatinine,_Urine_max           0.045807  0.830527  0.267900
# Albumin/Creatinine,_Urine_mean          0.140840  0.707447  0.499305
# Albumin/Creatinine,_Urine_median        0.663803  0.415220  1.268051
# ...                                          ...       ...       ...
# eGFR_median                             0.158839  0.690228  0.534855
# eGFR_min                                0.042042  0.837539  0.255771
# first_stage_icd                         2.496077  0.114130  3.131246
# gender                                  3.957421  0.046665  4.421511
# subject_id                              0.102700  0.748613  0.417708
#
# [82 rows x 3 columns]
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sksurv\metrics.py:482: RuntimeWarning: invalid value encountered in divide
#   true_pos = cumsum_tp / cumsum_tp[-1]
