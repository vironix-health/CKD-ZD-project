# %%
import sys
import os

# Use os.getcwd() to get the current working directory in a Jupyter notebook
parent_dir = os.path.dirname(os.getcwd())  # Get the parent directory of the current working directory
sys.path.append(parent_dir)

# %%
import pandas as pd
from skopt.space import Real, Integer
from driver import Driver

# %% [markdown]
# # Load Cleaned Master MIMIC-IV Dataset

# %%
# Cleaned Master MIMIC Data Set
df_master = pd.read_pickle('../MIMIC_IV/df_ckd_master_clean.pkl')
df_base = pd.read_pickle('../MIMIC_IV/df_ckd_base.pkl')

# %% [markdown]
# # Evaluate ResNet Pipeline

# %%
ResNet_cfg = {
    'name': 'ResNet', # Feature selection model long name
    'tag': 'rsnt', # Feature selection model identifier tag
    'response': 'stage_delta',  # Response variable for binary classification and Cox Proportional Hazards
    'duration': 'duration', # Duration in days until response or censorship
    'n_novel': 40, # Number of ranked novel features included in augmented KFRE dataset
    'test_size': 0.2, # Ratio of data reserved for testing
    'num_blocks': 3,
    'hidden_dim': 64,
    'num_classes': 1, # Updated to 1 for binary classification
    'epochs': 30,
    'patience': 5,
    'learning_rate': 0.001,
    'weight_decay': 1e-4,
    'batch_size': 256, # Batch size for SHAP computation
    'n_folds': 5, # Number of folds for CoxPH cross validation
    'penalizer': 0.0007, # CoxPH model penalizer
    'random_state': 42 # Seed for reproducibility
}

driver = Driver(ResNet_cfg, df_master, df_base)
driver.DeepLearningPipe()
# Out:
# Epoch 1/30, Training Loss: 0.2724805132020265, Validation Loss: 0.2794608152048154
# Epoch 2/30, Training Loss: 0.17672931773334064, Validation Loss: 0.32310275970534846
# Epoch 3/30, Training Loss: 0.11153371623632582, Validation Loss: 0.42693235115571454
# Epoch 4/30, Training Loss: 0.07314934472775679, Validation Loss: 0.5340438332747329
# Epoch 5/30, Training Loss: 0.03832677169570657, Validation Loss: 0.6731290434571829
# Epoch 6/30, Training Loss: 0.027875802823307986, Validation Loss: 0.7206374311989004
# Early stopping triggered
# Test AUC: 0.6443945717846422
#  ... (more hidden) ...
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\shap\plots\_beeswarm.py:962: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   pl.tight_layout()
# Iteration 1: norm_delta = 6.49e+00, step_size = 0.9500, log_lik = -8744.90665, newton_decrement = 9.75e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.25e+00, step_size = 0.2375, log_lik = -8337.90465, newton_decrement = 5.45e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.92e+00, step_size = 0.0772, log_lik = -8257.08737, newton_decrement = 4.66e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.38e+00, step_size = 0.1304, log_lik = -8143.44535, newton_decrement = 3.56e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.54e+00, step_size = 0.2205, log_lik = -8003.67826, newton_decrement = 2.21e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.35e+00, step_size = 0.3726, log_lik = -7869.31698, newton_decrement = 9.08e+01, seconds_since_start = 0.5
# Iteration 7: norm_delta = 9.41e-01, step_size = 0.6296, log_lik = -7790.63681, newton_decrement = 1.36e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 1.37e-02, step_size = 1.0000, log_lik = -7776.92297, newton_decrement = 7.84e-03, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.16e-05, step_size = 1.0000, log_lik = -7776.91512, newton_decrement = 1.95e-08, seconds_since_start = 0.9
# Convergence success after 9 iterations.
# Iteration 1: norm_delta = 6.56e+00, step_size = 0.9500, log_lik = -8829.99117, newton_decrement = 9.73e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.34e+00, step_size = 0.2375, log_lik = -8424.25272, newton_decrement = 5.40e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.01e+00, step_size = 0.0772, log_lik = -8344.10137, newton_decrement = 4.62e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.88e+00, step_size = 0.0326, log_lik = -8314.47395, newton_decrement = 4.33e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.66e+00, step_size = 0.0551, log_lik = -8268.05501, newton_decrement = 3.88e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.29e+00, step_size = 0.0931, log_lik = -8199.12340, newton_decrement = 3.21e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 3.71e+00, step_size = 0.1574, log_lik = -8105.89336, newton_decrement = 2.31e+02, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.84e+00, step_size = 0.2660, log_lik = -7999.23376, newton_decrement = 1.27e+02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.65e+00, step_size = 0.4496, log_lik = -7910.24662, newton_decrement = 4.04e+01, seconds_since_start = 0.9
# Iteration 10: norm_delta = 4.33e-01, step_size = 0.7598, log_lik = -7871.98254, newton_decrement = 2.65e+00, seconds_since_start = 1.0
# Iteration 11: norm_delta = 2.77e-03, step_size = 1.0000, log_lik = -7869.31957, newton_decrement = 3.03e-04, seconds_since_start = 1.1
# Iteration 12: norm_delta = 3.83e-07, step_size = 1.0000, log_lik = -7869.31926, newton_decrement = 2.31e-11, seconds_since_start = 1.2
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.52e+00, step_size = 0.9500, log_lik = -8805.41001, newton_decrement = 9.66e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.27e+00, step_size = 0.2375, log_lik = -8402.65598, newton_decrement = 5.31e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.94e+00, step_size = 0.0772, log_lik = -8323.78428, newton_decrement = 4.54e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.41e+00, step_size = 0.1304, log_lik = -8213.09614, newton_decrement = 3.46e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.57e+00, step_size = 0.2205, log_lik = -8077.38392, newton_decrement = 2.14e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.37e+00, step_size = 0.3726, log_lik = -7947.43524, newton_decrement = 8.76e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.48e-01, step_size = 0.6296, log_lik = -7871.50520, newton_decrement = 1.32e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 1.26e-02, step_size = 1.0000, log_lik = -7858.21872, newton_decrement = 6.92e-03, seconds_since_start = 0.8
# Iteration 9: norm_delta = 7.90e-06, step_size = 1.0000, log_lik = -7858.21180, newton_decrement = 8.10e-09, seconds_since_start = 0.9
# Convergence success after 9 iterations.
# Iteration 1: norm_delta = 6.67e+00, step_size = 0.9500, log_lik = -9037.41005, newton_decrement = 9.64e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.42e+00, step_size = 0.2375, log_lik = -8635.31928, newton_decrement = 5.44e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.08e+00, step_size = 0.0772, log_lik = -8554.63736, newton_decrement = 4.66e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.94e+00, step_size = 0.0326, log_lik = -8524.74525, newton_decrement = 4.37e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.72e+00, step_size = 0.0551, log_lik = -8477.87096, newton_decrement = 3.92e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.35e+00, step_size = 0.0931, log_lik = -8408.16453, newton_decrement = 3.26e+02, seconds_since_start = 0.7
# Iteration 7: norm_delta = 3.76e+00, step_size = 0.1574, log_lik = -8313.67699, newton_decrement = 2.35e+02, seconds_since_start = 0.8
# Iteration 8: norm_delta = 2.86e+00, step_size = 0.2660, log_lik = -8205.24092, newton_decrement = 1.30e+02, seconds_since_start = 0.9
# Iteration 9: norm_delta = 1.66e+00, step_size = 0.4496, log_lik = -8114.49618, newton_decrement = 4.12e+01, seconds_since_start = 1.0
# Iteration 10: norm_delta = 4.33e-01, step_size = 0.7598, log_lik = -8075.51644, newton_decrement = 2.67e+00, seconds_since_start = 1.1
# Iteration 11: norm_delta = 2.73e-03, step_size = 1.0000, log_lik = -8072.83397, newton_decrement = 3.54e-04, seconds_since_start = 1.2
# Iteration 12: norm_delta = 6.04e-07, step_size = 1.0000, log_lik = -8072.83362, newton_decrement = 1.22e-10, seconds_since_start = 1.2
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.52e+00, step_size = 0.9500, log_lik = -8886.68689, newton_decrement = 9.93e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.28e+00, step_size = 0.2375, log_lik = -8474.86016, newton_decrement = 5.48e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.95e+00, step_size = 0.0772, log_lik = -8393.56106, newton_decrement = 4.69e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.41e+00, step_size = 0.1304, log_lik = -8279.24482, newton_decrement = 3.58e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.58e+00, step_size = 0.2205, log_lik = -8138.51715, newton_decrement = 2.24e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.38e+00, step_size = 0.3726, log_lik = -8002.61813, newton_decrement = 9.30e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.55e-01, step_size = 0.6296, log_lik = -7921.80805, newton_decrement = 1.45e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 1.98e-02, step_size = 1.0000, log_lik = -7907.05575, newton_decrement = 3.24e-02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 8.19e-04, step_size = 1.0000, log_lik = -7907.02208, newton_decrement = 1.97e-04, seconds_since_start = 0.9
# Iteration 10: norm_delta = 5.00e-06, step_size = 1.0000, log_lik = -7907.02188, newton_decrement = 2.05e-08, seconds_since_start = 1.0
# Convergence success after 10 iterations.
# Average C-Index from cross-validation: 0.8878
# Best C-Index from cross-validation: 0.8931
# Standard Deviation of C-Index from cross-validation: 0.0071
#                                                 coef  exp(coef)      se(coef)  \
# covariate
# subject_id                             -1.598206e-08   1.000000  1.014136e-08
# gender                                  5.084469e-02   1.052159  6.788528e-02
# anchor_age                              3.578565e-01   1.430260  1.471121e-02
# disch_age                              -3.613021e-01   0.696768  1.468649e-02
# CKD_stage_first                        -1.022064e+00   0.359851  4.624368e-02
# ...                                              ...        ...           ...
# Hyperpotassemia                        -2.498676e-02   0.975323  7.585526e-02
# Other chronic pulmonary heart diseases  5.094126e-02   1.052261  7.576710e-02
# Basophils_first                        -9.658800e-03   0.990388  8.114581e-02
# Aortocoronary bypass status             3.688418e-02   1.037573  7.899606e-02
# Platelet_Count_min                      3.500107e-04   1.000350  5.368890e-04
#
#                                         coef lower 95%  coef upper 95%  \
# covariate
# subject_id                               -3.585876e-08    3.894642e-09
# gender                                   -8.220801e-02    1.838974e-01
# anchor_age                                3.290230e-01    3.866899e-01
# disch_age                                -3.900871e-01   -3.325172e-01
# CKD_stage_first                          -1.112700e+00   -9.314284e-01
# ...                                                ...             ...
# Hyperpotassemia                          -1.736603e-01    1.236868e-01
# Other chronic pulmonary heart diseases   -9.755952e-02    1.994420e-01
# Basophils_first                          -1.687017e-01    1.493841e-01
# Aortocoronary bypass status              -1.179453e-01    1.917136e-01
# Platelet_Count_min                       -7.022724e-04    1.402294e-03
#
#                                         exp(coef) lower 95%  \
# covariate
# subject_id                                         1.000000
# gender                                             0.921080
# anchor_age                                         1.389610
# disch_age                                          0.676998
# CKD_stage_first                                    0.328670
# ...                                                     ...
# Hyperpotassemia                                    0.840582
# Other chronic pulmonary heart diseases             0.907048
# Basophils_first                                    0.844761
# Aortocoronary bypass status                        0.888745
# Platelet_Count_min                                 0.999298
#
#                                         exp(coef) upper 95%  cmp to  \
# covariate
# subject_id                                         1.000000     0.0
# gender                                             1.201892     0.0
# anchor_age                                         1.472100     0.0
# disch_age                                          0.717116     0.0
# CKD_stage_first                                    0.393991     0.0
# ...                                                     ...     ...
# Hyperpotassemia                                    1.131661     0.0
# Other chronic pulmonary heart diseases             1.220721     0.0
# Basophils_first                                    1.161119     0.0
# Aortocoronary bypass status                        1.211324     0.0
# Platelet_Count_min                                 1.001403     0.0
#
#                                                 z              p    -log2(p)
# covariate
# subject_id                              -1.575929   1.150423e-01    3.119764
# gender                                   0.748980   4.538695e-01    1.139651
# anchor_age                              24.325420  1.055530e-130  431.772685
# disch_age                              -24.600985  1.232902e-133  441.514378
# CKD_stage_first                        -22.101708  3.043364e-108  357.162567
# ...                                           ...            ...         ...
# Hyperpotassemia                         -0.329400   7.418530e-01    0.430795
# Other chronic pulmonary heart diseases   0.672340   5.013672e-01    0.996060
# Basophils_first                         -0.119030   9.052515e-01    0.143610
# Aortocoronary bypass status              0.466912   6.405631e-01    0.642587
# Platelet_Count_min                       0.651924   5.144503e-01    0.958896
#
# [81 rows x 11 columns]
#                                    test_statistic         p  -log2(p)
# Acute kidney failure, unspecified        0.231144  0.630677  0.665028
# Albumin/Creatinine,_Urine_first          0.056196  0.812613  0.299360
# Albumin/Creatinine,_Urine_last           0.403409  0.525334  0.928694
# Albumin/Creatinine,_Urine_max            0.000514  0.981907  0.026342
# Albumin/Creatinine,_Urine_mean           0.230092  0.631455  0.663247
# ...                                           ...       ...       ...
# eGFR_median                              0.009938  0.920590  0.119369
# eGFR_min                                 0.032694  0.856513  0.223454
# gender                                   1.188354  0.275662  1.859028
# race_WHITE                               0.826190  0.363377  1.460463
# subject_id                               0.200525  0.654297  0.611982
#
# [81 rows x 3 columns]
# Brier Score at 1 year(s): 0.0295
# Brier Score at 2 year(s): 0.0520
# Brier Score at 3 year(s): 0.0710
# Brier Score at 4 year(s): 0.0762
# Brier Score at 5 year(s): 0.0802
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sksurv\metrics.py:482: RuntimeWarning: invalid value encountered in divide
#   true_pos = cumsum_tp / cumsum_tp[-1]
# AUC at 1 year(s): 0.9430
# AUC at 2 year(s): 0.9217
# AUC at 3 year(s): 0.9090
# AUC at 4 year(s): 0.9442
# AUC at 5 year(s): 0.9528
