# %%
import sys
import os

# Use os.getcwd() to get the current working directory in a Jupyter notebook
parent_dir = os.path.dirname(os.getcwd())  # Get the parent directory of the current working directory
sys.path.append(parent_dir)

# %%
import pandas as pd
from skopt.space import Real, Integer
from driver import Driver

# %% [markdown]
# # Load Cleaned Master MIMIC-IV Dataset

# %%
# Cleaned Master MIMIC Data Set
df_master = pd.read_pickle('../MIMIC_IV/df_ckd_master_clean.pkl')
df_base = pd.read_pickle('../MIMIC_IV/df_ckd_base.pkl')

# %% [markdown]
# # Evaluate Decision Tree Pipeline

# %%
DecisionTree_cfg = {
    'tag': 'dct', # Identifier tag for feature selection model
    'response': 'stage_delta',  # Response variable for binary classification and Cox Proportional Hazards
    'duration': 'duration', # Duration in days until response or censorship
    'n_novel': 40, # Number of ranked novel features included in augmented KFRE dataset
    'test_size': 0.1, # Ratio of data reserved for testing
    'val_size': 0.2, # Ratio of data reserved for testing in validation sets
    'n_valsets': 5, # Number of training validation sets
    'n_bayesian': 10, # Number of Bayesian hyperparameter optimization iterations 
    'n_folds': 5, # Number of folds for CoxPH cross validation
    'penalizer': 0.0007, # CoxPH model penalizer
    'auc_space': [
        Integer(1, 50, name='max_depth'),
        Integer(2, 20, name="min_samples_split"),
        Integer(1, 20, name="min_samples_leaf"),
    ], # Search space for Bayesian hyperparameter optimization
    'random_state': 42 # Seed for reproducibility
}

driver = Driver(DecisionTree_cfg, df_master, df_base)
driver.ClassicalLearningPipe()
# Out:
# Testing params: {'max_depth': 40, 'min_samples_split': 5, 'min_samples_leaf': 16}
# AUC for params: 0.8553303243196264
# Testing params: {'max_depth': 30, 'min_samples_split': 10, 'min_samples_leaf': 3}
# AUC for params: 0.7802091551014876
# Testing params: {'max_depth': 24, 'min_samples_split': 8, 'min_samples_leaf': 4}
# AUC for params: 0.78884583331157
# Testing params: {'max_depth': 33, 'min_samples_split': 3, 'min_samples_leaf': 15}
# AUC for params: 0.8461417974737573
# Testing params: {'max_depth': 47, 'min_samples_split': 2, 'min_samples_leaf': 20}
# AUC for params: 0.8626096346351325
# Testing params: {'max_depth': 31, 'min_samples_split': 13, 'min_samples_leaf': 1}
# AUC for params: 0.7815938714089692
# Testing params: {'max_depth': 2, 'min_samples_split': 11, 'min_samples_leaf': 9}
# AUC for params: 0.7820774898386798
# Testing params: {'max_depth': 3, 'min_samples_split': 20, 'min_samples_leaf': 5}
# AUC for params: 0.8438820479201118
# Testing params: {'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 8}
# AUC for params: 0.9038953480949589
# Testing params: {'max_depth': 49, 'min_samples_split': 10, 'min_samples_leaf': 17}
# AUC for params: 0.8614295015344788
# Best parameters found:  {'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 8}
# Best average AUC across validation sets:  0.9038953480949589
# Test AUC: 0.656556964573269
# Iteration 1: norm_delta = 6.79e+00, step_size = 0.9500, log_lik = -8744.90665, newton_decrement = 9.56e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.40e+00, step_size = 0.2375, log_lik = -8345.90634, newton_decrement = 5.31e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.04e+00, step_size = 0.0772, log_lik = -8267.04893, newton_decrement = 4.53e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.89e+00, step_size = 0.0326, log_lik = -8237.97435, newton_decrement = 4.24e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.66e+00, step_size = 0.0551, log_lik = -8192.47567, newton_decrement = 3.80e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.27e+00, step_size = 0.0931, log_lik = -8125.06169, newton_decrement = 3.13e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 3.67e+00, step_size = 0.1574, log_lik = -8034.26829, newton_decrement = 2.23e+02, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.78e+00, step_size = 0.2660, log_lik = -7931.17546, newton_decrement = 1.22e+02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.60e+00, step_size = 0.4496, log_lik = -7846.13406, newton_decrement = 3.82e+01, seconds_since_start = 0.9
# Iteration 10: norm_delta = 4.18e-01, step_size = 0.7598, log_lik = -7810.00329, newton_decrement = 2.49e+00, seconds_since_start = 1.0
# Iteration 11: norm_delta = 2.87e-03, step_size = 1.0000, log_lik = -7807.49803, newton_decrement = 4.04e-04, seconds_since_start = 1.1
# Iteration 12: norm_delta = 5.29e-07, step_size = 1.0000, log_lik = -7807.49763, newton_decrement = 4.12e-11, seconds_since_start = 1.2
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.96e+00, step_size = 0.9500, log_lik = -8829.99117, newton_decrement = 9.46e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.55e+00, step_size = 0.2375, log_lik = -8435.21358, newton_decrement = 5.23e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.18e+00, step_size = 0.0772, log_lik = -8357.55829, newton_decrement = 4.45e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 5.04e+00, step_size = 0.0326, log_lik = -8329.01673, newton_decrement = 4.16e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.98e+00, step_size = 0.0138, log_lik = -8317.62742, newton_decrement = 4.05e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.88e+00, step_size = 0.0233, log_lik = -8298.99785, newton_decrement = 3.86e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 4.71e+00, step_size = 0.0394, log_lik = -8269.21290, newton_decrement = 3.56e+02, seconds_since_start = 0.7
# Iteration 8: norm_delta = 4.44e+00, step_size = 0.0665, log_lik = -8223.42004, newton_decrement = 3.10e+02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 3.99e+00, step_size = 0.1124, log_lik = -8157.62955, newton_decrement = 2.44e+02, seconds_since_start = 0.9
# Iteration 10: norm_delta = 3.31e+00, step_size = 0.1899, log_lik = -8073.72843, newton_decrement = 1.60e+02, seconds_since_start = 1.0
# Iteration 11: norm_delta = 2.33e+00, step_size = 0.3210, log_lik = -7987.37348, newton_decrement = 7.45e+01, seconds_since_start = 1.0
# Iteration 12: norm_delta = 1.12e+00, step_size = 0.5425, log_lik = -7928.35670, newton_decrement = 1.62e+01, seconds_since_start = 1.1
# Iteration 13: norm_delta = 1.10e-01, step_size = 0.9168, log_lik = -7912.15810, newton_decrement = 1.58e-01, seconds_since_start = 1.2
# Iteration 14: norm_delta = 1.97e-04, step_size = 1.0000, log_lik = -7911.99995, newton_decrement = 2.71e-06, seconds_since_start = 1.3
# Iteration 15: norm_delta = 4.97e-09, step_size = 1.0000, log_lik = -7911.99994, newton_decrement = 4.16e-15, seconds_since_start = 1.4
# Convergence success after 15 iterations.
# Iteration 1: norm_delta = 6.85e+00, step_size = 0.9500, log_lik = -8805.41001, newton_decrement = 9.24e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.47e+00, step_size = 0.2375, log_lik = -8419.44884, newton_decrement = 5.16e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.10e+00, step_size = 0.0772, log_lik = -8342.79567, newton_decrement = 4.40e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.96e+00, step_size = 0.0326, log_lik = -8314.58003, newton_decrement = 4.12e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.72e+00, step_size = 0.0551, log_lik = -8270.45631, newton_decrement = 3.68e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.34e+00, step_size = 0.0931, log_lik = -8205.16637, newton_decrement = 3.02e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 3.73e+00, step_size = 0.1574, log_lik = -8117.50715, newton_decrement = 2.14e+02, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.83e+00, step_size = 0.2660, log_lik = -8018.69405, newton_decrement = 1.16e+02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.63e+00, step_size = 0.4496, log_lik = -7937.98420, newton_decrement = 3.58e+01, seconds_since_start = 0.9
# Iteration 10: norm_delta = 4.22e-01, step_size = 0.7598, log_lik = -7904.16179, newton_decrement = 2.28e+00, seconds_since_start = 1.0
# Iteration 11: norm_delta = 2.48e-03, step_size = 1.0000, log_lik = -7901.87494, newton_decrement = 3.38e-04, seconds_since_start = 1.1
# Iteration 12: norm_delta = 4.46e-07, step_size = 1.0000, log_lik = -7901.87460, newton_decrement = 3.21e-11, seconds_since_start = 1.2
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.98e+00, step_size = 0.9500, log_lik = -9037.41005, newton_decrement = 9.33e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.59e+00, step_size = 0.2375, log_lik = -8647.75329, newton_decrement = 5.26e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.22e+00, step_size = 0.0772, log_lik = -8569.64191, newton_decrement = 4.50e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 5.08e+00, step_size = 0.0326, log_lik = -8540.77796, newton_decrement = 4.22e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 5.02e+00, step_size = 0.0138, log_lik = -8529.23543, newton_decrement = 4.11e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.99e+00, step_size = 0.0058, log_lik = -8524.46950, newton_decrement = 4.06e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 4.95e+00, step_size = 0.0098, log_lik = -8516.52202, newton_decrement = 3.98e+02, seconds_since_start = 0.7
# Iteration 8: norm_delta = 4.88e+00, step_size = 0.0166, log_lik = -8503.39139, newton_decrement = 3.85e+02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 4.76e+00, step_size = 0.0281, log_lik = -8482.03651, newton_decrement = 3.65e+02, seconds_since_start = 0.9
# Iteration 10: norm_delta = 4.56e+00, step_size = 0.0475, log_lik = -8448.22789, newton_decrement = 3.32e+02, seconds_since_start = 1.0
# Iteration 11: norm_delta = 4.24e+00, step_size = 0.0803, log_lik = -8397.12125, newton_decrement = 2.82e+02, seconds_since_start = 1.1
# Iteration 12: norm_delta = 3.73e+00, step_size = 0.1356, log_lik = -8325.84054, newton_decrement = 2.12e+02, seconds_since_start = 1.2
# Iteration 13: norm_delta = 2.95e+00, step_size = 0.2292, log_lik = -8239.71133, newton_decrement = 1.27e+02, seconds_since_start = 1.3
# Iteration 14: norm_delta = 1.88e+00, step_size = 0.3874, log_lik = -8160.04986, newton_decrement = 4.90e+01, seconds_since_start = 1.4
# Iteration 15: norm_delta = 6.91e-01, step_size = 0.6546, log_lik = -8116.72363, newton_decrement = 6.32e+00, seconds_since_start = 1.5
# Iteration 16: norm_delta = 6.99e-03, step_size = 1.0000, log_lik = -8110.35425, newton_decrement = 3.07e-03, seconds_since_start = 1.6
# Iteration 17: norm_delta = 3.99e-06, step_size = 1.0000, log_lik = -8110.35118, newton_decrement = 3.09e-09, seconds_since_start = 1.7
# Convergence success after 17 iterations.
# Iteration 1: norm_delta = 6.87e+00, step_size = 0.9500, log_lik = -8886.68689, newton_decrement = 9.65e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.48e+00, step_size = 0.2375, log_lik = -8483.94369, newton_decrement = 5.34e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.12e+00, step_size = 0.0772, log_lik = -8404.67577, newton_decrement = 4.56e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.98e+00, step_size = 0.0326, log_lik = -8375.44786, newton_decrement = 4.27e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.74e+00, step_size = 0.0551, log_lik = -8329.70071, newton_decrement = 3.82e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.36e+00, step_size = 0.0931, log_lik = -8261.89145, newton_decrement = 3.15e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 3.75e+00, step_size = 0.1574, log_lik = -8170.49065, newton_decrement = 2.25e+02, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.84e+00, step_size = 0.2660, log_lik = -8066.61150, newton_decrement = 1.22e+02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.64e+00, step_size = 0.4496, log_lik = -7981.17299, newton_decrement = 3.83e+01, seconds_since_start = 0.9
# Iteration 10: norm_delta = 4.30e-01, step_size = 0.7598, log_lik = -7944.85850, newton_decrement = 2.54e+00, seconds_since_start = 1.0
# Iteration 11: norm_delta = 3.06e-03, step_size = 1.0000, log_lik = -7942.29684, newton_decrement = 6.64e-04, seconds_since_start = 1.1
# Iteration 12: norm_delta = 1.16e-06, step_size = 1.0000, log_lik = -7942.29617, newton_decrement = 2.25e-10, seconds_since_start = 1.2
# Convergence success after 12 iterations.
# Average C-Index from cross-validation: 0.8866
# Best C-Index from cross-validation: 0.8940
# Standard Deviation of C-Index from cross-validation: 0.0069
#                                                             coef  exp(coef)  \
# covariate
# subject_id                                         -1.345070e-08   1.000000
# gender                                              7.141646e-02   1.074028
# anchor_age                                          3.693818e-01   1.446840
# disch_age                                          -3.696189e-01   0.690998
# CKD_stage_first                                    -1.022859e+00   0.359566
# ...                                                          ...        ...
# Methicillin susceptible Staphylococcus aureus s... -2.705618e-01   0.762951
# Penicillins causing adverse effects in therapeu... -2.507644e-01   0.778206
# Heart valve replaced by other means                -1.488313e-01   0.861715
# Unspecified acquired hypothyroidism                -5.414270e-02   0.947297
# Nonspecific abnormal findings in stool contents     3.743118e-02   1.038141
#
#                                                         se(coef)  \
# covariate
# subject_id                                          1.023781e-08
# gender                                              6.678840e-02
# anchor_age                                          1.461811e-02
# disch_age                                           1.457508e-02
# CKD_stage_first                                     4.554930e-02
# ...                                                          ...
# Methicillin susceptible Staphylococcus aureus s...  2.117736e-01
# Penicillins causing adverse effects in therapeu...  2.892933e-01
# Heart valve replaced by other means                 1.365261e-01
# Unspecified acquired hypothyroidism                 7.407706e-02
# Nonspecific abnormal findings in stool contents     1.479573e-01
#
#                                                     coef lower 95%  \
# covariate
# subject_id                                           -3.351644e-08
# gender                                               -5.948640e-02
# anchor_age                                            3.407309e-01
# disch_age                                            -3.981855e-01
# CKD_stage_first                                      -1.112134e+00
# ...                                                            ...
# Methicillin susceptible Staphylococcus aureus s...   -6.856304e-01
# Penicillins causing adverse effects in therapeu...   -8.177688e-01
# Heart valve replaced by other means                  -4.164175e-01
# Unspecified acquired hypothyroidism                  -1.993311e-01
# Nonspecific abnormal findings in stool contents      -2.525599e-01
#
#                                                     coef upper 95%  \
# covariate
# subject_id                                            6.615028e-09
# gender                                                2.023193e-01
# anchor_age                                            3.980328e-01
# disch_age                                            -3.410522e-01
# CKD_stage_first                                      -9.335837e-01
# ...                                                            ...
# Methicillin susceptible Staphylococcus aureus s...    1.445068e-01
# Penicillins causing adverse effects in therapeu...    3.162399e-01
# Heart valve replaced by other means                   1.187550e-01
# Unspecified acquired hypothyroidism                   9.104567e-02
# Nonspecific abnormal findings in stool contents       3.274222e-01
#
#                                                     exp(coef) lower 95%  \
# covariate
# subject_id                                                     1.000000
# gender                                                         0.942248
# anchor_age                                                     1.405975
# disch_age                                                      0.671537
# CKD_stage_first                                                0.328857
# ...                                                                 ...
# Methicillin susceptible Staphylococcus aureus s...             0.503773
# Penicillins causing adverse effects in therapeu...             0.441415
# Heart valve replaced by other means                            0.659405
# Unspecified acquired hypothyroidism                            0.819279
# Nonspecific abnormal findings in stool contents                0.776810
#
#                                                     exp(coef) upper 95%  \
# covariate
# subject_id                                                     1.000000
# gender                                                         1.224239
# anchor_age                                                     1.488893
# disch_age                                                      0.711022
# CKD_stage_first                                                0.393142
# ...                                                                 ...
# Methicillin susceptible Staphylococcus aureus s...             1.155470
# Penicillins causing adverse effects in therapeu...             1.371959
# Heart valve replaced by other means                            1.126094
# Unspecified acquired hypothyroidism                            1.095319
# Nonspecific abnormal findings in stool contents                1.387387
#
#                                                     cmp to          z  \
# covariate
# subject_id                                             0.0  -1.313827
# gender                                                 0.0   1.069294
# anchor_age                                             0.0  25.268790
# disch_age                                              0.0 -25.359647
# CKD_stage_first                                        0.0 -22.456079
# ...                                                    ...        ...
# Methicillin susceptible Staphylococcus aureus s...     0.0  -1.277599
# Penicillins causing adverse effects in therapeu...     0.0  -0.866817
# Heart valve replaced by other means                    0.0  -1.090131
# Unspecified acquired hypothyroidism                    0.0  -0.730897
# Nonspecific abnormal findings in stool contents        0.0   0.252986
#
#                                                                 p    -log2(p)
# covariate
# subject_id                                           1.889045e-01    2.404271
# gender                                               2.849370e-01    1.811285
# anchor_age                                          7.040686e-141  465.576145
# disch_age                                           7.033890e-142  468.899467
# CKD_stage_first                                     1.116138e-111  368.575503
# ...                                                           ...         ...
# Methicillin susceptible Staphylococcus aureus s...   2.013907e-01    2.311931
# Penicillins causing adverse effects in therapeu...   3.860420e-01    1.373170
# Heart valve replaced by other means                  2.756556e-01    1.859061
# Unspecified acquired hypothyroidism                  4.648421e-01    1.105188
# Nonspecific abnormal findings in stool contents      8.002788e-01    0.321425
#
# [82 rows x 11 columns]
#                                            test_statistic         p  -log2(p)
# Abnormality of gait                              0.140764  0.707522  0.499152
# Acute and subacute bacterial endocarditis        0.217089  0.641267  0.641003
# Albumin/Creatinine,_Urine_first                  0.333662  0.563511  0.827485
# Albumin/Creatinine,_Urine_last                   0.002432  0.960671  0.057886
# Albumin/Creatinine,_Urine_max                    0.092172  0.761434  0.393209
# ...                                                   ...       ...       ...
# eGFR_median                                      0.006413  0.936173  0.095153
# eGFR_min                                         0.050908  0.821491  0.283683
# first_stage_icd                                  6.090224  0.013593  6.200972
# gender                                           1.823736  0.176869  2.499245
# subject_id                                       0.002000  0.964326  0.052408
#
# [82 rows x 3 columns]
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sksurv\metrics.py:482: RuntimeWarning: invalid value encountered in divide
#   true_pos = cumsum_tp / cumsum_tp[-1]
