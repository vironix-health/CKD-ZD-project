# %%
import sys
import os

# Use os.getcwd() to get the current working directory in a Jupyter notebook
parent_dir = os.path.dirname(os.getcwd())  # Get the parent directory of the current working directory
sys.path.append(parent_dir)

# %%
import pandas as pd
from skopt.space import Real, Integer
from driver import Driver

# %% [markdown]
# # Load Cleaned Master MIMIC-IV Dataset

# %%
# Cleaned Master MIMIC Data Set
df_master = pd.read_pickle('../MIMIC_IV/df_ckd_master_clean.pkl')
df_base = pd.read_pickle('../MIMIC_IV/df_ckd_base.pkl')

# %% [markdown]
# # Evaluate XGBoost Pipeline

# %%
XGboost_cfg = {
    'name': 'XGboost', # Feature selection model long name
    'tag': 'xgb', # Feature selection model identifier tag
    'response': 'stage_delta',  # Response variable for binary classification and Cox Proportional Hazards
    'duration': 'duration', # Duration in days until response or censorship
    'n_novel': 40, # Number of ranked novel features included in augmented KFRE dataset
    'test_size': 0.1, # Ratio of data reserved for testing
    'val_size': 0.2, # Ratio of data reserved for testing in validation sets
    'n_valsets': 5, # Number of training validation sets
    'n_bayesian': 10, # Number of Bayesian hyperparameter optimization iterations 
    'n_folds': 5, # Number of folds for CoxPH cross validation
    'penalizer': 0.0007, # CoxPH model penalizer
    'auc_space': [
        Integer(5, 20, name='max_depth'),
        Integer(1, 10, name='min_child_weight'),
        Real(0.5, 3.0, name='gamma'),
        Real(0.6, 1.0, name='subsample'),
        Real(0.6, 1.0, name='colsample_bytree'),
        Real(0.01, 0.6, name='colsample_bylevel'),
        Real(0.01, 0.3, name='learning_rate'),
        Integer(50, 150, name='n_estimators')
    ], # Search space for Bayesian hyperparameter optimization
    'seeds': [42, 73, 128, 256, 512] # Seeds for reproducibility
}

driver = Driver(XGboost_cfg, df_master, df_base)
driver.ClassicalLearningPipe()
# Out:
# Testing params: {'max_depth': 17, 'min_child_weight': 3, 'gamma': 2.449227500681924, 'subsample': 0.8387400631785948, 'colsample_bytree': 0.7783331011414365, 'colsample_bylevel': 0.06898520033262172, 'learning_rate': 0.1431821786701015, 'n_estimators': 83}
# AUC for params: 0.9364644643907611
# Testing params: {'max_depth': 7, 'min_child_weight': 7, 'gamma': 0.6410289475677506, 'subsample': 0.88879950890673, 'colsample_bytree': 0.9754210836063002, 'colsample_bylevel': 0.010459471846198455, 'learning_rate': 0.29774135219445313, 'n_estimators': 112}
# AUC for params: 0.895695471929886
# Testing params: {'max_depth': 14, 'min_child_weight': 1, 'gamma': 0.5576560626035394, 'subsample': 0.8099098641033557, 'colsample_bytree': 0.7599443886861023, 'colsample_bylevel': 0.0375327412960331, 'learning_rate': 0.2923891004640232, 'n_estimators': 73}
# AUC for params: 0.9222289847406191
# Testing params: {'max_depth': 6, 'min_child_weight': 7, 'gamma': 1.456154978167907, 'subsample': 0.9932923543227153, 'colsample_bytree': 0.786705157299192, 'colsample_bylevel': 0.5173648399744293, 'learning_rate': 0.20728918619045614, 'n_estimators': 95}
# AUC for params: 0.9515159152227813
# Testing params: {'max_depth': 5, 'min_child_weight': 9, 'gamma': 1.9082205446138485, 'subsample': 0.7541666010159664, 'colsample_bytree': 0.6063865008880857, 'colsample_bylevel': 0.14622735711706794, 'learning_rate': 0.07989738514754341, 'n_estimators': 118}
# AUC for params: 0.9439675757113599
# Testing params: {'max_depth': 14, 'min_child_weight': 8, 'gamma': 0.9334116337694303, 'subsample': 0.7564242430292963, 'colsample_bytree': 0.672894435115225, 'colsample_bylevel': 0.45566323208741505, 'learning_rate': 0.133295203602461, 'n_estimators': 71}
# AUC for params: 0.9512739424038724
# Testing params: {'max_depth': 14, 'min_child_weight': 1, 'gamma': 2.6057119364874968, 'subsample': 0.7799016533479063, 'colsample_bytree': 0.7580600944007259, 'colsample_bylevel': 0.5567287308183387, 'learning_rate': 0.22090887879836207, 'n_estimators': 83}
# AUC for params: 0.952012854902334
# Testing params: {'max_depth': 14, 'min_child_weight': 6, 'gamma': 2.9029300608733735, 'subsample': 0.9378135394712607, 'colsample_bytree': 0.8989280440549523, 'colsample_bylevel': 0.3284183581095571, 'learning_rate': 0.180157838042516, 'n_estimators': 147}
# AUC for params: 0.9531155281164908
# Testing params: {'max_depth': 14, 'min_child_weight': 3, 'gamma': 1.240683764260206, 'subsample': 0.666106775625201, 'colsample_bytree': 0.6062545626964776, 'colsample_bylevel': 0.25980687361675814, 'learning_rate': 0.12451564027091523, 'n_estimators': 79}
# AUC for params: 0.9470733258236569
# Testing params: {'max_depth': 5, 'min_child_weight': 3, 'gamma': 2.2783548818716253, 'subsample': 0.9160702162124823, 'colsample_bytree': 0.8423839899124046, 'colsample_bylevel': 0.556517518322876, 'learning_rate': 0.19881233739556392, 'n_estimators': 141}
# AUC for params: 0.9538269411014066
# Testing params: {'max_depth': 10, 'min_child_weight': 6, 'gamma': 0.933452960294806, 'subsample': 0.8074745490938097, 'colsample_bytree': 0.7237293577625215, 'colsample_bylevel': 0.06068539763948474, 'learning_rate': 0.2611908472769515, 'n_estimators': 98}
# AUC for params: 0.9290707973255513
# Testing params: {'max_depth': 17, 'min_child_weight': 10, 'gamma': 1.974994301736356, 'subsample': 0.7965102709574543, 'colsample_bytree': 0.9482630607656236, 'colsample_bylevel': 0.19984955663930612, 'learning_rate': 0.23202792384261245, 'n_estimators': 61}
# AUC for params: 0.9444525365003773
# Testing params: {'max_depth': 12, 'min_child_weight': 3, 'gamma': 0.9387528655114192, 'subsample': 0.9181845932325159, 'colsample_bytree': 0.6473121852976899, 'colsample_bylevel': 0.15822511196200456, 'learning_rate': 0.11959670874810557, 'n_estimators': 106}
# AUC for params: 0.9499240225878838
# Testing params: {'max_depth': 15, 'min_child_weight': 7, 'gamma': 2.8499746111907074, 'subsample': 0.7429253696706093, 'colsample_bytree': 0.6307631312226222, 'colsample_bylevel': 0.3224170087555978, 'learning_rate': 0.11612689599406166, 'n_estimators': 117}
# AUC for params: 0.9514997035643706
# Testing params: {'max_depth': 9, 'min_child_weight': 1, 'gamma': 2.1933076568464913, 'subsample': 0.8492070440096917, 'colsample_bytree': 0.9452314025547244, 'colsample_bylevel': 0.15772753983280408, 'learning_rate': 0.29382136671404163, 'n_estimators': 115}
# AUC for params: 0.9491594062979167
# Testing params: {'max_depth': 13, 'min_child_weight': 2, 'gamma': 0.6370841214646201, 'subsample': 0.6539117995442177, 'colsample_bytree': 0.8471621484819322, 'colsample_bylevel': 0.1458407939085695, 'learning_rate': 0.20447727436752106, 'n_estimators': 145}
# AUC for params: 0.939386659391096
# Testing params: {'max_depth': 13, 'min_child_weight': 2, 'gamma': 0.5211884563120379, 'subsample': 0.9576180738923996, 'colsample_bytree': 0.8333829272825677, 'colsample_bylevel': 0.17074979938718662, 'learning_rate': 0.1897027812146979, 'n_estimators': 134}
# AUC for params: 0.94936210313092
# Testing params: {'max_depth': 15, 'min_child_weight': 7, 'gamma': 2.468109121508276, 'subsample': 0.9197095358163327, 'colsample_bytree': 0.6157963653343597, 'colsample_bylevel': 0.05460292553473589, 'learning_rate': 0.2669933342704078, 'n_estimators': 135}
# AUC for params: 0.9203023166767782
# Testing params: {'max_depth': 15, 'min_child_weight': 2, 'gamma': 2.7473389935285817, 'subsample': 0.7328929847347122, 'colsample_bytree': 0.7275050570773035, 'colsample_bylevel': 0.5543184627394914, 'learning_rate': 0.15031544796447813, 'n_estimators': 142}
# AUC for params: 0.9519223450021105
# Testing params: {'max_depth': 8, 'min_child_weight': 2, 'gamma': 0.5695676809841717, 'subsample': 0.6837804790770629, 'colsample_bytree': 0.9729212122323618, 'colsample_bylevel': 0.37220699931586315, 'learning_rate': 0.06982249096998813, 'n_estimators': 116}
# AUC for params: 0.955807904428322
# Testing params: {'max_depth': 18, 'min_child_weight': 9, 'gamma': 1.450957537472126, 'subsample': 0.8078041620222459, 'colsample_bytree': 0.7464289803668099, 'colsample_bylevel': 0.22252936837415113, 'learning_rate': 0.23814194339825445, 'n_estimators': 108}
# AUC for params: 0.9412782851588091
# Testing params: {'max_depth': 7, 'min_child_weight': 8, 'gamma': 2.892667832034152, 'subsample': 0.664053871041874, 'colsample_bytree': 0.8652275241949706, 'colsample_bylevel': 0.18663001467892495, 'learning_rate': 0.16879997178885076, 'n_estimators': 147}
# AUC for params: 0.9439613527292068
# Testing params: {'max_depth': 18, 'min_child_weight': 7, 'gamma': 0.7027849425845566, 'subsample': 0.9329880177552772, 'colsample_bytree': 0.6789340155097219, 'colsample_bylevel': 0.23843431710668916, 'learning_rate': 0.22988406363993807, 'n_estimators': 109}
# AUC for params: 0.944923133471929
# Testing params: {'max_depth': 11, 'min_child_weight': 5, 'gamma': 0.5567211131224463, 'subsample': 0.6208850316143761, 'colsample_bytree': 0.7182779827750151, 'colsample_bylevel': 0.35248589604579256, 'learning_rate': 0.2593703752554241, 'n_estimators': 58}
# AUC for params: 0.9408771557044098
# Testing params: {'max_depth': 10, 'min_child_weight': 6, 'gamma': 0.5362308506802766, 'subsample': 0.6576883983716427, 'colsample_bytree': 0.6666607000082531, 'colsample_bylevel': 0.4341168731281085, 'learning_rate': 0.24526146072685343, 'n_estimators': 144}
# AUC for params: 0.938589514859067
# Testing params: {'max_depth': 15, 'min_child_weight': 9, 'gamma': 1.6467855952375128, 'subsample': 0.6087093345687992, 'colsample_bytree': 0.6865983389300583, 'colsample_bylevel': 0.018343213444212886, 'learning_rate': 0.21481742166033, 'n_estimators': 143}
# AUC for params: 0.9005080607043819
# Testing params: {'max_depth': 17, 'min_child_weight': 1, 'gamma': 2.8236508147114177, 'subsample': 0.8695981449134061, 'colsample_bytree': 0.8864981813320322, 'colsample_bylevel': 0.5962143512443494, 'learning_rate': 0.2568721599058064, 'n_estimators': 77}
# AUC for params: 0.9522849567287945
# Testing params: {'max_depth': 9, 'min_child_weight': 7, 'gamma': 2.1688093903183097, 'subsample': 0.7800449515022764, 'colsample_bytree': 0.6602817988441138, 'colsample_bylevel': 0.3689948876390806, 'learning_rate': 0.023320837976189758, 'n_estimators': 65}
# AUC for params: 0.9362103552734119
# Testing params: {'max_depth': 17, 'min_child_weight': 2, 'gamma': 2.2088342203498286, 'subsample': 0.6714441334860402, 'colsample_bytree': 0.647407249957168, 'colsample_bylevel': 0.2567121874626041, 'learning_rate': 0.0613654875179395, 'n_estimators': 128}
# AUC for params: 0.9509611915269611
# Testing params: {'max_depth': 17, 'min_child_weight': 5, 'gamma': 2.5421540836163716, 'subsample': 0.9342971764760399, 'colsample_bytree': 0.8915769629779049, 'colsample_bylevel': 0.0926709602772879, 'learning_rate': 0.08588736521814078, 'n_estimators': 126}
# AUC for params: 0.9453387444624319
# Testing params: {'max_depth': 18, 'min_child_weight': 6, 'gamma': 1.744583764751313, 'subsample': 0.8743052572786575, 'colsample_bytree': 0.9882838589040556, 'colsample_bylevel': 0.22175260799705973, 'learning_rate': 0.2609240533063088, 'n_estimators': 107}
# AUC for params: 0.9475594732285331
# Testing params: {'max_depth': 6, 'min_child_weight': 8, 'gamma': 2.1805293364529605, 'subsample': 0.8081390367281305, 'colsample_bytree': 0.7407083079909534, 'colsample_bylevel': 0.09642498540153738, 'learning_rate': 0.17307103381552902, 'n_estimators': 128}
# AUC for params: 0.9392324499514331
# Testing params: {'max_depth': 13, 'min_child_weight': 3, 'gamma': 1.8998961918802888, 'subsample': 0.7600502900966775, 'colsample_bytree': 0.624540063521517, 'colsample_bylevel': 0.28077137148751524, 'learning_rate': 0.1256725754287895, 'n_estimators': 57}
# AUC for params: 0.9512344385443047
# Testing params: {'max_depth': 16, 'min_child_weight': 1, 'gamma': 1.801999611045297, 'subsample': 0.6437029077957412, 'colsample_bytree': 0.6883578959122102, 'colsample_bylevel': 0.33110317314776877, 'learning_rate': 0.10121103643313485, 'n_estimators': 135}
# AUC for params: 0.9526383316540716
# Testing params: {'max_depth': 6, 'min_child_weight': 8, 'gamma': 0.9279986100111495, 'subsample': 0.7586778965453337, 'colsample_bytree': 0.6918196694026406, 'colsample_bylevel': 0.258556129393049, 'learning_rate': 0.08571395534520161, 'n_estimators': 79}
# AUC for params: 0.9494810027420678
# Testing params: {'max_depth': 18, 'min_child_weight': 9, 'gamma': 1.0800605396428309, 'subsample': 0.8128198728387316, 'colsample_bytree': 0.6457959707255607, 'colsample_bylevel': 0.038508764896425615, 'learning_rate': 0.21349369655989683, 'n_estimators': 146}
# AUC for params: 0.9222391127183874
# Testing params: {'max_depth': 18, 'min_child_weight': 5, 'gamma': 2.4448009544305602, 'subsample': 0.8365175913933166, 'colsample_bytree': 0.6133608904479668, 'colsample_bylevel': 0.07444971795996125, 'learning_rate': 0.1624278939442858, 'n_estimators': 101}
# AUC for params: 0.9373319432358969
# Testing params: {'max_depth': 8, 'min_child_weight': 5, 'gamma': 1.3319024984036414, 'subsample': 0.8098295794851015, 'colsample_bytree': 0.9195766816808415, 'colsample_bylevel': 0.28139142114052024, 'learning_rate': 0.2804519070417429, 'n_estimators': 84}
# AUC for params: 0.9434901348657814
# Testing params: {'max_depth': 17, 'min_child_weight': 9, 'gamma': 1.2149320452284664, 'subsample': 0.9425336391490517, 'colsample_bytree': 0.8483108593934907, 'colsample_bylevel': 0.3677152291041107, 'learning_rate': 0.08766469919149625, 'n_estimators': 78}
# AUC for params: 0.9531758608350268
# Testing params: {'max_depth': 16, 'min_child_weight': 8, 'gamma': 0.6680821093892199, 'subsample': 0.8840562878860336, 'colsample_bytree': 0.6427964075907837, 'colsample_bylevel': 0.5799536776404668, 'learning_rate': 0.15578248079430032, 'n_estimators': 148}
# AUC for params: 0.9483214885202471
# Testing params: {'max_depth': 11, 'min_child_weight': 3, 'gamma': 1.416838857627334, 'subsample': 0.6901321354054767, 'colsample_bytree': 0.8236588607061289, 'colsample_bylevel': 0.4125785161351308, 'learning_rate': 0.10453164519532707, 'n_estimators': 118}
# AUC for params: 0.949756660508019
# Testing params: {'max_depth': 18, 'min_child_weight': 4, 'gamma': 2.5583693664841713, 'subsample': 0.6673010641439363, 'colsample_bytree': 0.819948300801185, 'colsample_bylevel': 0.1459605426022886, 'learning_rate': 0.2977797780792895, 'n_estimators': 112}
# AUC for params: 0.9375029063178177
# Testing params: {'max_depth': 7, 'min_child_weight': 3, 'gamma': 1.5928373675895366, 'subsample': 0.8761945042476393, 'colsample_bytree': 0.7281895670882967, 'colsample_bylevel': 0.4950847183183785, 'learning_rate': 0.2771083406303684, 'n_estimators': 128}
# AUC for params: 0.9489062929613372
# Testing params: {'max_depth': 14, 'min_child_weight': 7, 'gamma': 1.0938247141561428, 'subsample': 0.7322272941326106, 'colsample_bytree': 0.8532168821575159, 'colsample_bylevel': 0.07616481867681611, 'learning_rate': 0.22437172621719484, 'n_estimators': 66}
# AUC for params: 0.9344334285038866
# Testing params: {'max_depth': 20, 'min_child_weight': 5, 'gamma': 2.0372858027923932, 'subsample': 0.7883017998992284, 'colsample_bytree': 0.8949214795778426, 'colsample_bylevel': 0.5258785927114321, 'learning_rate': 0.20417107155230685, 'n_estimators': 135}
# AUC for params: 0.9481641877421078
# Testing params: {'max_depth': 13, 'min_child_weight': 4, 'gamma': 0.7193657353623579, 'subsample': 0.8405764156607004, 'colsample_bytree': 0.6729931962601351, 'colsample_bylevel': 0.4158412087502628, 'learning_rate': 0.21372605852887397, 'n_estimators': 112}
# AUC for params: 0.943047028878398
# Testing params: {'max_depth': 10, 'min_child_weight': 4, 'gamma': 2.1019404773025543, 'subsample': 0.6558987988518561, 'colsample_bytree': 0.6667761144056432, 'colsample_bylevel': 0.29486911066031757, 'learning_rate': 0.28322736895662126, 'n_estimators': 52}
# AUC for params: 0.9421926555503124
# Testing params: {'max_depth': 18, 'min_child_weight': 5, 'gamma': 0.9065276531227255, 'subsample': 0.7589232006811557, 'colsample_bytree': 0.9944421359041863, 'colsample_bylevel': 0.447827359587067, 'learning_rate': 0.2920447312591175, 'n_estimators': 106}
# AUC for params: 0.9403699153567271
# Testing params: {'max_depth': 10, 'min_child_weight': 2, 'gamma': 1.4979242487918625, 'subsample': 0.6484617180138601, 'colsample_bytree': 0.8557442153411692, 'colsample_bylevel': 0.21357074716506141, 'learning_rate': 0.20068146117129354, 'n_estimators': 62}
# AUC for params: 0.9438705545288304
# Testing params: {'max_depth': 20, 'min_child_weight': 2, 'gamma': 2.003994153200019, 'subsample': 0.8830849532597265, 'colsample_bytree': 0.6120460952170717, 'colsample_bylevel': 0.06696827520213419, 'learning_rate': 0.11572286904686395, 'n_estimators': 108}
# AUC for params: 0.9243119456397405
# Best parameters found:  {'max_depth': 8, 'min_child_weight': 2, 'gamma': 0.5695676809841717, 'subsample': 0.6837804790770629, 'colsample_bytree': 0.9729212122323618, 'colsample_bylevel': 0.37220699931586315, 'learning_rate': 0.06982249096998813, 'n_estimators': 116}
# Best mean AUC across validation sets:  0.955807904428322
# Mean AUC: 0.7796232651739268
# Standard Deviation: 0.025708820893553926
# Max AUC: 0.8104705558613099
# Iteration 1: norm_delta = 6.46e+00, step_size = 0.9500, log_lik = -8744.90665, newton_decrement = 1.00e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.20e+00, step_size = 0.2375, log_lik = -8326.74547, newton_decrement = 5.59e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.86e+00, step_size = 0.0772, log_lik = -8243.80402, newton_decrement = 4.81e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.33e+00, step_size = 0.1304, log_lik = -8126.52628, newton_decrement = 3.71e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.50e+00, step_size = 0.2205, log_lik = -7980.67808, newton_decrement = 2.35e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.32e+00, step_size = 0.3726, log_lik = -7837.57381, newton_decrement = 9.95e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.25e-01, step_size = 0.6296, log_lik = -7751.16722, newton_decrement = 1.55e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 1.38e-02, step_size = 1.0000, log_lik = -7735.52331, newton_decrement = 1.36e-02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 2.17e-05, step_size = 1.0000, log_lik = -7735.50970, newton_decrement = 9.78e-08, seconds_since_start = 0.8
# Convergence success after 9 iterations.
# Iteration 1: norm_delta = 6.57e+00, step_size = 0.9500, log_lik = -8829.99117, newton_decrement = 1.01e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.32e+00, step_size = 0.2375, log_lik = -8410.40121, newton_decrement = 5.55e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.99e+00, step_size = 0.0772, log_lik = -8327.99685, newton_decrement = 4.76e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.45e+00, step_size = 0.1304, log_lik = -8211.78081, newton_decrement = 3.66e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.61e+00, step_size = 0.2205, log_lik = -8067.91294, newton_decrement = 2.30e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.39e+00, step_size = 0.3726, log_lik = -7927.79298, newton_decrement = 9.66e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.56e-01, step_size = 0.6296, log_lik = -7843.94503, newton_decrement = 1.49e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 1.27e-02, step_size = 1.0000, log_lik = -7828.88464, newton_decrement = 1.19e-02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 5.20e-05, step_size = 1.0000, log_lik = -7828.87276, newton_decrement = 2.31e-07, seconds_since_start = 0.8
# Iteration 10: norm_delta = 1.04e-07, step_size = 1.0000, log_lik = -7828.87276, newton_decrement = 5.65e-13, seconds_since_start = 0.9
# Convergence success after 10 iterations.
# Iteration 1: norm_delta = 6.52e+00, step_size = 0.9500, log_lik = -8805.41001, newton_decrement = 1.00e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.24e+00, step_size = 0.2375, log_lik = -8388.38816, newton_decrement = 5.49e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.90e+00, step_size = 0.0772, log_lik = -8306.82942, newton_decrement = 4.71e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.37e+00, step_size = 0.1304, log_lik = -8191.99112, newton_decrement = 3.61e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.55e+00, step_size = 0.2205, log_lik = -8050.16641, newton_decrement = 2.27e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.35e+00, step_size = 0.3726, log_lik = -7912.41291, newton_decrement = 9.47e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.41e-01, step_size = 0.6296, log_lik = -7830.19405, newton_decrement = 1.46e+01, seconds_since_start = 0.6
# Iteration 8: norm_delta = 1.52e-02, step_size = 1.0000, log_lik = -7815.49008, newton_decrement = 1.19e-02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 5.94e-04, step_size = 1.0000, log_lik = -7815.47809, newton_decrement = 6.16e-06, seconds_since_start = 0.8
# Iteration 10: norm_delta = 1.32e-06, step_size = 1.0000, log_lik = -7815.47809, newton_decrement = 2.92e-11, seconds_since_start = 0.9
# Convergence success after 10 iterations.
# Iteration 1: norm_delta = 6.66e+00, step_size = 0.9500, log_lik = -9037.41005, newton_decrement = 9.93e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.37e+00, step_size = 0.2375, log_lik = -8622.84239, newton_decrement = 5.61e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.03e+00, step_size = 0.0772, log_lik = -8539.58216, newton_decrement = 4.82e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.90e+00, step_size = 0.0326, log_lik = -8508.63269, newton_decrement = 4.53e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.67e+00, step_size = 0.0551, log_lik = -8460.02673, newton_decrement = 4.08e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.31e+00, step_size = 0.0931, log_lik = -8387.55148, newton_decrement = 3.40e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 3.72e+00, step_size = 0.1574, log_lik = -8288.85437, newton_decrement = 2.47e+02, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.84e+00, step_size = 0.2660, log_lik = -8174.74301, newton_decrement = 1.38e+02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.65e+00, step_size = 0.4496, log_lik = -8078.26385, newton_decrement = 4.43e+01, seconds_since_start = 0.9
# Iteration 10: norm_delta = 4.31e-01, step_size = 0.7598, log_lik = -8036.25334, newton_decrement = 2.97e+00, seconds_since_start = 1.0
# Iteration 11: norm_delta = 3.08e-03, step_size = 1.0000, log_lik = -8033.26007, newton_decrement = 8.05e-04, seconds_since_start = 1.1
# Iteration 12: norm_delta = 3.67e-06, step_size = 1.0000, log_lik = -8033.25926, newton_decrement = 3.66e-09, seconds_since_start = 1.2
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.52e+00, step_size = 0.9500, log_lik = -8886.68689, newton_decrement = 1.04e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.25e+00, step_size = 0.2375, log_lik = -8454.72880, newton_decrement = 5.62e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.92e+00, step_size = 0.0772, log_lik = -8371.28999, newton_decrement = 4.82e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.39e+00, step_size = 0.1304, log_lik = -8253.66931, newton_decrement = 3.71e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.57e+00, step_size = 0.2205, log_lik = -8107.93854, newton_decrement = 2.35e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.37e+00, step_size = 0.3726, log_lik = -7965.22283, newton_decrement = 9.96e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.50e-01, step_size = 0.6296, log_lik = -7878.58692, newton_decrement = 1.58e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 1.44e-02, step_size = 1.0000, log_lik = -7862.60469, newton_decrement = 1.77e-02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 4.76e-05, step_size = 1.0000, log_lik = -7862.58697, newton_decrement = 3.66e-07, seconds_since_start = 0.9
# Iteration 10: norm_delta = 7.47e-08, step_size = 1.0000, log_lik = -7862.58697, newton_decrement = 3.57e-13, seconds_since_start = 1.0
# Convergence success after 10 iterations.
# Average C-Index from cross-validation: 0.8876
# Best C-Index from cross-validation: 0.8929
# Standard Deviation of C-Index from cross-validation: 0.0071
#                                                coef  exp(coef)      se(coef)  \
# covariate
# subject_id                            -1.602375e-08   1.000000  1.014742e-08
# gender                                 1.239409e-01   1.131949  7.177872e-02
# anchor_age                             3.535982e-01   1.424183  1.475478e-02
# disch_age                             -3.549088e-01   0.701237  1.470785e-02
# CKD_stage_first                       -1.093672e+00   0.334984  4.897987e-02
# ...                                             ...        ...           ...
# Asparate_Aminotransferase_(AST)_first -6.681472e-04   0.999332  4.505260e-04
# Globulin_last                         -6.917456e-02   0.933164  6.428605e-02
# Urea_Nitrogen_median                   8.981605e-03   1.009022  3.035020e-03
# White_Blood_Cells_mean                 5.713962e-03   1.005730  1.036027e-02
# Eosinophils_max                       -6.693720e-03   0.993329  6.637946e-03
#
#                                        coef lower 95%  coef upper 95%  \
# covariate
# subject_id                              -3.591233e-08    3.864831e-09
# gender                                  -1.674284e-02    2.646246e-01
# anchor_age                               3.246793e-01    3.825170e-01
# disch_age                               -3.837356e-01   -3.260819e-01
# CKD_stage_first                         -1.189671e+00   -9.976733e-01
# ...                                               ...             ...
# Asparate_Aminotransferase_(AST)_first   -1.551162e-03    2.148675e-04
# Globulin_last                           -1.951729e-01    5.682378e-02
# Urea_Nitrogen_median                     3.033075e-03    1.493014e-02
# White_Blood_Cells_mean                  -1.459180e-02    2.601972e-02
# Eosinophils_max                         -1.970386e-02    6.316415e-03
#
#                                        exp(coef) lower 95%  \
# covariate
# subject_id                                        1.000000
# gender                                            0.983397
# anchor_age                                        1.383587
# disch_age                                         0.681312
# CKD_stage_first                                   0.304321
# ...                                                    ...
# Asparate_Aminotransferase_(AST)_first             0.998450
# Globulin_last                                     0.822692
# Urea_Nitrogen_median                              1.003038
# White_Blood_Cells_mean                            0.985514
# Eosinophils_max                                   0.980489
#
#                                        exp(coef) upper 95%  cmp to          z  \
# covariate
# subject_id                                        1.000000     0.0  -1.579096
# gender                                            1.302942     0.0   1.726708
# anchor_age                                        1.465970     0.0  23.964986
# disch_age                                         0.721746     0.0 -24.130573
# CKD_stage_first                                   0.368736     0.0 -22.329012
# ...                                                    ...     ...        ...
# Asparate_Aminotransferase_(AST)_first             1.000215     0.0  -1.483038
# Globulin_last                                     1.058469     0.0  -1.076043
# Urea_Nitrogen_median                              1.015042     0.0   2.959323
# White_Blood_Cells_mean                            1.026361     0.0   0.551526
# Eosinophils_max                                   1.006336     0.0  -1.008402
#
#                                                    p    -log2(p)
# covariate
# subject_id                              1.143141e-01    3.128925
# gender                                  8.422017e-02    3.569690
# anchor_age                             6.448894e-127  419.195816
# disch_age                              1.194400e-128  424.950510
# CKD_stage_first                        1.931514e-110  364.462358
# ...                                              ...         ...
# Asparate_Aminotransferase_(AST)_first   1.380643e-01    2.856588
# Globulin_last                           2.819080e-01    1.826704
# Urea_Nitrogen_median                    3.083156e-03    8.341377
# White_Blood_Cells_mean                  5.812729e-01    0.782712
# Eosinophils_max                         3.132614e-01    1.674561
#
# [81 rows x 11 columns]
#                                    test_statistic         p  -log2(p)
# Acute kidney failure, unspecified        0.169325  0.680713  0.554882
# Albumin/Creatinine,_Urine_first          0.083607  0.772468  0.372454
# Albumin/Creatinine,_Urine_last           0.016219  0.898661  0.154152
# Albumin/Creatinine,_Urine_max            0.093578  0.759676  0.396543
# Albumin/Creatinine,_Urine_mean           0.584864  0.444412  1.170031
# ...                                           ...       ...       ...
# eGFR_median                              0.044758  0.832450  0.264564
# eGFR_min                                 0.026796  0.869970  0.200962
# gender                                   1.530734  0.216002  2.210881
# marital_status_MARRIED                   0.050683  0.821879  0.283002
# subject_id                               0.175495  0.675274  0.566455
#
# [81 rows x 3 columns]
# Brier Score at 1 year(s): 0.0289
# Brier Score at 2 year(s): 0.0506
# Brier Score at 3 year(s): 0.0673
# Brier Score at 4 year(s): 0.0750
# Brier Score at 5 year(s): 0.0801
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sksurv\metrics.py:482: RuntimeWarning: invalid value encountered in divide
#   true_pos = cumsum_tp / cumsum_tp[-1]
# AUC at 1 year(s): 0.9494
# AUC at 2 year(s): 0.9171
# AUC at 3 year(s): 0.9071
# AUC at 4 year(s): 0.9376
# AUC at 5 year(s): 0.9507
