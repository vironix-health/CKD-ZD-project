# %%
import sys
import os

# Use os.getcwd() to get the current working directory in a Jupyter notebook
parent_dir = os.path.dirname(os.getcwd())  # Get the parent directory of the current working directory
sys.path.append(parent_dir)

# %%
import pandas as pd
from skopt.space import Real, Integer
from driver import Driver

# %% [markdown]
# # Load Cleaned Master MIMIC-IV Dataset

# %%
# Cleaned Master MIMIC Data Set
df_master = pd.read_pickle('../MIMIC_IV/df_ckd_master_clean.pkl')
df_base = pd.read_pickle('../MIMIC_IV/df_ckd_base.pkl')

# %% [markdown]
# # Evaluate Decision Tree Pipeline

# %%
DecisionTree_cfg = {
    'name': 'DecisionTree', # Feature selection model long name
    'tag': 'dct', # Feature selection model identifier tag
    'response': 'stage_delta',  # Response variable for binary classification and Cox Proportional Hazards
    'duration': 'duration', # Duration in days until response or censorship
    'n_novel': 40, # Number of ranked novel features included in augmented KFRE dataset
    'test_size': 0.1, # Ratio of data reserved for testing
    'val_size': 0.2, # Ratio of data reserved for testing in validation sets
    'n_valsets': 5, # Number of training validation sets
    'n_bayesian': 10, # Number of Bayesian hyperparameter optimization iterations 
    'n_folds': 5, # Number of folds for CoxPH cross validation
    'penalizer': 0.0007, # CoxPH model penalizer
    'auc_space': [
        Integer(1, 50, name='max_depth'),
        Integer(2, 20, name="min_samples_split"),
        Integer(1, 20, name="min_samples_leaf"),
    ], # Search space for Bayesian hyperparameter optimization
    'seeds': [42, 73, 128, 256, 512] # Seeds for reproducibility
}

driver = Driver(DecisionTree_cfg, df_master, df_base)
driver.ClassicalLearningPipe()
# Out:
# Testing params: {'max_depth': 40, 'min_samples_split': 5, 'min_samples_leaf': 16}
# AUC for params: 0.8643503085312002
# Testing params: {'max_depth': 30, 'min_samples_split': 10, 'min_samples_leaf': 3}
# AUC for params: 0.8000863536341246
# Testing params: {'max_depth': 24, 'min_samples_split': 8, 'min_samples_leaf': 4}
# AUC for params: 0.8026023206533637
# Testing params: {'max_depth': 33, 'min_samples_split': 3, 'min_samples_leaf': 15}
# AUC for params: 0.8568991575350978
# Testing params: {'max_depth': 47, 'min_samples_split': 2, 'min_samples_leaf': 20}
# AUC for params: 0.8708397377268646
# Testing params: {'max_depth': 31, 'min_samples_split': 13, 'min_samples_leaf': 1}
# AUC for params: 0.7910887070060248
# Testing params: {'max_depth': 2, 'min_samples_split': 11, 'min_samples_leaf': 9}
# AUC for params: 0.7997124598590963
# Testing params: {'max_depth': 3, 'min_samples_split': 20, 'min_samples_leaf': 5}
# AUC for params: 0.8460309208809411
# Testing params: {'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 8}
# AUC for params: 0.9125974294270751
# Testing params: {'max_depth': 49, 'min_samples_split': 10, 'min_samples_leaf': 17}
# AUC for params: 0.8699913015517675
# Testing params: {'max_depth': 16, 'min_samples_split': 13, 'min_samples_leaf': 4}
# AUC for params: 0.8124675324996291
# Testing params: {'max_depth': 26, 'min_samples_split': 8, 'min_samples_leaf': 3}
# AUC for params: 0.7683776987671372
# Testing params: {'max_depth': 43, 'min_samples_split': 11, 'min_samples_leaf': 17}
# AUC for params: 0.8545972689396008
# Testing params: {'max_depth': 48, 'min_samples_split': 13, 'min_samples_leaf': 10}
# AUC for params: 0.8243924084959546
# Testing params: {'max_depth': 44, 'min_samples_split': 8, 'min_samples_leaf': 16}
# AUC for params: 0.8548934526882587
# Testing params: {'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 5}
# AUC for params: 0.9099442365648469
# Testing params: {'max_depth': 10, 'min_samples_split': 16, 'min_samples_leaf': 3}
# AUC for params: 0.8678360638559649
# Testing params: {'max_depth': 13, 'min_samples_split': 9, 'min_samples_leaf': 12}
# AUC for params: 0.8710817133971439
# Testing params: {'max_depth': 35, 'min_samples_split': 14, 'min_samples_leaf': 19}
# AUC for params: 0.8586326042963076
# Testing params: {'max_depth': 19, 'min_samples_split': 3, 'min_samples_leaf': 11}
# AUC for params: 0.8347094866629299
# Testing params: {'max_depth': 45, 'min_samples_split': 17, 'min_samples_leaf': 8}
# AUC for params: 0.8206844878342439
# Testing params: {'max_depth': 26, 'min_samples_split': 9, 'min_samples_leaf': 8}
# AUC for params: 0.8170072011740972
# Testing params: {'max_depth': 40, 'min_samples_split': 12, 'min_samples_leaf': 3}
# AUC for params: 0.7894018762216402
# Testing params: {'max_depth': 39, 'min_samples_split': 19, 'min_samples_leaf': 4}
# AUC for params: 0.8123916514022472
# Testing params: {'max_depth': 33, 'min_samples_split': 7, 'min_samples_leaf': 11}
# AUC for params: 0.8383110251815233
# Testing params: {'max_depth': 49, 'min_samples_split': 18, 'min_samples_leaf': 13}
# AUC for params: 0.8468344500374114
# Testing params: {'max_depth': 5, 'min_samples_split': 17, 'min_samples_leaf': 5}
# AUC for params: 0.912454709439805
# Testing params: {'max_depth': 20, 'min_samples_split': 16, 'min_samples_leaf': 12}
# AUC for params: 0.8509088771008688
# Testing params: {'max_depth': 20, 'min_samples_split': 10, 'min_samples_leaf': 1}
# AUC for params: 0.7775308656186785
# Testing params: {'max_depth': 4, 'min_samples_split': 7, 'min_samples_leaf': 12}
# AUC for params: 0.9009608327609403
# Testing params: {'max_depth': 42, 'min_samples_split': 12, 'min_samples_leaf': 10}
# AUC for params: 0.8391318732115034
# Testing params: {'max_depth': 35, 'min_samples_split': 19, 'min_samples_leaf': 8}
# AUC for params: 0.8375731008173976
# Testing params: {'max_depth': 43, 'min_samples_split': 12, 'min_samples_leaf': 2}
# AUC for params: 0.7906783267179278
# Testing params: {'max_depth': 39, 'min_samples_split': 14, 'min_samples_leaf': 11}
# AUC for params: 0.8435453338107248
# Testing params: {'max_depth': 18, 'min_samples_split': 5, 'min_samples_leaf': 12}
# AUC for params: 0.8596939294932259
# Testing params: {'max_depth': 39, 'min_samples_split': 11, 'min_samples_leaf': 5}
# AUC for params: 0.8124290488730705
# Testing params: {'max_depth': 28, 'min_samples_split': 9, 'min_samples_leaf': 2}
# AUC for params: 0.7943344772701451
# Testing params: {'max_depth': 23, 'min_samples_split': 9, 'min_samples_leaf': 2}
# AUC for params: 0.7949130462253005
# Testing params: {'max_depth': 38, 'min_samples_split': 2, 'min_samples_leaf': 11}
# AUC for params: 0.8456151103368889
# Testing params: {'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 11}
# AUC for params: 0.9185956812322283
# Testing params: {'max_depth': 22, 'min_samples_split': 6, 'min_samples_leaf': 8}
# AUC for params: 0.8281516735228166
# Testing params: {'max_depth': 12, 'min_samples_split': 12, 'min_samples_leaf': 14}
# AUC for params: 0.8775050488196217
# Testing params: {'max_depth': 17, 'min_samples_split': 14, 'min_samples_leaf': 18}
# AUC for params: 0.8696593272765625
# Testing params: {'max_depth': 15, 'min_samples_split': 17, 'min_samples_leaf': 4}
# AUC for params: 0.8379425120103126
# Testing params: {'max_depth': 28, 'min_samples_split': 6, 'min_samples_leaf': 20}
# AUC for params: 0.8680479190503867
# Testing params: {'max_depth': 31, 'min_samples_split': 4, 'min_samples_leaf': 6}
# AUC for params: 0.8014431858661372
# Testing params: {'max_depth': 22, 'min_samples_split': 14, 'min_samples_leaf': 7}
# AUC for params: 0.8228113943773592
# Testing params: {'max_depth': 41, 'min_samples_split': 19, 'min_samples_leaf': 16}
# AUC for params: 0.8605726841840726
# Testing params: {'max_depth': 30, 'min_samples_split': 13, 'min_samples_leaf': 6}
# AUC for params: 0.8042397914850422
# Testing params: {'max_depth': 17, 'min_samples_split': 13, 'min_samples_leaf': 3}
# AUC for params: 0.8138914881390298
# Best parameters found:  {'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 11}
# Best mean AUC across validation sets:  0.9185956812322283
# Mean AUC: 0.7282591628557491
# Standard Deviation: 0.03636804803685545
# Max AUC: 0.7799027701339204
# Iteration 1: norm_delta = 6.71e+00, step_size = 0.9500, log_lik = -8744.90665, newton_decrement = 9.33e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.37e+00, step_size = 0.2375, log_lik = -8354.85944, newton_decrement = 5.33e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.02e+00, step_size = 0.0772, log_lik = -8275.73910, newton_decrement = 4.58e+02, seconds_since_start = 0.2
# Iteration 4: norm_delta = 4.88e+00, step_size = 0.0326, log_lik = -8246.32596, newton_decrement = 4.31e+02, seconds_since_start = 0.3
# Iteration 5: norm_delta = 4.65e+00, step_size = 0.0551, log_lik = -8200.13698, newton_decrement = 3.88e+02, seconds_since_start = 0.4
# Iteration 6: norm_delta = 4.28e+00, step_size = 0.0931, log_lik = -8131.28522, newton_decrement = 3.23e+02, seconds_since_start = 0.5
# Iteration 7: norm_delta = 3.69e+00, step_size = 0.1574, log_lik = -8037.59837, newton_decrement = 2.34e+02, seconds_since_start = 0.6
# Iteration 8: norm_delta = 2.80e+00, step_size = 0.2660, log_lik = -7929.52108, newton_decrement = 1.30e+02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 1.62e+00, step_size = 0.4496, log_lik = -7838.73528, newton_decrement = 4.10e+01, seconds_since_start = 0.8
# Iteration 10: norm_delta = 4.22e-01, step_size = 0.7598, log_lik = -7799.95896, newton_decrement = 2.58e+00, seconds_since_start = 0.9
# Iteration 11: norm_delta = 2.98e-03, step_size = 1.0000, log_lik = -7797.36818, newton_decrement = 3.28e-04, seconds_since_start = 1.0
# Iteration 12: norm_delta = 3.51e-06, step_size = 1.0000, log_lik = -7797.36785, newton_decrement = 8.29e-10, seconds_since_start = 1.0
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.87e+00, step_size = 0.9500, log_lik = -8829.99117, newton_decrement = 9.29e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.52e+00, step_size = 0.2375, log_lik = -8441.84019, newton_decrement = 5.27e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.17e+00, step_size = 0.0772, log_lik = -8363.63450, newton_decrement = 4.52e+02, seconds_since_start = 0.2
# Iteration 4: norm_delta = 5.03e+00, step_size = 0.0326, log_lik = -8334.64379, newton_decrement = 4.24e+02, seconds_since_start = 0.3
# Iteration 5: norm_delta = 4.97e+00, step_size = 0.0138, log_lik = -8323.03521, newton_decrement = 4.13e+02, seconds_since_start = 0.4
# Iteration 6: norm_delta = 4.87e+00, step_size = 0.0233, log_lik = -8304.01979, newton_decrement = 3.95e+02, seconds_since_start = 0.5
# Iteration 7: norm_delta = 4.71e+00, step_size = 0.0394, log_lik = -8273.54352, newton_decrement = 3.66e+02, seconds_since_start = 0.6
# Iteration 8: norm_delta = 4.44e+00, step_size = 0.0665, log_lik = -8226.49067, newton_decrement = 3.21e+02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 4.01e+00, step_size = 0.1124, log_lik = -8158.40020, newton_decrement = 2.55e+02, seconds_since_start = 0.8
# Iteration 10: norm_delta = 3.33e+00, step_size = 0.1899, log_lik = -8070.52310, newton_decrement = 1.70e+02, seconds_since_start = 0.8
# Iteration 11: norm_delta = 2.34e+00, step_size = 0.3210, log_lik = -7978.57857, newton_decrement = 8.05e+01, seconds_since_start = 0.9
# Iteration 12: norm_delta = 1.13e+00, step_size = 0.5425, log_lik = -7914.84745, newton_decrement = 1.75e+01, seconds_since_start = 1.0
# Iteration 13: norm_delta = 1.11e-01, step_size = 0.9168, log_lik = -7897.43909, newton_decrement = 1.53e-01, seconds_since_start = 1.1
# Iteration 14: norm_delta = 1.96e-04, step_size = 1.0000, log_lik = -7897.28573, newton_decrement = 1.48e-06, seconds_since_start = 1.2
# Iteration 15: norm_delta = 4.50e-09, step_size = 1.0000, log_lik = -7897.28573, newton_decrement = 1.64e-15, seconds_since_start = 1.2
# Convergence success after 15 iterations.
# Iteration 1: norm_delta = 6.74e+00, step_size = 0.9500, log_lik = -8805.41001, newton_decrement = 9.19e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.40e+00, step_size = 0.2375, log_lik = -8421.26771, newton_decrement = 5.21e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.06e+00, step_size = 0.0772, log_lik = -8343.93509, newton_decrement = 4.46e+02, seconds_since_start = 0.2
# Iteration 4: norm_delta = 4.92e+00, step_size = 0.0326, log_lik = -8315.29648, newton_decrement = 4.19e+02, seconds_since_start = 0.3
# Iteration 5: norm_delta = 4.69e+00, step_size = 0.0551, log_lik = -8270.39991, newton_decrement = 3.76e+02, seconds_since_start = 0.4
# Iteration 6: norm_delta = 4.32e+00, step_size = 0.0931, log_lik = -8203.67640, newton_decrement = 3.11e+02, seconds_since_start = 0.5
# Iteration 7: norm_delta = 3.73e+00, step_size = 0.1574, log_lik = -8113.37466, newton_decrement = 2.24e+02, seconds_since_start = 0.6
# Iteration 8: norm_delta = 2.83e+00, step_size = 0.2660, log_lik = -8010.16881, newton_decrement = 1.22e+02, seconds_since_start = 0.6
# Iteration 9: norm_delta = 1.63e+00, step_size = 0.4496, log_lik = -7924.69877, newton_decrement = 3.80e+01, seconds_since_start = 0.7
# Iteration 10: norm_delta = 4.24e-01, step_size = 0.7598, log_lik = -7888.83735, newton_decrement = 2.33e+00, seconds_since_start = 0.8
# Iteration 11: norm_delta = 2.39e-03, step_size = 1.0000, log_lik = -7886.49615, newton_decrement = 2.24e-04, seconds_since_start = 0.9
# Iteration 12: norm_delta = 3.59e-07, step_size = 1.0000, log_lik = -7886.49592, newton_decrement = 1.93e-11, seconds_since_start = 1.0
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.90e+00, step_size = 0.9500, log_lik = -9037.41005, newton_decrement = 9.25e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.53e+00, step_size = 0.2375, log_lik = -8651.05044, newton_decrement = 5.32e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.18e+00, step_size = 0.0772, log_lik = -8572.06982, newton_decrement = 4.58e+02, seconds_since_start = 0.2
# Iteration 4: norm_delta = 5.04e+00, step_size = 0.0326, log_lik = -8542.71051, newton_decrement = 4.30e+02, seconds_since_start = 0.3
# Iteration 5: norm_delta = 4.98e+00, step_size = 0.0138, log_lik = -8530.94151, newton_decrement = 4.19e+02, seconds_since_start = 0.4
# Iteration 6: norm_delta = 4.88e+00, step_size = 0.0233, log_lik = -8511.65468, newton_decrement = 4.01e+02, seconds_since_start = 0.5
# Iteration 7: norm_delta = 4.72e+00, step_size = 0.0394, log_lik = -8480.72012, newton_decrement = 3.72e+02, seconds_since_start = 0.5
# Iteration 8: norm_delta = 4.46e+00, step_size = 0.0665, log_lik = -8432.89960, newton_decrement = 3.27e+02, seconds_since_start = 0.6
# Iteration 9: norm_delta = 4.02e+00, step_size = 0.1124, log_lik = -8363.55559, newton_decrement = 2.61e+02, seconds_since_start = 0.7
# Iteration 10: norm_delta = 3.34e+00, step_size = 0.1899, log_lik = -8273.77596, newton_decrement = 1.75e+02, seconds_since_start = 0.8
# Iteration 11: norm_delta = 2.36e+00, step_size = 0.3210, log_lik = -8179.44979, newton_decrement = 8.28e+01, seconds_since_start = 0.9
# Iteration 12: norm_delta = 1.14e+00, step_size = 0.5425, log_lik = -8113.81227, newton_decrement = 1.80e+01, seconds_since_start = 0.9
# Iteration 13: norm_delta = 1.11e-01, step_size = 0.9168, log_lik = -8095.85136, newton_decrement = 1.58e-01, seconds_since_start = 1.0
# Iteration 14: norm_delta = 2.42e-04, step_size = 1.0000, log_lik = -8095.69259, newton_decrement = 5.41e-06, seconds_since_start = 1.1
# Iteration 15: norm_delta = 4.29e-07, step_size = 1.0000, log_lik = -8095.69258, newton_decrement = 4.16e-11, seconds_since_start = 1.2
# Convergence success after 15 iterations.
# Iteration 1: norm_delta = 6.76e+00, step_size = 0.9500, log_lik = -8886.68689, newton_decrement = 9.46e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.43e+00, step_size = 0.2375, log_lik = -8491.25260, newton_decrement = 5.38e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.08e+00, step_size = 0.0772, log_lik = -8411.41170, newton_decrement = 4.62e+02, seconds_since_start = 0.2
# Iteration 4: norm_delta = 4.95e+00, step_size = 0.0326, log_lik = -8381.77415, newton_decrement = 4.34e+02, seconds_since_start = 0.3
# Iteration 5: norm_delta = 4.72e+00, step_size = 0.0551, log_lik = -8335.26003, newton_decrement = 3.90e+02, seconds_since_start = 0.4
# Iteration 6: norm_delta = 4.34e+00, step_size = 0.0931, log_lik = -8265.99310, newton_decrement = 3.24e+02, seconds_since_start = 0.5
# Iteration 7: norm_delta = 3.75e+00, step_size = 0.1574, log_lik = -8171.89855, newton_decrement = 2.35e+02, seconds_since_start = 0.5
# Iteration 8: norm_delta = 2.85e+00, step_size = 0.2660, log_lik = -8063.61758, newton_decrement = 1.30e+02, seconds_since_start = 0.6
# Iteration 9: norm_delta = 1.65e+00, step_size = 0.4496, log_lik = -7972.86832, newton_decrement = 4.10e+01, seconds_since_start = 0.7
# Iteration 10: norm_delta = 4.30e-01, step_size = 0.7598, log_lik = -7934.02375, newton_decrement = 2.64e+00, seconds_since_start = 0.8
# Iteration 11: norm_delta = 2.95e-03, step_size = 1.0000, log_lik = -7931.37036, newton_decrement = 5.26e-04, seconds_since_start = 0.8
# Iteration 12: norm_delta = 2.03e-06, step_size = 1.0000, log_lik = -7931.36984, newton_decrement = 8.32e-10, seconds_since_start = 0.9
# Convergence success after 12 iterations.
# Average C-Index from cross-validation: 0.8855
# Best C-Index from cross-validation: 0.8901
# Standard Deviation of C-Index from cross-validation: 0.0051
#                                                            coef  exp(coef)  \
# covariate
# subject_id                                        -1.758096e-08   1.000000
# gender                                             6.912042e-02   1.071565
# anchor_age                                         3.562150e-01   1.427914
# disch_age                                         -3.600966e-01   0.697609
# CKD_stage_first                                   -1.059075e+00   0.346777
# ...                                                         ...        ...
# Other musculoskeletal symptoms referable to limbs -6.708702e-02   0.935114
# Cholesterol_Ratio_(Total/HDL)_last                 3.692283e-02   1.037613
# Glucose_mean                                      -3.601966e-03   0.996405
# Platelet_Count_last                                1.441658e-04   1.000144
# Reticulocyte_Count,_Manual_min                     3.639459e-02   1.037065
#
#                                                        se(coef)  \
# covariate
# subject_id                                         1.034149e-08
# gender                                             6.681761e-02
# anchor_age                                         1.470715e-02
# disch_age                                          1.464305e-02
# CKD_stage_first                                    4.749980e-02
# ...                                                         ...
# Other musculoskeletal symptoms referable to limbs  1.270337e-01
# Cholesterol_Ratio_(Total/HDL)_last                 2.077193e-02
# Glucose_mean                                       9.987869e-04
# Platelet_Count_last                                3.155271e-04
# Reticulocyte_Count,_Manual_min                     4.852771e-02
#
#                                                    coef lower 95%  \
# covariate
# subject_id                                          -3.784991e-08
# gender                                              -6.183969e-02
# anchor_age                                           3.273895e-01
# disch_age                                           -3.887965e-01
# CKD_stage_first                                     -1.152173e+00
# ...                                                           ...
# Other musculoskeletal symptoms referable to limbs   -3.160686e-01
# Cholesterol_Ratio_(Total/HDL)_last                  -3.789406e-03
# Glucose_mean                                        -5.559552e-03
# Platelet_Count_last                                 -4.742559e-04
# Reticulocyte_Count,_Manual_min                      -5.871797e-02
#
#                                                    coef upper 95%  \
# covariate
# subject_id                                           2.687992e-09
# gender                                               2.000805e-01
# anchor_age                                           3.850405e-01
# disch_age                                           -3.313968e-01
# CKD_stage_first                                     -9.659768e-01
# ...                                                           ...
# Other musculoskeletal symptoms referable to limbs    1.818945e-01
# Cholesterol_Ratio_(Total/HDL)_last                   7.763507e-02
# Glucose_mean                                        -1.644379e-03
# Platelet_Count_last                                  7.625875e-04
# Reticulocyte_Count,_Manual_min                       1.315071e-01
#
#                                                    exp(coef) lower 95%  \
# covariate
# subject_id                                                    1.000000
# gender                                                        0.940034
# anchor_age                                                    1.387342
# disch_age                                                     0.677872
# CKD_stage_first                                               0.315950
# ...                                                                ...
# Other musculoskeletal symptoms referable to limbs             0.729009
# Cholesterol_Ratio_(Total/HDL)_last                            0.996218
# Glucose_mean                                                  0.994456
# Platelet_Count_last                                           0.999526
# Reticulocyte_Count,_Manual_min                                0.942973
#
#                                                    exp(coef) upper 95%  \
# covariate
# subject_id                                                    1.000000
# gender                                                        1.221501
# anchor_age                                                    1.469674
# disch_age                                                     0.717920
# CKD_stage_first                                               0.380611
# ...                                                                ...
# Other musculoskeletal symptoms referable to limbs             1.199488
# Cholesterol_Ratio_(Total/HDL)_last                            1.080728
# Glucose_mean                                                  0.998357
# Platelet_Count_last                                           1.000763
# Reticulocyte_Count,_Manual_min                                1.140546
#
#                                                    cmp to          z  \
# covariate
# subject_id                                            0.0  -1.700041
# gender                                                0.0   1.034464
# anchor_age                                            0.0  24.220536
# disch_age                                             0.0 -24.591633
# CKD_stage_first                                       0.0 -22.296405
# ...                                                   ...        ...
# Other musculoskeletal symptoms referable to limbs     0.0  -0.528104
# Cholesterol_Ratio_(Total/HDL)_last                    0.0   1.777535
# Glucose_mean                                          0.0  -3.606341
# Platelet_Count_last                                   0.0   0.456905
# Reticulocyte_Count,_Manual_min                        0.0   0.749975
#
#                                                                p    -log2(p)
# covariate
# subject_id                                          8.912322e-02    3.488055
# gender                                              3.009192e-01    1.732552
# anchor_age                                         1.352037e-129  428.093590
# disch_age                                          1.552327e-133  441.182004
# CKD_stage_first                                    4.004077e-110  363.410621
# ...                                                          ...         ...
# Other musculoskeletal symptoms referable to limbs   5.974271e-01    0.743165
# Cholesterol_Ratio_(Total/HDL)_last                  7.548029e-02    3.727756
# Glucose_mean                                        3.105456e-04   11.652907
# Platelet_Count_last                                 6.477395e-01    0.626514
# Reticulocyte_Count,_Manual_min                      4.532695e-01    1.141559
#
# [64 rows x 11 columns]
#                                        test_statistic         p  -log2(p)
# Absolute_Lymphocyte_Count_last               0.163121  0.686299  0.543091
# Acute kidney failure, unspecified            2.184951  0.139366  2.843055
# Alanine_Aminotransferase_(ALT)_median        0.022131  0.881739  0.181577
# Albumin/Creatinine,_Urine_first              0.586009  0.443967  1.171477
# Albumin/Creatinine,_Urine_last               0.290239  0.590067  0.761048
# ...                                               ...       ...       ...
# eGFR_mean                                    0.014676  0.903577  0.146281
# eGFR_median                                  0.028823  0.865188  0.208915
# eGFR_min                                     0.048399  0.825873  0.276009
# gender                                       2.542246  0.110837  3.173488
# subject_id                                   0.026227  0.871347  0.198681
#
# [64 rows x 3 columns]
# Brier Score at 1 year(s): 0.0309
# Brier Score at 2 year(s): 0.0496
# Brier Score at 3 year(s): 0.0646
# Brier Score at 4 year(s): 0.0841
# Brier Score at 5 year(s): 0.1010
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sksurv\metrics.py:482: RuntimeWarning: invalid value encountered in divide
#   true_pos = cumsum_tp / cumsum_tp[-1]
# AUC at 1 year(s): 0.9340
# AUC at 2 year(s): 0.9494
# AUC at 3 year(s): 0.9407
# AUC at 4 year(s): 0.9090
# AUC at 5 year(s): 0.9111
