# %%
import sys
import os

# Use os.getcwd() to get the current working directory in a Jupyter notebook
parent_dir = os.path.dirname(os.getcwd())  # Get the parent directory of the current working directory
sys.path.append(parent_dir)

# %%
import pandas as pd
from skopt.space import Real, Integer
from driver import Driver

# %% [markdown]
# # Load Cleaned Master MIMIC-IV Dataset

# %%
# Cleaned Master MIMIC Data Set
df_master = pd.read_pickle('../MIMIC_IV/df_ckd_master_clean.pkl')
df_base = pd.read_pickle('../MIMIC_IV/df_ckd_base.pkl')

# %% [markdown]
# # Evaluate FCNN Pipeline

# %%
FCNN_cfg = {
    'name': 'FCNN', # Feature selection model long name
    'tag': 'fcnn', # Feature selection model identifier tag
    'response': 'stage_delta',  # Response variable for binary classification and Cox Proportional Hazards
    'duration': 'duration', # Duration in days until response or censorship
    'n_novel': 40, # Number of ranked novel features included in augmented KFRE dataset
    'test_size': 0.2, # Ratio of data reserved for testing
    'epochs': 35,
    'patience': 5,
    'learning_rate': 0.001,
    'weight_decay': 1e-4,
    'batch_size': 256, # Batch size for SHAP computation
    'n_folds': 5, # Number of folds for CoxPH cross validation
    'penalizer': 0.0007, # CoxPH model penalizer
    'random_state': 42 # Seed for reproducibility
}

driver = Driver(FCNN_cfg, df_master, df_base)
driver.DeepLearningPipe()
# Out:
# Epoch 1/35, Training Loss: 0.27994915716011415, Validation Loss: 0.27974087169224565
# Epoch 2/35, Training Loss: 0.2002262662122534, Validation Loss: 0.28809306770563126
# Epoch 3/35, Training Loss: 0.13515543538431468, Validation Loss: 0.340194009244442
# Epoch 4/35, Training Loss: 0.07989782963175623, Validation Loss: 0.4682997031645341
# Epoch 5/35, Training Loss: 0.05379582459863741, Validation Loss: 0.5962299406528473
# Epoch 6/35, Training Loss: 0.047067638722430936, Validation Loss: 0.7078571285713803
# Early stopping triggered
# Test AUC: 0.6285445770306546
#  ... (more hidden) ...
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\shap\plots\_beeswarm.py:962: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   pl.tight_layout()
# Iteration 1: norm_delta = 6.46e+00, step_size = 0.9500, log_lik = -8744.90665, newton_decrement = 9.86e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.22e+00, step_size = 0.2375, log_lik = -8333.13993, newton_decrement = 5.49e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.89e+00, step_size = 0.0772, log_lik = -8251.61165, newton_decrement = 4.71e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.36e+00, step_size = 0.1304, log_lik = -8136.61715, newton_decrement = 3.62e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.53e+00, step_size = 0.2205, log_lik = -7994.29698, newton_decrement = 2.28e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.34e+00, step_size = 0.3726, log_lik = -7855.91991, newton_decrement = 9.49e+01, seconds_since_start = 0.5
# Iteration 7: norm_delta = 9.40e-01, step_size = 0.6296, log_lik = -7773.61107, newton_decrement = 1.45e+01, seconds_since_start = 0.6
# Iteration 8: norm_delta = 1.44e-02, step_size = 1.0000, log_lik = -7759.00950, newton_decrement = 1.00e-02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 1.67e-05, step_size = 1.0000, log_lik = -7758.99945, newton_decrement = 4.12e-08, seconds_since_start = 0.8
# Convergence success after 9 iterations.
# Iteration 1: norm_delta = 6.55e+00, step_size = 0.9500, log_lik = -8829.99117, newton_decrement = 9.77e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.32e+00, step_size = 0.2375, log_lik = -8422.21617, newton_decrement = 5.48e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.99e+00, step_size = 0.0772, log_lik = -8340.90763, newton_decrement = 4.70e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.45e+00, step_size = 0.1304, log_lik = -8226.19144, newton_decrement = 3.61e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.61e+00, step_size = 0.2205, log_lik = -8084.27869, newton_decrement = 2.27e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.40e+00, step_size = 0.3726, log_lik = -7946.61693, newton_decrement = 9.40e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.66e-01, step_size = 0.6296, log_lik = -7865.05066, newton_decrement = 1.43e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 1.43e-02, step_size = 1.0000, log_lik = -7850.61525, newton_decrement = 9.33e-03, seconds_since_start = 0.8
# Iteration 9: norm_delta = 3.27e-05, step_size = 1.0000, log_lik = -7850.60591, newton_decrement = 5.89e-08, seconds_since_start = 0.9
# Convergence success after 9 iterations.
# Iteration 1: norm_delta = 6.47e+00, step_size = 0.9500, log_lik = -8805.41001, newton_decrement = 9.81e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.22e+00, step_size = 0.2375, log_lik = -8396.17796, newton_decrement = 5.42e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.90e+00, step_size = 0.0772, log_lik = -8315.68365, newton_decrement = 4.64e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.37e+00, step_size = 0.1304, log_lik = -8202.47997, newton_decrement = 3.55e+02, seconds_since_start = 0.3
# Iteration 5: norm_delta = 3.55e+00, step_size = 0.2205, log_lik = -8063.09903, newton_decrement = 2.21e+02, seconds_since_start = 0.4
# Iteration 6: norm_delta = 2.36e+00, step_size = 0.3726, log_lik = -7928.67179, newton_decrement = 9.14e+01, seconds_since_start = 0.5
# Iteration 7: norm_delta = 9.50e-01, step_size = 0.6296, log_lik = -7849.44610, newton_decrement = 1.38e+01, seconds_since_start = 0.6
# Iteration 8: norm_delta = 1.34e-02, step_size = 1.0000, log_lik = -7835.52799, newton_decrement = 7.57e-03, seconds_since_start = 0.7
# Iteration 9: norm_delta = 1.38e-05, step_size = 1.0000, log_lik = -7835.52042, newton_decrement = 1.93e-08, seconds_since_start = 0.8
# Convergence success after 9 iterations.
# Iteration 1: norm_delta = 6.67e+00, step_size = 0.9500, log_lik = -9037.41005, newton_decrement = 9.78e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.39e+00, step_size = 0.2375, log_lik = -8628.84690, newton_decrement = 5.49e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.05e+00, step_size = 0.0772, log_lik = -8547.28901, newton_decrement = 4.72e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.92e+00, step_size = 0.0326, log_lik = -8517.03114, newton_decrement = 4.43e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.70e+00, step_size = 0.0551, log_lik = -8469.54597, newton_decrement = 3.98e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.33e+00, step_size = 0.0931, log_lik = -8398.82257, newton_decrement = 3.31e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 3.75e+00, step_size = 0.1574, log_lik = -8302.66440, newton_decrement = 2.40e+02, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.86e+00, step_size = 0.2660, log_lik = -8191.67208, newton_decrement = 1.34e+02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.66e+00, step_size = 0.4496, log_lik = -8097.91349, newton_decrement = 4.30e+01, seconds_since_start = 0.9
# Iteration 10: norm_delta = 4.35e-01, step_size = 0.7598, log_lik = -8057.17446, newton_decrement = 2.83e+00, seconds_since_start = 0.9
# Iteration 11: norm_delta = 2.92e-03, step_size = 1.0000, log_lik = -8054.32633, newton_decrement = 5.42e-04, seconds_since_start = 1.0
# Iteration 12: norm_delta = 1.05e-06, step_size = 1.0000, log_lik = -8054.32579, newton_decrement = 2.18e-10, seconds_since_start = 1.2
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.54e+00, step_size = 0.9500, log_lik = -8886.68689, newton_decrement = 9.93e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.28e+00, step_size = 0.2375, log_lik = -8472.14598, newton_decrement = 5.49e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.95e+00, step_size = 0.0772, log_lik = -8390.59843, newton_decrement = 4.71e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.41e+00, step_size = 0.1304, log_lik = -8275.63963, newton_decrement = 3.62e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.58e+00, step_size = 0.2205, log_lik = -8133.35860, newton_decrement = 2.28e+02, seconds_since_start = 0.4
# Iteration 6: norm_delta = 2.39e+00, step_size = 0.3726, log_lik = -7994.59074, newton_decrement = 9.62e+01, seconds_since_start = 0.5
# Iteration 7: norm_delta = 9.58e-01, step_size = 0.6296, log_lik = -7911.02425, newton_decrement = 1.51e+01, seconds_since_start = 0.6
# Iteration 8: norm_delta = 1.39e-02, step_size = 1.0000, log_lik = -7895.73066, newton_decrement = 1.51e-02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 2.74e-05, step_size = 1.0000, log_lik = -7895.71549, newton_decrement = 1.64e-07, seconds_since_start = 0.8
# Iteration 10: norm_delta = 3.80e-09, step_size = 1.0000, log_lik = -7895.71549, newton_decrement = 6.98e-16, seconds_since_start = 0.9
# Convergence success after 10 iterations.
# Average C-Index from cross-validation: 0.8877
# Best C-Index from cross-validation: 0.8946
# Standard Deviation of C-Index from cross-validation: 0.0071
#                            coef  exp(coef)      se(coef)  coef lower 95%  \
# covariate
# subject_id        -2.152566e-08   1.000000  1.044086e-08   -4.198938e-08
# gender             7.206445e-02   1.074725  6.850427e-02   -6.220146e-02
# anchor_age         3.500054e-01   1.419075  1.480366e-02    3.209907e-01
# disch_age         -3.517252e-01   0.703473  1.476064e-02   -3.806555e-01
# CKD_stage_first   -1.074736e+00   0.341388  4.939265e-02   -1.171544e+00
# ...                         ...        ...           ...             ...
# Sodium_mean       -2.116013e-02   0.979062  1.707000e-02   -5.461673e-02
# Other chest pain   6.013229e-02   1.061977  8.620403e-02   -1.088245e-01
# Creatinine_median -4.151170e-02   0.959338  4.748804e-02   -1.345865e-01
# Neutrophils_min   -7.700757e-03   0.992329  5.043431e-03   -1.758570e-02
# Creatinine_mean    1.043520e-02   1.010490  3.548193e-02   -5.910810e-02
#
#                    coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%  \
# covariate
# subject_id          -1.061948e-09             1.000000             1.000000
# gender               2.063304e-01             0.939694             1.229159
# anchor_age           3.790200e-01             1.378493             1.460852
# disch_age           -3.227949e-01             0.683413             0.724122
# CKD_stage_first     -9.779285e-01             0.309888             0.376089
# ...                           ...                  ...                  ...
# Sodium_mean          1.229646e-02             0.946848             1.012372
# Other chest pain     2.290891e-01             0.896888             1.257454
# Creatinine_median    5.156315e-02             0.874077             1.052916
# Neutrophils_min      2.184186e-03             0.982568             1.002187
# Creatinine_mean      7.997850e-02             0.942605             1.083264
#
#                    cmp to          z              p    -log2(p)
# covariate
# subject_id            0.0  -2.061675   3.923871e-02    4.671579
# gender                0.0   1.051970   2.928132e-01    1.771947
# anchor_age            0.0  23.643158  1.388007e-123  408.124141
# disch_age             0.0 -23.828592  1.688431e-125  414.485329
# CKD_stage_first       0.0 -21.759033  5.673242e-105  346.298277
# ...                   ...        ...            ...         ...
# Sodium_mean           0.0  -1.239609   2.151200e-01    2.216787
# Other chest pain      0.0   0.697558   4.854538e-01    1.042594
# Creatinine_median     0.0  -0.874151   3.820363e-01    1.388219
# Neutrophils_min       0.0  -1.526889   1.267887e-01    2.979502
# Creatinine_mean       0.0   0.294099   7.686822e-01    0.379541
#
# [81 rows x 11 columns]
#                                    test_statistic         p  -log2(p)
# Acute kidney failure, unspecified        1.684900  0.194275  2.363831
# Albumin/Creatinine,_Urine_first          0.387011  0.533875  0.905427
# Albumin/Creatinine,_Urine_last           0.047729  0.827063  0.273931
# Albumin/Creatinine,_Urine_max            0.073312  0.786574  0.346346
# Albumin/Creatinine,_Urine_mean           0.049727  0.823539  0.280092
# ...                                           ...       ...       ...
# eGFR_median                              0.063243  0.801441  0.319331
# eGFR_min                                 0.047163  0.828075  0.272166
# gender                                   5.073293  0.024297  5.363067
# race_WHITE                               0.046282  0.829663  0.269402
# subject_id                               0.025022  0.874312  0.193779
#
# [81 rows x 3 columns]
# Brier Score at 1 year(s): 0.0295
# Brier Score at 2 year(s): 0.0488
# Brier Score at 3 year(s): 0.0626
# Brier Score at 4 year(s): 0.0820
# Brier Score at 5 year(s): 0.0974
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sksurv\metrics.py:482: RuntimeWarning: invalid value encountered in divide
#   true_pos = cumsum_tp / cumsum_tp[-1]
# AUC at 1 year(s): 0.9392
# AUC at 2 year(s): 0.9492
# AUC at 3 year(s): 0.9418
# AUC at 4 year(s): 0.9143
# AUC at 5 year(s): 0.9155
