# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %% [markdown]
# # Load Data Sources into Pandas Dataframes

# %%
# Hong et al. data set
df_hong = pd.read_csv("hong_et_al/df_updt.csv")

# %%
# MIMIC-IV data extracts necessary for ANOVA analysis
df_icd = pd.read_pickle('mimic_iv_extract/df_icd_codes_with_description.pkl')
df_history = pd.read_pickle('mimic_iv_extract/df_past_medical_history.pkl')
df_lab_events = pd.read_pickle("mimic_iv_extract/df_lab_events.pkl")
df_ckd_lab_items = pd.read_pickle("mimic_iv_extract/df_ckd_lab_items.pkl")

# %% [markdown]
# # Define Helper Functions

# %%
# helper function for dropping sparsely populated columns from dataframes with specified threshold

def drop_sparse_columns(df, sparsity_threshold):
    # calculate a series of percentage NaN values in each column
    pct_NaN = df.isna().mean()
    
    # identify 'sparse columns' NaN percentage >= sparsity_threshold
    sprs_Cols = pct_NaN[pct_NaN >= sparsity_threshold].index
    
    # drop sparse columns from the frame and return
    df.drop(columns=sprs_Cols, inplace=True)
    return df

# %%
# helper function for dropping column names matching the regex pattern passed to the argument

def drop_columns_like(df, rgx):
    # Use rgx argument to filter columns that match the regular expression pattern
    columns_to_drop = df.filter(regex=rgx).columns
    
    # Drop the columns
    df.drop(columns=columns_to_drop, inplace=True)
    return df

# %%
# helper function for identifying and dropping binary columns from a dataframe

def drop_binary_columns(df):
    # Iterate over columns checking if only binary values are present
    for column in df.columns:
        if pd.Series(df[column].unique()).isin([0, 1]).all():
            # Drop the binary column
            df = df.drop(column, axis=1)
    return df

# %%
# helper function for performing ANOVA analysis on a dataframe for a specified target column and feature set

def ANOVA(df, targ_col, features):
    # Dictionary to hold ANOVA results
    anova_results = {}
    
    for feature in features:
        # Only proceed if the column exists in the DataFrame to avoid KeyError
        if feature in df.columns:
            try:
                # Prepare the formula for the OLS model. Using 'Q()' around feature names to handle numeric column names.
                formula = f'Q("{feature}") ~ C({targ_col})'
                
                # Fit the model
                model = ols(formula, data=df).fit()
                
                # Perform ANOVA
                anova_table = sm.stats.anova_lm(model, typ=2)
                
                # Extract the p-value for the group effect
                p_value = float(anova_table["PR(>F)"][0])
                
                # Store the result
                anova_results[feature] = p_value
            except ValueError:
                continue  # Skip ValueErrors in sparse features to the next iteration
        else:
            anova_results[feature] = 'Feature column not found'

    # sort anova results in order of increasing p-value
    anova_results = sorted(anova_results.items(), key=lambda item: item[1])

    return anova_results

# %% [markdown]
# # Format Target Dataframe Containing Hospital Admissions Related to CKD Diagnoses from MIMIC-IV

# %%
# subset the CKD patients using ICD-9 codes (585)
df_target = df_icd[df_icd['icd_code'].str.startswith('585')]

# ensure the target column is of type 'category' for ANOVA analysis
df_target['icd_code'] = df_target['icd_code'].astype('category')

df_target.head()
# Out:
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\1649109332.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_target['icd_code'] = df_target['icd_code'].astype('category')
#        hadm_id  subject_id icd_code  seq_num  \
# 222   24522342    10031358     5859       36
# 262   20755971    10038081     5859       29
# 401   22394571    10098215     5859       32
# 770   21801929    10173670     5859       28
# 1672  29393377    10332722     5853       28
#
#                                         long_title
# 222            Chronic kidney disease, unspecified
# 262            Chronic kidney disease, unspecified
# 401            Chronic kidney disease, unspecified
# 770            Chronic kidney disease, unspecified
# 1672  Chronic kidney disease, Stage III (moderate)

# %% [markdown]
# # Format Features Dataframe Containing All CKD Related Lab Events from MIMIC-IV

# %%
# cast itemid column to string in CKD lab items frame
df_ckd_lab_items['itemid'] = df_ckd_lab_items['itemid'].astype(str)

# %%
# create a frame of all lab events to use as features for ANOVA
df_lab_features = df_lab_events.copy()

# convert lab features value column to float
df_lab_features['value'] = pd.to_numeric(df_lab_features['value'], errors='coerce')

# pivot lab features DataFrame such that each unique lab item ID becomes its own column with the mean value for the corresponding subject and hadm ID
df_lab_features = df_lab_features.pivot_table(index=['subject_id', 'hadm_id'], columns='itemid', values='value', aggfunc='mean').reset_index()

# merge the DataFrames on 'hadm_id' and 'subject_id'
df_lab_features_mrg = pd.merge(df_target, df_lab_features, on=['hadm_id', 'subject_id'])

# drop columns with all NaN values
df_lab_features_mrg = drop_sparse_columns(df_lab_features_mrg, 1)

# map column names to string
df_lab_features_mrg.columns = df_lab_features_mrg.columns.map(str)

df_lab_features_mrg.head(3)
# Out:
#     hadm_id  subject_id icd_code  seq_num  \
# 0  24522342    10031358     5859       36
# 1  20755971    10038081     5859       29
# 2  22394571    10098215     5859       32
#
#                             long_title     50808      50811  50853  50861  \
# 0  Chronic kidney disease, unspecified       NaN        NaN    NaN    NaN
# 1  Chronic kidney disease, unspecified  1.137500        NaN    NaN    9.8
# 2  Chronic kidney disease, unspecified  1.186957  11.533333    NaN   25.6
#
#    50862  ...  51272  51273  51282  51283  51284  51300      51301  51492  \
# 0    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN  13.114286    NaN
# 1  3.525  ...    NaN    NaN   0.12    4.9    NaN    NaN   5.534783   30.0
# 2  2.700  ...    NaN    NaN    NaN    NaN    NaN    NaN   9.096629   30.0
#
#        51493  51494
# 0        NaN    NaN
# 1  21.333333    NaN
# 2  16.666667    NaN
#
# [3 rows x 77 columns]

# %% [markdown]
# # Perform ANOVA Analysis on MIMIC-IV Dataframes

# %%
# isolate a list of column names to evalute as features from the df_lab_features_mrg frame
features = list(df_lab_features_mrg.columns[df_lab_features_mrg.columns.get_loc('long_title') + 1:])

anova_mimic_features = ANOVA(df_lab_features_mrg, 'icd_code', features)
# Out:
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\regression\linear_model.py:1716: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:1529: RuntimeWarning: invalid value encountered in multiply
#   cov_p = self.normalized_cov_params * scale
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:1888: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 6, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:1888: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 6, but rank is 4
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:1888: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 6, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:1888: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 6, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:1888: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 6, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:1888: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 6, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:1888: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 6, but rank is 4
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:1888: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 6, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:1888: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 6, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:1888: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 6, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:1888: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 6, but rank is 4
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:1888: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 6, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:1888: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 6, but rank is 4
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:1888: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 6, but rank is 5
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:1888: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 6, but rank is 4
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])

# %%
# Display the results
for tup in anova_mimic_features:
    print(f"{df_ckd_lab_items.loc[df_ckd_lab_items['itemid'] == tup[0], 'label'].values[0]}:\n    p-value = {tup[1]}")
# Out:
# Chloride:
#     p-value = 0.0
# Creatinine:
#     p-value = 0.0
# Phosphate:
#     p-value = 0.0
# Urea_Nitrogen:
#     p-value = 0.0
# MCV:
#     p-value = 2.1473631214254582e-282
# MCHC:
#     p-value = 6.20979821678653e-281
# Hemoglobin:
#     p-value = 8.230572969674965e-255
# Potassium:
#     p-value = 1.5448844327362312e-246
# Sodium:
#     p-value = 7.174852529422103e-243
# Bicarbonate:
#     p-value = 1.6236057454893205e-190
# Protein:
#     p-value = 1.4646527499097125e-146
# MCH:
#     p-value = 5.58863911876911e-48
# 25-OH_Vitamin_D:
#     p-value = 1.875751483511302e-42
# Reticulocyte_Count,_Manual:
#     p-value = 8.350544106151282e-40
# Urea_Nitrogen,_Urine:
#     p-value = 4.727064161484161e-32
# Platelet_Count:
#     p-value = 4.186215823027653e-28
# Total_Protein,_Urine:
#     p-value = 3.9539730475227007e-26
# Uric_Acid:
#     p-value = 2.4953930774451954e-23
# White_Blood_Cells:
#     p-value = 7.544174589898482e-19
# Protein/Creatinine_Ratio:
#     p-value = 5.587634233032481e-17
# Free_Calcium:
#     p-value = 7.85012705266186e-15
# Creatinine,_Urine:
#     p-value = 2.7132181593714197e-14
# Calcium,_Total:
#     p-value = 8.172499192672539e-10
# Protein_C,_Functional:
#     p-value = 1.508219678501988e-09
# Lymphocytes:
#     p-value = 1.5515838645214287e-09
# Basophils:
#     p-value = 9.799872248714909e-09
# Eosinophils:
#     p-value = 1.600316551169057e-08
# Hemoglobin:
#     p-value = 2.2956486088347978e-08
# Glucose:
#     p-value = 1.854984111425684e-07
# Neutrophils:
#     p-value = 4.205769637712163e-07
# Hemoglobin_A2:
#     p-value = 5.52443316833016e-07
# Cholesterol,_Total:
#     p-value = 1.1829017079894939e-05
# Protein_S,_Functional:
#     p-value = 2.8766648026779958e-05
# Cholesterol,_LDL,_Calculated:
#     p-value = 2.9804020210161443e-05
# Bilirubin,_Total:
#     p-value = 6.300760428228861e-05
# RBC_Casts:
#     p-value = 8.157007968899734e-05
# 24_hr_Protein:
#     p-value = 0.00014097633813008457
# 24_hr_Creatinine:
#     p-value = 0.00017800081301188063
# Protein_S,_Antigen:
#     p-value = 0.0005667537625216628
# Myelocytes:
#     p-value = 0.000974771262177893
# Monocytes:
#     p-value = 0.0017046914512882153
# RBC:
#     p-value = 0.0021027541870151834
# Bicarbonate,_Urine:
#     p-value = 0.0058794413336149464
# Albumin,_Urine:
#     p-value = 0.017556474001326417
# Amylase/Creatinine_Ratio,_Urine:
#     p-value = 0.02254096523101932
# Alanine_Aminotransferase_(ALT):
#     p-value = 0.027949138723314743
# Albumin:
#     p-value = 0.03796791011225203
# Creatinine,_Serum:
#     p-value = 0.07585483019263083
# Creatinine_Clearance:
#     p-value = 0.08008883145293598
# Protein_C,_Antigen:
#     p-value = 0.1495296174781862
# Bilirubin,_Indirect:
#     p-value = 0.18865682486421706
# WBC_Count:
#     p-value = 0.22078430411931377
# Albumin/Creatinine,_Urine:
#     p-value = 0.24586924906996566
# Absolute_Lymphocyte_Count:
#     p-value = 0.25105592911164465
# Nucleated_Red_Cells:
#     p-value = 0.26682766653638074
# Reticulocyte_Count,_Absolute:
#     p-value = 0.32317166468250247
# Bilirubin,_Direct:
#     p-value = 0.34170467504921725
# Eosinophil_Count:
#     p-value = 0.36874611365997373
# Asparate_Aminotransferase_(AST):
#     p-value = 0.4399155193940626
# Metamyelocytes:
#     p-value = 0.4522049997851839
# Cholesterol,_HDL:
#     p-value = 0.5506293355437084
# Hemoglobin_F:
#     p-value = 0.5579753094562536
# Cholesterol,_LDL,_Measured:
#     p-value = 0.6566120850100643
# Gamma_Glutamyltransferase:
#     p-value = 0.6864098475683461
# Reticulocyte_Count,_Automated:
#     p-value = 0.7371421763304986
# Globulin:
#     p-value = 0.7610753183168761
# Urine_Creatinine:
#     p-value = 0.8577529433487162
# Lymphocytes,_Percent:
#     p-value = 0.9003272101388744
# Cholesterol_Ratio_(Total/HDL):
#     p-value = 0.9070463939094147
# Protein,_Total:
#     p-value = 0.9401988016542859
# Hemoglobin_C:
#     p-value = 0.9725286368190669

# %% [markdown]
# # Format Features Dataframe from Hong et al. Dataset

# %%
df_hong_features = df_hong.copy()

# Drop non-numeric features by batches
df_hong_features.drop(columns=df_hong_features.columns[:299], inplace=True)

# Drop columns related to triage features using helper function
df_hong_features = drop_columns_like(df_hong_features, '^cc_')

df_hong_features = drop_columns_like(df_hong_features, '^triage_')

# Drop remaining binary features using helper function
df_hong_features = drop_binary_columns(df_hong_features)

# %% [markdown]
# # Perform ANOVA Analysis on Hong et al. Dataset

# %%
# isolate a list of column names to evalute as features from the df_lab_features_mrg frame
features = list(df_hong_features.columns)

anova_hong_features = ANOVA(df_hong, 'chrkidneydisease_Stg', features)
# Out:
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\regression\linear_model.py:1716: RuntimeWarning: invalid value encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:1888: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:1888: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 1
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsmodels\base\model.py:1888: ValueWarning: covariance of constraints does not have full rank. The number of constraints is 4, but rank is 3
#   warnings.warn('covariance of constraints does not have full '
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# ...
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])
# C:\Users\zdana\AppData\Local\Temp\ipykernel_25992\317416107.py:21: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value = float(anova_table["PR(>F)"][0])

# %%
# Display the results
for tup in anova_hong_features:
    print(f"{tup[0]}:\n    p-value = {tup[1]}")
# Out:
# n_edvisits:
#     p-value = 0.0
# n_admissions:
#     p-value = 0.0
# absolutelymphocytecount_last:
#     p-value = 0.0
# albumin_last:
#     p-value = 0.0
# alkphos_last:
#     p-value = 0.0
# anc(absneutrophilcount)_last:
#     p-value = 0.0
# aniongap_last:
#     p-value = 0.0
# b-typenatriureticpeptide,pro(probnp)_last:
#     p-value = 0.0
# bun_last:
#     p-value = 0.0
# bun/creatratio_last:
#     p-value = 0.0
# calcium_last:
#     p-value = 0.0
# chloride_last:
#     p-value = 0.0
# co2_last:
#     p-value = 0.0
# creatinine_last:
#     p-value = 0.0
# egfr_CKD_EPI:
#     p-value = 0.0
# egfr_last:
#     p-value = 0.0
# egfr(nonafricanamerican)_last:
#     p-value = 0.0
# egfr(aframer)_last:
#     p-value = 0.0
# globulin_last:
#     p-value = 0.0
# glucose_last:
#     p-value = 0.0
# hematocrit_last:
#     p-value = 0.0
# hemoglobin_last:
#     p-value = 0.0
# inr_last:
#     p-value = 0.0
# lymphs_last:
#     p-value = 0.0
# magnesium_last:
#     p-value = 0.0
# mchc_last:
#     p-value = 0.0
# mcv_last:
#     p-value = 0.0
# monocytes_last:
#     p-value = 0.0
# neutrophils_last:
#     p-value = 0.0
# phosphorus_last:
#     p-value = 0.0
# platelets_last:
#     p-value = 0.0
# pocbun_last:
#     p-value = 0.0
# poccreatinine_last:
#     p-value = 0.0
# pochematocrit_last:
#     p-value = 0.0
# pocionizedcalcium_last:
#     p-value = 0.0
# pocpotassium_last:
#     p-value = 0.0
# potassium_last:
#     p-value = 0.0
# prothrombintime_last:
#     p-value = 0.0
# rbc_last:
#     p-value = 0.0
# rdw_last:
#     p-value = 0.0
# sodium_last:
#     p-value = 0.0
# absolutelymphocytecount_min:
#     p-value = 0.0
# albumin_min:
#     p-value = 0.0
# alkphos_min:
#     p-value = 0.0
# aniongap_min:
#     p-value = 0.0
# b-typenatriureticpeptide,pro(probnp)_min:
#     p-value = 0.0
# bun_min:
#     p-value = 0.0
# bun/creatratio_min:
#     p-value = 0.0
# calcium_min:
#     p-value = 0.0
# calculatedo2saturation(poc)_min:
#     p-value = 0.0
# chloride_min:
#     p-value = 0.0
# co2_min:
#     p-value = 0.0
# creatinine_min:
#     p-value = 0.0
# egfr_min:
#     p-value = 0.0
# egfr(nonafricanamerican)_min:
#     p-value = 0.0
# egfr(aframer)_min:
#     p-value = 0.0
# globulin_min:
#     p-value = 0.0
# glucose_min:
#     p-value = 0.0
# hematocrit_min:
#     p-value = 0.0
# hemoglobin_min:
#     p-value = 0.0
# inr_min:
#     p-value = 0.0
# lymphs_min:
#     p-value = 0.0
# mchc_min:
#     p-value = 0.0
# mcv_min:
#     p-value = 0.0
# neutrophils_min:
#     p-value = 0.0
# phosphorus_min:
#     p-value = 0.0
# platelets_min:
#     p-value = 0.0
# po2(poc)_min:
#     p-value = 0.0
# pocbun_min:
#     p-value = 0.0
# poccreatinine_min:
#     p-value = 0.0
# pochematocrit_min:
#     p-value = 0.0
# pocionizedcalcium_min:
#     p-value = 0.0
# pocpotassium_min:
#     p-value = 0.0
# pocsodium_min:
#     p-value = 0.0
# potassium_min:
#     p-value = 0.0
# prothrombintime_min:
#     p-value = 0.0
# rbc_min:
#     p-value = 0.0
# rdw_min:
#     p-value = 0.0
# sodium_min:
#     p-value = 0.0
# troponint_min:
#     p-value = 0.0
# albumin_max:
#     p-value = 0.0
# alkphos_max:
#     p-value = 0.0
# anc(absneutrophilcount)_max:
#     p-value = 0.0
# aniongap_max:
#     p-value = 0.0
# b-typenatriureticpeptide,pro(probnp)_max:
#     p-value = 0.0
# bun_max:
#     p-value = 0.0
# bun/creatratio_max:
#     p-value = 0.0
# calculatedo2saturation(poc)_max:
#     p-value = 0.0
# chloride_max:
#     p-value = 0.0
# creatinine_max:
#     p-value = 0.0
# egfr_max:
#     p-value = 0.0
# egfr(nonafricanamerican)_max:
#     p-value = 0.0
# egfr(aframer)_max:
#     p-value = 0.0
# globulin_max:
#     p-value = 0.0
# glucose_max:
#     p-value = 0.0
# hematocrit_max:
#     p-value = 0.0
# hemoglobin_max:
#     p-value = 0.0
# inr_max:
#     p-value = 0.0
# lymphs_max:
#     p-value = 0.0
# magnesium_max:
#     p-value = 0.0
# mchc_max:
#     p-value = 0.0
# mcv_max:
#     p-value = 0.0
# monocytes_max:
#     p-value = 0.0
# mpv_max:
#     p-value = 0.0
# neutrophils_max:
#     p-value = 0.0
# phosphorus_max:
#     p-value = 0.0
# platelets_max:
#     p-value = 0.0
# po2(poc)_max:
#     p-value = 0.0
# pocbun_max:
#     p-value = 0.0
# poccreatinine_max:
#     p-value = 0.0
# pochematocrit_max:
#     p-value = 0.0
# pocionizedcalcium_max:
#     p-value = 0.0
# pocpotassium_max:
#     p-value = 0.0
# pocsodium_max:
#     p-value = 0.0
# potassium_max:
#     p-value = 0.0
# proteintotal_max:
#     p-value = 0.0
# prothrombintime_max:
#     p-value = 0.0
# rbc_max:
#     p-value = 0.0
# rdw_max:
#     p-value = 0.0
# troponint_max:
#     p-value = 0.0
# absolutelymphocytecount_median:
#     p-value = 0.0
# albumin_median:
#     p-value = 0.0
# alkphos_median:
#     p-value = 0.0
# anc(absneutrophilcount)_median:
#     p-value = 0.0
# aniongap_median:
#     p-value = 0.0
# b-typenatriureticpeptide,pro(probnp)_median:
#     p-value = 0.0
# bun_median:
#     p-value = 0.0
# bun/creatratio_median:
#     p-value = 0.0
# calcium_median:
#     p-value = 0.0
# calculatedo2saturation(poc)_median:
#     p-value = 0.0
# chloride_median:
#     p-value = 0.0
# co2_median:
#     p-value = 0.0
# creatinine_median:
#     p-value = 0.0
# egfr_median:
#     p-value = 0.0
# egfr(nonafricanamerican)_median:
#     p-value = 0.0
# egfr(aframer)_median:
#     p-value = 0.0
# globulin_median:
#     p-value = 0.0
# glucose_median:
#     p-value = 0.0
# hematocrit_median:
#     p-value = 0.0
# hemoglobin_median:
#     p-value = 0.0
# inr_median:
#     p-value = 0.0
# lymphs_median:
#     p-value = 0.0
# magnesium_median:
#     p-value = 0.0
# mchc_median:
#     p-value = 0.0
# mcv_median:
#     p-value = 0.0
# monocytes_median:
#     p-value = 0.0
# neutrophils_median:
#     p-value = 0.0
# phosphorus_median:
#     p-value = 0.0
# platelets_median:
#     p-value = 0.0
# po2(poc)_median:
#     p-value = 0.0
# pocbun_median:
#     p-value = 0.0
# poccreatinine_median:
#     p-value = 0.0
# pocglucose_median:
#     p-value = 0.0
# pochematocrit_median:
#     p-value = 0.0
# pocionizedcalcium_median:
#     p-value = 0.0
# pocpotassium_median:
#     p-value = 0.0
# pocsodium_median:
#     p-value = 0.0
# potassium_median:
#     p-value = 0.0
# proteintotal_median:
#     p-value = 0.0
# prothrombintime_median:
#     p-value = 0.0
# rbc_median:
#     p-value = 0.0
# rdw_median:
#     p-value = 0.0
# sodium_median:
#     p-value = 0.0
# troponint_median:
#     p-value = 0.0
# bloodua_npos:
#     p-value = 0.0
# proteinua_npos:
#     p-value = 0.0
# pregtestur_count:
#     p-value = 0.0
# bloodculture,routine_count:
#     p-value = 0.0
# spo2_last:
#     p-value = 0.0
# sbp_last:
#     p-value = 0.0
# dbp_last:
#     p-value = 0.0
# o2_device_last:
#     p-value = 0.0
# spo2_min:
#     p-value = 0.0
# sbp_min:
#     p-value = 0.0
# dbp_min:
#     p-value = 0.0
# pulse_max:
#     p-value = 0.0
# resp_max:
#     p-value = 0.0
# spo2_max:
#     p-value = 0.0
# sbp_max:
#     p-value = 0.0
# o2_device_max:
#     p-value = 0.0
# pulse_median:
#     p-value = 0.0
# resp_median:
#     p-value = 0.0
# spo2_median:
#     p-value = 0.0
# sbp_median:
#     p-value = 0.0
# dbp_median:
#     p-value = 0.0
# o2_device_median:
#     p-value = 0.0
# cxr_count:
#     p-value = 0.0
# echo_count:
#     p-value = 0.0
# ekg_count:
#     p-value = 0.0
# otherimg_count:
#     p-value = 0.0
# otherus_count:
#     p-value = 0.0
# meds_analgesics:
#     p-value = 0.0
# meds_antiasthmatics:
#     p-value = 0.0
# meds_antibiotics:
#     p-value = 0.0
# meds_anticoagulants:
#     p-value = 0.0
# meds_antihyperglycemics:
#     p-value = 0.0
# meds_antiplateletdrugs:
#     p-value = 0.0
# meds_autonomicdrugs:
#     p-value = 0.0
# meds_cardiacdrugs:
#     p-value = 0.0
# meds_cardiovascular:
#     p-value = 0.0
# meds_colonystimulatingfactors:
#     p-value = 0.0
# meds_diuretics:
#     p-value = 0.0
# meds_eentpreps:
#     p-value = 0.0
# meds_elect/caloric/h2o:
#     p-value = 0.0
# meds_gastrointestinal:
#     p-value = 0.0
# meds_hormones:
#     p-value = 0.0
# meds_psychotherapeuticdrugs:
#     p-value = 0.0
# meds_thyroidpreps:
#     p-value = 0.0
# meds_unclassifieddrugproducts:
#     p-value = 0.0
# meds_vitamins:
#     p-value = 0.0
# n_surgeries:
#     p-value = 0.0
# pocglucose_max:
#     p-value = 5e-324
# meds_skinpreps:
#     p-value = 6.64e-321
# pulse_last:
#     p-value = 1.979973e-318
# proteintotal_min:
#     p-value = 2.532383588165e-312
# pocglucose_min:
#     p-value = 1.3616447329864985e-308
# resp_last:
#     p-value = 2.730601707047881e-308
# meds_antiarthritics:
#     p-value = 3.693569773365412e-305
# ketonesua_npos:
#     p-value = 8.493546038317042e-305
# eos_max:
#     p-value = 2.2225897823855996e-303
# absolutelymphocytecount_max:
#     p-value = 6.289608443511502e-298
# meds_antifungals:
#     p-value = 4.8858693701089975e-297
# pocsodium_last:
#     p-value = 1.2406086917355142e-288
# meds_miscellaneousmedicalsupplies,devices,non-drug:
#     p-value = 1.5730862715498705e-285
# meds_immunosuppressants:
#     p-value = 3.6536903582745403e-274
# basos_min:
#     p-value = 9.611134958363334e-273
# calculatedo2saturation(poc)_last:
#     p-value = 7.162345523385821e-260
# meds_anesthetics:
#     p-value = 1.4121577704986092e-254
# magnesium_min:
#     p-value = 1.5541732582478354e-240
# resp_min:
#     p-value = 1.1116252608410094e-237
# co2,poc_min:
#     p-value = 5.982235945668104e-231
# baseexcess(poc)_min:
#     p-value = 1.2690266219402837e-227
# meds_diagnostic:
#     p-value = 1.0168780518587526e-226
# temp_min:
#     p-value = 6.721932497374383e-223
# dbp_max:
#     p-value = 1.2704222189980503e-216
# wbc_max:
#     p-value = 6.801410209461559e-212
# proteintotal_last:
#     p-value = 3.2264433520406514e-207
# co2_max:
#     p-value = 3.270011556760286e-204
# temp_max:
#     p-value = 2.4627215179805246e-201
# calculatedco2(poc)_min:
#     p-value = 2.2716733117062844e-197
# mpv_last:
#     p-value = 3.7363957894502016e-193
# glucose,meter_median:
#     p-value = 1.958396368750813e-185
# o2satcalculated,venous(poc)_median:
#     p-value = 7.235036604798353e-183
# monocytes_min:
#     p-value = 1.2249021403366567e-181
# nitriteua_npos:
#     p-value = 2.137996480172319e-180
# anc(absneutrophilcount)_min:
#     p-value = 4.2058864582491946e-178
# alanineaminotransferase(alt)_median:
#     p-value = 9.613465074116529e-178
# o2_device_min:
#     p-value = 6.367813712095144e-176
# glucose,meter_min:
#     p-value = 7.53527743680522e-176
# ptt_max:
#     p-value = 5.0978534900954226e-172
# po2(poc)_last:
#     p-value = 1.3781131653164916e-171
# mpv_median:
#     p-value = 1.8920995134799477e-166
# o2satcalculated,venous(poc)_max:
#     p-value = 1.8334047310946455e-163
# pocph_min:
#     p-value = 4.268583410108765e-161
# meds_cough/coldpreparations:
#     p-value = 4.413765040261434e-161
# calculatedhco3(poc)i_min:
#     p-value = 5.533965242455397e-160
# calcium_max:
#     p-value = 3.873100014198019e-159
# po2,venous(poc)_median:
#     p-value = 1.2812603022219622e-157
# alanineaminotransferase(alt)_min:
#     p-value = 3.159183160550548e-157
# meds_antivirals:
#     p-value = 1.4463391695543867e-154
# alanineaminotransferase(alt)_max:
#     p-value = 3.552799430009877e-153
# ptt_median:
#     p-value = 4.665991367693566e-152
# basos_median:
#     p-value = 1.4567117643644434e-150
# meds_cnsdrugs:
#     p-value = 1.0607771910834342e-148
# leukocytesua_npos:
#     p-value = 1.082570701993708e-141
# pulse_min:
#     p-value = 5.2389301156429166e-138
# pocph_median:
#     p-value = 1.3848308134989425e-135
# glucoseua_npos:
#     p-value = 2.989896786330808e-134
# glucose,meter_max:
#     p-value = 2.7815310488544616e-129
# mch_max:
#     p-value = 4.724455182582677e-126
# po2,venous(poc)_max:
#     p-value = 1.129177392658915e-124
# headct_count:
#     p-value = 1.5900442663407607e-124
# o2satcalculated,venous(poc)_min:
#     p-value = 2.208995950007591e-124
# aspartateaminotransferase(ast)_max:
#     p-value = 5.364977167012836e-120
# po2,venous(poc)_min:
#     p-value = 7.621708718490054e-117
# wbc_last:
#     p-value = 8.738470198639807e-116
# o2satcalculated,venous(poc)_last:
#     p-value = 1.600745646555809e-115
# proteinua_count:
#     p-value = 4.299775294106056e-115
# nitriteua_count:
#     p-value = 4.670547782566622e-115
# leukocytesua_count:
#     p-value = 4.684332242703461e-115
# glucoseua_count:
#     p-value = 5.180601637072669e-115
# ketonesua_count:
#     p-value = 5.18479288708228e-115
# bloodua_count:
#     p-value = 5.516655951955023e-115
# eos_median:
#     p-value = 1.3886079661912756e-110
# pocph_max:
#     p-value = 6.469360790063558e-110
# troponint_last:
#     p-value = 8.637026926069123e-108
# meds_antihistamines:
#     p-value = 1.6757984392587693e-106
# wbc/hpf_max:
#     p-value = 1.1561225795702303e-103
# baseexcess(poc)_median:
#     p-value = 4.788463037108669e-99
# ptt_last:
#     p-value = 6.032985344461234e-97
# basos_last:
#     p-value = 4.649123564434687e-92
# eos_last:
#     p-value = 2.171355734316244e-90
# po2,venous(poc)_last:
#     p-value = 2.53803063959218e-87
# aspartateaminotransferase(ast)_median:
#     p-value = 2.0197043411011245e-85
# meds_herbals:
#     p-value = 2.681012262856841e-85
# meds_contraceptives:
#     p-value = 7.708219403230591e-84
# immaturegranulocytes_last:
#     p-value = 1.712548494836834e-83
# calculatedco2(poc)_median:
#     p-value = 1.1309041462293313e-82
# pco2(poc)_min:
#     p-value = 3.462004145707567e-77
# alanineaminotransferase(alt)_last:
#     p-value = 7.117581606783237e-77
# wbc/hpf_median:
#     p-value = 1.2192802890671852e-75
# baseexcess(poc)_last:
#     p-value = 6.153612907208895e-75
# co2,poc_median:
#     p-value = 3.5261624836301717e-74
# ptt_min:
#     p-value = 9.843553743371872e-73
# immaturegranulocytes_median:
#     p-value = 1.0518618394860655e-71
# sodium_max:
#     p-value = 4.5764687745289255e-70
# calculatedhco3(poc)i_median:
#     p-value = 5.027889678788835e-70
# immaturegranulocytes_max:
#     p-value = 5.429833706525608e-70
# wbc_median:
#     p-value = 5.7978734149486675e-68
# pocglucose_last:
#     p-value = 3.243929629521506e-66
# temp_median:
#     p-value = 4.4723453123042434e-66
# lipase_max:
#     p-value = 5.046731369554584e-66
# urineculture,routine_count:
#     p-value = 7.646798525580071e-66
# urineculture,routine_npos:
#     p-value = 1.2839446812298612e-65
# meds_pre-natalvitamins:
#     p-value = 6.835063166793666e-65
# immaturegrans(abs)_median:
#     p-value = 2.2994606358733347e-64
# otherct_count:
#     p-value = 1.1506864347148675e-62
# immaturegrans(abs)_last:
#     p-value = 8.377329154318778e-61
# aspartateaminotransferase(ast)_min:
#     p-value = 1.0763643650885622e-59
# immaturegrans(abs)_max:
#     p-value = 1.8372417188085194e-59
# baseexcess(poc)_max:
#     p-value = 1.964806016581294e-56
# calculatedco2(poc)_last:
#     p-value = 5.702844439637942e-56
# lactate,poc_min:
#     p-value = 2.2487820604427266e-55
# immaturegranulocytes_min:
#     p-value = 3.320217290388219e-55
# co2,poc_last:
#     p-value = 9.632921774163904e-55
# meds_antineoplastics:
#     p-value = 9.885302463861481e-54
# ph,venous(poc)_min:
#     p-value = 9.916056388235595e-53
# wbc/hpf_last:
#     p-value = 1.0162701411202322e-50
# calculatedhco3(poc)i_last:
#     p-value = 1.0445506222147749e-50
# meds_antiinfectives/miscellaneous:
#     p-value = 1.909749636943399e-49
# wbc/hpf_min:
#     p-value = 8.697624026015704e-49
# calculatedco2(poc)_max:
#     p-value = 3.944500944729519e-48
# mpv_min:
#     p-value = 3.886984280357921e-47
# meds_sedative/hypnotics:
#     p-value = 6.448031879875291e-47
# lipase_median:
#     p-value = 2.0464712175436787e-46
# mch_median:
#     p-value = 2.286063631933224e-45
# mch_last:
#     p-value = 7.899845654712096e-44
# meds_antiparkinsondrugs:
#     p-value = 3.699266164698051e-43
# immaturegrans(abs)_min:
#     p-value = 4.813868987973572e-43
# aspartateaminotransferase(ast)_last:
#     p-value = 1.3040347391116368e-42
# pco2(poc)_median:
#     p-value = 1.5239426477393555e-41
# troponini(poc)_max:
#     p-value = 2.1145341611717714e-41
# ph,venous(poc)_median:
#     p-value = 5.350895156613026e-41
# calculatedhco3(poc)i_max:
#     p-value = 1.7375971885077462e-38
# wbc_min:
#     p-value = 2.13623829186341e-38
# lipase_min:
#     p-value = 5.863080785151239e-37
# baseexcess,venous(poc)_min:
#     p-value = 1.5095282820032532e-36
# mch_min:
#     p-value = 1.7668074997465142e-34
# ph,venous(poc)_max:
#     p-value = 3.297896544460914e-34
# co2calculated,venous(poc)_min:
#     p-value = 1.7762143089335592e-33
# pocph_last:
#     p-value = 2.8013745190475466e-33
# eos_min:
#     p-value = 1.484858669676378e-30
# ph,venous(poc)_last:
#     p-value = 8.202293216704265e-30
# hco3calculated,venous(poc)_min:
#     p-value = 2.7431904492063546e-29
# lactate,poc_median:
#     p-value = 5.072695708211539e-28
# co2,poc_max:
#     p-value = 7.339367155553038e-28
# troponini(poc)_median:
#     p-value = 8.436823871525103e-27
# monosabs_last:
#     p-value = 1.0692717147971546e-26
# monosabs_median:
#     p-value = 6.484075324007625e-26
# monosabs_max:
#     p-value = 1.127991642081483e-25
# bilirubintotal_min:
#     p-value = 1.205621194053796e-25
# baseexcess,venous(poc)_median:
#     p-value = 3.31421695230708e-25
# monosabs_min:
#     p-value = 1.1485708831157246e-24
# basos_max:
#     p-value = 4.712637433005046e-24
# eosinoabs_max:
#     p-value = 7.605790184839479e-24
# glucose,meter_last:
#     p-value = 9.123675712646695e-24
# co2calculated,venous(poc)_median:
#     p-value = 1.615925117253829e-23
# pco2(poc)_max:
#     p-value = 8.461348880473134e-23
# tsh_median:
#     p-value = 1.7985261904260442e-22
# tsh_max:
#     p-value = 4.62502239660081e-22
# baseexcess,venous(poc)_max:
#     p-value = 1.2680873483785168e-21
# lipase_last:
#     p-value = 2.251183127771509e-21
# tsh_min:
#     p-value = 5.126760986593597e-21
# hco3calculated,venous(poc)_median:
#     p-value = 8.091459679900894e-21
# temp_last:
#     p-value = 8.24669631725872e-21
# lactate,poc_max:
#     p-value = 4.294419524112459e-20
# otherxr_count:
#     p-value = 4.300163161832809e-20
# pco2,venous(poc)_min:
#     p-value = 1.0752432427296306e-18
# co2calculated,venous(poc)_max:
#     p-value = 1.162770613882369e-18
# bilirubintotal_median:
#     p-value = 1.105492550510557e-16
# baseexcess,venous(poc)_last:
#     p-value = 1.6942076831323373e-16
# hco3calculated,venous(poc)_max:
#     p-value = 1.7177233317246387e-16
# meds_antiinfectives:
#     p-value = 3.0550816960820577e-16
# eosinoabs_last:
#     p-value = 7.925038002620057e-16
# co2calculated,venous(poc)_last:
#     p-value = 8.670422551431239e-15
# troponini(poc)_last:
#     p-value = 9.970855102204224e-15
# troponini(poc)_min:
#     p-value = 2.872250578749594e-14
# bilirubintotal_max:
#     p-value = 1.0051940878629e-13
# pco2,venous(poc)_median:
#     p-value = 1.1613359776247176e-13
# pco2(poc)_last:
#     p-value = 1.954664103705776e-13
# hco3calculated,venous(poc)_last:
#     p-value = 2.922240701878202e-13
# bilirubintotal_last:
#     p-value = 2.8856433406333877e-12
# meds_analgesicandantihistaminecombination:
#     p-value = 8.471307098517055e-12
# lactate,poc_last:
#     p-value = 5.025792746074886e-11
# eosinoabs_median:
#     p-value = 1.0675228960184102e-10
# bilirubindirect_last:
#     p-value = 7.819273763483212e-09
# tsh_last:
#     p-value = 7.932097863740421e-09
# meds_blood:
#     p-value = 5.733639500743087e-08
# bilirubindirect_min:
#     p-value = 7.766048835952322e-08
# nrbc_max:
#     p-value = 1.60518334718396e-07
# pco2,venous(poc)_max:
#     p-value = 2.2715874029396396e-07
# pco2,venous(poc)_last:
#     p-value = 4.801920184611632e-07
# mri_count:
#     p-value = 1.0366632113425395e-06
# bilirubindirect_median:
#     p-value = 1.0930179515122326e-05
# basosabs_last:
#     p-value = 8.832954113531542e-05
# basosabs_max:
#     p-value = 0.00016351663759855688
# bilirubindirect_max:
#     p-value = 0.00037854014791156805
# eosinoabs_min:
#     p-value = 0.0006254301305505016
# epithelialcells_min:
#     p-value = 0.0009602917656496081
# epithelialcells_max:
#     p-value = 0.0009602917656496081
# epithelialcells_median:
#     p-value = 0.0009602917656496081
# basosabs_median:
#     p-value = 0.0012234164187839612
# pregtestur_npos:
#     p-value = 0.001511195099005068
# meds_antidotes:
#     p-value = 0.002179088074880573
# meds_musclerelaxants:
#     p-value = 0.002986362501689824
# nrbc_last:
#     p-value = 0.0032917649415150157
# basosabs_min:
#     p-value = 0.0036276167727148563
# nrbc_min:
#     p-value = 0.00997560021950017
# nrbc_median:
#     p-value = 0.015079379790001126
# cktotal_max:
#     p-value = 0.01521725639897416
# acetonebld_median:
#     p-value = 0.022276608605419718
# acetonebld_max:
#     p-value = 0.023897117067046243
# d-dimer_max:
#     p-value = 0.02566936016878687
# cktotal_median:
#     p-value = 0.03589521395722193
# acetonebld_min:
#     p-value = 0.03605702095206291
# cktotal_last:
#     p-value = 0.04621747592036615
# cktotal_min:
#     p-value = 0.0594343379599015
# meds_anti-obesitydrugs:
#     p-value = 0.06700880121502788
# d-dimer_median:
#     p-value = 0.10994854196784316
# d-dimer_min:
#     p-value = 0.1689791159392645
# rbc/hpf_last:
#     p-value = 0.2544600344597546
# poctroponini._min:
#     p-value = 0.35863569027818526
# poctroponini._median:
#     p-value = 0.35886168006840247
# poctroponini._max:
#     p-value = 0.359074827055267
# meds_biologicals:
#     p-value = 0.3783610262907067
# meds_smokingdeterrents:
#     p-value = 0.39133787002574555
# poctroponini._last:
#     p-value = 0.425068478579989
# acetonebld_last:
#     p-value = 0.42898159183840223
# epithelialcells_last:
#     p-value = 0.5272992889619005
# rbc/hpf_min:
#     p-value = 0.5317678886445559
# rbc/hpf_max:
#     p-value = 0.5779699130310547
# nrbcabsolute_median:
#     p-value = 0.8291535054507767
# meds_antihistamineanddecongestantcombination:
#     p-value = 0.8562634524014098
# nrbcabsolute_last:
#     p-value = 0.8598576338909701
# nrbcabsolute_max:
#     p-value = 0.889618029676118
# nrbcabsolute_min:
#     p-value = 0.9395814872077869
# d-dimer_last:
#     p-value = 0.9513716623590095
# rbc/hpf_median:
#     p-value = 0.9542357177205472
# benzodiazepinesscreen,urine,noconf._min:
#     p-value = 0.955954835309974
# benzodiazepinesscreen,urine,noconf._max:
#     p-value = 0.955954835309974
# benzodiazepinesscreen,urine,noconf._median:
#     p-value = 0.955954835309974
