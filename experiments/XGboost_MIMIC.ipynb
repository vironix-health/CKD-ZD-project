# %%
import sys
import os

# Use os.getcwd() to get the current working directory in a Jupyter notebook
parent_dir = os.path.dirname(os.getcwd())  # Get the parent directory of the current working directory
sys.path.append(parent_dir)

# %%
import pandas as pd
from skopt.space import Real, Integer
from driver import Driver

# %% [markdown]
# # Load Cleaned Master MIMIC-IV Dataset

# %%
# Cleaned Master MIMIC Data Set
df_master = pd.read_pickle('../MIMIC_IV/df_ckd_master_clean.pkl')
df_base = pd.read_pickle('../MIMIC_IV/df_ckd_base.pkl')

# %% [markdown]
# # Evaluate XGBoost Pipeline

# %%
XGboost_cfg = {
    'name': 'XGboost', # Feature selection model long name
    'tag': 'xgb', # Feature selection model identifier tag
    'response': 'stage_delta',  # Response variable for binary classification and Cox Proportional Hazards
    'duration': 'duration', # Duration in days until response or censorship
    'n_novel': 40, # Number of ranked novel features included in augmented KFRE dataset
    'test_size': 0.1, # Ratio of data reserved for testing
    'val_size': 0.2, # Ratio of data reserved for testing in validation sets
    'n_valsets': 5, # Number of training validation sets
    'n_bayesian': 10, # Number of Bayesian hyperparameter optimization iterations 
    'n_folds': 5, # Number of folds for CoxPH cross validation
    'penalizer': 0.0007, # CoxPH model penalizer
    'auc_space': [
        Integer(5, 20, name='max_depth'),
        Integer(1, 10, name='min_child_weight'),
        Real(0.5, 3.0, name='gamma'),
        Real(0.6, 1.0, name='subsample'),
        Real(0.6, 1.0, name='colsample_bytree'),
        Real(0.01, 0.6, name='colsample_bylevel'),
        Real(0.01, 0.3, name='learning_rate'),
        Integer(50, 150, name='n_estimators')
    ], # Search space for Bayesian hyperparameter optimization
    'random_state': 42 # Seed for reproducibility
}

driver = Driver(XGboost_cfg, df_master, df_base)
driver.ClassicalLearningPipe()
# Out:
# Testing params: {'max_depth': 17, 'min_child_weight': 3, 'gamma': 2.449227500681924, 'subsample': 0.8387400631785948, 'colsample_bytree': 0.7783331011414365, 'colsample_bylevel': 0.06898520033262172, 'learning_rate': 0.1431821786701015, 'n_estimators': 83}
# AUC for params: 0.9380285441140328
# Testing params: {'max_depth': 7, 'min_child_weight': 7, 'gamma': 0.6410289475677506, 'subsample': 0.88879950890673, 'colsample_bytree': 0.9754210836063002, 'colsample_bylevel': 0.010459471846198455, 'learning_rate': 0.29774135219445313, 'n_estimators': 112}
# AUC for params: 0.8944073898804372
# Testing params: {'max_depth': 14, 'min_child_weight': 1, 'gamma': 0.5576560626035394, 'subsample': 0.8099098641033557, 'colsample_bytree': 0.7599443886861023, 'colsample_bylevel': 0.0375327412960331, 'learning_rate': 0.2923891004640232, 'n_estimators': 73}
# AUC for params: 0.9123162080942798
# Testing params: {'max_depth': 6, 'min_child_weight': 7, 'gamma': 1.456154978167907, 'subsample': 0.9932923543227153, 'colsample_bytree': 0.786705157299192, 'colsample_bylevel': 0.5173648399744293, 'learning_rate': 0.20728918619045614, 'n_estimators': 95}
# AUC for params: 0.9500612734485298
# Testing params: {'max_depth': 5, 'min_child_weight': 9, 'gamma': 1.9082205446138485, 'subsample': 0.7541666010159664, 'colsample_bytree': 0.6063865008880857, 'colsample_bylevel': 0.14622735711706794, 'learning_rate': 0.07989738514754341, 'n_estimators': 118}
# AUC for params: 0.941104225558828
# Testing params: {'max_depth': 14, 'min_child_weight': 8, 'gamma': 0.9334116337694303, 'subsample': 0.7564242430292963, 'colsample_bytree': 0.672894435115225, 'colsample_bylevel': 0.45566323208741505, 'learning_rate': 0.133295203602461, 'n_estimators': 71}
# AUC for params: 0.9487165103795515
# Testing params: {'max_depth': 14, 'min_child_weight': 1, 'gamma': 2.6057119364874968, 'subsample': 0.7799016533479063, 'colsample_bytree': 0.7580600944007259, 'colsample_bylevel': 0.5567287308183387, 'learning_rate': 0.22090887879836207, 'n_estimators': 83}
# AUC for params: 0.9521186510788506
# Testing params: {'max_depth': 14, 'min_child_weight': 6, 'gamma': 2.9029300608733735, 'subsample': 0.9378135394712607, 'colsample_bytree': 0.8989280440549523, 'colsample_bylevel': 0.3284183581095571, 'learning_rate': 0.180157838042516, 'n_estimators': 147}
# AUC for params: 0.952855063868304
# Testing params: {'max_depth': 14, 'min_child_weight': 3, 'gamma': 1.240683764260206, 'subsample': 0.666106775625201, 'colsample_bytree': 0.6062545626964776, 'colsample_bylevel': 0.25980687361675814, 'learning_rate': 0.12451564027091523, 'n_estimators': 79}
# AUC for params: 0.9469059269916796
# Testing params: {'max_depth': 5, 'min_child_weight': 3, 'gamma': 2.2783548818716253, 'subsample': 0.9160702162124823, 'colsample_bytree': 0.8423839899124046, 'colsample_bylevel': 0.556517518322876, 'learning_rate': 0.19881233739556392, 'n_estimators': 141}
# AUC for params: 0.9537734369575978
# Best parameters found:  {'max_depth': 5, 'min_child_weight': 3, 'gamma': 2.2783548818716253, 'subsample': 0.9160702162124823, 'colsample_bytree': 0.8423839899124046, 'colsample_bylevel': 0.556517518322876, 'learning_rate': 0.19881233739556392, 'n_estimators': 141}
# Best average AUC across validation sets:  0.9537734369575978
# Test AUC: 0.7619061996779388
# Iteration 1: norm_delta = 6.43e+00, step_size = 0.9500, log_lik = -8744.90665, newton_decrement = 9.96e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.16e+00, step_size = 0.2375, log_lik = -8329.12426, newton_decrement = 5.63e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.83e+00, step_size = 0.0772, log_lik = -8245.58363, newton_decrement = 4.85e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.30e+00, step_size = 0.1304, log_lik = -8127.36698, newton_decrement = 3.74e+02, seconds_since_start = 0.5
# Iteration 5: norm_delta = 3.49e+00, step_size = 0.2205, log_lik = -7980.27733, newton_decrement = 2.37e+02, seconds_since_start = 0.6
# Iteration 6: norm_delta = 2.32e+00, step_size = 0.3726, log_lik = -7836.12226, newton_decrement = 9.97e+01, seconds_since_start = 0.7
# Iteration 7: norm_delta = 9.34e-01, step_size = 0.6296, log_lik = -7749.61758, newton_decrement = 1.52e+01, seconds_since_start = 0.8
# Iteration 8: norm_delta = 1.46e-02, step_size = 1.0000, log_lik = -7734.23910, newton_decrement = 9.14e-03, seconds_since_start = 0.9
# Iteration 9: norm_delta = 1.28e-05, step_size = 1.0000, log_lik = -7734.22996, newton_decrement = 3.34e-08, seconds_since_start = 1.0
# Convergence success after 9 iterations.
# Iteration 1: norm_delta = 6.59e+00, step_size = 0.9500, log_lik = -8829.99117, newton_decrement = 9.96e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.30e+00, step_size = 0.2375, log_lik = -8414.16810, newton_decrement = 5.62e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.97e+00, step_size = 0.0772, log_lik = -8330.71241, newton_decrement = 4.83e+02, seconds_since_start = 0.4
# Iteration 4: norm_delta = 4.43e+00, step_size = 0.1304, log_lik = -8212.81734, newton_decrement = 3.72e+02, seconds_since_start = 0.5
# Iteration 5: norm_delta = 3.59e+00, step_size = 0.2205, log_lik = -8066.63899, newton_decrement = 2.34e+02, seconds_since_start = 0.6
# Iteration 6: norm_delta = 2.38e+00, step_size = 0.3726, log_lik = -7924.23810, newton_decrement = 9.78e+01, seconds_since_start = 0.7
# Iteration 7: norm_delta = 9.58e-01, step_size = 0.6296, log_lik = -7839.34896, newton_decrement = 1.49e+01, seconds_since_start = 0.8
# Iteration 8: norm_delta = 1.46e-02, step_size = 1.0000, log_lik = -7824.30127, newton_decrement = 8.04e-03, seconds_since_start = 0.9
# Iteration 9: norm_delta = 1.11e-05, step_size = 1.0000, log_lik = -7824.29322, newton_decrement = 1.36e-08, seconds_since_start = 1.0
# Convergence success after 9 iterations.
# Iteration 1: norm_delta = 6.52e+00, step_size = 0.9500, log_lik = -8805.41001, newton_decrement = 9.93e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.22e+00, step_size = 0.2375, log_lik = -8390.75106, newton_decrement = 5.53e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.89e+00, step_size = 0.0772, log_lik = -8308.66475, newton_decrement = 4.74e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.35e+00, step_size = 0.1304, log_lik = -8193.06292, newton_decrement = 3.63e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.53e+00, step_size = 0.2205, log_lik = -8050.40752, newton_decrement = 2.27e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.34e+00, step_size = 0.3726, log_lik = -7912.39828, newton_decrement = 9.39e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.36e-01, step_size = 0.6296, log_lik = -7831.02193, newton_decrement = 1.40e+01, seconds_since_start = 0.8
# Iteration 8: norm_delta = 1.27e-02, step_size = 1.0000, log_lik = -7816.91286, newton_decrement = 7.19e-03, seconds_since_start = 0.9
# Iteration 9: norm_delta = 8.45e-06, step_size = 1.0000, log_lik = -7816.90567, newton_decrement = 1.23e-08, seconds_since_start = 1.0
# Convergence success after 9 iterations.
# Iteration 1: norm_delta = 6.65e+00, step_size = 0.9500, log_lik = -9037.41005, newton_decrement = 1.00e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.33e+00, step_size = 0.2375, log_lik = -8619.26002, newton_decrement = 5.67e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.99e+00, step_size = 0.0772, log_lik = -8535.05054, newton_decrement = 4.88e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.45e+00, step_size = 0.1304, log_lik = -8416.08620, newton_decrement = 3.76e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.61e+00, step_size = 0.2205, log_lik = -8268.53599, newton_decrement = 2.37e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.40e+00, step_size = 0.3726, log_lik = -8124.67609, newton_decrement = 9.90e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.69e-01, step_size = 0.6296, log_lik = -8038.78795, newton_decrement = 1.52e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 1.57e-02, step_size = 1.0000, log_lik = -8023.46280, newton_decrement = 1.21e-02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 3.59e-05, step_size = 1.0000, log_lik = -8023.45073, newton_decrement = 2.05e-07, seconds_since_start = 0.9
# Iteration 10: norm_delta = 5.12e-08, step_size = 1.0000, log_lik = -8023.45073, newton_decrement = 2.59e-13, seconds_since_start = 1.1
# Convergence success after 10 iterations.
# Iteration 1: norm_delta = 6.56e+00, step_size = 0.9500, log_lik = -8886.68689, newton_decrement = 1.02e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.24e+00, step_size = 0.2375, log_lik = -8461.62506, newton_decrement = 5.69e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.91e+00, step_size = 0.0772, log_lik = -8377.14975, newton_decrement = 4.89e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.37e+00, step_size = 0.1304, log_lik = -8257.74387, newton_decrement = 3.78e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.54e+00, step_size = 0.2205, log_lik = -8109.21080, newton_decrement = 2.40e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.35e+00, step_size = 0.3726, log_lik = -7962.93861, newton_decrement = 1.03e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.43e-01, step_size = 0.6296, log_lik = -7873.39830, newton_decrement = 1.65e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 1.51e-02, step_size = 1.0000, log_lik = -7856.64786, newton_decrement = 1.79e-02, seconds_since_start = 0.9
# Iteration 9: norm_delta = 7.37e-04, step_size = 1.0000, log_lik = -7856.62991, newton_decrement = 1.15e-05, seconds_since_start = 1.0
# Iteration 10: norm_delta = 6.06e-06, step_size = 1.0000, log_lik = -7856.62989, newton_decrement = 7.21e-10, seconds_since_start = 1.1
# Convergence success after 10 iterations.
# Average C-Index from cross-validation: 0.8878
# Best C-Index from cross-validation: 0.8921
# Standard Deviation of C-Index from cross-validation: 0.0051
#                                coef  exp(coef)      se(coef)  coef lower 95%  \
# covariate
# subject_id            -1.596304e-08   1.000000  1.032484e-08   -3.619935e-08
# gender                 2.142596e-01   1.238944  7.203402e-02    7.307550e-02
# anchor_age             3.390786e-01   1.403654  1.492198e-02    3.098320e-01
# disch_age             -3.444836e-01   0.708586  1.485120e-02   -3.735914e-01
# CKD_stage_first       -1.086858e+00   0.337275  4.764346e-02   -1.180237e+00
# ...                             ...        ...           ...             ...
# Neutrophils_last       5.629044e-03   1.005645  3.158080e-03   -5.606785e-04
# Lymphocytes_first      2.689187e-03   1.002693  3.870580e-03   -4.897010e-03
# Atrial fibrillation   -1.093485e-02   0.989125  6.752711e-02   -1.432855e-01
# MCV_last              -2.906249e-03   0.997098  6.607061e-03   -1.585585e-02
# Platelet_Count_median  5.676354e-04   1.000568  5.444517e-04   -4.994704e-04
#
#                        coef upper 95%  exp(coef) lower 95%  \
# covariate
# subject_id               4.273279e-09             1.000000
# gender                   3.554437e-01             1.075812
# anchor_age               3.683251e-01             1.363196
# disch_age               -3.153758e-01             0.688258
# CKD_stage_first         -9.934781e-01             0.307206
# ...                               ...                  ...
# Neutrophils_last         1.181877e-02             0.999439
# Lymphocytes_first        1.027538e-02             0.995115
# Atrial fibrillation      1.214158e-01             0.866507
# MCV_last                 1.004335e-02             0.984269
# Platelet_Count_median    1.634741e-03             0.999501
#
#                        exp(coef) upper 95%  cmp to          z              p  \
# covariate
# subject_id                        1.000000     0.0  -1.546081   1.220851e-01
# gender                            1.426814     0.0   2.974422   2.935410e-03
# anchor_age                        1.445312     0.0  22.723435  2.628288e-114
# disch_age                         0.729515     0.0 -23.195672  5.035013e-119
# CKD_stage_first                   0.370287     0.0 -22.812312  3.460779e-115
# ...                                    ...     ...        ...            ...
# Neutrophils_last                  1.011889     0.0   1.782426   7.467976e-02
# Lymphocytes_first                 1.010328     0.0   0.694776   4.871955e-01
# Atrial fibrillation               1.129094     0.0  -0.161933   8.713588e-01
# MCV_last                          1.010094     0.0  -0.439870   6.600311e-01
# Platelet_Count_median             1.001636     0.0   1.042582   2.971421e-01
#
#                          -log2(p)
# covariate
# subject_id               3.034041
# gender                   8.412222
# anchor_age             377.305679
# disch_age              392.977448
# CKD_stage_first        380.230634
# ...                           ...
# Neutrophils_last         3.743139
# Lymphocytes_first        1.037427
# Atrial fibrillation      0.198661
# MCV_last                 0.599394
# Platelet_Count_median    1.750775
#
# [81 rows x 11 columns]
#                                   test_statistic         p  -log2(p)
# Albumin/Creatinine,_Urine_first         0.038147  0.845147  0.242725
# Albumin/Creatinine,_Urine_last          0.035683  0.850171  0.234175
# Albumin/Creatinine,_Urine_max           0.052166  0.819336  0.287473
# Albumin/Creatinine,_Urine_mean          0.042782  0.836136  0.258190
# Albumin/Creatinine,_Urine_median        0.018691  0.891256  0.166089
# ...                                          ...       ...       ...
# eGFR_median                             0.056486  0.812139  0.300201
# eGFR_min                                0.036349  0.848797  0.236508
# gender                                  0.414912  0.519487  0.944841
# marital_status_MARRIED                  0.008592  0.926148  0.110686
# subject_id                              0.000156  0.990043  0.014437
#
# [81 rows x 3 columns]
# Brier Score at 1 year(s): 0.0307
# Brier Score at 2 year(s): 0.0563
# Brier Score at 3 year(s): 0.0709
# Brier Score at 4 year(s): 0.0843
# Brier Score at 5 year(s): 0.1037
# AUC at 1 year(s): 0.9501
# AUC at 2 year(s): 0.9434
# AUC at 3 year(s): 0.9380
# AUC at 4 year(s): 0.9269
# AUC at 5 year(s): 0.9143
