# %%
import sys
import os

# Use os.getcwd() to get the current working directory in a Jupyter notebook
parent_dir = os.path.dirname(os.getcwd())  # Get the parent directory of the current working directory
sys.path.append(parent_dir)

# %%
import pandas as pd
from skopt.space import Real, Integer
from driver import Driver

# %% [markdown]
# # Load Cleaned Master MIMIC-IV Dataset

# %%
# Cleaned Master MIMIC Data Set
df_master = pd.read_pickle('../MIMIC_IV/df_ckd_master_clean.pkl')
df_base = pd.read_pickle('../MIMIC_IV/df_ckd_base.pkl')

# %% [markdown]
# # Evaluate ResNet Pipeline

# %%
ResNet_cfg = {
    'name': 'ResNet',
    'tag': 'rsnt', # Identifier tag for feature selection model
    'response': 'stage_delta',  # Response variable for binary classification and Cox Proportional Hazards
    'duration': 'duration', # Duration in days until response or censorship
    'n_novel': 40, # Number of ranked novel features included in augmented KFRE dataset
    'test_size': 0.2, # Ratio of data reserved for testing
    'num_blocks': 3,
    'hidden_dim': 64,
    'num_classes': 1, # Updated to 1 for binary classification
    'epochs': 30,
    'patience': 5,
    'learning_rate': 0.001,
    'weight_decay': 1e-4,
    'batch_size': 256, # Batch size for SHAP computation
    'n_folds': 5, # Number of folds for CoxPH cross validation
    'penalizer': 0.0007, # CoxPH model penalizer
    'random_state': 42 # Seed for reproducibility
}

driver = Driver(ResNet_cfg, df_master, df_base)
driver.DeepLearningPipe()
# Out:
# Epoch 1/30, Training Loss: 0.2807247715536505, Validation Loss: 0.2735935500399633
# Epoch 2/30, Training Loss: 0.1787118436768651, Validation Loss: 0.3015681159767238
# Epoch 3/30, Training Loss: 0.11658475759693167, Validation Loss: 0.37180629440329294
# Epoch 4/30, Training Loss: 0.06473826993764802, Validation Loss: 0.5193395435132764
# Epoch 5/30, Training Loss: 0.037257541793885386, Validation Loss: 0.6335768967189572
# Epoch 6/30, Training Loss: 0.026887296260445673, Validation Loss: 0.7247427820482037
# Early stopping triggered
# Test AUC: 0.6629737724970763
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:22<00:00,  2.04s/it]
# C:\Users\zdana\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\shap\plots\_beeswarm.py:962: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   pl.tight_layout()
# Iteration 1: norm_delta = 6.51e+00, step_size = 0.9500, log_lik = -8744.90665, newton_decrement = 9.73e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.24e+00, step_size = 0.2375, log_lik = -8338.52287, newton_decrement = 5.53e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.91e+00, step_size = 0.0772, log_lik = -8256.48318, newton_decrement = 4.75e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.37e+00, step_size = 0.1304, log_lik = -8140.55486, newton_decrement = 3.66e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.54e+00, step_size = 0.2205, log_lik = -7996.77219, newton_decrement = 2.30e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.34e+00, step_size = 0.3726, log_lik = -7856.76536, newton_decrement = 9.59e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.38e-01, step_size = 0.6296, log_lik = -7773.64878, newton_decrement = 1.45e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 1.43e-02, step_size = 1.0000, log_lik = -7759.07207, newton_decrement = 9.87e-03, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.24e-05, step_size = 1.0000, log_lik = -7759.06219, newton_decrement = 3.48e-08, seconds_since_start = 0.9
# Convergence success after 9 iterations.
# Iteration 1: norm_delta = 6.57e+00, step_size = 0.9500, log_lik = -8829.99117, newton_decrement = 9.78e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.32e+00, step_size = 0.2375, log_lik = -8422.00128, newton_decrement = 5.49e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.99e+00, step_size = 0.0772, log_lik = -8340.49158, newton_decrement = 4.72e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.45e+00, step_size = 0.1304, log_lik = -8225.46681, newton_decrement = 3.62e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.61e+00, step_size = 0.2205, log_lik = -8083.13130, newton_decrement = 2.27e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.39e+00, step_size = 0.3726, log_lik = -7944.92237, newton_decrement = 9.47e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.59e-01, step_size = 0.6296, log_lik = -7862.75095, newton_decrement = 1.45e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 1.44e-02, step_size = 1.0000, log_lik = -7848.06213, newton_decrement = 1.13e-02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.33e-05, step_size = 1.0000, log_lik = -7848.05080, newton_decrement = 3.47e-08, seconds_since_start = 0.9
# Convergence success after 9 iterations.
# Iteration 1: norm_delta = 6.51e+00, step_size = 0.9500, log_lik = -8805.41001, newton_decrement = 9.73e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.24e+00, step_size = 0.2375, log_lik = -8399.87509, newton_decrement = 5.41e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.91e+00, step_size = 0.0772, log_lik = -8319.64514, newton_decrement = 4.63e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.38e+00, step_size = 0.1304, log_lik = -8206.74598, newton_decrement = 3.54e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.55e+00, step_size = 0.2205, log_lik = -8067.62665, newton_decrement = 2.21e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.36e+00, step_size = 0.3726, log_lik = -7933.21084, newton_decrement = 9.18e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.48e-01, step_size = 0.6296, log_lik = -7853.59278, newton_decrement = 1.40e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 1.41e-02, step_size = 1.0000, log_lik = -7839.42803, newton_decrement = 9.12e-03, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.22e-05, step_size = 1.0000, log_lik = -7839.41891, newton_decrement = 1.97e-08, seconds_since_start = 0.8
# Convergence success after 9 iterations.
# Iteration 1: norm_delta = 6.65e+00, step_size = 0.9500, log_lik = -9037.41005, newton_decrement = 9.71e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.38e+00, step_size = 0.2375, log_lik = -8632.10036, newton_decrement = 5.55e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.04e+00, step_size = 0.0772, log_lik = -8549.65805, newton_decrement = 4.78e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.90e+00, step_size = 0.0326, log_lik = -8518.99091, newton_decrement = 4.49e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.68e+00, step_size = 0.0551, log_lik = -8470.82235, newton_decrement = 4.04e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.31e+00, step_size = 0.0931, log_lik = -8398.98926, newton_decrement = 3.37e+02, seconds_since_start = 0.5
# Iteration 7: norm_delta = 3.73e+00, step_size = 0.1574, log_lik = -8301.15110, newton_decrement = 2.45e+02, seconds_since_start = 0.6
# Iteration 8: norm_delta = 2.84e+00, step_size = 0.2660, log_lik = -8187.98951, newton_decrement = 1.37e+02, seconds_since_start = 0.7
# Iteration 9: norm_delta = 1.64e+00, step_size = 0.4496, log_lik = -8092.22629, newton_decrement = 4.40e+01, seconds_since_start = 0.8
# Iteration 10: norm_delta = 4.29e-01, step_size = 0.7598, log_lik = -8050.56497, newton_decrement = 2.90e+00, seconds_since_start = 0.9
# Iteration 11: norm_delta = 2.84e-03, step_size = 1.0000, log_lik = -8047.64538, newton_decrement = 5.10e-04, seconds_since_start = 1.0
# Iteration 12: norm_delta = 7.41e-07, step_size = 1.0000, log_lik = -8047.64487, newton_decrement = 1.32e-10, seconds_since_start = 1.1
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.53e+00, step_size = 0.9500, log_lik = -8886.68689, newton_decrement = 9.94e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.26e+00, step_size = 0.2375, log_lik = -8474.67142, newton_decrement = 5.55e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.93e+00, step_size = 0.0772, log_lik = -8392.30405, newton_decrement = 4.77e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.39e+00, step_size = 0.1304, log_lik = -8276.03249, newton_decrement = 3.67e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.56e+00, step_size = 0.2205, log_lik = -8131.86168, newton_decrement = 2.32e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.37e+00, step_size = 0.3726, log_lik = -7990.90153, newton_decrement = 9.80e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.50e-01, step_size = 0.6296, log_lik = -7905.68861, newton_decrement = 1.55e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.09e-02, step_size = 1.0000, log_lik = -7889.92882, newton_decrement = 3.24e-02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.07e-03, step_size = 1.0000, log_lik = -7889.89544, newton_decrement = 1.33e-04, seconds_since_start = 0.9
# Iteration 10: norm_delta = 6.06e-06, step_size = 1.0000, log_lik = -7889.89530, newton_decrement = 8.70e-09, seconds_since_start = 1.0
# Convergence success after 10 iterations.
# Average C-Index from cross-validation: 0.8875
# Best C-Index from cross-validation: 0.8941
# Standard Deviation of C-Index from cross-validation: 0.0064
#                                                             coef  exp(coef)  \
# covariate
# subject_id                                         -1.662948e-08   1.000000
# gender                                              8.872481e-02   1.092780
# anchor_age                                          3.450376e-01   1.412043
# disch_age                                          -3.464780e-01   0.707174
# CKD_stage_first                                    -1.080948e+00   0.339274
# ...                                                          ...        ...
# Unspecified gastritis and gastroduodenitis, wit...  1.876190e-02   1.018939
# Long-term (current) use of insulin                 -4.499913e-02   0.955998
# Delirium due to conditions classified elsewhere    -8.818236e-02   0.915594
# Constipation, unspecified                          -2.109359e-01   0.809826
# Sodium_median                                      -3.904792e-02   0.961705
#
#                                                         se(coef)  \
# covariate
# subject_id                                          1.030458e-08
# gender                                              6.774011e-02
# anchor_age                                          1.488129e-02
# disch_age                                           1.484126e-02
# CKD_stage_first                                     4.778219e-02
# ...                                                          ...
# Unspecified gastritis and gastroduodenitis, wit...  1.203334e-01
# Long-term (current) use of insulin                  7.746738e-02
# Delirium due to conditions classified elsewhere     1.007463e-01
# Constipation, unspecified                           7.862685e-02
# Sodium_median                                       1.972436e-02
#
#                                                     coef lower 95%  \
# covariate
# subject_id                                           -3.682608e-08
# gender                                               -4.404336e-02
# anchor_age                                            3.158708e-01
# disch_age                                            -3.755663e-01
# CKD_stage_first                                      -1.174599e+00
# ...                                                            ...
# Unspecified gastritis and gastroduodenitis, wit...   -2.170871e-01
# Long-term (current) use of insulin                   -1.968324e-01
# Delirium due to conditions classified elsewhere      -2.856415e-01
# Constipation, unspecified                            -3.650416e-01
# Sodium_median                                        -7.770696e-02
#
#                                                     coef upper 95%  \
# covariate
# subject_id                                            3.567125e-09
# gender                                                2.214930e-01
# anchor_age                                            3.742044e-01
# disch_age                                            -3.173897e-01
# CKD_stage_first                                      -9.872967e-01
# ...                                                            ...
# Unspecified gastritis and gastroduodenitis, wit...    2.546109e-01
# Long-term (current) use of insulin                    1.068341e-01
# Delirium due to conditions classified elsewhere       1.092767e-01
# Constipation, unspecified                            -5.683007e-02
# Sodium_median                                        -3.888806e-04
#
#                                                     exp(coef) lower 95%  \
# covariate
# subject_id                                                     1.000000
# gender                                                         0.956912
# anchor_age                                                     1.371453
# disch_age                                                      0.686900
# CKD_stage_first                                                0.308943
# ...                                                                 ...
# Unspecified gastritis and gastroduodenitis, wit...             0.804860
# Long-term (current) use of insulin                             0.821328
# Delirium due to conditions classified elsewhere                0.751532
# Constipation, unspecified                                      0.694168
# Sodium_median                                                  0.925236
#
#                                                     exp(coef) upper 95%  \
# covariate
# subject_id                                                     1.000000
# gender                                                         1.247938
# anchor_age                                                     1.453834
# disch_age                                                      0.728047
# CKD_stage_first                                                0.372583
# ...                                                                 ...
# Unspecified gastritis and gastroduodenitis, wit...             1.289960
# Long-term (current) use of insulin                             1.112750
# Delirium due to conditions classified elsewhere                1.115471
# Constipation, unspecified                                      0.944755
# Sodium_median                                                  0.999611
#
#                                                     cmp to          z  \
# covariate
# subject_id                                             0.0  -1.613795
# gender                                                 0.0   1.309783
# anchor_age                                             0.0  23.186000
# disch_age                                              0.0 -23.345593
# CKD_stage_first                                        0.0 -22.622406
# ...                                                    ...        ...
# Unspecified gastritis and gastroduodenitis, wit...     0.0   0.155916
# Long-term (current) use of insulin                     0.0  -0.580878
# Delirium due to conditions classified elsewhere        0.0  -0.875291
# Constipation, unspecified                              0.0  -2.682746
# Sodium_median                                          0.0  -1.979680
#
#                                                                 p    -log2(p)
# covariate
# subject_id                                           1.065719e-01    3.230101
# gender                                               1.902694e-01    2.393884
# anchor_age                                          6.303726e-119  392.653238
# disch_age                                           1.527803e-120  398.019913
# CKD_stage_first                                     2.608589e-113  373.994605
# ...                                                           ...         ...
# Unspecified gastritis and gastroduodenitis, wit...   8.760992e-01    0.190834
# Long-term (current) use of insulin                   5.613224e-01    0.833098
# Delirium due to conditions classified elsewhere      3.814154e-01    1.390565
# Constipation, unspecified                            7.302044e-03    7.097484
# Sodium_median                                        4.773953e-02    4.388672
#
# [81 rows x 11 columns]
#                                           test_statistic         p  -log2(p)
# Acidosis                                        2.482197  0.115141  3.118522
# Acute kidney failure, unspecified               1.372832  0.241326  2.050945
# Acute on chronic diastolic heart failure        0.053753  0.816657  0.292199
# Albumin/Creatinine,_Urine_first                 0.081659  0.775061  0.367617
# Albumin/Creatinine,_Urine_last                  0.000256  0.987236  0.018534
# ...                                                  ...       ...       ...
# eGFR_min                                        0.034745  0.852131  0.230852
# gender                                          0.003464  0.953067  0.069350
# marital_status_SINGLE                           0.817370  0.365950  1.450281
# race_WHITE                                      1.221802  0.269007  1.894283
# subject_id                                      0.028590  0.865729  0.208013
#
# [81 rows x 3 columns]
