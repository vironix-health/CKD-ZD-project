# %%
import sys
import os

# Use os.getcwd() to get the current working directory in a Jupyter notebook
parent_dir = os.path.dirname(os.getcwd())  # Get the parent directory of the current working directory
sys.path.append(parent_dir)

# %%
import pandas as pd
from skopt.space import Real, Integer
from driver import Driver

# %% [markdown]
# # Load Cleaned Master MIMIC-IV Dataset

# %%
# Cleaned Master MIMIC Data Set
df_master = pd.read_pickle('../MIMIC_IV/df_ckd_master_clean.pkl')
df_base = pd.read_pickle('../MIMIC_IV/df_ckd_base.pkl')

# %% [markdown]
# # Evaluate Logistic Regression Pipeline

# %%
LogisticRegression_cfg = {
    'name': 'LogisticRegression', # Feature selection model long name
    'tag': 'lr', # Feature selection model identifier tag
    'response': 'stage_delta',  # Response variable for binary classification and Cox Proportional Hazards
    'duration': 'duration', # Duration in days until response or censorship
    'n_novel': 40, # Number of ranked novel features included in augmented KFRE dataset
    'test_size': 0.1, # Ratio of data reserved for testing
    'val_size': 0.2, # Ratio of data reserved for testing in validation sets
    'n_valsets': 5, # Number of training validation sets
    'n_bayesian': 10, # Number of Bayesian hyperparameter optimization iterations 
    'n_folds': 5, # Number of folds for CoxPH cross validation
    'penalizer': 0.0007, # CoxPH model penalizer
    'auc_space': [
        Real(0.01, 1.0, name="C")
    ], # Search space for Bayesian hyperparameter optimization
    'seeds': [42, 73, 128, 256, 512] # Seeds for reproducibility
}

driver = Driver(LogisticRegression_cfg, df_master, df_base)
driver.ClassicalLearningPipe()
# Out:
# Testing params: {'C': 0.7985775569916307}
# AUC for params: 0.8284011771089107
# Testing params: {'C': 0.1916004419675022}
# AUC for params: 0.8351286016058037
# Testing params: {'C': 0.7818940902700418}
# AUC for params: 0.8286605939060896
# Testing params: {'C': 0.6008816563670223}
# AUC for params: 0.8297160299516187
# Testing params: {'C': 0.45137442532505534}
# AUC for params: 0.831005908643637
# Testing params: {'C': 0.10897516665982288}
# AUC for params: 0.8377594946705242
# Testing params: {'C': 0.4646564030462086}
# AUC for params: 0.8308427645145127
# Testing params: {'C': 0.3403715250276317}
# AUC for params: 0.8323117787752385
# Testing params: {'C': 0.1514381497427214}
# AUC for params: 0.8362578725353312
# Testing params: {'C': 0.6543795882193645}
# AUC for params: 0.8292339343445224
# Testing params: {'C': 0.31226567755069373}
# AUC for params: 0.8372073172408416
# Testing params: {'C': 0.61181792905017}
# AUC for params: 0.8332107061850043
# Testing params: {'C': 0.18164737227674316}
# AUC for params: 0.8401792083145917
# Testing params: {'C': 0.523499509007179}
# AUC for params: 0.8341192114307298
# Testing params: {'C': 0.3162301604622408}
# AUC for params: 0.8370837249825142
# Testing params: {'C': 0.09504837908998286}
# AUC for params: 0.8440402282620869
# Testing params: {'C': 0.8675135820833861}
# AUC for params: 0.8311624564196316
# Testing params: {'C': 0.48327690485792146}
# AUC for params: 0.8347235117560718
# Testing params: {'C': 0.8345249412769205}
# AUC for params: 0.8312118641626774
# Testing params: {'C': 0.9574917946013984}
# AUC for params: 0.8305720331630709
# Testing params: {'C': 0.8930988597908126}
# AUC for params: 0.8181331974622632
# Testing params: {'C': 0.8493879445649267}
# AUC for params: 0.818475716932296
# Testing params: {'C': 0.3865791848389619}
# AUC for params: 0.823020948553744
# Testing params: {'C': 0.5243153010050587}
# AUC for params: 0.8209614436176494
# Testing params: {'C': 0.3724117264078547}
# AUC for params: 0.8232811300182536
# Testing params: {'C': 0.36661707574645697}
# AUC for params: 0.8233912883275739
# Testing params: {'C': 0.788829392980248}
# AUC for params: 0.8188269195753455
# Testing params: {'C': 0.5811915874552458}
# AUC for params: 0.8206418716343901
# Testing params: {'C': 0.12186473241622876}
# AUC for params: 0.8307697325354229
# Testing params: {'C': 0.7751919284168015}
# AUC for params: 0.8189983532422715
# Testing params: {'C': 0.8360530299712682}
# AUC for params: 0.8193004079890536
# Testing params: {'C': 0.53378275827473}
# AUC for params: 0.8219566852318001
# Testing params: {'C': 0.50285517084152}
# AUC for params: 0.8223163401281871
# Testing params: {'C': 0.6889055117646773}
# AUC for params: 0.8203534210119386
# Testing params: {'C': 0.9710025507875375}
# AUC for params: 0.8188128414067585
# Testing params: {'C': 0.36531369816455783}
# AUC for params: 0.8241214849042834
# Testing params: {'C': 0.8666028026663646}
# AUC for params: 0.8193168692936359
# Testing params: {'C': 0.5779255535252658}
# AUC for params: 0.8213185986497692
# Testing params: {'C': 0.07631182242817167}
# AUC for params: 0.8341432250741174
# Testing params: {'C': 0.7709895356990388}
# AUC for params: 0.8199699880650023
# Testing params: {'C': 0.4266282996521709}
# AUC for params: 0.8304168820493288
# Testing params: {'C': 0.21473334419707352}
# AUC for params: 0.8347584844354896
# Testing params: {'C': 0.3730681876204243}
# AUC for params: 0.831449651068079
# Testing params: {'C': 0.23307703512855482}
# AUC for params: 0.834113976353388
# Testing params: {'C': 0.5635556802476691}
# AUC for params: 0.828644202462273
# Testing params: {'C': 0.685513103345389}
# AUC for params: 0.8274067298170642
# Testing params: {'C': 0.3327114784254269}
# AUC for params: 0.8320314725276832
# Testing params: {'C': 0.6797946670560702}
# AUC for params: 0.8274544082303606
# Testing params: {'C': 0.888616245943116}
# AUC for params: 0.8259989209748738
# Testing params: {'C': 0.2872368713593622}
# AUC for params: 0.8328890346044091
# Best parameters found:  {'C': 0.09504837908998286}
# Best mean AUC across validation sets:  0.8440402282620869
# Mean AUC: 0.7026919613686038
# Standard Deviation: 0.022951131383017204
# Max AUC: 0.7267628205128205
# Iteration 1: norm_delta = 6.52e+00, step_size = 0.9500, log_lik = -8744.90665, newton_decrement = 9.96e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.25e+00, step_size = 0.2375, log_lik = -8329.44669, newton_decrement = 5.47e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.91e+00, step_size = 0.0772, log_lik = -8248.26315, newton_decrement = 4.69e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.37e+00, step_size = 0.1304, log_lik = -8133.97098, newton_decrement = 3.59e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.54e+00, step_size = 0.2205, log_lik = -7992.92818, newton_decrement = 2.25e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.34e+00, step_size = 0.3726, log_lik = -7856.23133, newton_decrement = 9.37e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.40e-01, step_size = 0.6296, log_lik = -7774.85829, newton_decrement = 1.45e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 1.54e-02, step_size = 1.0000, log_lik = -7760.16630, newton_decrement = 1.65e-02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 6.99e-05, step_size = 1.0000, log_lik = -7760.14979, newton_decrement = 7.62e-07, seconds_since_start = 0.9
# Iteration 10: norm_delta = 6.29e-09, step_size = 1.0000, log_lik = -7760.14979, newton_decrement = 6.20e-15, seconds_since_start = 1.0
# Convergence success after 10 iterations.
# Iteration 1: norm_delta = 6.61e+00, step_size = 0.9500, log_lik = -8829.99117, newton_decrement = 1.00e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.35e+00, step_size = 0.2375, log_lik = -8412.85744, newton_decrement = 5.53e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.01e+00, step_size = 0.0772, log_lik = -8330.71926, newton_decrement = 4.75e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.87e+00, step_size = 0.0326, log_lik = -8300.26940, newton_decrement = 4.46e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.65e+00, step_size = 0.0551, log_lik = -8252.50516, newton_decrement = 4.00e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.28e+00, step_size = 0.0931, log_lik = -8181.43022, newton_decrement = 3.32e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 3.70e+00, step_size = 0.1574, log_lik = -8084.96521, newton_decrement = 2.40e+02, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.82e+00, step_size = 0.2660, log_lik = -7973.97662, newton_decrement = 1.34e+02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.64e+00, step_size = 0.4496, log_lik = -7880.57968, newton_decrement = 4.29e+01, seconds_since_start = 0.9
# Iteration 10: norm_delta = 4.34e-01, step_size = 0.7598, log_lik = -7839.87327, newton_decrement = 2.91e+00, seconds_since_start = 1.0
# Iteration 11: norm_delta = 4.60e-03, step_size = 1.0000, log_lik = -7836.94332, newton_decrement = 6.81e-04, seconds_since_start = 1.1
# Iteration 12: norm_delta = 5.48e-06, step_size = 1.0000, log_lik = -7836.94264, newton_decrement = 1.03e-09, seconds_since_start = 1.2
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.54e+00, step_size = 0.9500, log_lik = -8805.41001, newton_decrement = 9.94e+02, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.26e+00, step_size = 0.2375, log_lik = -8390.65396, newton_decrement = 5.50e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.93e+00, step_size = 0.0772, log_lik = -8309.03396, newton_decrement = 4.70e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.39e+00, step_size = 0.1304, log_lik = -8194.36560, newton_decrement = 3.59e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.56e+00, step_size = 0.2205, log_lik = -8053.49131, newton_decrement = 2.23e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.36e+00, step_size = 0.3726, log_lik = -7918.18591, newton_decrement = 9.15e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.51e-01, step_size = 0.6296, log_lik = -7838.82176, newton_decrement = 1.39e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 1.93e-02, step_size = 1.0000, log_lik = -7824.79328, newton_decrement = 1.24e-02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 8.91e-05, step_size = 1.0000, log_lik = -7824.78085, newton_decrement = 2.23e-07, seconds_since_start = 0.9
# Iteration 10: norm_delta = 3.26e-09, step_size = 1.0000, log_lik = -7824.78085, newton_decrement = 2.66e-16, seconds_since_start = 1.0
# Convergence success after 10 iterations.
# Iteration 1: norm_delta = 6.69e+00, step_size = 0.9500, log_lik = -9037.41005, newton_decrement = 1.00e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.39e+00, step_size = 0.2375, log_lik = -8620.20551, newton_decrement = 5.53e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 5.05e+00, step_size = 0.0772, log_lik = -8538.06240, newton_decrement = 4.74e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.91e+00, step_size = 0.0326, log_lik = -8507.62828, newton_decrement = 4.45e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 4.69e+00, step_size = 0.0551, log_lik = -8459.89153, newton_decrement = 4.00e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 4.32e+00, step_size = 0.0931, log_lik = -8388.85208, newton_decrement = 3.32e+02, seconds_since_start = 0.6
# Iteration 7: norm_delta = 3.73e+00, step_size = 0.1574, log_lik = -8292.37656, newton_decrement = 2.41e+02, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.85e+00, step_size = 0.2660, log_lik = -8181.13469, newton_decrement = 1.35e+02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.66e+00, step_size = 0.4496, log_lik = -8087.01253, newton_decrement = 4.36e+01, seconds_since_start = 0.9
# Iteration 10: norm_delta = 4.39e-01, step_size = 0.7598, log_lik = -8045.59297, newton_decrement = 3.01e+00, seconds_since_start = 1.0
# Iteration 11: norm_delta = 5.46e-03, step_size = 1.0000, log_lik = -8042.55573, newton_decrement = 9.77e-04, seconds_since_start = 1.1
# Iteration 12: norm_delta = 9.13e-06, step_size = 1.0000, log_lik = -8042.55475, newton_decrement = 2.25e-09, seconds_since_start = 1.2
# Convergence success after 12 iterations.
# Iteration 1: norm_delta = 6.60e+00, step_size = 0.9500, log_lik = -8886.68689, newton_decrement = 1.01e+03, seconds_since_start = 0.1
# Iteration 2: norm_delta = 5.30e+00, step_size = 0.2375, log_lik = -8464.84341, newton_decrement = 5.58e+02, seconds_since_start = 0.2
# Iteration 3: norm_delta = 4.96e+00, step_size = 0.0772, log_lik = -8381.98231, newton_decrement = 4.78e+02, seconds_since_start = 0.3
# Iteration 4: norm_delta = 4.41e+00, step_size = 0.1304, log_lik = -8265.26957, newton_decrement = 3.67e+02, seconds_since_start = 0.4
# Iteration 5: norm_delta = 3.57e+00, step_size = 0.2205, log_lik = -8121.10880, newton_decrement = 2.30e+02, seconds_since_start = 0.5
# Iteration 6: norm_delta = 2.37e+00, step_size = 0.3726, log_lik = -7981.09111, newton_decrement = 9.66e+01, seconds_since_start = 0.6
# Iteration 7: norm_delta = 9.51e-01, step_size = 0.6296, log_lik = -7897.16416, newton_decrement = 1.53e+01, seconds_since_start = 0.7
# Iteration 8: norm_delta = 2.23e-02, step_size = 1.0000, log_lik = -7881.66124, newton_decrement = 2.18e-02, seconds_since_start = 0.8
# Iteration 9: norm_delta = 1.62e-04, step_size = 1.0000, log_lik = -7881.63934, newton_decrement = 8.39e-07, seconds_since_start = 0.9
# Iteration 10: norm_delta = 1.19e-08, step_size = 1.0000, log_lik = -7881.63934, newton_decrement = 3.80e-15, seconds_since_start = 1.0
# Convergence success after 10 iterations.
# Average C-Index from cross-validation: 0.8900
# Best C-Index from cross-validation: 0.9016
# Standard Deviation of C-Index from cross-validation: 0.0092
#                                              coef  exp(coef)      se(coef)  \
# covariate
# subject_id                          -1.928263e-08   1.000000  1.035112e-08
# gender                               1.555253e-01   1.168271  7.077585e-02
# anchor_age                           3.466509e-01   1.414323  1.483420e-02
# disch_age                           -3.492742e-01   0.705200  1.481862e-02
# CKD_stage_first                     -9.964798e-01   0.369177  4.777979e-02
# ...                                           ...        ...           ...
# Urea_Nitrogen_min                    8.911595e-03   1.008951  4.847917e-03
# Cholesterol,_LDL,_Calculated_median  2.684282e-03   1.002688  1.344234e-03
# Monocytes_min                       -1.076546e-02   0.989292  2.319066e-02
# Neutrophils_max                     -2.686096e-03   0.997318  4.935014e-03
# Protein,_Total_min                  -1.024578e-01   0.902616  9.657610e-02
#
#                                      coef lower 95%  coef upper 95%  \
# covariate
# subject_id                            -3.957046e-08    1.005203e-09
# gender                                 1.680718e-02    2.942434e-01
# anchor_age                             3.175764e-01    3.757254e-01
# disch_age                             -3.783182e-01   -3.202303e-01
# CKD_stage_first                       -1.090126e+00   -9.028331e-01
# ...                                             ...             ...
# Urea_Nitrogen_min                     -5.901487e-04    1.841334e-02
# Cholesterol,_LDL,_Calculated_median    4.963092e-05    5.318932e-03
# Monocytes_min                         -5.621832e-02    3.468740e-02
# Neutrophils_max                       -1.235855e-02    6.986354e-03
# Protein,_Total_min                    -2.917435e-01    8.682786e-02
#
#                                      exp(coef) lower 95%  exp(coef) upper 95%  \
# covariate
# subject_id                                      1.000000             1.000000
# gender                                          1.016949             1.342111
# anchor_age                                      1.373794             1.456047
# disch_age                                       0.685013             0.725982
# CKD_stage_first                                 0.336174             0.405419
# ...                                                  ...                  ...
# Urea_Nitrogen_min                               0.999410             1.018584
# Cholesterol,_LDL,_Calculated_median             1.000050             1.005333
# Monocytes_min                                   0.945333             1.035296
# Neutrophils_max                                 0.987718             1.007011
# Protein,_Total_min                              0.746960             1.090709
#
#                                      cmp to          z              p  \
# covariate
# subject_id                              0.0  -1.862853   6.248289e-02
# gender                                  0.0   2.197435   2.798943e-02
# anchor_age                              0.0  23.368354  8.969450e-121
# disch_age                               0.0 -23.569958  7.837811e-123
# CKD_stage_first                         0.0 -20.855675   1.353753e-96
# ...                                     ...        ...            ...
# Urea_Nitrogen_min                       0.0   1.838232   6.602829e-02
# Cholesterol,_LDL,_Calculated_median     0.0   1.996885   4.583764e-02
# Monocytes_min                           0.0  -0.464215   6.424935e-01
# Neutrophils_max                         0.0  -0.544293   5.862396e-01
# Protein,_Total_min                      0.0  -1.060902   2.887342e-01
#
#                                        -log2(p)
# covariate
# subject_id                             4.000395
# gender                                 5.158974
# anchor_age                           398.788280
# disch_age                            405.626705
# CKD_stage_first                      318.468133
# ...                                         ...
# Urea_Nitrogen_min                      3.920772
# Cholesterol,_LDL,_Calculated_median    4.447323
# Monocytes_min                          0.638246
# Neutrophils_max                        0.770438
# Protein,_Total_min                     1.792186
#
# [81 rows x 11 columns]
#                                   test_statistic         p  -log2(p)
# Albumin/Creatinine,_Urine_first         0.000057  0.993957  0.008744
# Albumin/Creatinine,_Urine_last          0.000258  0.987178  0.018617
# Albumin/Creatinine,_Urine_max           0.031368  0.859422  0.218561
# Albumin/Creatinine,_Urine_mean          0.062562  0.802492  0.317442
# Albumin/Creatinine,_Urine_median        0.169200  0.680824  0.554646
# ...                                          ...       ...       ...
# eGFR_median                             0.005597  0.940363  0.088711
# eGFR_min                                0.024226  0.876312  0.190484
# gender                                  0.022580  0.880556  0.183514
# marital_status_SINGLE                   1.090191  0.296429  1.754242
# subject_id                              0.106639  0.744004  0.426619
#
# [81 rows x 3 columns]
# Brier Score at 1 year(s): 0.0308
# Brier Score at 2 year(s): 0.0550
# Brier Score at 3 year(s): 0.0673
# Brier Score at 4 year(s): 0.0830
# Brier Score at 5 year(s): 0.1033
# AUC at 1 year(s): 0.9634
# AUC at 2 year(s): 0.9499
# AUC at 3 year(s): 0.9453
# AUC at 4 year(s): 0.9300
# AUC at 5 year(s): 0.9234
